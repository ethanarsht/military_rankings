# %%
# -*- coding: utf-8 -*-

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from html_table_parser import parser_functions as parse
from time import sleep
import scipy
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
import random
import matplotlib.pyplot as plt
import math
% matplotlib inline

# %%
import lxml
import requests
import html5lib
pd.options.display.max_rows = 50

# %%
from bokeh.models import HoverTool, CategoricalColorMapper, OpenURL, TapTool, ResetTool
from bokeh.plotting import ColumnDataSource, figure, output_file, show, save, output_notebook
from bokeh.io import curdoc

# %%
table_pages = ['https://en.wikipedia.org/wiki/List_of_battles_before_301',
               'https://en.wikipedia.org/wiki/List_of_battles_301%E2%80%931300',
               'https://en.wikipedia.org/wiki/List_of_battles_1301%E2%80%931600',
               'https://en.wikipedia.org/wiki/List_of_battles_since_2001']

# %%
list_pages = ['https://en.wikipedia.org/wiki/List_of_battles_1601%E2%80%931800',
               'https://en.wikipedia.org/wiki/List_of_battles_1801%E2%80%931900',
               'https://en.wikipedia.org/wiki/List_of_battles_1901%E2%80%932000',]

# %%
def list_battles(url):
    req = requests.get(url)
    print req.status_code
    era = req.content
    era_soup = BeautifulSoup(era)
    bullets = era_soup.find_all('li')
    
    for bullet in bullets:
        print bullet
        if 'title' in str(bullet):
#             if 'expedition' or 'recapture' or 'capture' or 'war' or 'action' or 'battle' or 'siege' or 'operation' or 'fall' in str(bullet).lower():
#                 if 'List+of+battles' not in str(bullet):
                    if 'footer' not in str(bullet):
                        link = bullet.a['href']
                        link_list.append(link)

                        title = bullet.a['title']
                        title_list.append(title)
                    else:
                        print 'NEXT ENTRY: ' + str(bullet)
#                 else:
#                     print 'NEXT ENTRY: ' + str(bullet)
#             else:
#                 print 'NEXT ENTRY: ' + str(bullet)
        else: 
            print 'NEXT ENTRY' + str(bullet)
# Out:
#   File "<ipython-input-7-17f2e63ac4c1>", line 3
#     print req.status_code
#             ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(int req.status_code)?

# %%
title_list = []
link_list = []
for url in list_pages:
    list_battles(url)

# %%
link_list

# %%
df_late_battles = pd.concat([pd.Series(link_list), pd.Series(title_list)], axis = 1).drop_duplicates()

# %%
df_late_battles = df_late_battles.rename(columns = {0:'url', 1:'Battle'})

# %%
df_late_battles

# %%
df_late_battles[~df_late_battles['Battle'].str.contains('Battle' or 'Operation')]

# %%
df_late_battles.to_csv('battle_list_1600-', encoding = 'utf-8')

# %%
df_late_battles = pd.read_csv('battle_list_1600-.csv', encoding = 'utf-8')

# %%
df_late_battles.head()

# %%
df_late_battles = df_late_battles.drop(['Column1', 'Column4'], axis = 1)
df_late_battles.columns = df_late_battles.iloc[0]
df_late_battles = df_late_battles.drop(0)

# %%
battle_list = []
link_list = []

# %%
def early_battles(link):
    req = requests.get(link)
    print req.status_code
    era = req.content
    era_soup = BeautifulSoup(era)
    tables = era_soup.find_all('table', {'class': 'wikitable'})

    for table in tables:
        cells = table.find_all('td')
        for cell in cells:
            if cell.a is not None:
                a = ['Fall', 'Battle', 'Siege', 'Capture', 'Operation', 'Action', 'Recapture']
                if any(x in str(cell.a['href']) for x in a):
                    battle_list.append(cell.a['title'])
                    link_list.append(cell.a['href'])

# %%
for page in table_pages:
    print page
    early_battles(page)

# %%
df_battles = pd.DataFrame({'battle': battle_list,
                          'link':link_list})

# %%
df_battles = df_battles.rename(columns = {'link':'url', 'battle':'Battle'})

# %%
len(df_battles)

# %%
len(df_late_battles)

# %%
df_battles.head()

# %%
df_url = pd.concat([df_late_battles, df_battles]).reset_index(drop = True)

# %%
len(df_url)

# %%
len(df_url.drop_duplicates())

# %%
s_req = requests.get('https://en.wikipedia.org/Alexander_the_Great')

soup = BeautifulSoup(s_req.text)

ul = soup.find('ul', {'class':'redirectText'})

# %%
if ul is not None:
    print 'works'

# %%
df_battle_all = pd.DataFrame()
df_battle = pd.DataFrame()
def table_scrape(url, name):
#     sleep(1)
    print name
    link = 'https://en.wikipedia.org' + url
    b_req = requests.get(link)

    soup = BeautifulSoup(b_req.text)
    
    bell = soup.find('table', {'class':'infobox vevent'})
    
    if bell is not None:

        details = pd.DataFrame(parse.make2d(bell))
    else:
        return b_req
    

    if 'Belligerents' in str(bell):
    
        clean_rows = details.drop_duplicates(0).set_index(0,drop = True).loc[['Date', 'Location', 'Result'],:]

        clean_col = clean_rows.transpose().reset_index(drop = True)

        df_x_bells = pd.DataFrame()

        html_table = bell.find_all('tr')
        bell_list = []
        bell_y_list = []

        for index, cell in zip(range(0, len(html_table)), html_table):
            if 'Commanders and leaders' in str(cell):
                leaders = html_table[index + 1]
                cells = leaders.find_all('td')
                count = 0
                for cell in cells:
                    count += 1
                    anchors = cell.find_all('a')
                    for anchor in anchors:
                        if 'title' in str(anchor):
                            if 'class="image"' in str(anchor):
                                cl = 'image'
                            elif 'class="thumbborder"' in str(anchor):
                                cl = 'thumb'
                            elif 'cite_note' in str(anchor):
                                cl = 'cite'
                            elif 'disambiguation needed' in str(anchor):
                                cl = 'disam'
                            elif 'cnote_g' in str(anchor):
                                cl = 'cnote'
                            else:
                                title = anchor['title']
                                if any(title == x for x in ['Napoleon I','Alexander III of Macedon']):
                                    print 'napoleon or alex redirect'

                                ref = anchor['href']
                                link = 'https://en.wikipedia.org' + ref

                                if len(ref) <= 10:
                                    t_req = requests.get(link)
                                elif any(ref[8] + ref[9] + ref[10] == x for x in ['pt.', 'tr.', 'ko.', 'ja.', 'th.','da.', 'es.', 'de.', 'it.', 'fr.', 'zh.']):
                                    print 'Not English!'
                                    link = ref
                                    t_req = requests.get(link)
                                elif soup.find('ul', {'class':'redirectText'}) is not None:
                                    print 'REDIRECT'
                                    print title
                                    ul = soup.find('ul', {'class':'redirectText'})
                                    a = ul.a
                                    redirect = a['href']
                                    link = 'https://en.wikipedia.org' + redirect
                                    t_req = requests.get(link)
                                else:
                                    t_req = requests.get(link)

                                t_soup = BeautifulSoup(t_req.text)

                                c_name = t_soup.find('title')
                                c_name = str(c_name)

                                if c_name:
                                    c_name = c_name.replace(' - Wikipedia', '').replace('<title>', '').replace('</title>', '')
                                else:
                                    if count == 1:
                                        bell_list.append(title)
                                    elif count == 2:
                                        bell_y_list.append(title)
                                if 'ex.php?title=' in ref:
                                    ref = ref.replace('ex.php?title=', '')
                                    ref = ref.replace('&action=edit&redlink=1', '')

                                omit_list = ['Capital punishment', 
                                             'Military advisor', 
                                             'Wounded in action', 
                                             'Prisoner of war', 
                                             'Killed in action', 
                                             'Surrender (military)', 
                                             'Surrendered',
                                             'Common military ranks in English']

                                if all(c_name != x for x in omit_list):


                                    if count == 1:

                                        bell_list.append(c_name)
                                    elif count == 2:
                                        bell_y_list.append(c_name)



        for bell in bell_list:
            clean_col['belligerent'] = bell
            df_x_bells = pd.concat([df_x_bells, clean_col])
            df_x_bells = df_x_bells.reset_index(drop = True)


        df_y_bells = pd.DataFrame()
        for bell in bell_y_list:
            clean_col['belligerent'] = bell
            df_y_bells = pd.concat([df_y_bells, clean_col])
            df_y_bells = df_y_bells.reset_index(drop = True)

        df_y_bells = df_y_bells.rename(columns = {0:'Location'})

        if 'Strength' in str(details[0]):
            strength_finder = details[details[0] == 'Strength']


            strength_row = strength_finder.index + 1

            strength = details.loc[strength_row]

            strength_x = strength.iloc[0,0]

            strength_y = strength.iloc[0,1]
        else:
            strength_x = 'unknown'
            strength_y = 'unknown'

        df_x_bells['own'] = strength_x

        df_x_bells['opp'] = strength_y

        df_y_bells['own'] = strength_y

        df_y_bells['opp'] = strength_x

        if 'Casualties and losses' not in str(details[0]):
            df_x_bells['taken'] = np.NaN
            df_x_bells['inflicted'] = np.NaN
            df_y_bells['taken'] = np.NaN
            df_y_bells['inflicted'] = np.NaN

        else:

            casualties_finder = details[details[0] == 'Casualties and losses']

            casualties_row = casualties_finder.index + 1

            casualties = details.loc[casualties_row]

            casualties_x = casualties.iloc[0,0]

            casualties_y = casualties.iloc[0,1]

            df_x_bells['taken'] = casualties_x

            df_x_bells['inflicted'] = casualties_y

            df_y_bells['taken'] = casualties_y

            df_y_bells['inflicted'] = casualties_x



        df_x_bells['Battle'] = name

        df_y_bells['Battle'] = name

        df_x_bells['pos'] = 'L'

        df_y_bells['pos'] = 'R'

        df_battle = pd.concat([df_x_bells, df_y_bells]).reset_index(drop = True)

        df_battle_all = pd.concat([df_battle_all, df_battle]).reset_index(drop = True).drop_duplicates()

        global df_battle_all
    else:
        print 'Filtered: ' + name

# %%
count = 0
for num, rows in {1:df_url[:200],
             2:df_url[200:400], 
             3:df_url[400:600], 
             4:df_url[600:800],
             5:df_url[800:1000],
             6:df_url[1000:1200],
             7:df_url[1200:1400],
             8:df_url[1400:1600],
             9:df_url[1600:1800],
             10:df_url[1800:2000],
             11:df_url[2000:2200],
             12:df_url[2200:2400],
             13:df_url[2400:2600],
             14:df_url[2600:2800],
             15:df_url[2800:3000],
             16:df_url[3000:3200],
             17:df_url[3200:3400],
             18:df_url[3400:]}.iteritems():
    df_battle = pd.DataFrame()
    df_batch = rows
    for index, row in df_batch.iterrows():
        count += 1
        global count
        print str(count) + '/' + str(len(df_url))
        table_scrape(row['url'], row['Battle'])
    df_battle_all.to_csv('rows_{}.csv'.format(num), encoding = 'utf-8')
    print 'NEW FRAME' + str(num)

# %%
row_list = ['rows_1.csv',
 'rows_2.csv',
 'rows_3.csv',
 'rows_4.csv',
 'rows_5.csv',
 'rows_6.csv',
 'rows_7.csv',
 'rows_8.csv',
 'rows_9.csv',
 'rows_10.csv',
 'rows_11.csv',
 'rows_12.csv',
 'rows_13.csv',
 'rows_14.csv',
 'rows_15.csv',
 'rows_16.csv',
 'rows_17.csv',
 'rows_18.csv']

# %%
df_comm = pd.DataFrame()
for sheet in row_list:
    df_rows = pd.read_csv(sheet)
    df_comm = pd.concat([df_comm, df_rows]).reset_index(drop = True)

# %%
df_comm = df_comm.drop('Unnamed: 0', axis = 1)

# %%
len(df_comm)

# %%
len(df_comm)

# %%
df_comm.to_csv('battles_dirty.csv', encoding = 'utf-8')

# %%
df_comm = pd.read_csv('battles_dirty.csv').drop('Unnamed: 0', axis = 1)

# %%
df_comm = df_comm.drop_duplicates()

# %%
df_comm.head()

# %%
len(df_comm)

# %%
df_comm[df_comm.belligerent.str.contains('Nasser')]

# %%
len(df_comm.drop_duplicates())

# %%
df_comm = df_comm.drop_duplicates().reset_index(drop = True)

# %%
df_comm.to_csv('battles_deduped.csv')

# %%
len(df_comm[df_comm.belligerent.str.contains('Napoleon')])

# %%
df_comm[df_comm.belligerent.str.contains('Scipio')]

# %%
df_results = pd.read_csv('result_column.csv')

# %%
df_results[df_results.Battle == 'Battle_of_Camarón']

# %%
df_comm.head()

# %%
df_results.head()

# %%
df_more_results = pd.merge(df_comm, df_results, how = 'outer', on = ['Battle', 'belligerent', 'pos', 'Result'])

# %%
df_more_results = df_more_results[df_more_results.VorD.isnull()]

# %%
df_more_results = df_more_results.drop_duplicates(subset = ['Battle', 'Date', 'VorD'])

# %%
df_more_results.head()

# %%
df_more_results.to_csv('adding_results_10.21.csv', encoding = 'utf-8')

# %%
df_comm[df_comm.Battle == 'Battle_of_Camarón']

# %%
df_comm[df_comm.belligerent == 'Ambroise de Loré']

# %%
df_vl = pd.merge(df_comm, df_results, how = 'outer', on = ['Battle', 'belligerent', 'Result', 'pos'])

# %%
df_vl

# %%
df_vl = df_vl.sort('VorD')

# %%
df_vl[df_vl.belligerent == 'Ambroise de Loré']

# %%
df_vl[df_vl.belligerent == 'Saracens']

# %%
df_vl.to_csv('additional_results.csv')

# %%
df_10_21_fill = df_vl[df_vl.VorD.isnull()]

# %%
df_ar = pd.read_csv('additional_results.csv', encoding = 'utf-8')

# %%
df_strength = df_ar.drop(['Unnamed: 0', 'Location', 'Result', 'inflicted', 'taken', 'opp'], axis = 1)

# %%
df_strength = df_strength.sort('Battle').reset_index(drop = True)

# %%
df_strength_dd = df_strength.drop_duplicates(['own', 'pos'], keep = 'first')

# %%
df_strength_dd.own = df_strength_dd.own.str.replace('\r',' ').str.replace('\n', ' ').replace('\n', ' ')

# %%
df_strength_dd = df_strength_dd.sort('Battle').reset_index(drop = True)

# %%
df_strength_dd

# %%
df_strength_dd.to_csv('strength_entry.csv', encoding = 'utf-8')

# %%
df_strength_new = df_strength.drop_duplicates(['own', 'pos', 'Battle'], keep = 'first')

# %%
df_strength_fill = pd.read_excel('strength_entry.xlsx', encoding = 'utf-8')

# %%
df_battles = pd.read_csv('battles_deduped.csv', encoding = 'utf-8').drop('Unnamed: 0', axis = 1)

# %%
df_battles = df_battles.drop(['taken', 'inflicted'], axis = 1)

# %%
df_strength_fill.Battle = df_strength_fill.Battle.str.replace(u"â€“",u'–')

# %%
df_some_strength = pd.merge(df_battles, df_strength_fill, how = 'outer', on = ['Battle', 'pos']).drop(['own_y', 'belligerent_y', 'Date_y'], axis = 1).rename(columns = {'Date_x':'Date','own_x':'own', 'belligerent_x':'belligerent'})

# %%
df_some_strength[df_some_strength.Battle.str.contains('Battle_of_Jena')]

# %%
df_test = df_some_strength.iloc[:,9:]

# %%
df_str_two = df_some_strength[df_some_strength['Infantry'].isnull() & df_some_strength['Cavalry'].isnull() & df_some_strength['Artillery'].isnull() & df_some_strength['Ships'].isnull() & df_some_strength['Airforce'].isnull() & df_some_strength['Special'].isnull()]

# %%
df_str_two.head()

# %%
df_str_two = df_str_two.drop_duplicates(['Battle', 'Date', 'Location', 'Result', 'pos']).drop('VorD', axis = 1)

# %%
len(df_str_two)

# %%
df_merger = df_strength.drop(['Date', 'belligerent', 'own'], axis = 1)

# %%
df_merger = df_merger.drop_duplicates()

# %%
df_str_two.head()

# %%
df_str_two = pd.merge(df_str_two, df_merger, on = ['Battle', 'pos'], how = 'outer').dropna(subset = ['Date', 'Location', 'Result'])

# %%
df_str_two = df_str_two.dropna(subset = ['VorD'])

# %%
df_str_two.to_csv('strength_entry_two.csv')

# %%
df_str_two

# %%
df_partial = pd.read_excel('PARTIAL_strength_entry_two.xlsx', encoding = 'utf-8')

# %%
df_str_two.head()

# %%
df_str_two = df_str_two.drop(['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special'], axis = 1)

# %%
df_partial = df_partial.drop(['Date', 'Location', 'Result', 'belligerent','own', 'Column1'],axis = 1)

# %%
df_partial.columns

# %%
df_str_two.head()

# %%
df_finish = pd.merge(df_str_two, df_partial, on = ['Battle', 'pos', 'VorD'], how = 'outer')

# %%
drop_list = list(df_finish[df_finish['Date'].isnull()].index)

# %%
df_finish = df_finish.drop(drop_list)

# %%
df_finish.to_csv('last_strength_entry.csv', encoding = 'utf-8')

# %%
df_some_strength

# %%
df_some_strength[df_some_strength.Battle.str.contains('Siege of La Rochelle')]

# %%
df_more_strength = pd.read_excel('last_strength_entry.xlsx')

# %%
df_more_strength.head()

# %%
df_some_strength.head()

# %%
df_more_strength = pd.merge(df_more_strength, df_str_two, on = ['Battle', 'pos'], how = 'outer').drop(['own_y', 'Infantry_y', 'Cavalry_y', 'Artillery_y', 'Ships_y', 'Airforce_y', 'Special_y', 'Date_y', 'Location_y', 'Result_y', 'belligerent_y'], axis = 1).dropna(subset = ['Date_x'])

# %%
df_more_strength.columns = df_more_strength.columns.str.replace('_x', '')

# %%
df_more_strength.head()

# %%
df_some_strength.head()

# %%
df_more_strength

# %%
df_fill_two = pd.merge(df_battles, df_more_strength, on = ['Battle', 'pos'], how = 'outer').drop(['Date_y', 
                                                                                    'Location_y', 
                                                                                    'belligerent_y', 
                                                                                    'Result_y', 'own_y', 
                                                                                    'opp_y'], axis = 1)

# %%
df_fill_two.columns = df_fill_two.columns.str.replace('_x', '')

# %%
df_some_strength = df_some_strength[df_some_strength['Infantry'].notnull() | df_some_strength['Cavalry'].notnull() | df_some_strength['Artillery'].notnull() | df_some_strength['Ships'].notnull() | df_some_strength['Airforce'].notnull() | df_some_strength['Special'].notnull()]

# %%
len(df_some_strength)

# %%
df_fill_two = df_fill_two[df_fill_two['Infantry'].notnull() | df_fill_two['Cavalry'].notnull() | df_fill_two['Artillery'].notnull() | df_fill_two['Ships'].notnull() | df_fill_two['Airforce'].notnull() | df_fill_two['Special'].notnull()]

# %%
df_some_strength

# %%
df_fill_two

# %%
df_all_strength = pd.concat([df_fill_two, df_some_strength]).reset_index(drop = True)

# %%
len(df_battles)

# %%
df_char = df_all_strength[df_all_strength.Date.isnull()]

# %%
df_char.to_excel('special_character_fix.xlsx')

# %%
df_all_strength[df_all_strength.Battle.str.contains('Battle_of_Tenn')]

# %%
df_all_strength.to_excel('all_strength_probably.xlsx')

# %%
df_battles[df_battles.Battle.str.contains('dlingen')]

# %%
df_char.Battle

# %%
df_strength_all = pd.read_excel('all_strength_probably.xlsx')

# %%
df_strength_all = df_strength_all.drop_duplicates()

# %%
df_left = df_strength_all[df_strength_all.pos == 'L']

# %%
df_left = df_left.drop(['Date', 'Location', 'Result', 'belligerent', 'opp', 'own'], axis = 1)

# %%
df_left = df_left.drop_duplicates(subset = ['Battle'])

# %%
df_left = df_left.dropna(subset = ['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special'], how = 'all')

# %%
df_right = df_strength_all[df_strength_all.pos == 'R']

# %%
df_right = df_right.drop_duplicates(subset = ['Battle'])

# %%
df_right = df_right.drop(['Date', 'Location', 'Result', 'belligerent', 'opp', 'own', 'VorD'], axis = 1)

# %%
df_right = df_right.dropna(subset = ['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special'], how = 'all')

# %%
df_model = pd.merge(df_left, df_right, on = 'Battle', how = 'outer').dropna(subset = ['pos_x', 'pos_y']).reset_index(drop = True)

# %%
df_model
# Out:
#                                    Battle pos_x VorD  Infantry_x  Cavalry_x  \
# 0        1898_invasion_of_GuantÃ¡namo_Bay     L    V       923.0        NaN
# 1                   1948_Arab–Israeli_War     L    V    117500.0        NaN
# 2                        1982_Lebanon_War     L    I    113000.0     2397.0
# 3              1998_Battle_of_Kilinochchi     L    D         1.0        NaN
# 4                          Abagana_Ambush     L    D      6000.0        NaN
# 5              Action_at_Bronkhorstspruit     L    D       268.0        NaN
# 6                        Attack_on_Rabaul     L    V         NaN        NaN
# 7                Attack_on_Sydney_Harbour     L    I         NaN        NaN
# 8                     Battle of "The Saw"     L    V     10000.0     2000.0
# 9                     Battle of Ã‡Ä±ldÄ±r     L    V         1.0        NaN
# 10                 Battle of Aanandapuram     L    V       111.0        NaN
# 11                     Battle of Abrittus     L    D         1.0        NaN
# 12                       Battle of Abydos     L    V         NaN        NaN
# 13                     Battle of Acheloos     L    V     60000.0        NaN
# 14                       Battle of Actium     L    V     19000.0        NaN
# 15                   Battle of Ad Decimum     L    V     15000.0        NaN
# 16            Battle of Adrianople (1205)     L    V     40000.0        NaN
# 17             Battle of Adrianople (324)     L    V    130000.0        NaN
# 18             Battle of Adrianople (378)     L    D     22500.0        NaN
# 19                         Battle of Adys     L    V     15000.0      500.0
# 20                  Battle of Aegospotami     L    V         NaN        NaN
# 21                       Battle of Affane     L    D       350.0      180.0
# 22                Battle of Ager Falernus     L    V      2000.0        NaN
# 23               Battle of Ager Sanguinis     L    D         1.0        NaN
# 24                    Battle of Agincourt     L    V      7500.0        NaN
# ...                                   ...   ...  ...         ...        ...
# 2460                       Spanish Armada     L    V         NaN        NaN
# 2461                   St._Clair's_Defeat     L    V      1100.0        NaN
# 2462               St._James's_Day_Battle     L    V         NaN        NaN
# 2463                          Suez_Crisis     L    V    254000.0        NaN
# 2464                   Sutjeska_offensive     L    I    127000.0        NaN
# 2465                    Ten_days_campaign     L    V     94000.0        NaN
# 2466                  Ten_Days_of_Brescia     L    D      2500.0        NaN
# 2467                        Tet_Offensive     L    V   1000000.0        NaN
# 2468          Third_Battle_of_Chattanooga     L    V     72533.0        NaN
# 2469                 Third_Battle_of_Gaza     L    V     23000.0        NaN
# 2470              Third_Battle_of_Kharkov     L    D    346000.0        NaN
# 2471              Third_Battle_of_Krithia     L    D         1.0        NaN
# 2472         Third_Battle_of_Mount_Hermon     L    V      1000.0        NaN
# 2473              Third_Battle_of_Panipat     L    V     58000.0    42000.0
# 2474          Third_Battle_of_Shipka_Pass     L    V      8000.0        NaN
# 2475           Third_Battle_of_the_Isonzo     L    D         1.0        NaN
# 2476           Third_Battle_of_Winchester     L    V     40000.0        NaN
# 2477           Turkish_invasion_of_Cyprus     L    V     60000.0        NaN
# 2478  USS_United_States_vs_HMS_Macedonian     L    V         NaN        NaN
# 2479                           Vimy_Ridge     L    V    170000.0        NaN
# 2480               Warsaw_Ghetto_Uprising     L    V      2090.0        NaN
# 2481                      Warsaw_Uprising     L    D     34500.0        NaN
# 2482               Warsaw_Uprising_(1794)     L    V      5775.0        NaN
# 2483                Wounded_Knee_Massacre     L    V       438.0        NaN
# 2484                       Yom_Kippur_War     L    V    395000.0     4700.0
#
#       Artillery_x  Ships_x  Airforce_x  Special_x pos_y  Infantry_y  \
# 0             NaN      6.0         NaN        NaN     R      5000.0
# 1             NaN      NaN         NaN        NaN     R     58800.0
# 2             NaN      NaN       634.0        NaN     R     37500.0
# 3             NaN      NaN         NaN        NaN     R         1.0
# 4             NaN      NaN         NaN        NaN     R       700.0
# 5             NaN      NaN         NaN        NaN     R       250.0
# 6             NaN     16.0       631.0        NaN     R         NaN
# 7             NaN     19.0         NaN        NaN     R         NaN
# 8             NaN      NaN         NaN        NaN     R     50000.0
# 9             NaN      NaN         NaN        NaN     R     32000.0
# 10            NaN      NaN         NaN        NaN     R         1.0
# 11            NaN      NaN         NaN        NaN     R         1.0
# 12            NaN     92.0         NaN        NaN     R         NaN
# 13            NaN      NaN         NaN        NaN     R     62000.0
# 14            NaN    250.0         NaN        NaN     R     22000.0
# 15            NaN      NaN         NaN        NaN     R     11000.0
# 16            NaN      NaN         NaN        NaN     R     40000.0
# 17            NaN      NaN         NaN        NaN     R    165000.0
# 18            NaN      NaN         NaN        NaN     R     51750.0
# 19            NaN      NaN         NaN        NaN     R      5000.0
# 20            NaN    170.0         NaN        NaN     R         NaN
# 21            NaN      NaN         NaN        NaN     R         1.0
# 22            NaN      NaN         NaN        NaN     R      4000.0
# 23            NaN      NaN         NaN        NaN     R     40000.0
# 24            NaN      NaN         NaN        NaN     R     24000.0
# ...           ...      ...         ...        ...   ...         ...
# 2460          NaN    127.0         NaN        NaN     R         NaN
# 2461          NaN      NaN         NaN        NaN     R      1000.0
# 2462          NaN    106.0         NaN        NaN     R         NaN
# 2463          NaN      NaN         NaN        NaN     R    300000.0
# 2464          NaN      NaN       300.0        NaN     R     22148.0
# 2465          NaN      NaN         NaN        NaN     R     50000.0
# 2466          NaN      NaN         NaN        NaN     R         1.0
# 2467          NaN      NaN         NaN        NaN     R    460000.0
# 2468          NaN      NaN         NaN        NaN     R     48948.0
# 2469          NaN      NaN         NaN        NaN     R      6250.0
# 2470          NaN      NaN         NaN        NaN     R     70000.0
# 2471          NaN      NaN         NaN        NaN     R     18600.0
# 2472          NaN      NaN         NaN        NaN     R       400.0
# 2473        125.0      NaN         NaN        NaN     R     30000.0
# 2474          NaN      NaN         NaN        NaN     R     30000.0
# 2475          NaN      NaN         NaN        NaN     R         1.0
# 2476          NaN      NaN         NaN        NaN     R     11000.0
# 2477          NaN      NaN         NaN        NaN     R     42000.0
# 2478          NaN      1.0         NaN        NaN     R         NaN
# 2479          NaN      NaN         NaN        NaN     R     37500.0
# 2480          NaN      NaN         NaN        NaN     R      1000.0
# 2481          NaN      NaN         NaN        NaN     R     19000.0
# 2482          NaN      NaN         NaN        NaN     R      8000.0
# 2483         22.0      NaN         NaN        NaN     R       120.0
# 2484        945.0      NaN       440.0        NaN     R    990750.0
#
#       Cavalry_y  Artillery_y  Ships_y  Airforce_y  Special_y
# 0           NaN          3.0      2.0         NaN        NaN
# 1           NaN          NaN      NaN         NaN        NaN
# 2         882.0       1125.0      NaN       450.0        NaN
# 3           NaN          NaN      NaN         NaN        NaN
# 4           NaN          NaN      NaN         NaN        NaN
# 5           NaN          NaN      NaN         NaN        NaN
# 6           NaN          NaN     21.0       200.0        NaN
# 7           NaN          NaN      8.0         2.0        NaN
# 8           NaN          NaN      NaN         NaN        NaN
# 9           NaN          NaN      NaN         NaN        NaN
# 10          NaN          NaN      NaN         NaN        NaN
# 11          NaN          NaN      NaN         NaN        NaN
# 12          NaN          NaN     97.0         NaN        NaN
# 13          NaN          NaN      NaN         NaN        NaN
# 14          NaN          NaN    290.0         NaN        NaN
# 15          NaN          NaN      NaN         NaN        NaN
# 16          NaN          NaN      NaN         NaN        NaN
# 17          NaN          NaN      NaN         NaN        NaN
# 18          NaN          NaN      NaN         NaN        NaN
# 19        500.0          NaN      NaN         NaN        5.0
# 20          NaN          NaN    180.0         NaN        NaN
# 21          NaN          NaN      NaN         NaN        NaN
# 22          NaN          NaN      NaN         NaN        NaN
# 23          NaN          NaN      NaN         NaN        NaN
# 24          NaN          NaN      NaN         NaN        NaN
# ...         ...          ...      ...         ...        ...
# 2460        NaN          NaN    130.0         NaN        NaN
# 2461        NaN          NaN      NaN         NaN        NaN
# 2462        NaN          NaN    118.0         NaN        NaN
# 2463        NaN          NaN      NaN         NaN        NaN
# 2464        NaN          NaN      NaN         NaN        NaN
# 2465        NaN          NaN      NaN         NaN        NaN
# 2466        NaN          NaN      NaN         NaN        NaN
# 2467        NaN          NaN      NaN         NaN        NaN
# 2468        NaN          NaN      NaN         NaN        NaN
# 2469        NaN          NaN      NaN         NaN        NaN
# 2470        NaN          NaN      NaN         NaN        NaN
# 2471        NaN          NaN      NaN         NaN        NaN
# 2472        NaN          NaN      NaN         NaN        NaN
# 2473    40000.0          NaN      NaN         NaN        NaN
# 2474        NaN          NaN      NaN         NaN        NaN
# 2475        NaN          NaN      NaN         NaN        NaN
# 2476        NaN          NaN      NaN         NaN        NaN
# 2477        NaN          NaN      NaN         NaN        NaN
# 2478        NaN          NaN      1.0         NaN        NaN
# 2479        NaN          NaN      NaN         NaN        NaN
# 2480        NaN          NaN      NaN         NaN        NaN
# 2481        NaN          NaN      NaN         NaN        NaN
# 2482        NaN          NaN      NaN         NaN        NaN
# 2483        NaN          NaN      NaN         NaN        NaN
# 2484     7500.0       1720.0    104.0       594.0        NaN
#
# [2485 rows x 16 columns]

# %%
df_model.VorD.value_counts()
# Out:
# V    1524
# D     775
# I     173
# L       1
# v       1
# Name: VorD, dtype: int64

# %%
(1524 - 775) / 2
# Out:
# 374.5

# %%
df_v = df_model[df_model.VorD == 'V']

# %%
v_list = list(df_v.index)

# %%
ran_list = random.sample(v_list, 374)

# %%
df_switch = df_model.iloc[ran_list]

# %%
df_switch['Infantry_hold'] = df_switch['Infantry_x']
df_switch['Cavalry_hold'] = df_switch['Cavalry_x']
df_switch['Artillery_hold'] = df_switch['Artillery_x']
df_switch['Ships_hold'] = df_switch['Ships_x']
df_switch['Airforce_hold'] = df_switch['Airforce_x']
df_switch['Special_hold'] = df_switch['Special_x']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_switch['Infantry_x'] = df_switch['Infantry_y']
df_switch['Cavalry_x'] = df_switch['Cavalry_y']
df_switch['Artillery_x'] = df_switch['Artillery_y']
df_switch['Ships_x'] = df_switch['Ships_y']
df_switch['Airforce_x'] = df_switch['Airforce_y']
df_switch['Special_x'] = df_switch['Special_y']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_switch['Infantry_y'] = df_switch['Infantry_hold']
df_switch['Cavalry_y'] = df_switch['Cavalry_hold']
df_switch['Artillery_y'] = df_switch['Artillery_hold']
df_switch['Ships_y'] = df_switch['Ships_hold']
df_switch['Airforce_y'] = df_switch['Airforce_hold']
df_switch['Special_y'] = df_switch['Special_hold']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_switch = df_switch.drop(['Infantry_hold', 'Cavalry_hold', 'Artillery_hold', 'Ships_hold', 'Airforce_hold', 'Special_hold'], axis = 1)

# %%
df_switch.VorD = 'D'

# %%
df_switch.VorD.value_counts()
# Out:
# D    374
# Name: VorD, dtype: int64

# %%
df_model = df_model.drop(ran_list)

# %%
df_model = pd.concat([df_model, df_switch])

# %%
df_model.VorD.value_counts()
# Out:
# V    1150
# D    1149
# I     173
# L       1
# v       1
# Name: VorD, dtype: int64

# %%
df_model.loc[2378, 'Infantry_y'] = 25000

# %%
df_model.loc[2363, 'Infantry_x'] = 500

# %%
df_model = df_model[df_model.Infantry_x != 1.0]
df_model = df_model[df_model.Infantry_y != 1.0]

# %%
df_model = df_model.fillna(0)

# %%
df_model['infantry_diff'] = (df_model['Infantry_x'] - df_model['Infantry_y']) / (df_model['Infantry_x'] + df_model['Infantry_y'])
df_model['cavalry_diff'] = (df_model['Cavalry_x'] - df_model['Cavalry_y']) / (df_model['Cavalry_x'] + df_model['Cavalry_y'])
df_model['artillery_diff'] = (df_model['Artillery_x'] - df_model['Artillery_y']) / (df_model['Artillery_x'] + df_model['Artillery_y'])
df_model['ships_diff'] = (df_model['Ships_x'] - df_model['Ships_y']) / (df_model['Ships_x'] + df_model['Ships_y'])
df_model['airforce_diff'] = (df_model['Airforce_x'] - df_model['Airforce_y']) / (df_model['Airforce_x'] + df_model['Airforce_y'])
df_model['special_diff'] = (df_model['Special_x'] - df_model['Special_y']) / (df_model['Special_x'] + df_model['Special_y'])

# %%
df_diff = pd.concat([df_model['VorD'], df_model['Battle'], df_model['infantry_diff'],df_model['cavalry_diff'],df_model['artillery_diff'], df_model['ships_diff'],
                    df_model['airforce_diff'], df_model['special_diff']], axis = 1)

# %%
df_diff = df_diff[df_diff.VorD != 'I']

# %%
df_model[df_model.Battle == 'Siege of Noda']
# Out:
#              Battle pos_x VorD  Infantry_x  Cavalry_x  Artillery_x  Ships_x  \
# 2363  Siege of Noda     L    V       500.0        0.0          0.0      0.0
#
#       Airforce_x  Special_x pos_y      ...       Artillery_y  Ships_y  \
# 2363         0.0        0.0     R      ...               0.0      0.0
#
#       Airforce_y  Special_y  infantry_diff  cavalry_diff  artillery_diff  \
# 2363         0.0        0.0       0.818182           NaN             NaN
#
#       ships_diff  airforce_diff  special_diff
# 2363         NaN            NaN           NaN
#
# [1 rows x 22 columns]

# %%
df_diff.sort_values('infantry_diff', ascending = False)
# Out:
#      VorD                                  Battle  infantry_diff  \
# 622     V                       Battle of Sudomer       1.000000
# 644     V                     Battle of the Arius       1.000000
# 1933    D              Battle_of_the_Mississinewa       1.000000
# 578     D                         Battle of Salsu       1.000000
# 2045    V                 Battle_of_Warsaw_(1705)       1.000000
# 506     D                       Battle of Obertyn       1.000000
# 1136    D                Battle_of_Elizabeth_City       1.000000
# 476     V                Battle of NÄ›meckÃ½ Brod       1.000000
# 934     D             Battle_of_Brices_Crossroads       1.000000
# 431     V              Battle of Marj Rahit (684)       1.000000
# 677     D                   Battle of the Ticinus       1.000000
# 152     D                    Battle of Callinicum       1.000000
# 2241    V                         Operation_Torch       1.000000
# 544     V                   Battle of Pontvallain       1.000000
# 164     D                       Battle of Carrhae       1.000000
# 1217    D                        Battle_of_Gangut       1.000000
# 327     D                     Battle of Ikh Bayan       1.000000
# 363     V                       Battle of Kerbela       0.987142
# 2285    D            Second_Battle_of_Sabine_Pass       0.985703
# 489     D                     Battle of Neopatras       0.973684
# 2267    D                 Second_Battle_of_Dalton       0.968504
# 552     D                      Battle of Prinitza       0.966292
# 428     D                       Battle of Maritsa       0.965066
# 1469    D                  Battle_of_Lugou_Bridge       0.964912
# 727     D                   Battle of Vitkov Hill       0.960784
# ...   ...                                     ...            ...
# 2206    V                 Naval_Battle_of_Angamos            NaN
# 2209    D           Naval_Battle_of_Vella_Lavella            NaN
# 2264    V              Second_Battle_of_Algeciras            NaN
# 2288    V                  Second_Battle_of_Sirte            NaN
# 2294    D         Second_Battle_of_Tripoli_Harbor            NaN
# 2454    V                  Sinking_of_CSS_Alabama            NaN
# 2455    D  Sinking_of_Prince_of_Wales_and_Repulse            NaN
# 2460    V                          Spanish Armada            NaN
# 2462    V                  St._James's_Day_Battle            NaN
# 2478    V     USS_United_States_vs_HMS_Macedonian            NaN
# 1414    D                  Battle_of_Lagos_(1693)            NaN
# 472     D                         Battle of Mylae            NaN
# 1925    D                   Battle_of_the_Gabbard            NaN
# 1927    D              Battle_of_the_Japanese_Sea            NaN
# 1594    D                      Battle_of_Navarino            NaN
# 1797    D                  Battle_of_Scheveningen            NaN
# 2231    D                     Operation_Hailstone            NaN
# 2208    D             Naval_Battle_of_Guadalcanal            NaN
# 1139    D           Battle_of_Empress_Augusta_Bay            NaN
# 975     D                    Battle_of_Cape_Spada            NaN
# 877     D            Battle_of_Beachy_Head_(1690)            NaN
# 1937    D                      Battle_of_the_Nile            NaN
# 1504    D             Battle_of_Manila_Bay_(1898)            NaN
# 980     D        Battle_of_Cape_St_Vincent_(1797)            NaN
# 221     D                     Battle of Cynossema            NaN
#
#       cavalry_diff  artillery_diff  ships_diff  airforce_diff  special_diff
# 622      -1.000000             NaN         NaN            NaN           1.0
# 644      -1.000000             NaN         NaN            NaN           NaN
# 1933     -1.000000             NaN         NaN            NaN           NaN
# 578      -1.000000             NaN         NaN            NaN           NaN
# 2045     -0.660839             NaN         NaN            NaN           NaN
# 506      -0.582573       -0.612903         NaN            NaN           NaN
# 1136           NaN        1.000000   -0.368421            NaN           NaN
# 476      -1.000000             NaN         NaN            NaN           NaN
# 934      -0.029412        1.000000         NaN            NaN           NaN
# 431      -1.000000             NaN         NaN            NaN           NaN
# 677      -0.318681             NaN         NaN            NaN           NaN
# 152      -0.600000             NaN         NaN            NaN           NaN
# 2241     -1.000000             NaN   -1.000000      -1.000000           NaN
# 544      -1.000000             NaN         NaN            NaN           NaN
# 164      -0.428571             NaN         NaN            NaN           NaN
# 1217           NaN             NaN   -0.831776            NaN           NaN
# 327      -1.000000             NaN         NaN            NaN           NaN
# 363            NaN             NaN         NaN            NaN           NaN
# 2285           NaN       -1.000000    1.000000            NaN           NaN
# 489            NaN             NaN         NaN            NaN           NaN
# 2267           NaN             NaN         NaN            NaN           NaN
# 552            NaN             NaN         NaN            NaN           NaN
# 428            NaN             NaN         NaN            NaN           NaN
# 1469           NaN             NaN         NaN            NaN           NaN
# 727            NaN             NaN         NaN            NaN           NaN
# ...            ...             ...         ...            ...           ...
# 2206           NaN             NaN    0.500000            NaN           NaN
# 2209           NaN             NaN   -0.657143            NaN           NaN
# 2264           NaN             NaN   -0.200000            NaN           NaN
# 2288           NaN             NaN    0.230769            NaN           NaN
# 2294           NaN       -0.090909         NaN            NaN           NaN
# 2454           NaN             NaN    0.000000            NaN           NaN
# 2455           NaN             NaN    1.000000      -1.000000           NaN
# 2460           NaN             NaN   -0.011673            NaN           NaN
# 2462           NaN             NaN   -0.053571            NaN           NaN
# 2478           NaN             NaN    0.000000            NaN           NaN
# 1414           NaN             NaN   -0.724138            NaN           NaN
# 472            NaN             NaN    0.115880            NaN           NaN
# 1925           NaN             NaN   -0.010101            NaN           NaN
# 1927           NaN             NaN   -0.333333            NaN           NaN
# 1594           NaN             NaN    0.536842            NaN           NaN
# 1797           NaN        1.000000   -1.000000            NaN           NaN
# 2231           NaN             NaN   -0.590909      -0.254526           NaN
# 2208           NaN             NaN    0.322034            NaN           NaN
# 1139           NaN             NaN   -0.090909       1.000000           NaN
# 975            NaN             NaN   -0.500000            NaN           NaN
# 877            NaN             NaN   -0.145038            NaN           NaN
# 1937           NaN             NaN    0.062500            NaN           NaN
# 1504           NaN             NaN    0.181818            NaN           NaN
# 980            NaN             NaN    0.241379            NaN           NaN
# 221            NaN             NaN    0.061728            NaN           NaN
#
# [1977 rows x 8 columns]

# %%
df_diff = df_diff.drop(174)

# %%
df_diff = df_diff.fillna(0)

# %%
df_x = pd.DataFrame(df_diff.iloc[:, 2:])

# %%
df_x = df_x.drop('artillery_diff', axis = 1)

# %%
df_y = pd.DataFrame(df_diff.iloc[:, 0])

# %%
df_y.VorD = df_y.VorD.replace('V', 1).replace('D', 0).replace('L', 0).replace('v', 1)

# %%
df_y.VorD = df_y.VorD.astype('float')

# %%
df_x = df_x.iloc[:, :-1]

# %%
lr = LogisticRegression()
lr.fit(df_x, df_y)
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr.score(df_x, df_y)
# Out:
# 0.54605263157894735

# %%
pd.Series(df_x.columns)
# Out:
# 0    infantry_diff
# 1     cavalry_diff
# 2       ships_diff
# 3    airforce_diff
# dtype: object

# %%
lr.coef_[0]
# Out:
# array([ 0.41040138,  0.10005783,  0.57131573,  0.12249231])

# %%
pd.concat([pd.Series(lr.coef_[0]), pd.Series(df_x.columns)], axis = 1)
# Out:
#           0              1
# 0  0.410401  infantry_diff
# 1  0.100058   cavalry_diff
# 2  0.571316     ships_diff
# 3  0.122492  airforce_diff

# %%
df_test = pd.concat([df_y.reset_index(drop = True), pd.Series(lr.predict(df_x))], axis = 1)

# %%
df_test.head()
# Out:
#    VorD    0
# 0   1.0  1.0
# 1   1.0  1.0
# 2   0.0  1.0
# 3   0.0  1.0
# 4   1.0  1.0

# %%
len(df_test)
# Out:
# 1976

# %%
count = 0
for i, row in df_test.iterrows():
    if row['VorD'] == row[0]:
        count = count + 1

# %%
scores = cross_val_score(lr, df_x, df_y.VorD, cv = 10)

# %%
scores.mean()
# Out:
# 0.53957431457431448

# %%
pd.concat([pd.DataFrame(lr.predict_proba(df_x)), df_x.reset_index(drop = True)] ,axis = 1)
# Out:
#              0         1  infantry_diff  cavalry_diff  ships_diff  \
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.518652
# 5          0.000000
# 6          0.000000
# 7          0.000000
# 8          0.000000
# 9          0.000000
# 10         0.000000
# 11         0.000000
# 12         0.000000
# 13         0.000000
# 14         0.000000
# 15         0.000000
# 16         0.000000
# 17         0.000000
# 18         0.000000
# 19         0.000000
# 20         0.000000
# 21         0.000000
# 22         0.000000
# 23         0.000000
# 24         0.000000
# ...             ...
# 1951       0.000000
# 1952       0.000000
# 1953       0.000000
# 1954       0.000000
# 1955       0.000000
# 1956       0.000000
# 1957       0.000000
# 1958       0.000000
# 1959       0.000000
# 1960       0.000000
# 1961       0.000000
# 1962       0.000000
# 1963       0.000000
# 1964       0.000000
# 1965       0.000000
# 1966       0.000000
# 1967       0.000000
# 1968      -0.646143
# 1969       0.000000
# 1970       0.000000
# 1971       0.000000
# 1972       0.000000
# 1973       0.000000
# 1974       0.000000
# 1975       0.000000
#
# [1976 rows x 6 columns]

# %%
lr.coef_
# Out:
# array([[ 0.41040138,  0.10005783,  0.57131573,  0.12249231]])

# %%
df_test = pd.DataFrame({'infantry_diff':.99,
                       'cavalry_diff':.99,
                       'artillery_diff':.99,
                       'ships_diff':.99,
                       'airforce_diff:':.99}, index = [0])

# %%
df_test
# Out:
#    airforce_diff:  artillery_diff  cavalry_diff  infantry_diff  ships_diff
# 0            0.99            0.99          0.99           0.99        0.99

# %%
lr.predict_proba(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-fb05974c7b4f> in <module>()
# ----> 1 lr.predict_proba(df_test)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py in predict_proba(self, X)
#    1334         calculate_ovr = self.coef_.shape[0] == 1 or self.multi_class == "ovr"
#    1335         if calculate_ovr:
# -> 1336             return super(LogisticRegression, self)._predict_proba_lr(X)
#    1337         else:
#    1338             return softmax(self.decision_function(X), copy=False)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in _predict_proba_lr(self, X)
#     336         multiclass is handled by normalizing that over all classes.
#     337         """
# --> 338         prob = self.decision_function(X)
#     339         prob *= -1
#     340         np.exp(prob, prob)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in decision_function(self, X)
#     303         if X.shape[1] != n_features:
#     304             raise ValueError("X has %d features per sample; expecting %d"
# --> 305                              % (X.shape[1], n_features))
#     306
#     307         scores = safe_sparse_dot(X, self.coef_.T,
#
# ValueError: X has 5 features per sample; expecting 4

# %%
df_model.VorD.value_counts()

# %%
1524 + 775
# Out:
# 2299

# %%
2300 /2 - 775
# Out:
# 375.0

# %%
rf = RandomForestClassifier()
rf.fit(df_x, df_y)
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf.score(df_x, df_y)
# Out:
# 0.82287449392712553

# %%
scores = cross_val_score(rf, df_x, df_y.VorD, cv = 5)

# %%
scores
# Out:
# array([ 0.52525253,  0.48484848,  0.55050505,  0.47208122,  0.50761421])

# %%
rf.feature_importances_
# Out:
# array([ 0.76749778,  0.09964859,  0.1080132 ,  0.02484043])

# %%
pd.concat([pd.DataFrame(rf.predict_proba(df_x)), df_x.reset_index(drop = True)], axis = 1)
# Out:
#              0         1  infantry_diff  cavalry_diff  ships_diff  \
# 0     0.100000  0.900000      -0.688334      0.000000    0.500000
# 1     0.189526  0.810474       0.332955      0.000000    0.000000
# 2     0.600000  0.400000       0.791045      0.000000    0.000000
# 3     1.000000  0.000000       0.034749      0.000000    0.000000
# 4     0.100000  0.900000       0.000000      0.000000   -0.135135
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          0.518652
# 5          0.000000
# 6          0.000000
# 7          0.000000
# 8          0.000000
# 9          0.000000
# 10         0.000000
# 11         0.000000
# 12         0.000000
# 13         0.000000
# 14         0.000000
# 15         0.000000
# 16         0.000000
# 17         0.000000
# 18         0.000000
# 19         0.000000
# 20         0.000000
# 21         0.000000
# 22         0.000000
# 23         0.000000
# 24         0.000000
# ...             ...
# 1951       0.000000
# 1952       0.000000
# 1953       0.000000
# 1954       0.000000
# 1955       0.000000
# 1956       0.000000
# 1957       0.000000
# 1958       0.000000
# 1959       0.000000
# 1960       0.000000
# 1961       0.000000
# 1962       0.000000
# 1963       0.000000
# 1964       0.000000
# 1965       0.000000
# 1966       0.000000
# 1967       0.000000
# 1968      -0.646143
# 1969       0.000000
# 1970       0.000000
# 1971       0.000000
# 1972       0.000000
# 1973       0.000000
# 1974       0.000000
# 1975       0.000000
#
# [1976 rows x 6 columns]

# %%
df_strength_all.loc[60, 'VorD'] = 'V'
df_strength_all.loc[61, 'VorD'] = 'V'

# %%
df_strength_all.loc[3479:3485, 'VorD'] = 'V'

# %%
df_strength_all.loc[3485, 'VorD'] = 'D'

# %%
df_strength_all.loc[3802:3803, 'VorD'] = 'V'
df_strength_all.loc[3804:3807, 'VorD'] = 'D'

# %%
df_strength_all.loc[4142:4143, 'VorD'] = 'D'

# %%
df_strength_all.VorD = df_strength_all.VorD.str.replace('L', 'D')

# %%
df_strength_all.VorD = df_strength_all.VorD.str.replace('v', 'V')

# %%
df_strength_all.VorD = df_strength_all.VorD.str.replace('W', 'V')

# %%
null_fill = df_strength_all[df_strength_all.VorD.isnull()]

# %%
null_fill
# Out:
#                         Battle  \
# 4981       Battle_of_Gadebusch
# 4982       Battle_of_Gadebusch
# 5100     Battle_of_Goose_Green
# 5101     Battle_of_Goose_Green
# 6236         Battle_of_Meissen
# 6237         Battle_of_Meissen
# 6307      Battle_of_Mobile_Bay
# 6308      Battle_of_Mobile_Bay
# 6309      Battle_of_Mobile_Bay
# 6310      Battle_of_Mobile_Bay
# 7216     Battle_of_Savo_Island
# 7217     Battle_of_Savo_Island
# 7218     Battle_of_Savo_Island
# 7219     Battle_of_Savo_Island
# 7313     Battle_of_Shimonoseki
# 7314     Battle_of_Shimonoseki
# 7315     Battle_of_Shimonoseki
# 7316     Battle_of_Shimonoseki
# 7317     Battle_of_Shimonoseki
# 7653     Battle_of_the_Bridges
# 8056            Battle_of_Uman
# 8057            Battle_of_Uman
# 8058            Battle_of_Uman
# 8059            Battle_of_Uman
# 8060            Battle_of_Uman
# 8353  Battle_of_Wireless_Ridge
# 8354  Battle_of_Wireless_Ridge
# 8591              Convoy_PQ-17
# 8592              Convoy_PQ-17
# 8593              Convoy_PQ-17
# 8594              Convoy_PQ-17
# 9114  Kamenets-Podolsky_pocket
# 9115  Kamenets-Podolsky_pocket
# 9116  Kamenets-Podolsky_pocket
# 9117  Kamenets-Podolsky_pocket
# 9118  Kamenets-Podolsky_pocket
# 9119  Kamenets-Podolsky_pocket
# 9120  Kamenets-Podolsky_pocket
# 9121  Kamenets-Podolsky_pocket
# 9122  Kamenets-Podolsky_pocket
# 9233            Operatie_Kraai
# 9234            Operatie_Kraai
# 9390        Operation_Meghdoot
# 9391        Operation_Meghdoot
# 9392        Operation_Meghdoot
# 9393        Operation_Meghdoot
# 9508       Sand_Creek_Massacre
# 9942   Siege of Jerusalem (70)
# 9943   Siege of Jerusalem (70)
#
#                                                    Date  \
# 4981  9 December 1712 (O.S.)\r\r\r\n20 December 1712...
# 7218               Victor Crutchley
# 7219                     Royal Navy
# 7313                            Sir
# 7314         Augustus Leopold Kuper
# 7315                Benjamin Jaurès
# 7316         François de Casembroot
# 7317                 David McDougal
# 7653                        Colonel
# 8056                        Marshal
# 8057                Semyon Budyonny
# 8058                Colonel general
# 8059               Mikhail Kirponos
# 8060                  Ivan Tyulenev
# 8353             Lieutenant colonel
# 8354                   Omar Giménez
# 8591    John Tovey, 1st Baron Tovey
# 8592          Louis Keppel Hamilton
# 8593                    Jack Broome
# 8594               Commodore (rank)
# 9114                  Georgy Zhukov
# 9115                Nikolai Vatutin
# 9116            1st Ukrainian Front
# 9117                     Ivan Konev
# 9118                   Steppe Front
# 9119             Erich von Manstein
# 9120               Army Group South
# 9121             Hans-Valentin Hube
# 9122                1st Panzer Army
# 9233                General officer
# 9234                    Simon Spoor
# 9390             Lieutenant general
# 9391           Zahid Ali Akbar Khan
# 9392              Brigadier general
# 9393               Pervez Musharraf
# 9508                   Black Kettle
# 9942                Simon bar Giora
# 9943                Simon bar Giora
#
#                                                     opp  \
# 4981  17,000:[b]\r\r\r\n8,300 Danish foot,\r\r\r\n4,...
# 4982  17,000:[b]\r\r\r\n8,300 Danish foot,\r\r\r\n4,...
# 5100                                             690[6]
# 5101                                             690[6]
# 6236                                             26,000
# 6237                                             26,000
# 6307      3 gunboats\r\r\r\n1 ironclad\r\r\r\n1,500 men
# 6308      3 gunboats\r\r\r\n1 ironclad\r\r\r\n1,500 men
# 6309      3 gunboats\r\r\r\n1 ironclad\r\r\r\n1,500 men
# 6310      3 gunboats\r\r\r\n1 ironclad\r\r\r\n1,500 men
# 7216  5 heavy cruisers,\r\r\r\n2 light cruisers,\r\r...
# 7217  5 heavy cruisers,\r\r\r\n2 light cruisers,\r\r...
# 7218  5 heavy cruisers,\r\r\r\n2 light cruisers,\r\r...
# 7219  5 heavy cruisers,\r\r\r\n2 light cruisers,\r\r...
# 7313  Land:\r\r\r\n1,500\r\r\r\n100 artillery pieces...
# 7314  Land:\r\r\r\n1,500\r\r\r\n100 artillery pieces...
# 7315  Land:\r\r\r\n1,500\r\r\r\n100 artillery pieces...
# 7316  Land:\r\r\r\n1,500\r\r\r\n100 artillery pieces...
# 7317  Land:\r\r\r\n1,500\r\r\r\n100 artillery pieces...
# 7653  Elements of 1st Republican Guard Corps\r\r\r\n...
# 8056                           400,000\r\r\r\n600 tanks
# 8057                           400,000\r\r\r\n600 tanks
# 8058                           400,000\r\r\r\n600 tanks
# 8059                           400,000\r\r\r\n600 tanks
# 8060                           400,000\r\r\r\n600 tanks
# 8353                                                600
# 8354                                                600
# 8591  1 battleship (in port),\r\r\r\nU-boats,\r\r\r\...
# 8592  1 battleship (in port),\r\r\r\nU-boats,\r\r\r\...
# 8593  1 battleship (in port),\r\r\r\nU-boats,\r\r\r\...
# 8594  1 battleship (in port),\r\r\r\nU-boats,\r\r\r\...
# 9114                                        200,000 men
# 9115                                        200,000 men
# 9116                                        200,000 men
# 9117                                        200,000 men
# 9118                                        200,000 men
# 9119                                        500,000 men
# 9120                                        500,000 men
# 9121                                        500,000 men
# 9122                                        500,000 men
# 9233                              3 Mitsubishi Zeros[2]
# 9234                              3 Mitsubishi Zeros[2]
# 9390                                         3,000+ [5]
# 9391                                         3,000+ [5]
# 9392                                         3,000+ [5]
# 9393                                         3,000+ [5]
# 9508                                             700[1]
# 9942                                             70,000
# 9943                                             70,000
#
#                                                     own pos VorD  Infantry  \
# 4981  12,500:[a]\r\r\r\n6,500 foot,\r\r\r\n6,000 hor...   L  NaN    6500.0
# 4982  12,500:[a]\r\r\r\n6,500 foot,\r\r\r\n6,000 hor...   L  NaN    6500.0
# 5100  684[4]–871 army\r\r\r\n202 airforce\r\r\r\n10 ...   L  NaN     990.0
# 5101  684[4]–871 army\r\r\r\n202 airforce\r\r\r\n10 ...   L  NaN     990.0
# 6236                                             21,000   L  NaN   21000.0
# 6237                                             21,000   L  NaN   21000.0
# 6307  12 wooden ships\r\r\r\n2 gunboats\r\r\r\n4 iro...   L  NaN    5500.0
# 6308  12 wooden ships\r\r\r\n2 gunboats\r\r\r\n4 iro...   L  NaN    5500.0
# 6309  12 wooden ships\r\r\r\n2 gunboats\r\r\r\n4 iro...   L  NaN    5500.0
# 6310  12 wooden ships\r\r\r\n2 gunboats\r\r\r\n4 iro...   L  NaN    5500.0
# 7216  6 heavy cruisers,\r\r\r\n2 light cruisers,\r\r...   L  NaN      23.0
# 7217  6 heavy cruisers,\r\r\r\n2 light cruisers,\r\r...   L  NaN      23.0
# 7218  6 heavy cruisers,\r\r\r\n2 light cruisers,\r\r...   L  NaN      23.0
# 7219  6 heavy cruisers,\r\r\r\n2 light cruisers,\r\r...   L  NaN      23.0
# 7313  Land:\r\r\r\n2,000\r\r\r\nSea:\r\r\r\n28 warships   L  NaN    2000.0
# 7314  Land:\r\r\r\n2,000\r\r\r\nSea:\r\r\r\n28 warships   L  NaN    2000.0
# 7315  Land:\r\r\r\n2,000\r\r\r\nSea:\r\r\r\n28 warships   L  NaN    2000.0
# 7316  Land:\r\r\r\n2,000\r\r\r\nSea:\r\r\r\n28 warships   L  NaN    2000.0
# 7317  Land:\r\r\r\n2,000\r\r\r\nSea:\r\r\r\n28 warships   L  NaN    2000.0
# 7653  Elements of 35th Brigade\r\r\r\n7th Tank Bn, 3...   R  NaN       1.0
# 8056              300,000\r\r\r\n317 tanks and 858 guns   R  NaN  300000.0
# 8057              300,000\r\r\r\n317 tanks and 858 guns   R  NaN  300000.0
# 8058              300,000\r\r\r\n317 tanks and 858 guns   R  NaN  300000.0
# 8059              300,000\r\r\r\n317 tanks and 858 guns   R  NaN  300000.0
# 8060              300,000\r\r\r\n317 tanks and 858 guns   R  NaN  300000.0
# 8353                                                500   L  NaN     500.0
# 8354                                                500   L  NaN     500.0
# 8591  6 destroyers,\r\r\r\n2 anti-aircraft ships,\r\...   L  NaN       NaN
# 8592  6 destroyers,\r\r\r\n2 anti-aircraft ships,\r\...   L  NaN       NaN
# 8593  6 destroyers,\r\r\r\n2 anti-aircraft ships,\r\...   L  NaN       NaN
# 8594  6 destroyers,\r\r\r\n2 anti-aircraft ships,\r\...   L  NaN       NaN
# 9114                                        500,000 men   R  NaN  500000.0
# 9115                                        500,000 men   R  NaN  500000.0
# 9116                                        500,000 men   R  NaN  500000.0
# 9117                                        500,000 men   R  NaN  500000.0
# 9118                                        500,000 men   R  NaN  500000.0
# 9119                                        200,000 men   L  NaN  200000.0
# 9120                                        200,000 men   L  NaN  200000.0
# 9121                                        200,000 men   L  NaN  200000.0
# 9122                                        200,000 men   L  NaN  200000.0
# 9233  800–900 airborne infantry[5]\r\r\r\n23 Douglas...   R  NaN     850.0
# 9234  800–900 airborne infantry[5]\r\r\r\n23 Douglas...   R  NaN     850.0
# 9390                                           3,000[5]   R  NaN    3000.0
# 9391                                           3,000[5]   R  NaN    3000.0
# 9392                                           3,000[5]   R  NaN    3000.0
# 9393                                           3,000[5]   R  NaN    3000.0
# 9508                                             70–200   R  NaN     135.0
# 9942                                      20,000–30,000   R  NaN   25000.0
# 9943                                      20,000–30,000   R  NaN   25000.0
#
#       Cavalry  Artillery  Ships  Airforce  Special
# 4981   6000.0       25.0    NaN       NaN      NaN
# 4982   6000.0       25.0    NaN       NaN      NaN
# 5100      NaN        NaN    NaN       NaN      NaN
# 5101      NaN        NaN    NaN       NaN      NaN
# 6236      NaN        NaN    NaN       NaN      NaN
# 6237      NaN        NaN    NaN       NaN      NaN
# 6307      NaN        NaN   18.0       NaN      NaN
# 6308      NaN        NaN   18.0       NaN      NaN
# 6309      NaN        NaN   18.0       NaN      NaN
# 6310      NaN        NaN   18.0       NaN      NaN
# 7216      NaN        NaN    NaN       NaN      NaN
# 7217      NaN        NaN    NaN       NaN      NaN
# 7218      NaN        NaN    NaN       NaN      NaN
# 7219      NaN        NaN    NaN       NaN      NaN
# 7313      NaN        NaN   28.0       NaN      NaN
# 7314      NaN        NaN   28.0       NaN      NaN
# 7315      NaN        NaN   28.0       NaN      NaN
# 7316      NaN        NaN   28.0       NaN      NaN
# 7317      NaN        NaN   28.0       NaN      NaN
# 7653      NaN        NaN    NaN       NaN      NaN
# 8056    317.0      858.0    NaN       NaN      NaN
# 8057    317.0      858.0    NaN       NaN      NaN
# 8058    317.0      858.0    NaN       NaN      NaN
# 8059    317.0      858.0    NaN       NaN      NaN
# 8060    317.0      858.0    NaN       NaN      NaN
# 8353      NaN        NaN    NaN       NaN      NaN
# 8354      NaN        NaN    NaN       NaN      NaN
# 8591      NaN        NaN   62.0       NaN      NaN
# 8592      NaN        NaN   62.0       NaN      NaN
# 8593      NaN        NaN   62.0       NaN      NaN
# 8594      NaN        NaN   62.0       NaN      NaN
# 9114      NaN        NaN    NaN       NaN      NaN
# 9115      NaN        NaN    NaN       NaN      NaN
# 9116      NaN        NaN    NaN       NaN      NaN
# 9117      NaN        NaN    NaN       NaN      NaN
# 9118      NaN        NaN    NaN       NaN      NaN
# 9119      NaN        NaN    NaN       NaN      NaN
# 9120      NaN        NaN    NaN       NaN      NaN
# 9121      NaN        NaN    NaN       NaN      NaN
# 9122      NaN        NaN    NaN       NaN      NaN
# 9233      NaN        NaN    NaN       NaN      NaN
# 9234      NaN        NaN    NaN       NaN      NaN
# 9390      NaN        NaN    NaN       NaN      NaN
# 9391      NaN        NaN    NaN       NaN      NaN
# 9392      NaN        NaN    NaN       NaN      NaN
# 9393      NaN        NaN    NaN       NaN      NaN
# 9508      NaN        NaN    NaN       NaN      NaN
# 9942      NaN        NaN    NaN       NaN      NaN
# 9943      NaN        NaN    NaN       NaN      NaN

# %%
null_fill['VorD'] = ['V', 'D', 'D', 'V', 'V', 'D', 'V', 'V', 'V', 'V', 'D', 'D', 'D', 'D', 'V', 'V', 'V', 'V', 'V',
                    'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D','D', 'D', 'D', 'D', 'V', 'V', 'V', 'V', 'V', 'D', 'D', 'D', 'D',
                    'V', 'V', 'D', 'D', 'D', 'D', np.NaN, 'D', np.NaN]
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_strength_all.VorD.loc[null_fill.index] = null_fill['VorD']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_strength_all = df_strength_all[df_strength_all.belligerent != 'Sweden']

# %%
import re

# %%
year_list = []
for i, row in df_strength_all.iterrows():
    d = row['Date']
    if isinstance(d, str):
        if re.search(r'[12]\d{3}', d):
            year = re.search(r'[12]\d{3}', d).group(0)
            year = int(year)
            if 'BC' in d:
                year = year * -1
            year_list.append({'Year':year, 'Index':i})
        elif re.search(r'[12]\d{2}', d):
            year = re.search(r'[12]\d{2}', d).group(0)
            year = int(year)
            if 'BC' in d:
                year = year * -1
            year_list.append({'Year':year, 'Index':i})

# %%
df_years = pd.DataFrame(year_list).set_index('Index', drop = True)

# %%
df_strength_all['year'] = pd.Series()

# %%
df_strength_all['year'].loc[df_years.index] = df_years.Year
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_strength_all.to_csv('current_run.csv', encoding = 'utf-8')

# %%
df_strength_all = pd.read_csv('current_run.csv', encoding = 'utf-8').drop('Unnamed: 0', axis = 1)

# %%
df_run = df_strength_all[df_strength_all.VorD.notnull()]

# %%
df_run.Battle = df_run.Battle.str.replace('_'," ")
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_run
# Out:
#                                  Battle  \
# 0      1898 invasion of GuantÃ¡namo Bay
# 1      1898 invasion of GuantÃ¡namo Bay
# 2      1898 invasion of GuantÃ¡namo Bay
# 3                 1948 Arab–Israeli War
# 4                 1948 Arab–Israeli War
# 5                 1948 Arab–Israeli War
# 6                 1948 Arab–Israeli War
# 7                 1948 Arab–Israeli War
# 8                 1948 Arab–Israeli War
# 9                 1948 Arab–Israeli War
# 10                1948 Arab–Israeli War
# 11                1948 Arab–Israeli War
# 12                1948 Arab–Israeli War
# 13                1948 Arab–Israeli War
# 14                1948 Arab–Israeli War
# 15                1948 Arab–Israeli War
# 16                1948 Arab–Israeli War
# 17                1948 Arab–Israeli War
# 18                1948 Arab–Israeli War
# 19                1948 Arab–Israeli War
# 20                1948 Arab–Israeli War
# 21                1948 Arab–Israeli War
# 22                1948 Arab–Israeli War
# 23                1948 Arab–Israeli War
# 24                1948 Arab–Israeli War
# ...                                 ...
# 10490                   Warsaw Uprising
# 10491            Warsaw Uprising (1794)
# 10492            Warsaw Uprising (1794)
# 10493            Warsaw Uprising (1794)
# 10494             Wounded Knee Massacre
# 16                   Farouk of Egypt
# 17              Abdullah I of Jordan
# 18               Muzahim al-Pachachi
# 19                    Husni al-Za'im
# 20                  Amin al-Husseini
# 21                Ahmed Ali al-Mwawi
# 22                   Mohammed Naguib
# 23                  John Bagot Glubb
# 24                   Habis al-Majali
# ...                              ...
# 10490                Petro Dyachenko
# 10491                Iosif Igelström
# 10492          Stanisław Mokronowski
# 10493                   Jan Kiliński
# 10494               James W. Forsyth
# 10495                    Spotted Elk
# 10496                    Anwar Sadat
# 10497                 Hafez al-Assad
# 10498               Ahmad Ismail Ali
# 10499                  Mustafa Tlass
# 10500                 Saad el-Shazly
# 10501                 Yusuf Shakkour
# 10502  Mohamed Abdel Ghani el-Gamasy
# 10503                      Ali Aslan
# 10504                    Omar Abrash
# 10505                     Golda Meir
# 10506                    Moshe Dayan
# 10507                   David Elazar
# 10508                     Israel Tal
# 10509                   Shmuel Gonen
# 10510                   Yitzhak Hofi
# 10511                    Benny Peled
# 10512                   Haim Bar-Lev
# 10513                 Albert Mandler
# 10514                   Ariel Sharon
#
#                                                      opp  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Egypt: 10,000 initially, rising to 20,000[cita...
# 4      Egypt: 10,000 initially, rising to 20,000[cita...
# 5      Egypt: 10,000 initially, rising to 20,000[cita...
# 6      Egypt: 10,000 initially, rising to 20,000[cita...
# 7      Egypt: 10,000 initially, rising to 20,000[cita...
# 8      Egypt: 10,000 initially, rising to 20,000[cita...
# 9      Egypt: 10,000 initially, rising to 20,000[cita...
# 10     Egypt: 10,000 initially, rising to 20,000[cita...
# 11     Egypt: 10,000 initially, rising to 20,000[cita...
# 12     Egypt: 10,000 initially, rising to 20,000[cita...
# 13     Egypt: 10,000 initially, rising to 20,000[cita...
# 14     Egypt: 10,000 initially, rising to 20,000[cita...
# 15     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 16     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 17     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 18     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 19     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 20     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 21     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 22     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 23     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 24     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# ...                                                  ...
# 10490           Range 20,000[3] to 49,000[4] (initially)
# 10491     3,000–3,500 soldiers,\r\r\r\n~2,500 militia[1]
# 10492                                  8,000 soldiers[1]
# 10493                                  8,000 soldiers[1]
# 10494                                         120 men[2]
# 10495  500 effectives:\r\r\r\n7th U.S. Cavalry:\r\r\r...
# 10496  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10497  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10498  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10499  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10500  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10501  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10502  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10503  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10504  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10505  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10506  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10507  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10508  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10509  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10510  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10511  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10512  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10513  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10514  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
#
#                                                      own pos VorD  Infantry  \
# 0                                                    NaN   R    D    5000.0
# 1                                                    NaN   R    D    5000.0
# 2                                                    NaN   L    V     923.0
# 3      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 4      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 5      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 6      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 7      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 8      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 9      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 10     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 11     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 12     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 13     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 14     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L    V  117500.0
# 15     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# 16     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# 17     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# 18     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# 19     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# 20     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# 21     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# 22     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# 23     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# 24     Egypt: 10,000 initially, rising to 20,000[cita...   R    D   58800.0
# ...                                                  ...  ..  ...       ...
# 10490           Range 13,000[5] to 25,000[6] (initially)   R    V   19000.0
# 10491                                  8,000 soldiers[1]   R    D    8000.0
# 10492     3,000–3,500 soldiers,\r\r\r\n~2,500 militia[1]   L    V    5775.0
# 10493     3,000–3,500 soldiers,\r\r\r\n~2,500 militia[1]   L    V    5775.0
# 10494  500 effectives:\r\r\r\n7th U.S. Cavalry:\r\r\r...   L    V     438.0
# 10495                                         120 men[2]   R    D     120.0
# 10496  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R    D  990750.0
# 10497  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R    D  990750.0
# 10498  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R    D  990750.0
# 10499  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R    D  990750.0
# 10500  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R    D  990750.0
# 10501  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R    D  990750.0
# 10502  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R    D  990750.0
# 10503  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R    D  990750.0
# 10504  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R    D  990750.0
# 10505  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
# 10506  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
# 10507  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
# 10508  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
# 10509  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
# 10510  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
# 10511  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
# 10512  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
# 10513  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
# 10514  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L    V  395000.0
#
#        Cavalry  Artillery  Ships  Airforce  Special    year
# 0          NaN        3.0    2.0       NaN      NaN     NaN
# 1          NaN        7.0    2.0       NaN      NaN     NaN
# 2          NaN        NaN    6.0       NaN      NaN     NaN
# 3          NaN        NaN    NaN       NaN      NaN  1948.0
# 4          NaN        NaN    NaN       NaN      NaN  1948.0
# 5          NaN        NaN    NaN       NaN      NaN  1948.0
# 6          NaN        NaN    NaN       NaN      NaN  1948.0
# 7          NaN        NaN    NaN       NaN      NaN  1948.0
# 8          NaN        NaN    NaN       NaN      NaN  1948.0
# 9          NaN        NaN    NaN       NaN      NaN  1948.0
# 10         NaN        NaN    NaN       NaN      NaN  1948.0
# 11         NaN        NaN    NaN       NaN      NaN  1948.0
# 12         NaN        NaN    NaN       NaN      NaN  1948.0
# 13         NaN        NaN    NaN       NaN      NaN  1948.0
# 14         NaN        NaN    NaN       NaN      NaN  1948.0
# 15         NaN        NaN    NaN       NaN      NaN  1948.0
# 16         NaN        NaN    NaN       NaN      NaN  1948.0
# 17         NaN        NaN    NaN       NaN      NaN  1948.0
# 18         NaN        NaN    NaN       NaN      NaN  1948.0
# 19         NaN        NaN    NaN       NaN      NaN  1948.0
# 20         NaN        NaN    NaN       NaN      NaN  1948.0
# 21         NaN        NaN    NaN       NaN      NaN  1948.0
# 22         NaN        NaN    NaN       NaN      NaN  1948.0
# 23         NaN        NaN    NaN       NaN      NaN  1948.0
# 24         NaN        NaN    NaN       NaN      NaN  1948.0
# ...        ...        ...    ...       ...      ...     ...
# 10490      NaN        NaN    NaN       NaN      NaN  1944.0
# 10491      NaN        NaN    NaN       NaN      NaN  1794.0
# 10492      NaN        NaN    NaN       NaN      NaN  1794.0
# 10493      NaN        NaN    NaN       NaN      NaN  1794.0
# 10494      NaN       22.0    NaN       NaN      NaN  1890.0
# 10495      NaN        NaN    NaN       NaN      NaN  1890.0
# 10496   7500.0     1720.0  104.0     594.0      NaN  1973.0
# 10497   7500.0     1720.0  104.0     594.0      NaN  1973.0
# 10498   7500.0     1720.0  104.0     594.0      NaN  1973.0
# 10499   7500.0     1720.0  104.0     594.0      NaN  1973.0
# 10500   7500.0     1720.0  104.0     594.0      NaN  1973.0
# 10501   7500.0     1720.0  104.0     594.0      NaN  1973.0
# 10502   7500.0     1720.0  104.0     594.0      NaN  1973.0
# 10503   7500.0     1720.0  104.0     594.0      NaN  1973.0
# 10504   7500.0     1720.0  104.0     594.0      NaN  1973.0
# 10505   4700.0      945.0    NaN     440.0      NaN  1973.0
# 10506   4700.0      945.0    NaN     440.0      NaN  1973.0
# 10507   4700.0      945.0    NaN     440.0      NaN  1973.0
# 10508   4700.0      945.0    NaN     440.0      NaN  1973.0
# 10509   4700.0      945.0    NaN     440.0      NaN  1973.0
# 10510   4700.0      945.0    NaN     440.0      NaN  1973.0
# 10511   4700.0      945.0    NaN     440.0      NaN  1973.0
# 10512   4700.0      945.0    NaN     440.0      NaN  1973.0
# 10513   4700.0      945.0    NaN     440.0      NaN  1973.0
# 10514   4700.0      945.0    NaN     440.0      NaN  1973.0
#
# [10513 rows x 16 columns]

# %%
arras_1 = {'Battle':['Battle of Arras', 'Battle of Arras'], 
           'Date':['21 May 1940', '21 May 1940'],
           'Location':['Arras', 'Arras'], 
           'Result':['German victory', 'German victory'] ,
           'belligerent':['Erwin Rommel', 'Harold Franklyn'],
           'opp':['manual', 'manual'],
           'own':['manual', 'manual'], 
           'pos':['R', 'L'],
           'VorD':['V', 'D'],
           'Infantry':[7500.0, 2000.0],
           'Cavalry':[225.0, 74.0],
           'Artillery':[np.NaN, np.NaN],
           'Ships': [np.NaN, np.NaN],
           'Airforce': [np.NaN, np.NaN],
           'Special': [np.NaN, np.NaN],
           'year':[1940, 1940]}

# %%
df_run = pd.concat([df_run,pd.DataFrame(arras_1, index = [10515,10516])])

# %%
df_run
# Out:
#        Airforce  Artillery                            Battle  Cavalry  \
# 0           NaN        3.0  1898 invasion of GuantÃ¡namo Bay      NaN
# 1           NaN        7.0  1898 invasion of GuantÃ¡namo Bay      NaN
# 2           NaN        NaN  1898 invasion of GuantÃ¡namo Bay      NaN
# 3           NaN        NaN             1948 Arab–Israeli War      NaN
# 4           NaN        NaN             1948 Arab–Israeli War      NaN
# 5           NaN        NaN             1948 Arab–Israeli War      NaN
# 6           NaN        NaN             1948 Arab–Israeli War      NaN
# 7           NaN        NaN             1948 Arab–Israeli War      NaN
# 8           NaN        NaN             1948 Arab–Israeli War      NaN
# 9           NaN        NaN             1948 Arab–Israeli War      NaN
# 10          NaN        NaN             1948 Arab–Israeli War      NaN
# 11          NaN        NaN             1948 Arab–Israeli War      NaN
# 12          NaN        NaN             1948 Arab–Israeli War      NaN
# 13          NaN        NaN             1948 Arab–Israeli War      NaN
# 14          NaN        NaN             1948 Arab–Israeli War      NaN
# 15          NaN        NaN             1948 Arab–Israeli War      NaN
# 16          NaN        NaN             1948 Arab–Israeli War      NaN
# 17          NaN        NaN             1948 Arab–Israeli War      NaN
# 18          NaN        NaN             1948 Arab–Israeli War      NaN
# 19          NaN        NaN             1948 Arab–Israeli War      NaN
# 20          NaN        NaN             1948 Arab–Israeli War      NaN
# 21          NaN        NaN             1948 Arab–Israeli War      NaN
# 22          NaN        NaN             1948 Arab–Israeli War      NaN
# 23          NaN        NaN             1948 Arab–Israeli War      NaN
# 24          NaN        NaN             1948 Arab–Israeli War      NaN
# ...         ...        ...                               ...      ...
# 10492       NaN        NaN            Warsaw Uprising (1794)      NaN
# 10493       NaN        NaN            Warsaw Uprising (1794)      NaN
# 10494       NaN       22.0             Wounded Knee Massacre      NaN
# 10495       NaN        NaN             Wounded Knee Massacre      NaN
# 10496     594.0     1720.0                    Yom Kippur War   7500.0
# 10497     594.0     1720.0                    Yom Kippur War   7500.0
# 10498     594.0     1720.0                    Yom Kippur War   7500.0
# 10499     594.0     1720.0                    Yom Kippur War   7500.0
# 10500     594.0     1720.0                    Yom Kippur War   7500.0
# 10501     594.0     1720.0                    Yom Kippur War   7500.0
# 10502     594.0     1720.0                    Yom Kippur War   7500.0
# 10503     594.0     1720.0                    Yom Kippur War   7500.0
# 10504     594.0     1720.0                    Yom Kippur War   7500.0
# 10505     440.0      945.0                    Yom Kippur War   4700.0
# 10506     440.0      945.0                    Yom Kippur War   4700.0
# 10507     440.0      945.0                    Yom Kippur War   4700.0
# 10508     440.0      945.0                    Yom Kippur War   4700.0
# 10509     440.0      945.0                    Yom Kippur War   4700.0
# 10510     440.0      945.0                    Yom Kippur War   4700.0
# 10511     440.0      945.0                    Yom Kippur War   4700.0
# 10512     440.0      945.0                    Yom Kippur War   4700.0
# 10513     440.0      945.0                    Yom Kippur War   4700.0
# 10514     440.0      945.0                    Yom Kippur War   4700.0
# 10515       NaN        NaN                   Battle of Arras    225.0
# 10516       NaN        NaN                   Battle of Arras     74.0
#
#                                                     Date  Infantry  \
# 0                                                    NaN    5000.0
# 1                                                    NaN    5000.0
# 2                                                    NaN     923.0
# 3      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
#
\
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Egypt: 10,000 initially, rising to 20,000[cita...
# 4      Egypt: 10,000 initially, rising to 20,000[cita...
# 5      Egypt: 10,000 initially, rising to 20,000[cita...
# 6      Egypt: 10,000 initially, rising to 20,000[cita...
# 7      Egypt: 10,000 initially, rising to 20,000[cita...
# 8      Egypt: 10,000 initially, rising to 20,000[cita...
# 9      Egypt: 10,000 initially, rising to 20,000[cita...
# 10     Egypt: 10,000 initially, rising to 20,000[cita...
# 11     Egypt: 10,000 initially, rising to 20,000[cita...
# 12     Egypt: 10,000 initially, rising to 20,000[cita...
# 13     Egypt: 10,000 initially, rising to 20,000[cita...
# 14     Egypt: 10,000 initially, rising to 20,000[cita...
# 15     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 16     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 17     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 18     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 19     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 20     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 21     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 22     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 23     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 24     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# ...                                                  ...
# 10492                                  8,000 soldiers[1]
# 10493                                  8,000 soldiers[1]
# 10494                                         120 men[2]
# 10495  500 effectives:\r\r\r\n7th U.S. Cavalry:\r\r\r...
# 10496  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10497  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10498  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10499  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10500  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10501  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10502  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10503  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10504  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10505  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10506  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10507  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10508  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10509  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10510  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10511  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10512  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10513  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10514  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10515                                             manual
# 10516                                             manual
#
#                                                      own pos    year
# 0                                                    NaN   R     NaN
# 1                                                    NaN   R     NaN
# 2                                                    NaN   L     NaN
# 3      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 4      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 5      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 6      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 7      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 8      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 9      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 10     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 11     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 12     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 13     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 14     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 15     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 16     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 17     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 18     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 19     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 20     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 21     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 22     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 23     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 24     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# ...                                                  ...  ..     ...
# 10492     3,000–3,500 soldiers,\r\r\r\n~2,500 militia[1]   L  1794.0
# 10493     3,000–3,500 soldiers,\r\r\r\n~2,500 militia[1]   L  1794.0
# 10494  500 effectives:\r\r\r\n7th U.S. Cavalry:\r\r\r...   L  1890.0
# 10495                                         120 men[2]   R  1890.0
# 10496  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10497  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10498  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10499  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10500  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10501  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10502  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10503  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10504  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10505  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10506  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10507  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10508  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10509  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10510  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10511  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10512  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10513  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10514  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10515                                             manual   R  1940.0
# 10516                                             manual   L  1940.0
#
# [10515 rows x 16 columns]

# %%
len(arras_1)
# Out:
# 16

# %%
df_lookup = df_strength_all.drop_duplicates(subset = ['Battle', 'pos'])

# %%
df_lookup.Battle = df_lookup.Battle.str.replace('_', ' ')
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_lookup = pd.concat([df_lookup, pd.DataFrame(arras_1, index = [10515,10516])])

# %%
df_lookup[df_lookup['Battle'] == 'Six Day War']
# Out:
#        Airforce  Artillery       Battle  Cavalry                      Date  \
# 10330     957.0        NaN  Six Day War   2504.0  June 5–10, 1967 (6 days)
# 10342     300.0        NaN  Six Day War    800.0  June 5–10, 1967 (6 days)
#
#        Infantry     Location                    Result  Ships  Special VorD  \
# 10330  547000.0  Middle East  Decisive Israeli victory    NaN      NaN    D
# 10342  264000.0  Middle East  Decisive Israeli victory    NaN      NaN    V
#
#               belligerent                                                opp  \
# 10330  Gamal Abdel Nasser  50,000 troops\r\r\r\n214,000 reserves\r\r\r\n3...
# 10342         Levi Eshkol  Egypt: 240,000\r\r\r\nSyria, Jordan, and Iraq:...
#
#                                                      own pos    year
# 10330  Egypt: 240,000\r\r\r\nSyria, Jordan, and Iraq:...   R  1967.0
# 10342  50,000 troops\r\r\r\n214,000 reserves\r\r\r\n3...   L  1967.0

# %%
war_list = []
battle_list = []
def commander_war(general):
#     print general
    war = 0
    global df_battles
    df_dbg = df_run[df_run.belligerent == general]
    df_battles = pd.DataFrame()
    for battle in df_dbg.Battle.unique():
        global row
        row = df_dbg[df_dbg.Battle == battle].reset_index(drop = True)
        
        battle = row.loc[0,'Battle']

        df_str = df_lookup[df_lookup.Battle == battle].reset_index(drop = True)
        
        outcome = pd.DataFrame(row.loc[:,'VorD']).iloc[0,0]
        
        
        if row.loc[0, 'pos'] == 'L':
            opp_row = df_str[df_str.pos == 'R']
        if row.loc[0, 'pos'] == 'R':
            opp_row = df_str[df_str.pos == 'L']
            
       
            
        
        year = row.loc[0, 'year']

        own = row.drop(['Battle', 'Date', 'Location', 'Result', 'belligerent', 'opp', 'own', 'pos', 'VorD', 'year'], axis = 1)

        opp = opp_row.drop(['Battle', 'Date', 'Location', 'Result', 'belligerent', 'opp', 'own', 'pos', 'VorD', 'year'], axis = 1)
        
        opp = opp.rename(columns = {'Infantry':'infantry_opp', 
                                    'Cavalry':'cavalry_opp', 
                                    'Artillery':'artillery_opp', 
                                    'Ships':'ships_opp', 
                                    'Airforce':'airforce_opp',
                                    'Special':'special_opp'})

        opp = opp.reset_index(drop= True)

        pred_row = pd.concat([own, opp], axis = 1)
        
        pred_diff = pd.DataFrame()
        
        pred_diff['infantry_diff'] = (pred_row['Infantry'] - pred_row['infantry_opp']) / (pred_row['Infantry'] + pred_row['infantry_opp'])
        pred_diff['cavalry_dfff'] = (pred_row['Cavalry'] - pred_row['cavalry_opp']) / (pred_row['Cavalry'] + pred_row['cavalry_opp'])
        pred_diff['artillery_diff'] = (pred_row['Artillery'] - pred_row['artillery_opp']) / (pred_row['Artillery'] + pred_row['artillery_opp'])
        pred_diff['ships_diff'] = (pred_row['Ships'] - pred_row['ships_opp']) / (pred_row['Ships'] + pred_row['ships_opp'])
        pred_diff['airforce_diff'] = (pred_row['Airforce'] - pred_row['airforce_opp']) / (pred_row['Airforce'] + pred_row['airforce_opp'])
        pred_diff['special_diff'] = (pred_row['Special'] - pred_row['special_opp']) / (pred_row['Special'] + pred_row['special_opp'])

#         pred_diff = pred_diff.drop(['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special', 'infantry_opp', 'cavalry_opp', 'artillery_opp', 'ships_opp', 'airforce_opp', 'special_opp'], axis = 1)

        pred_diff = pred_diff.fillna(0)

        pred_diff = pred_diff.drop(['artillery_diff', 'special_diff'], axis = 1)

        df_pred = pd.DataFrame(lr.predict_proba(pred_diff))
        
#         if row.loc[0, 'Infantry'] == 1.0:
        

        if len(df_str) == 1:
            if row.loc[0, 'VorD'] == 'V':
                value = 0.5
#                 print 'UNKNOWN'
            elif row.loc[0, 'VorD'] == 'D':
                value = -.5
#                 print 'UNKNOWN'
            elif row.loc[0, 'VorD'] == 'I':
                value = 0
#                 print 'UNKNOWN'
        else:
            if df_str.Infantry.loc[0] == 1.0 or df_str.Infantry.loc[1] == 1.0:
                if row.loc[0, 'VorD'] == 'V':
                    value = 0.5
#                     print 'UNKNOWN'
                elif row.loc[0, 'VorD'] == 'D':
                    value = -.5
#                     print 'UNKNOWN'
                elif row.loc[0, 'VorD'] == 'I':
                    value = 0
#                     print 'UNKNOWN'
            else:
                if row.loc[0, 'VorD'] == 'V':
                    value = df_pred.iloc[0,0]
                elif row.loc[0, 'VorD'] == 'D':
                    value = 0 - df_pred.iloc[0,1]
                elif row.loc[0, 'VorD'] == 'I':
                    value = .5 - df_pred.iloc[0,1]
        
        

#         print u' '.join(battle).encode('utf-8').strip(' ') +': ' + str(value).encode('utf-8')

        
        
        
        war = war + value
        battle_list.append({'General':general,
                            'Battle': battle,
                            'Value': value,
                            'Year': year,
                            'Outcome': outcome})
        df_battles = pd.DataFrame(battle_list)
        
#     print 'Total: ' + str(war)
#     print u' '.join(general).encode('utf-8').strip(' ') + ': ' + str(war)
#     if len(df_dbg) > 4:
#         war_list.append({'General':general,
#                      'WAR':war})
    war_list.append({'General': general,
                    'WAR': war,
                    'Battles': len(df_dbg)})
    print(war)

# %%
war_list = []
count = 0
for general in df_run.belligerent.unique():
    count += 1
    print(str(general) + ': ' + str(count) + '/' + str(len(df_run)))
    commander_war(general)
# Out:
# nan: 1/10515
# 0
# David Ben-Gurion: 2/10515
# 0.963921031428
# Yisrael Galili: 3/10515
# 0.460661036375
# Yaakov Dori: 4/10515
# 0.460661036375
# Yigael Yadin: 5/10515
# 0.460661036375
# Mickey Marcus: 6/10515
# 0.460661036375
# Yigal Allon: 7/10515
# 0.460661036375
# Yitzhak Rabin: 8/10515
# 1.01983269776
# David Shaltiel: 9/10515
# 0.460661036375
# Moshe Dayan: 10/10515
# 2.07208683902
# Shimon Avidan: 11/10515
# 0.460661036375
# Moshe Carmel: 12/10515
# 0.460661036375
# Yitzhak Sadeh: 13/10515
# 0.460661036375
# Abdul Rahman Hassan Azzam: 14/10515
# -0.471129951199
# Farouk of Egypt: 15/10515
# -0.471129951199
# Abdullah I of Jordan: 16/10515
# -0.471129951199
# Muzahim al-Pachachi: 17/10515
# -0.471129951199
# Husni al-Za'im: 18/10515
# -0.471129951199
# Amin al-Husseini: 19/10515
# -0.471129951199
# Ahmed Ali al-Mwawi: 20/10515
# -0.471129951199
# Mohammed Naguib: 21/10515
# -0.471129951199
# John Bagot Glubb: 22/10515
# -0.471129951199
# Habis al-Majali: 23/10515
# -0.471129951199
# Hasan Salama: 24/10515
# -0.471129951199
# Arab Liberation Army: 25/10515
# -0.471129951199
# Fawzi al-Qawuqji: 26/10515
# -0.471129951199
# Menachem Begin: 27/10515
# -0.0729606285373
# Ariel Sharon: 28/10515
# 2.12347174269
# Rafael Eitan: 29/10515
# -0.0729606285373
# David Ivry: 30/10515
# -0.0729606285373
# Ze'ev Almog: 31/10515
# -0.0729606285373
# Bachir Gemayel: 32/10515
# -0.0729606285373
# Fadi Frem: 33/10515
# -0.0729606285373
# Elie Hobeika: 34/10515
# -0.0729606285373
# Fawzi Mahfuz: 35/10515
# -0.0729606285373
# Saad Haddad: 36/10515
# -0.0729606285373
# Yasser Arafat: 37/10515
# 0.0626361818053
# Hafez al-Assad: 38/10515
# -0.496752254139
# Mustafa Tlass: 39/10515
# Anwar Sadat: 6614/10515
# -0.559388435944
# Yusuf Shakkour: 6615/10515
# -0.559388435944
# Mohamed Abdel Ghani el-Gamasy: 6616/10515
# -0.559388435944
# Ali Aslan: 6617/10515
# -0.559388435944
# Golda Meir: 6618/10515
# 0.548994146208
# Yitzhak Hofi: 6619/10515
# 0.548994146208
# Harold Franklyn: 6620/10515
# -0.43362035906

# %%
pred_row
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-b3031b827e6e> in <module>()
# ----> 1 pred_row
#
# NameError: name 'pred_row' is not defined

# %%
row.loc[0, 'Battle']

# %%
df_run[df_run.belligerent == 'Alexane']

# %%
df_totalwar = pd.DataFrame(war_list).sort_values('WAR', ascending = False).reset_index(drop = True)

# %%
df_totalwar[df_totalwar.General == 'Alexander the Great']
# Out:
#    Battles              General       WAR
# 9        9  Alexander the Great  4.348132

# %%
df_totalwar[df_totalwar.General == 'Ariel Sharon']
# Out:
#     Battles       General       WAR
# 58        7  Ariel Sharon  2.123472

# %%
df_totalwar
# Out:
#       Battles                                            General        WAR
# 0          43                                           Napoleon  16.517669
# 1          17                                      Julius Caesar   7.297279
# 2          18           Arthur Wellesley, 1st Duke of Wellington   7.060648
# 3          18                                     Takeda Shingen   6.107016
# 4          14                                Khalid ibn al-Walid   5.596840
# 5          17                                           Hannibal   5.429139
# 6          16                                   Ulysses S. Grant   4.964954
# 7          14                                Frederick the Great   4.600003
# 8          10                                      Georgy Zhukov   4.554002
# 9           9                                Alexander the Great   4.348132
# 10         11                                       Oda Nobunaga   4.194409
# 11         11                              Mustafa Kemal Atatürk   3.547912
# 12         13                                     Ferdinand Foch   3.516567
# 13         12                        Douglas Haig, 1st Earl Haig   3.512844
# 14          7                                           Augustus   3.351751
# 15         14                                P. G. T. Beauregard   3.100091
# 16          8                             Prince Eugene of Savoy   3.069104
# 17          6                                        Iosif Gurko   3.052080
# 18          6                               Edward IV of England   3.034470
# 19          6            John Churchill, 1st Duke of Marlborough   2.954981
# 20          7                                     Sarath Fonseka   2.932276
# 21          6                                      André Masséna   2.931150
# 22          9                                 Richmond K. Turner   2.922769
# 23          8                                           Ibn Saud   2.907331
# 24          6                                 Bernard Montgomery   2.895519
# ...       ...                                                ...        ...
# 6595        5                                 Ahmed Muhtar Pasha  -1.696809
# 6596        6                                     Saddam Hussein  -1.731831
# 6597        7                                     Joseph Wheeler  -1.734807
# 6598       15                                     Sterling Price  -1.802616
# 6599        4                       William I of the Netherlands  -1.936342
# 6600        7                             Velupillai Prabhakaran  -1.942629
# 6601        4                                    Muammar Gaddafi  -1.956468
# 6602        9                         Prince Rupert of the Rhine  -2.020796
# 6603       27                                      Robert E. Lee  -2.106372
# 6604        4                                       Andrea Doria  -2.124507
# 6605        4                      Sigismund, Holy Roman Emperor  -2.161824
# 6606        5  François Sébastien Charles Joseph de Croix, Co...  -2.413264
# 6607        5                                          Inkpaduta  -2.465307
# 6608       11                 Rupprecht, Crown Prince of Bavaria  -2.539071
# 6609        7                        Antonio López de Santa Anna  -2.660394
# 6610        5                                Süleyman Hüsnü Paşa  -2.674283
# 6611        8                                      Braxton Bragg  -2.869302
# 6612        6                        Franz Conrad von Hötzendorf  -2.922497
# 6613        9                                    Fritz von Below  -2.979620
# 6614       13                                  John S. Marmaduke  -3.120335
# 6615       11                                 Jean-de-Dieu Soult  -3.489510
# 6616        7               Prince Charles Alexander of Lorraine  -3.635533
# 6617       10                                     John Bell Hood  -4.110658
# 6618       10                                   Max von Gallwitz  -4.377160
# 6619       16                                 Capital punishment  -4.868257
#
# [6620 rows x 3 columns]

# %%
std = np.std(df_totalwar.WAR)

# %%
tw_mean = df_totalwar.WAR.mean()

# %%
(16.678901 - tw_mean) / std

# %%
(7.428568 - tw_mean) / std

# %%
def graph(commander):
    battle_list = []
    global df_battles
    df_battles = pd.DataFrame()
    commander_war(commander)

    df_battles.Year = df_battles.Year.fillna(-5000)
    df_battles.Year = df_battles.Year.astype(float, errors = 'ignore')
    df_battles = df_battles.sort_values('Year')
    wl = pd.DataFrame(df_battles.Outcome.value_counts())
    
    if 'V' in wl.index:
        wins = wl.loc['V', 'Outcome']
    else:
        wins = 0
    if 'D' in wl.index:
        losses = wl.loc['D', 'Outcome']
    else:
        losses = 0
    if 'I' in wl.index:
        draws = wl.loc['I', 'Outcome']
    else:
        draws = 0
    df_battles = df_battles.reset_index(drop = True)
    for i, row in df_battles.iterrows():
        df_battles.ix[i, 'cumulative'] = sum(df_battles.Value[0:i+1])

    plt.figure(figsize = (12,9))
    plt.style.use('fivethirtyeight')
    plt.bar(df_battles.index, 
            df_battles['Value'], 
            label = 'Battle Value', 
            color = df_battles.Outcome.map({'V':'blue', 'I':'orange', 'D':'red'}), 
            alpha = .5, 
            zorder = 2)
    if max(df_battles.cumulative) < 1 and min(df_battles.cumulative) > 1:
        plt.ylim(-1,1)
    plt.plot(df_battles.index, df_battles['cumulative'], color = 'black', label = 'Cumulative WARG', zorder = 1)
#     plt.scatter(df_battles.index, df_battles['cumulative'], s = 100, zorder = 2)
    plt.xticks(df_battles.index, df_battles['Battle'], rotation = 'vertical')

    plt.title(commander + ' ({} - {} - {})'.format(wins, draws, losses))
    plt.tight_layout()
    
    plt.savefig('{}_warg.png'.format(commander))

# %%
df_run = df_run.dropna(subset = ['belligerent'])

# %%
battle_list = []
graph('Moshe Dayan')

# %%
df_battles

# %%
df_model[df_model.Battle == 'Battle_of_Borodino'].transpose()

# %%
df_model[df_model.Battle == 'Six Day War']

# %%
df_battles

# %%
df_war = pd.DataFrame(war_list).sort_values('WAR', ascending = False).reset_index(drop = True)

# %%
df_war.head()

# %%
df_totalwar = df_totalwar[df_totalwar.General != 'Capital punishment']
df_totalwar = df_totalwar[df_totalwar.General != 'Lieutenant general']

# %%
df_totalwar[df_totalwar.General == 'Erwin Rommel']

# %%
import seaborn as sns

# %%
sns.distplot(df_totalwar['WAR'], kde = False, bins = 30)
plt.title("Distribution of Generals' War")
plt.ylabel('Number of Generals')
plt.annotate('Napoleon', xy = (16.713, 1), xytext = (17.713, 400), arrowprops = dict(facecolor = 'black'))
plt.annotate('Julius Caesar', xy = (7.364545, 1), xytext = (8.364545, 400), arrowprops = dict(facecolor = 'black'))
plt.tight_layout()
plt.savefig('/home/ethanarsht/Downloads/distplot.png')

# %%
def index():
    output_file('docs/index.html')
    source = ColumnDataSource(data = dict(battles = df_totalwar.Battles,
                                          war = df_totalwar.WAR,
                                          general = df_totalwar.General))

    hover = HoverTool(tooltips = [('General', '@general'),
                                  ('Battles', '@battles'),
                                  ('WAR', '@war'),
                                      ])
    p = figure(title = 'WAR vs Number of Battles',
               plot_height = 600, 
               plot_width = 800,

               tools = [hover, "tap", 'box_zoom', ResetTool()])
    p.circle(x = 'war', y = 'battles', size = 10, source = source)
    p.xaxis.axis_label = 'WAR'
    p.yaxis.axis_label = 'Battles'

    link = "{}.html".format('@general')

    if link == 'https://ethanarsht.github.io/military_rankings/Thomas de Courtenay, 5th/13th Earl of Devon':
            link = 'https://ethanarsht.github.io/military_rankings/Thomas de Courtenay'
    url = link
    taptool = p.select(type=TapTool)
    taptool.callback = OpenURL(url=url)
    save(p)

# %%
index()

# %%
df_battles
# Out:
#             Battle          General Outcome     Value    Year  cumulative
# 0  Battle of Arras  Harold Franklyn       D -0.430169  1940.0   -0.430169

# %%
def bokeh(commander):
    global df_battles
    
    df_battles = pd.DataFrame()
    commander_war(commander)
    
#     df_battles = df_battles[df_battles.General == commander]
    df_battles.Year = df_battles.Year.fillna(-5000)
    df_battles.Year = df_battles.Year.astype(float, errors = 'ignore')
    df_battles = df_battles.sort_values('Year')
    wl = pd.DataFrame(df_battles.Outcome.value_counts())
    
    if 'V' in wl.index:
        wins = wl.loc['V', 'Outcome']
    else:
        wins = 0
    if 'D' in wl.index:
        losses = wl.loc['D', 'Outcome']
    else:
        losses = 0
    if 'I' in wl.index:
        draws = wl.loc['I', 'Outcome']
    else:
        draws = 0
    df_battles = df_battles.reset_index(drop = True)
    for i, row in df_battles.iterrows():
        df_battles.ix[i, 'cumulative'] = sum(df_battles.Value[0:i+1])
    
    
    source = ColumnDataSource(data = dict(battle = df_battles.Battle,
                              general = df_battles.General,
                              outcome = df_battles.Outcome,
                              value = df_battles.Value,
                              year = df_battles.Year,
                              cumulative = df_battles.cumulative))
    if all(x != -5000 for x in df_battles.Year):
        hover = HoverTool(tooltips = [('Battle', '@battle'),
                                  ('Outcome', '@outcome'),
                                  ('WAR', '@value'),
                                  ('Cumulative WAR', '@cumulative'),
                                  ('Year', '@year')])
    else:
        hover = HoverTool(tooltips = [('Battle', '@battle'),
                                  ('Outcome', '@outcome'),
                                  ('WAR', '@value'),
                                  ('Cumulative WAR', '@cumulative')
                                  ])
    
    x = list(df_battles.Battle)
    y = list(df_battles.Value)
    y_cum = list(df_battles.cumulative)
    
    if commander == 'Thomas de Courtenay, 5th/13th Earl of Devon':
        commander = 'Thomas de Courtenay'
    
    output_file('docs/{}.html'.format(commander))
#     output_file('{}.html'.format(commander))
    
    p = figure(title = commander + ' ({} - {} - {})'.format(wins, draws, losses), 
               plot_width=800, 
               plot_height=600, 
               x_range = x, 
               tools = [hover, "tap"])
#     p.xaxis.axis_label = "General's Biography: en.wikipedia.org/wiki/{}".format(commander)
    
    p.line(x = 'battle', y = 'cumulative', source = source, line_width = 5)
#     url = 'en.wikipedia.org/wiki/{}'.format(commander)
#     taptool = p.select(type=TapTool)
#     taptool.callback = OpenURL(url=url)
    
    color_mapper = CategoricalColorMapper(factors=['V', 'D', 'I'], palette=['Blue', 'Red', 'Yellow'])
    p.vbar(x = 'battle', 
           top = 'value', 
           source = source, 
           width = 0.9, 
           color={'field': 'outcome', 'transform': color_mapper},
           alpha = 0.5)
    url = 'en.wikipedia.org/wiki/@battle'
    taptool = p.select(type=TapTool)
    taptool.callback = OpenURL(url=url)
    
    p.xaxis.major_label_orientation = math.pi/2
    

#     show(p)
    save(p)

# %%
battle_list = []
bokeh('Napoleon')
# Out:
# 16.678282131
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
df_battles
# Out:
#                             Battle   General Outcome     Value    Year  \
# 0                  Siege of Toulon  Napoleon       V  0.479531  1793.0
# 1             Battle of Montenotte  Napoleon       V  0.478016  1796.0
# 2            Battle of Castiglione  Napoleon       V  0.489183  1796.0
# 3                   Battle of Lodi  Napoleon       V  0.473926  1796.0
# 4                Battle of Bassano  Napoleon       V  0.468786  1796.0
# 5   Battle of the Bridge of Arcole  Napoleon       V  0.507813  1796.0
# 6                 Battle of Rivoli  Napoleon       V  0.518113  1797.0
# 7           Battle of the Pyramids  Napoleon       V  0.518009  1798.0
# 8                Siege of El Arish  Napoleon       V  0.572390  1799.0
# 9             Siege of Acre (1799)  Napoleon       V  0.578863  1799.0
# 10         Battle of Abukir (1799)  Napoleon       V  0.539486  1799.0
# 11               Battle of Marengo  Napoleon       V  0.511538  1800.0
# 12            Battle of Austerlitz  Napoleon       V  0.506088  1805.0
# 13                   Battle of Ulm  Napoleon       V  0.464398  1805.0
# 14        Battle of Jena–Auerstedt  Napoleon       V  0.527709  1806.0
# 15                 Battle of Eylau  Napoleon       V  0.499176  1807.0
# 16             Battle of Friedland  Napoleon       V  0.478626  1807.0
# 17            Battle of Somosierra  Napoleon       V  0.459173  1808.0
# 18                Battle of Wagram  Napoleon       V  0.502020  1809.0
# 19              Battle of Ratisbon  Napoleon       V  0.480614  1809.0
# 20             Battle of Abensberg  Napoleon       V  0.484768  1809.0
# 21       Battle of Landshut (1809)  Napoleon       V  0.461392  1809.0
# 22        Battle of Aspern-Essling  Napoleon       D -0.485299  1809.0
# 23               Battle of Krasnoi  Napoleon       D -0.475902  1812.0
# 24       Battle of Maloyaroslavets  Napoleon       V  0.503377  1812.0
# 25              Battle of Berezina  Napoleon       D -0.487902  1812.0
# 26              Battle of Borodino  Napoleon       V  0.491666  1812.0
# 27       Battle of Smolensk (1812)  Napoleon       V  0.498497  1812.0
# 28               Battle of Bautzen  Napoleon       V  0.474431  1813.0
# 29               Battle of Leipzig  Napoleon       D -0.469467  1813.0
# 30               Battle of Dresden  Napoleon       V  0.521681  1813.0
# 31                 Battle of Hanau  Napoleon       V  0.542800  1813.0
# 32          Battle of Reims (1814)  Napoleon       V  0.472548  1814.0
# 33                  Battle of Laon  Napoleon       V  0.541170  1814.0
# 34            Battle of Montmirail  Napoleon       V  0.505599  1814.0
# 35               Battle of Brienne  Napoleon       V  0.489183  1814.0
# 36             Battle of Montereau  Napoleon       V  0.468786  1814.0
# 37             Battle of Vauchamps  Napoleon       V  0.535848  1814.0
# 38        Battle of Arcis-sur-Aube  Napoleon       V  0.543335  1814.0
# 39               Battle of Craonne  Napoleon       V  0.524098  1814.0
# 40           Battle of Champaubert  Napoleon       V  0.430006  1814.0
# 41                 Battle of Ligny  Napoleon       V  0.514912  1815.0
# 42              Battle of Waterloo  Napoleon       D -0.460702  1815.0
#
#     cumulative
# 0     0.479531
# 1     0.957547
# 2     1.446729
# 3     1.920655
# 4     2.389441
# 5     2.897254
# 6     3.415367
# 7     3.933376
# 8     4.505766
# 9     5.084629
# 10    5.624115
# 11    6.135653
# 12    6.641741
# 13    7.106139
# 14    7.633848
# 15    8.133024
# 16    8.611650
# 17    9.070824
# 18    9.572843
# 19   10.053457
# 20   10.538225
# 21   10.999617
# 22   10.514318
# 23   10.038416
# 24   10.541793
# 25   10.053891
# 26   10.545557
# 27   11.044054
# 28   11.518485
# 29   11.049018
# 30   11.570699
# 31   12.113498
# 32   12.586046
# 33   13.127217
# 34   13.632816
# 35   14.121999
# 36   14.590785
# 37   15.126633
# 38   15.669968
# 39   16.194066
# 40   16.624072
# 41   17.138984
# 42   16.678282

# %%
count = 0
for general in df_run.belligerent.unique()[1:]:
    battle_list = []
    count += 1
    print(str(count) + '/' + str(len(df_run.belligerent.unique())))
    print(general)
    bokeh(general)
# Out:
# 1/6620
# David Ben-Gurion
# 0.971442287354
# 2/6620
# Yisrael Galili
# 0.464436526043
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# 3/6620
# Yaakov Dori
# 0.464436526043
# 4/6620
# Yigael Yadin
# 0.464436526043
# 5/6620
# Mickey Marcus
# 0.464436526043
# 6/6620
# Yigal Allon
# 0.464436526043
# 7/6620
# Yitzhak Rabin
# 1.02673901816
# 8/6620
# David Shaltiel
# 0.464436526043
# 9/6620
# Moshe Dayan
# 2.0862261049
# 10/6620
# Shimon Avidan
# 0.464436526043
# 11/6620
# Moshe Carmel
# 0.464436526043
# 12/6620
# Yitzhak Sadeh
# 0.464436526043
# 13/6620
# Abdul Rahman Hassan Azzam
# -0.467428236013
# 14/6620
# Farouk of Egypt
# -0.467428236013
# 15/6620
# Abdullah I of Jordan
# -0.467428236013
# 16/6620
# Muzahim al-Pachachi
# -0.467428236013
# 17/6620
# Husni al-Za'im
# -0.467428236013
# 18/6620
# Amin al-Husseini
# -0.467428236013
# 19/6620
# Ahmed Ali al-Mwawi
# -0.467428236013
# 20/6620
# Mohammed Naguib
# -0.467428236013
# 21/6620
# John Bagot Glubb
# -0.467428236013
# 22/6620
# Habis al-Majali
# -0.467428236013
# 23/6620
# Hasan Salama
# -0.467428236013
# 24/6620
# Arab Liberation Army
# -0.467428236013
# 25/6620
# Fawzi al-Qawuqji
# -0.467428236013
# 26/6620
# Menachem Begin
# -0.0689526608217
# 27/6620
# Ariel Sharon
# 2.14131954943
# 28/6620
# Rafael Eitan
# -0.465408761718
# 6592/6620
# Paweł Frenkiel
# -0.465408761718
# 6593/6620
# Tadeusz Bór-Komorowski
# -0.531152502966
# 6594/6620
# Tadeusz Pełczyński
# -0.531152502966
# 6595/6620
# Antoni Chruściel
# -0.531152502966
# 6596/6620
# Karol Ziemski
# -0.531152502966
# 6597/6620
# Edward Pfeiffer
# -0.531152502966
# 6598/6620
# Leopold Okulicki
# -0.531152502966
# 6599/6620
# Jan Mazurkiewicz
# -0.531152502966
# 6600/6620
# Zygmunt Berling
# -0.531152502966
# 6601/6620
# Nikolaus von Vormann
# 0.528157412362
# 6602/6620
# Reiner Stahel
# 0.528157412362
# 6603/6620
# Erich von dem Bach-Zelewski
# 0.528157412362
# 6604/6620
# Heinz Reinefarth
# 0.528157412362
# 6605/6620
# Bronislav Kaminski
# 0.528157412362
# 6606/6620
# Oskar Dirlewanger
# 0.528157412362
# 6607/6620
# Petro Dyachenko
# 0.528157412362
# 6608/6620
# Iosif Igelström
# -0.518047802125
# 6609/6620
# Stanisław Mokronowski
# 0.515045430223
# 6610/6620
# Jan Kiliński
# 0.515045430223
# 6611/6620
# James W. Forsyth
# 0.440380354834
# 6612/6620
# Spotted Elk
# -0.443345382409
# 6613/6620
# Anwar Sadat
# -0.555451973967
# 6614/6620
# Yusuf Shakkour
# -0.555451973967
# 6615/6620
# Mohamed Abdel Ghani el-Gamasy
# -0.555451973967
# 6616/6620
# Ali Aslan
# -0.555451973967
# 6617/6620
# Golda Meir
# 0.55248132543
# 6618/6620
# Yitzhak Hofi
# 0.55248132543
# 6619/6620
# Harold Franklyn
# -0.430169415049

# %%
mka = df_run.loc[8965, 'belligerent']

# %%
mka

# %%
df_battles

# %%
battle_list = []
bokeh(u'Ariel Sharon')

# %%
df_warchart = pd.DataFrame({'Labels': ['Win = 1', 'Replacement-Level Performance = .51', 'WAR From Battle = .49'],
              'Values': [1, .51, .49]})

# %%
df_warchart = df_warchart.sort_values('Values', ascending = True)

# %%
df_warchart

# %%
df_warchart = df_warchart.iloc[::-1]

# %%
fig = plt.figure(figsize = (12,9))
plt.style.use('fivethirtyeight')
plt.bar(df_warchart.index, df_warchart.Values, width = 1, color = ['red', 'blue', 'yellow'])
plt.xticks(df_warchart.index + .5, df_warchart.Labels, rotation = 45)
plt.xticks()
plt.title("Bonaparte's WAR in Battle of Borodino")
plt.tight_layout()
plt.savefig('napoleon_war_sample')

# ax.set_axis_bgcolor('gray')

# %%
df_warchart_two = pd.DataFrame({'Labels': ['Win = -1', 'Replacement-Level Performance = .49', 'WAR From Battle = -.51'],
              'Values': [-1, -.49, -.51]})

# %%
fig = plt.figure(figsize = (12,9))
plt.style.use('fivethirtyeight')
plt.bar(df_warchart_two.index, df_warchart_two.Values, width = 1, color = ['red', 'blue', 'white'])
plt.xticks(df_warchart_two.index, df_warchart_two.Labels, rotation = 45)
plt.title("Kutuzov's WAR in Battle of Borodino")
plt.tight_layout()
plt.savefig('/home/ethanarsht/Downloads/kutuzov_war_sample')

# ax.set_axis_bgcolor('gray')
