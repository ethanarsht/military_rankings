# %%
# -*- coding: utf-8 -*-

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from html_table_parser import parser_functions as parse
from time import sleep
import scipy
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
import random
import matplotlib.pyplot as plt
import math
% matplotlib inline

# %%
import lxml
import requests
import html5lib
pd.options.display.max_rows = 50

# %%
from bokeh.models import HoverTool, CategoricalColorMapper, OpenURL, TapTool, ResetTool
from bokeh.plotting import ColumnDataSource, figure, output_file, show, save, output_notebook
from bokeh.io import curdoc
from bokeh.models.glyphs import VBar

# %%
table_pages = ['https://en.wikipedia.org/wiki/List_of_battles_before_301',
               'https://en.wikipedia.org/wiki/List_of_battles_301%E2%80%931300',
               'https://en.wikipedia.org/wiki/List_of_battles_1301%E2%80%931600',
               'https://en.wikipedia.org/wiki/List_of_battles_since_2001']

# %%
list_pages = ['https://en.wikipedia.org/wiki/List_of_battles_1601%E2%80%931800',
               'https://en.wikipedia.org/wiki/List_of_battles_1801%E2%80%931900',
               'https://en.wikipedia.org/wiki/List_of_battles_1901%E2%80%932000',]

# %%
def list_battles(url):
    req = requests.get(url)
    print req.status_code
    era = req.content
    era_soup = BeautifulSoup(era)
    bullets = era_soup.find_all('li')
    
    for bullet in bullets:
        print bullet
        if 'title' in str(bullet):
#             if 'expedition' or 'recapture' or 'capture' or 'war' or 'action' or 'battle' or 'siege' or 'operation' or 'fall' in str(bullet).lower():
#                 if 'List+of+battles' not in str(bullet):
                    if 'footer' not in str(bullet):
                        link = bullet.a['href']
                        link_list.append(link)

                        title = bullet.a['title']
                        title_list.append(title)
                    else:
                        print 'NEXT ENTRY: ' + str(bullet)
#                 else:
#                     print 'NEXT ENTRY: ' + str(bullet)
#             else:
#                 print 'NEXT ENTRY: ' + str(bullet)
        else: 
            print 'NEXT ENTRY' + str(bullet)

# %%
title_list = []
link_list = []
for url in list_pages:
    list_battles(url)

# %%
link_list

# %%
df_late_battles = pd.concat([pd.Series(link_list), pd.Series(title_list)], axis = 1).drop_duplicates()

# %%
df_late_battles = df_late_battles.rename(columns = {0:'url', 1:'Battle'})

# %%
df_late_battles

# %%
df_late_battles[~df_late_battles['Battle'].str.contains('Battle' or 'Operation')]

# %%
df_late_battles.to_csv('battle_list_1600-', encoding = 'utf-8')

# %%
df_late_battles = pd.read_csv('battle_list_1600-.csv', encoding = 'utf-8')

# %%
df_late_battles.head()

# %%
df_late_battles = df_late_battles.drop(['Column1', 'Column4'], axis = 1)
df_late_battles.columns = df_late_battles.iloc[0]
df_late_battles = df_late_battles.drop(0)

# %%
battle_list = []
link_list = []

# %%
def early_battles(link):
    req = requests.get(link)
    print req.status_code
    era = req.content
    era_soup = BeautifulSoup(era)
    tables = era_soup.find_all('table', {'class': 'wikitable'})

    for table in tables:
        cells = table.find_all('td')
        for cell in cells:
            if cell.a is not None:
                a = ['Fall', 'Battle', 'Siege', 'Capture', 'Operation', 'Action', 'Recapture']
                if any(x in str(cell.a['href']) for x in a):
                    battle_list.append(cell.a['title'])
                    link_list.append(cell.a['href'])

# %%
for page in table_pages:
    print page
    early_battles(page)

# %%
df_battles = pd.DataFrame({'battle': battle_list,
                          'link':link_list})

# %%
df_battles = df_battles.rename(columns = {'link':'url', 'battle':'Battle'})

# %%
len(df_battles)

# %%
len(df_late_battles)

# %%
df_battles.head()

# %%
df_url = pd.concat([df_late_battles, df_battles]).reset_index(drop = True)

# %%
len(df_url)

# %%
len(df_url.drop_duplicates())

# %%
s_req = requests.get('https://en.wikipedia.org/Alexander_the_Great')

soup = BeautifulSoup(s_req.text)

ul = soup.find('ul', {'class':'redirectText'})

# %%
if ul is not None:
    print 'works'

# %%
df_battle_all = pd.DataFrame()
df_battle = pd.DataFrame()
def table_scrape(url, name):
#     sleep(1)
    print name
    link = 'https://en.wikipedia.org' + url
    b_req = requests.get(link)

    soup = BeautifulSoup(b_req.text)
    
    bell = soup.find('table', {'class':'infobox vevent'})
    
    if bell is not None:

        details = pd.DataFrame(parse.make2d(bell))
    else:
        return b_req
    

    if 'Belligerents' in str(bell):
    
        clean_rows = details.drop_duplicates(0).set_index(0,drop = True).loc[['Date', 'Location', 'Result'],:]

        clean_col = clean_rows.transpose().reset_index(drop = True)

        df_x_bells = pd.DataFrame()

        html_table = bell.find_all('tr')
        bell_list = []
        bell_y_list = []

        for index, cell in zip(range(0, len(html_table)), html_table):
            if 'Commanders and leaders' in str(cell):
                leaders = html_table[index + 1]
                cells = leaders.find_all('td')
                count = 0
                for cell in cells:
                    count += 1
                    anchors = cell.find_all('a')
                    for anchor in anchors:
                        if 'title' in str(anchor):
                            if 'class="image"' in str(anchor):
                                cl = 'image'
                            elif 'class="thumbborder"' in str(anchor):
                                cl = 'thumb'
                            elif 'cite_note' in str(anchor):
                                cl = 'cite'
                            elif 'disambiguation needed' in str(anchor):
                                cl = 'disam'
                            elif 'cnote_g' in str(anchor):
                                cl = 'cnote'
                            else:
                                title = anchor['title']
                                if any(title == x for x in ['Napoleon I','Alexander III of Macedon']):
                                    print 'napoleon or alex redirect'

                                ref = anchor['href']
                                link = 'https://en.wikipedia.org' + ref

                                if len(ref) <= 10:
                                    t_req = requests.get(link)
                                elif any(ref[8] + ref[9] + ref[10] == x for x in ['pt.', 'tr.', 'ko.', 'ja.', 'th.','da.', 'es.', 'de.', 'it.', 'fr.', 'zh.']):
                                    print 'Not English!'
                                    link = ref
                                    t_req = requests.get(link)
                                elif soup.find('ul', {'class':'redirectText'}) is not None:
                                    print 'REDIRECT'
                                    print title
                                    ul = soup.find('ul', {'class':'redirectText'})
                                    a = ul.a
                                    redirect = a['href']
                                    link = 'https://en.wikipedia.org' + redirect
                                    t_req = requests.get(link)
                                else:
                                    t_req = requests.get(link)

                                t_soup = BeautifulSoup(t_req.text)

                                c_name = t_soup.find('title')
                                c_name = str(c_name)

                                if c_name:
                                    c_name = c_name.replace(' - Wikipedia', '').replace('<title>', '').replace('</title>', '')
                                else:
                                    if count == 1:
                                        bell_list.append(title)
                                    elif count == 2:
                                        bell_y_list.append(title)
                                if 'ex.php?title=' in ref:
                                    ref = ref.replace('ex.php?title=', '')
                                    ref = ref.replace('&action=edit&redlink=1', '')

                                omit_list = ['Capital punishment', 
                                             'Military advisor', 
                                             'Wounded in action', 
                                             'Prisoner of war', 
                                             'Killed in action', 
                                             'Surrender (military)', 
                                             'Surrendered',
                                             'Common military ranks in English']

                                if all(c_name != x for x in omit_list):


                                    if count == 1:

                                        bell_list.append(c_name)
                                    elif count == 2:
                                        bell_y_list.append(c_name)



        for bell in bell_list:
            clean_col['belligerent'] = bell
            df_x_bells = pd.concat([df_x_bells, clean_col])
            df_x_bells = df_x_bells.reset_index(drop = True)


        df_y_bells = pd.DataFrame()
        for bell in bell_y_list:
            clean_col['belligerent'] = bell
            df_y_bells = pd.concat([df_y_bells, clean_col])
            df_y_bells = df_y_bells.reset_index(drop = True)

        df_y_bells = df_y_bells.rename(columns = {0:'Location'})

        if 'Strength' in str(details[0]):
            strength_finder = details[details[0] == 'Strength']


            strength_row = strength_finder.index + 1

            strength = details.loc[strength_row]

            strength_x = strength.iloc[0,0]

            strength_y = strength.iloc[0,1]
        else:
            strength_x = 'unknown'
            strength_y = 'unknown'

        df_x_bells['own'] = strength_x

        df_x_bells['opp'] = strength_y

        df_y_bells['own'] = strength_y

        df_y_bells['opp'] = strength_x

        if 'Casualties and losses' not in str(details[0]):
            df_x_bells['taken'] = np.NaN
            df_x_bells['inflicted'] = np.NaN
            df_y_bells['taken'] = np.NaN
            df_y_bells['inflicted'] = np.NaN

        else:

            casualties_finder = details[details[0] == 'Casualties and losses']

            casualties_row = casualties_finder.index + 1

            casualties = details.loc[casualties_row]

            casualties_x = casualties.iloc[0,0]

            casualties_y = casualties.iloc[0,1]

            df_x_bells['taken'] = casualties_x

            df_x_bells['inflicted'] = casualties_y

            df_y_bells['taken'] = casualties_y

            df_y_bells['inflicted'] = casualties_x



        df_x_bells['Battle'] = name

        df_y_bells['Battle'] = name

        df_x_bells['pos'] = 'L'

        df_y_bells['pos'] = 'R'

        df_battle = pd.concat([df_x_bells, df_y_bells]).reset_index(drop = True)

        df_battle_all = pd.concat([df_battle_all, df_battle]).reset_index(drop = True).drop_duplicates()

        global df_battle_all
    else:
        print 'Filtered: ' + name

# %%
count = 0
for num, rows in {1:df_url[:200],
             2:df_url[200:400], 
             3:df_url[400:600], 
             4:df_url[600:800],
             5:df_url[800:1000],
             6:df_url[1000:1200],
             7:df_url[1200:1400],
             8:df_url[1400:1600],
             9:df_url[1600:1800],
             10:df_url[1800:2000],
             11:df_url[2000:2200],
             12:df_url[2200:2400],
             13:df_url[2400:2600],
             14:df_url[2600:2800],
             15:df_url[2800:3000],
             16:df_url[3000:3200],
             17:df_url[3200:3400],
             18:df_url[3400:]}.iteritems():
    df_battle = pd.DataFrame()
    df_batch = rows
    for index, row in df_batch.iterrows():
        count += 1
        global count
        print str(count) + '/' + str(len(df_url))
        table_scrape(row['url'], row['Battle'])
    df_battle_all.to_csv('rows_{}.csv'.format(num), encoding = 'utf-8')
    print 'NEW FRAME' + str(num)

# %%
row_list = ['rows_1.csv',
 'rows_2.csv',
 'rows_3.csv',
 'rows_4.csv',
 'rows_5.csv',
 'rows_6.csv',
 'rows_7.csv',
 'rows_8.csv',
 'rows_9.csv',
 'rows_10.csv',
 'rows_11.csv',
 'rows_12.csv',
 'rows_13.csv',
 'rows_14.csv',
 'rows_15.csv',
 'rows_16.csv',
 'rows_17.csv',
 'rows_18.csv']

# %%
df_comm = pd.DataFrame()
for sheet in row_list:
    df_rows = pd.read_csv(sheet)
    df_comm = pd.concat([df_comm, df_rows]).reset_index(drop = True)

# %%
df_comm = df_comm.drop('Unnamed: 0', axis = 1)

# %%
len(df_comm)

# %%
len(df_comm)

# %%
df_comm.to_csv('battles_dirty.csv', encoding = 'utf-8')

# %%
df_comm = pd.read_csv('battles_dirty.csv').drop('Unnamed: 0', axis = 1)

# %%
df_comm = df_comm.drop_duplicates()

# %%
df_comm.head()

# %%
len(df_comm)

# %%
df_comm[df_comm.belligerent.str.contains('Nasser')]

# %%
len(df_comm.drop_duplicates())

# %%
df_comm = df_comm.drop_duplicates().reset_index(drop = True)

# %%
df_comm.to_csv('battles_deduped.csv')

# %%
len(df_comm[df_comm.belligerent.str.contains('Napoleon')])

# %%
df_comm[df_comm.belligerent.str.contains('Scipio')]

# %%
df_results = pd.read_csv('result_column.csv')

# %%
df_results[df_results.Battle == 'Battle_of_Camarón']

# %%
df_comm.head()

# %%
df_results.head()

# %%
df_more_results = pd.merge(df_comm, df_results, how = 'outer', on = ['Battle', 'belligerent', 'pos', 'Result'])

# %%
df_more_results = df_more_results[df_more_results.VorD.isnull()]

# %%
df_more_results = df_more_results.drop_duplicates(subset = ['Battle', 'Date', 'VorD'])

# %%
df_more_results.head()

# %%
df_more_results.to_csv('adding_results_10.21.csv', encoding = 'utf-8')

# %%
df_comm[df_comm.Battle == 'Battle_of_Camarón']

# %%
df_comm[df_comm.belligerent == 'Ambroise de Loré']

# %%
df_vl = pd.merge(df_comm, df_results, how = 'outer', on = ['Battle', 'belligerent', 'Result', 'pos'])

# %%
df_vl

# %%
df_vl = df_vl.sort('VorD')

# %%
df_vl[df_vl.belligerent == 'Ambroise de Loré']

# %%
df_vl[df_vl.belligerent == 'Saracens']

# %%
df_vl.to_csv('additional_results.csv')

# %%
df_10_21_fill = df_vl[df_vl.VorD.isnull()]

# %%
df_ar = pd.read_csv('additional_results.csv', encoding = 'utf-8')

# %%
df_strength = df_ar.drop(['Unnamed: 0', 'Location', 'Result', 'inflicted', 'taken', 'opp'], axis = 1)

# %%
df_strength = df_strength.sort('Battle').reset_index(drop = True)

# %%
df_strength_dd = df_strength.drop_duplicates(['own', 'pos'], keep = 'first')

# %%
df_strength_dd.own = df_strength_dd.own.str.replace('\r',' ').str.replace('\n', ' ').replace('\n', ' ')

# %%
df_strength_dd = df_strength_dd.sort('Battle').reset_index(drop = True)

# %%
df_strength_dd

# %%
df_strength_dd.to_csv('strength_entry.csv', encoding = 'utf-8')

# %%
df_strength_new = df_strength.drop_duplicates(['own', 'pos', 'Battle'], keep = 'first')

# %%
df_strength_fill = pd.read_excel('strength_entry.xlsx', encoding = 'utf-8')

# %%
df_battles = pd.read_csv('battles_deduped.csv', encoding = 'utf-8').drop('Unnamed: 0', axis = 1)

# %%
df_battles = df_battles.drop(['taken', 'inflicted'], axis = 1)

# %%
df_strength_fill.Battle = df_strength_fill.Battle.str.replace(u"â€“",u'–')

# %%
df_some_strength = pd.merge(df_battles, df_strength_fill, how = 'outer', on = ['Battle', 'pos']).drop(['own_y', 'belligerent_y', 'Date_y'], axis = 1).rename(columns = {'Date_x':'Date','own_x':'own', 'belligerent_x':'belligerent'})

# %%
df_some_strength[df_some_strength.Battle.str.contains('Battle_of_Jena')]

# %%
df_test = df_some_strength.iloc[:,9:]

# %%
df_str_two = df_some_strength[df_some_strength['Infantry'].isnull() & df_some_strength['Cavalry'].isnull() & df_some_strength['Artillery'].isnull() & df_some_strength['Ships'].isnull() & df_some_strength['Airforce'].isnull() & df_some_strength['Special'].isnull()]

# %%
df_str_two.head()

# %%
df_str_two = df_str_two.drop_duplicates(['Battle', 'Date', 'Location', 'Result', 'pos']).drop('VorD', axis = 1)

# %%
len(df_str_two)

# %%
df_merger = df_strength.drop(['Date', 'belligerent', 'own'], axis = 1)

# %%
df_merger = df_merger.drop_duplicates()

# %%
df_str_two.head()

# %%
df_str_two = pd.merge(df_str_two, df_merger, on = ['Battle', 'pos'], how = 'outer').dropna(subset = ['Date', 'Location', 'Result'])

# %%
df_str_two = df_str_two.dropna(subset = ['VorD'])

# %%
df_str_two.to_csv('strength_entry_two.csv')

# %%
df_str_two

# %%
df_partial = pd.read_excel('PARTIAL_strength_entry_two.xlsx', encoding = 'utf-8')

# %%
df_str_two.head()

# %%
df_str_two = df_str_two.drop(['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special'], axis = 1)

# %%
df_partial = df_partial.drop(['Date', 'Location', 'Result', 'belligerent','own', 'Column1'],axis = 1)

# %%
df_partial.columns

# %%
df_str_two.head()

# %%
df_finish = pd.merge(df_str_two, df_partial, on = ['Battle', 'pos', 'VorD'], how = 'outer')

# %%
drop_list = list(df_finish[df_finish['Date'].isnull()].index)

# %%
df_finish = df_finish.drop(drop_list)

# %%
df_finish.to_csv('last_strength_entry.csv', encoding = 'utf-8')

# %%
df_some_strength

# %%
df_some_strength[df_some_strength.Battle.str.contains('Siege of La Rochelle')]

# %%
df_more_strength = pd.read_excel('last_strength_entry.xlsx')

# %%
df_more_strength.head()

# %%
df_some_strength.head()

# %%
df_more_strength = pd.merge(df_more_strength, df_str_two, on = ['Battle', 'pos'], how = 'outer').drop(['own_y', 'Infantry_y', 'Cavalry_y', 'Artillery_y', 'Ships_y', 'Airforce_y', 'Special_y', 'Date_y', 'Location_y', 'Result_y', 'belligerent_y'], axis = 1).dropna(subset = ['Date_x'])

# %%
df_more_strength.columns = df_more_strength.columns.str.replace('_x', '')

# %%
df_more_strength.head()

# %%
df_some_strength.head()

# %%
df_more_strength

# %%
df_fill_two = pd.merge(df_battles, df_more_strength, on = ['Battle', 'pos'], how = 'outer').drop(['Date_y', 
                                                                                    'Location_y', 
                                                                                    'belligerent_y', 
                                                                                    'Result_y', 'own_y', 
                                                                                    'opp_y'], axis = 1)

# %%
df_fill_two.columns = df_fill_two.columns.str.replace('_x', '')

# %%
df_some_strength = df_some_strength[df_some_strength['Infantry'].notnull() | df_some_strength['Cavalry'].notnull() | df_some_strength['Artillery'].notnull() | df_some_strength['Ships'].notnull() | df_some_strength['Airforce'].notnull() | df_some_strength['Special'].notnull()]

# %%
len(df_some_strength)

# %%
df_fill_two = df_fill_two[df_fill_two['Infantry'].notnull() | df_fill_two['Cavalry'].notnull() | df_fill_two['Artillery'].notnull() | df_fill_two['Ships'].notnull() | df_fill_two['Airforce'].notnull() | df_fill_two['Special'].notnull()]

# %%
df_some_strength

# %%
df_fill_two

# %%
df_all_strength = pd.concat([df_fill_two, df_some_strength]).reset_index(drop = True)

# %%
len(df_battles)

# %%
df_char = df_all_strength[df_all_strength.Date.isnull()]

# %%
df_char.to_excel('special_character_fix.xlsx')

# %%
df_all_strength[df_all_strength.Battle.str.contains('Battle_of_Tenn')]

# %%
df_all_strength.to_excel('all_strength_probably.xlsx')

# %%
df_battles[df_battles.Battle.str.contains('dlingen')]

# %%
df_char.Battle

# %%
df_strength_all = pd.read_excel('all_strength_probably.xlsx')

# %%
df_strength_all.loc[9988, 'Infantry'] = 2000

# %%
df_strength_all = df_strength_all.drop_duplicates()

# %%
df_left = df_strength_all[df_strength_all.pos == 'L']

# %%
df_left = df_left.drop(['Date', 'Location', 'Result', 'belligerent', 'opp', 'own'], axis = 1)

# %%
df_left = df_left.drop_duplicates(subset = ['Battle'])

# %%
df_left = df_left.dropna(subset = ['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special'], how = 'all')

# %%
df_right = df_strength_all[df_strength_all.pos == 'R']

# %%
df_right = df_right.drop_duplicates(subset = ['Battle'])

# %%
df_right = df_right.drop(['Date', 'Location', 'Result', 'belligerent', 'opp', 'own', 'VorD'], axis = 1)

# %%
df_right = df_right.dropna(subset = ['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special'], how = 'all')

# %%
df_model = pd.merge(df_left, df_right, on = 'Battle', how = 'outer').dropna(subset = ['pos_x', 'pos_y']).reset_index(drop = True)

# %%
df_v = df_model[df_model.VorD == 'V']

# %%
v_list = list(df_v.index)

# %%
ran_list = random.sample(v_list, 374)

# %%
df_switch = df_model.iloc[ran_list]

# %%
df_switch['Infantry_hold'] = df_switch['Infantry_x']
df_switch['Cavalry_hold'] = df_switch['Cavalry_x']
df_switch['Artillery_hold'] = df_switch['Artillery_x']
df_switch['Ships_hold'] = df_switch['Ships_x']
df_switch['Airforce_hold'] = df_switch['Airforce_x']
df_switch['Special_hold'] = df_switch['Special_x']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_switch['Infantry_x'] = df_switch['Infantry_y']
df_switch['Cavalry_x'] = df_switch['Cavalry_y']
df_switch['Artillery_x'] = df_switch['Artillery_y']
df_switch['Ships_x'] = df_switch['Ships_y']
df_switch['Airforce_x'] = df_switch['Airforce_y']
df_switch['Special_x'] = df_switch['Special_y']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_switch['Infantry_y'] = df_switch['Infantry_hold']
df_switch['Cavalry_y'] = df_switch['Cavalry_hold']
df_switch['Artillery_y'] = df_switch['Artillery_hold']
df_switch['Ships_y'] = df_switch['Ships_hold']
df_switch['Airforce_y'] = df_switch['Airforce_hold']
df_switch['Special_y'] = df_switch['Special_hold']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_switch = df_switch.drop(['Infantry_hold', 'Cavalry_hold', 'Artillery_hold', 'Ships_hold', 'Airforce_hold', 'Special_hold'], axis = 1)

# %%
df_switch.VorD = 'D'

# %%
df_model = df_model.drop(ran_list)

# %%
df_model = pd.concat([df_model, df_switch])

# %%
df_model.loc[2378, 'Infantry_y'] = 25000

# %%
df_model.loc[2363, 'Infantry_x'] = 500

# %%
df_model = df_model[df_model.Infantry_x != 1.0]
df_model = df_model[df_model.Infantry_y != 1.0]

# %%
df_model = df_model.fillna(0)

# %%
df_model['infantry_diff'] = (df_model['Infantry_x'] - df_model['Infantry_y']) / (df_model['Infantry_x'] + df_model['Infantry_y'])
df_model['cavalry_diff'] = (df_model['Cavalry_x'] - df_model['Cavalry_y']) / (df_model['Cavalry_x'] + df_model['Cavalry_y'])
df_model['artillery_diff'] = (df_model['Artillery_x'] - df_model['Artillery_y']) / (df_model['Artillery_x'] + df_model['Artillery_y'])
df_model['ships_diff'] = (df_model['Ships_x'] - df_model['Ships_y']) / (df_model['Ships_x'] + df_model['Ships_y'])
df_model['airforce_diff'] = (df_model['Airforce_x'] - df_model['Airforce_y']) / (df_model['Airforce_x'] + df_model['Airforce_y'])
df_model['special_diff'] = (df_model['Special_x'] - df_model['Special_y']) / (df_model['Special_x'] + df_model['Special_y'])

# %%
df_diff = pd.concat([df_model['VorD'], df_model['Battle'], df_model['infantry_diff'],df_model['cavalry_diff'],df_model['artillery_diff'], df_model['ships_diff'],
                    df_model['airforce_diff'], df_model['special_diff']], axis = 1)

# %%
df_diff = df_diff[df_diff.VorD != 'I']

# %%
df_diff = df_diff.drop(174)

# %%
df_diff = df_diff.fillna(0)

# %%
df_x = pd.DataFrame(df_diff.iloc[:, 2:])

# %%
df_x = df_x.drop('artillery_diff', axis = 1)

# %%
df_y = pd.DataFrame(df_diff.iloc[:, 0])

# %%
df_y.VorD = df_y.VorD.replace('V', 1).replace('D', 0).replace('L', 0).replace('v', 1)

# %%
df_y.VorD = df_y.VorD.astype('float')

# %%
df_x = df_x.iloc[:, :-1]

# %%
lr = LogisticRegression()
lr.fit(df_x, df_y)
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr.score(df_x, df_y)
# Out:
# 0.54352226720647778

# %%
df_strength_all.loc[60, 'VorD'] = 'V'
df_strength_all.loc[61, 'VorD'] = 'V'

# %%
df_strength_all.loc[3479:3485, 'VorD'] = 'V'

# %%
df_strength_all.loc[3485, 'VorD'] = 'D'

# %%
df_strength_all.loc[3802:3803, 'VorD'] = 'V'
df_strength_all.loc[3804:3807, 'VorD'] = 'D'

# %%
df_strength_all.loc[4142:4143, 'VorD'] = 'D'

# %%
df_strength_all.VorD = df_strength_all.VorD.str.replace('L', 'D')

# %%
df_strength_all.VorD = df_strength_all.VorD.str.replace('v', 'V')

# %%
df_strength_all.VorD = df_strength_all.VorD.str.replace('W', 'V')

# %%
null_fill = df_strength_all[df_strength_all.VorD.isnull()]

# %%
null_fill['VorD'] = ['V', 'D', 'D', 'V', 'V', 'D', 'V', 'V', 'V', 'V', 'D', 'D', 'D', 'D', 'V', 'V', 'V', 'V', 'V',
                    'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D','D', 'D', 'D', 'D', 'V', 'V', 'V', 'V', 'V', 'D', 'D', 'D', 'D',
                    'V', 'V', 'D', 'D', 'D', 'D', np.NaN, 'D', np.NaN]
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_strength_all.VorD.loc[null_fill.index] = null_fill['VorD']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_strength_all = df_strength_all[df_strength_all.belligerent != 'Sweden']

# %%
import re

# %%
year_list = []
for i, row in df_strength_all.iterrows():
    d = row['Date']
    if isinstance(d, str):
        if re.search(r'[12]\d{3}', d):
            year = re.search(r'[12]\d{3}', d).group(0)
            year = int(year)
            if 'BC' in d:
                year = year * -1
            year_list.append({'Year':year, 'Index':i})
        elif re.search(r'[12]\d{2}', d):
            year = re.search(r'[12]\d{2}', d).group(0)
            year = int(year)
            if 'BC' in d:
                year = year * -1
            year_list.append({'Year':year, 'Index':i})

# %%
df_years = pd.DataFrame(year_list).set_index('Index', drop = True)

# %%
df_strength_all['year'] = pd.Series()

# %%
df_strength_all['year'].loc[df_years.index] = df_years.Year
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_strength_all.to_csv('current_run.csv', encoding = 'utf-8')

# %%
df_strength_all = pd.read_csv('current_run.csv', encoding = 'utf-8').drop('Unnamed: 0', axis = 1)

# %%
df_run = df_strength_all[df_strength_all.VorD.notnull()]

# %%
df_run.Battle = df_run.Battle.str.replace('_'," ")
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
arras_1 = {'Battle':['Battle of Arras', 'Battle of Arras'], 
           'Date':['21 May 1940', '21 May 1940'],
           'Location':['Arras', 'Arras'], 
           'Result':['German victory', 'German victory'] ,
           'belligerent':['Erwin Rommel', 'Harold Franklyn'],
           'opp':['manual', 'manual'],
           'own':['manual', 'manual'], 
           'pos':['R', 'L'],
           'VorD':['V', 'D'],
           'Infantry':[7500.0, 2000.0],
           'Cavalry':[225.0, 74.0],
           'Artillery':[np.NaN, np.NaN],
           'Ships': [np.NaN, np.NaN],
           'Airforce': [np.NaN, np.NaN],
           'Special': [np.NaN, np.NaN],
           'year':[1940, 1940]}

# %%
df_run = pd.concat([df_run,pd.DataFrame(arras_1, index = [10515,10516])])

# %%
df_run
# Out:
#        Airforce  Artillery                            Battle  Cavalry  \
# 0           NaN        3.0  1898 invasion of GuantÃ¡namo Bay      NaN
# 1           NaN        7.0  1898 invasion of GuantÃ¡namo Bay      NaN
# 2           NaN        NaN  1898 invasion of GuantÃ¡namo Bay      NaN
# 3           NaN        NaN             1948 Arab–Israeli War      NaN
# 4           NaN        NaN             1948 Arab–Israeli War      NaN
# 5           NaN        NaN             1948 Arab–Israeli War      NaN
# 6           NaN        NaN             1948 Arab–Israeli War      NaN
# 7           NaN        NaN             1948 Arab–Israeli War      NaN
# 8           NaN        NaN             1948 Arab–Israeli War      NaN
# 9           NaN        NaN             1948 Arab–Israeli War      NaN
# 10          NaN        NaN             1948 Arab–Israeli War      NaN
# 11          NaN        NaN             1948 Arab–Israeli War      NaN
# 12          NaN        NaN             1948 Arab–Israeli War      NaN
# 13          NaN        NaN             1948 Arab–Israeli War      NaN
# 14          NaN        NaN             1948 Arab–Israeli War      NaN
# 15          NaN        NaN             1948 Arab–Israeli War      NaN
# 16          NaN        NaN             1948 Arab–Israeli War      NaN
# 17          NaN        NaN             1948 Arab–Israeli War      NaN
# 18          NaN        NaN             1948 Arab–Israeli War      NaN
# 19          NaN        NaN             1948 Arab–Israeli War      NaN
# 20          NaN        NaN             1948 Arab–Israeli War      NaN
# 21          NaN        NaN             1948 Arab–Israeli War      NaN
# 22          NaN        NaN             1948 Arab–Israeli War      NaN
# 23          NaN        NaN             1948 Arab–Israeli War      NaN
# 24          NaN        NaN             1948 Arab–Israeli War      NaN
# ...         ...        ...                               ...      ...
# 10492       NaN        NaN            Warsaw Uprising (1794)      NaN
# 10493       NaN        NaN            Warsaw Uprising (1794)      NaN
# 10494       NaN       22.0             Wounded Knee Massacre      NaN
# 10495       NaN        NaN             Wounded Knee Massacre      NaN
# 10496     594.0     1720.0                    Yom Kippur War   7500.0
# 10497     594.0     1720.0                    Yom Kippur War   7500.0
# 10498     594.0     1720.0                    Yom Kippur War   7500.0
# 10499     594.0     1720.0                    Yom Kippur War   7500.0
# 10500     594.0     1720.0                    Yom Kippur War   7500.0
# 10501     594.0     1720.0                    Yom Kippur War   7500.0
# 10502     594.0     1720.0                    Yom Kippur War   7500.0
# 10503     594.0     1720.0                    Yom Kippur War   7500.0
# 10504     594.0     1720.0                    Yom Kippur War   7500.0
# 10505     440.0      945.0                    Yom Kippur War   4700.0
# 10506     440.0      945.0                    Yom Kippur War   4700.0
# 10507     440.0      945.0                    Yom Kippur War   4700.0
# 10508     440.0      945.0                    Yom Kippur War   4700.0
# 10509     440.0      945.0                    Yom Kippur War   4700.0
# 10510     440.0      945.0                    Yom Kippur War   4700.0
# 10511     440.0      945.0                    Yom Kippur War   4700.0
# 10512     440.0      945.0                    Yom Kippur War   4700.0
# 10513     440.0      945.0                    Yom Kippur War   4700.0
# 10514     440.0      945.0                    Yom Kippur War   4700.0
# 10515       NaN        NaN                   Battle of Arras    225.0
# 10516       NaN        NaN                   Battle of Arras     74.0
#
#                                                     Date  Infantry  \
# 0                                                    NaN    5000.0
# 1                                                    NaN    5000.0
# 2                                                    NaN     923.0
# 3      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 4      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 5      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 6      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 7      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 8      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 9      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 10     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 11     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 12     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 13     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 14     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 15     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 16     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 17     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 18     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 19     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 20     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 21     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 22     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 23     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 24     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# ...                                                  ...       ...
# 10492                                17 to 19 April 1794    5775.0
# 10493                                17 to 19 April 1794    5775.0
# 10494                                   29 December 1890     438.0
# 10495                                   29 December 1890     120.0
# 10496                                 October 6–25, 1973  990750.0
# 10497                                 October 6–25, 1973  990750.0
# 10498                                 October 6–25, 1973  990750.0
# 10499                                 October 6–25, 1973  990750.0
# 10500                                 October 6–25, 1973  990750.0
# 10501                                 October 6–25, 1973  990750.0
# 10502                                 October 6–25, 1973  990750.0
# 10503                                 October 6–25, 1973  990750.0
# 10504                                 October 6–25, 1973  990750.0
# 10505                                 October 6–25, 1973  395000.0
# 10506                                 October 6–25, 1973  395000.0
# 10507                                 October 6–25, 1973  395000.0
# 10508                                 October 6–25, 1973  395000.0
# 10509                                 October 6–25, 1973  395000.0
# 10510                                 October 6–25, 1973  395000.0
# 10511                                 October 6–25, 1973  395000.0
# 10512                                 October 6–25, 1973  395000.0
# 10513                                 October 6–25, 1973  395000.0
# 10514                                 October 6–25, 1973  395000.0
# 10515                                        21 May 1940    7500.0
# 10516                                        21 May 1940    2000.0
#
#                                                 Location  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Former British Mandate of Palestine, Sinai Pen...
# 4      Former British Mandate of Palestine, Sinai Pen...
# 5      Former British Mandate of Palestine, Sinai Pen...
# 6      Former British Mandate of Palestine, Sinai Pen...
# 7      Former British Mandate of Palestine, Sinai Pen...
# 8      Former British Mandate of Palestine, Sinai Pen...
# 9      Former British Mandate of Palestine, Sinai Pen...
# 10     Former British Mandate of Palestine, Sinai Pen...
# 11     Former British Mandate of Palestine, Sinai Pen...
# 12     Former British Mandate of Palestine, Sinai Pen...
# 13     Former British Mandate of Palestine, Sinai Pen...
# 14     Former British Mandate of Palestine, Sinai Pen...
# 15     Former British Mandate of Palestine, Sinai Pen...
# 16     Former British Mandate of Palestine, Sinai Pen...
# 17     Former British Mandate of Palestine, Sinai Pen...
# 18     Former British Mandate of Palestine, Sinai Pen...
# 19     Former British Mandate of Palestine, Sinai Pen...
# 20     Former British Mandate of Palestine, Sinai Pen...
# 21     Former British Mandate of Palestine, Sinai Pen...
# 22     Former British Mandate of Palestine, Sinai Pen...
# 23     Former British Mandate of Palestine, Sinai Pen...
# 24     Former British Mandate of Palestine, Sinai Pen...
# ...                                                  ...
# 10492                                     Warsaw, Poland
# 10493                                     Warsaw, Poland
# 10494                   Wounded Knee Creek, South Dakota
# 10495                   Wounded Knee Creek, South Dakota
# 10496  Both banks of the Suez Canal, Golan Heights an...
# 10497  Both banks of the Suez Canal, Golan Heights an...
# 10498  Both banks of the Suez Canal, Golan Heights an...
# 10499  Both banks of the Suez Canal, Golan Heights an...
# 10500  Both banks of the Suez Canal, Golan Heights an...
# 10501  Both banks of the Suez Canal, Golan Heights an...
# 10502  Both banks of the Suez Canal, Golan Heights an...
# 10503  Both banks of the Suez Canal, Golan Heights an...
# 10504  Both banks of the Suez Canal, Golan Heights an...
# 10505  Both banks of the Suez Canal, Golan Heights an...
# 10506  Both banks of the Suez Canal, Golan Heights an...
# 10507  Both banks of the Suez Canal, Golan Heights an...
# 10508  Both banks of the Suez Canal, Golan Heights an...
# 10509  Both banks of the Suez Canal, Golan Heights an...
# 10510  Both banks of the Suez Canal, Golan Heights an...
# 10511  Both banks of the Suez Canal, Golan Heights an...
# 10512  Both banks of the Suez Canal, Golan Heights an...
# 10513  Both banks of the Suez Canal, Golan Heights an...
# 10514  Both banks of the Suez Canal, Golan Heights an...
# 10515                                              Arras
# 10516                                              Arras
#
#                                                   Result  Ships  Special VorD  \
# 0                                                    NaN    2.0      NaN    D
# 1                                                    NaN    2.0      NaN    D
# 2                                                    NaN    6.0      NaN    V
# 3      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 4      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 5      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 6      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 7      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 8      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 9      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 10     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 11     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 12     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 13     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 14     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 15     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 16     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 17     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 18     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 19     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 20     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 21     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 22     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 23     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 24     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# ...                                                  ...    ...      ...  ...
# 10492                                     Polish victory    NaN      NaN    V
# 10493                                     Polish victory    NaN      NaN    V
# 10494                              United States victory    NaN      NaN    V
# 10495                              United States victory    NaN      NaN    D
# 10496  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10497  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10498  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10499  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10500  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10501  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10502  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10503  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10504  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10505  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10506  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10507  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10508  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10509  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10510  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10511  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10512  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10513  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10514  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10515                                     German victory    NaN      NaN    V
# 10516                                     German victory    NaN      NaN    D
#
#                          belligerent  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                   David Ben-Gurion
# 4                     Yisrael Galili
# 5                        Yaakov Dori
# 6                       Yigael Yadin
# 7                      Mickey Marcus
# 8                        Yigal Allon
# 9                      Yitzhak Rabin
# 10                    David Shaltiel
# 11                       Moshe Dayan
# 12                     Shimon Avidan
# 13                      Moshe Carmel
# 14                     Yitzhak Sadeh
# 15         Abdul Rahman Hassan Azzam
# 16                   Farouk of Egypt
# 17              Abdullah I of Jordan
# 18               Muzahim al-Pachachi
# 19                    Husni al-Za'im
# 20                  Amin al-Husseini
# 21                Ahmed Ali al-Mwawi
# 22                   Mohammed Naguib
# 23                  John Bagot Glubb
# 24                   Habis al-Majali
# ...                              ...
# 10492          Stanisław Mokronowski
# 10493                   Jan Kiliński
# 10494               James W. Forsyth
# 10495                    Spotted Elk
# 10496                    Anwar Sadat
# 10497                 Hafez al-Assad
# 10498               Ahmad Ismail Ali
# 10499                  Mustafa Tlass
# 10500                 Saad el-Shazly
# 10501                 Yusuf Shakkour
# 10502  Mohamed Abdel Ghani el-Gamasy
# 10503                      Ali Aslan
# 10504                    Omar Abrash
# 10505                     Golda Meir
# 10506                    Moshe Dayan
# 10507                   David Elazar
# 10508                     Israel Tal
# 10509                   Shmuel Gonen
# 10510                   Yitzhak Hofi
# 10511                    Benny Peled
# 10512                   Haim Bar-Lev
# 10513                 Albert Mandler
# 10514                   Ariel Sharon
# 10515                   Erwin Rommel
# 10516                Harold Franklyn
#
#                                                      opp  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Egypt: 10,000 initially, rising to 20,000[cita...
# 4      Egypt: 10,000 initially, rising to 20,000[cita...
# 5      Egypt: 10,000 initially, rising to 20,000[cita...
# 6      Egypt: 10,000 initially, rising to 20,000[cita...
# 7      Egypt: 10,000 initially, rising to 20,000[cita...
# 8      Egypt: 10,000 initially, rising to 20,000[cita...
# 9      Egypt: 10,000 initially, rising to 20,000[cita...
# 10     Egypt: 10,000 initially, rising to 20,000[cita...
# 11     Egypt: 10,000 initially, rising to 20,000[cita...
# 12     Egypt: 10,000 initially, rising to 20,000[cita...
# 13     Egypt: 10,000 initially, rising to 20,000[cita...
# 14     Egypt: 10,000 initially, rising to 20,000[cita...
# 15     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 16     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 17     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 18     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 19     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 20     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 21     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 22     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 23     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 24     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# ...                                                  ...
# 10492                                  8,000 soldiers[1]
# 10493                                  8,000 soldiers[1]
# 10494                                         120 men[2]
# 10495  500 effectives:\r\r\r\n7th U.S. Cavalry:\r\r\r...
# 10496  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10497  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10498  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10499  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10500  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10501  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10502  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10503  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10504  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10505  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10506  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10507  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10508  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10509  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10510  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10511  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10512  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10513  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10514  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10515                                             manual
# 10516                                             manual
#
#                                                      own pos    year
# 0                                                    NaN   R     NaN
# 1                                                    NaN   R     NaN
# 2                                                    NaN   L     NaN
# 3      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 4      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 5      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 6      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 7      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 8      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 9      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 10     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 11     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 12     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 13     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 14     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 15     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 16     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 17     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 18     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 19     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 20     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 21     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 22     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 23     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 24     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# ...                                                  ...  ..     ...
# 10492     3,000–3,500 soldiers,\r\r\r\n~2,500 militia[1]   L  1794.0
# 10493     3,000–3,500 soldiers,\r\r\r\n~2,500 militia[1]   L  1794.0
# 10494  500 effectives:\r\r\r\n7th U.S. Cavalry:\r\r\r...   L  1890.0
# 10495                                         120 men[2]   R  1890.0
# 10496  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10497  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10498  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10499  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10500  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10501  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10502  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10503  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10504  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10505  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10506  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10507  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10508  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10509  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10510  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10511  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10512  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10513  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10514  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10515                                             manual   R  1940.0
# 10516                                             manual   L  1940.0
#
# [10515 rows x 16 columns]

# %%
df_lookup = df_strength_all.drop_duplicates(subset = ['Battle', 'pos'])

# %%
df_lookup.Battle = df_lookup.Battle.str.replace('_', ' ')
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_lookup = pd.concat([df_lookup, pd.DataFrame(arras_1, index = [10515,10516])])

# %%
war_list = []
battle_list = []
def commander_war(general):
#     print general
    war = 0
    global df_battles
    df_dbg = df_run[df_run.belligerent == general]
    df_battles = pd.DataFrame()
    for battle in df_dbg.Battle.unique():


        row = df_dbg[df_dbg.Battle == battle].reset_index(drop = True)
        
        battle = row.loc[0,'Battle']

        df_str = df_lookup[df_lookup.Battle == battle].reset_index(drop = True)
        
        outcome = pd.DataFrame(row.loc[:,'VorD']).iloc[0,0]
        
        
        if row.loc[0, 'pos'] == 'L':
            opp_row = df_str[df_str.pos == 'R']
        if row.loc[0, 'pos'] == 'R':
            opp_row = df_str[df_str.pos == 'L']
            
       
            
        year = row.loc[0, 'year']

        own = row.drop(['Battle', 'Date', 'Location', 'Result', 'belligerent', 'opp', 'own', 'pos', 'VorD', 'year'], axis = 1)

        opp = opp_row.drop(['Battle', 'Date', 'Location', 'Result', 'belligerent', 'opp', 'own', 'pos', 'VorD', 'year'], axis = 1)
        
        opp = opp.rename(columns = {'Infantry':'infantry_opp', 
                                    'Cavalry':'cavalry_opp', 
                                    'Artillery':'artillery_opp', 
                                    'Ships':'ships_opp', 
                                    'Airforce':'airforce_opp',
                                    'Special':'special_opp'})

        opp = opp.reset_index(drop= True)

        pred_row = pd.concat([own, opp], axis = 1)
        
        pred_diff = pd.DataFrame()
        
        pred_diff['infantry_diff'] = (pred_row['Infantry'] - pred_row['infantry_opp']) / (pred_row['Infantry'] + pred_row['infantry_opp'])
        pred_diff['cavalry_dfff'] = (pred_row['Cavalry'] - pred_row['cavalry_opp']) / (pred_row['Cavalry'] + pred_row['cavalry_opp'])
        pred_diff['artillery_diff'] = (pred_row['Artillery'] - pred_row['artillery_opp']) / (pred_row['Artillery'] + pred_row['artillery_opp'])
        pred_diff['ships_diff'] = (pred_row['Ships'] - pred_row['ships_opp']) / (pred_row['Ships'] + pred_row['ships_opp'])
        pred_diff['airforce_diff'] = (pred_row['Airforce'] - pred_row['airforce_opp']) / (pred_row['Airforce'] + pred_row['airforce_opp'])
        pred_diff['special_diff'] = (pred_row['Special'] - pred_row['special_opp']) / (pred_row['Special'] + pred_row['special_opp'])

#         pred_diff = pred_diff.drop(['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special', 'infantry_opp', 'cavalry_opp', 'artillery_opp', 'ships_opp', 'airforce_opp', 'special_opp'], axis = 1)

        pred_diff = pred_diff.fillna(0)

        pred_diff = pred_diff.drop(['artillery_diff', 'special_diff'], axis = 1)
        if battle == 'Siege of Kojinyama':
            print(pred_diff)
            
        df_pred = pd.DataFrame(lr.predict_proba(pred_diff))
        
#         if row.loc[0, 'Infantry'] == 1.0:
        

        if len(df_str) == 1:
            if row.loc[0, 'VorD'] == 'V':
                value = 0.5
#                 print 'UNKNOWN'
            elif row.loc[0, 'VorD'] == 'D':
                value = -.5
#                 print 'UNKNOWN'
            elif row.loc[0, 'VorD'] == 'I':
                value = 0
#                 print 'UNKNOWN'
        else:
            if df_str.Infantry.loc[0] == 1.0 or df_str.Infantry.loc[1] == 1.0:
                if row.loc[0, 'VorD'] == 'V':
                    value = 0.5
#                     print 'UNKNOWN'
                elif row.loc[0, 'VorD'] == 'D':
                    value = -.5
#                     print 'UNKNOWN'
                elif row.loc[0, 'VorD'] == 'I':
                    value = 0
#                     print 'UNKNOWN'
            else:
                if row.loc[0, 'VorD'] == 'V':
                    value = df_pred.iloc[0,0]
                elif row.loc[0, 'VorD'] == 'D':
                    value = 0 - df_pred.iloc[0,1]
                elif row.loc[0, 'VorD'] == 'I':
                    value = .5 - df_pred.iloc[0,1]
        
        

#         print u' '.join(battle).encode('utf-8').strip(' ') +': ' + str(value).encode('utf-8')

        
        
        
        war = war + value
        battle_list.append({'General':general,
                            'Battle': battle,
                            'Value': value,
                            'Year': year,
                            'Outcome': outcome})
        df_battles = pd.DataFrame(battle_list)
        
#     print 'Total: ' + str(war)
#     print u' '.join(general).encode('utf-8').strip(' ') + ': ' + str(war)
#     if len(df_dbg) > 4:
#         war_list.append({'General':general,
#                      'WAR':war})
    war_list.append({'General': general,
                    'WAR': war,
                    'Battles': len(df_dbg)})
    print(war)

# %%
war_list = []
count = 0
for general in df_run.belligerent.unique():
    count += 1
    print(str(general) + ': ' + str(count) + '/' + str(len(df_run.belligerent.unique())))
    commander_war(general)
# Out:
# nan: 1/6620
# 0
# David Ben-Gurion: 2/6620
# 0.968086391
# Yisrael Galili: 3/6620
# 0.462461721355
# Yaakov Dori: 4/6620
# 0.462461721355
# Yigael Yadin: 5/6620
# 0.462461721355
# Mickey Marcus: 6/6620
# 0.462461721355
# Yigal Allon: 7/6620
# 0.462461721355
# Yitzhak Rabin: 8/6620
# 1.02429796446
# David Shaltiel: 9/6620
# 0.462461721355
# Moshe Dayan: 10/6620
# 2.08171069483
# Shimon Avidan: 11/6620
# 0.462461721355
# Moshe Carmel: 12/6620
# 0.462461721355
# Yitzhak Sadeh: 13/6620
# 0.462461721355
# Abdul Rahman Hassan Azzam: 14/6620
# -0.468442418538
# Farouk of Egypt: 15/6620
# -0.468442418538
# Abdullah I of Jordan: 16/6620
# -0.468442418538
# Muzahim al-Pachachi: 17/6620
# -0.468442418538
# Husni al-Za'im: 18/6620
# -0.468442418538
# Amin al-Husseini: 19/6620
# -0.468442418538
# Ahmed Ali al-Mwawi: 20/6620
# -0.468442418538
# Mohammed Naguib: 21/6620
# -0.468442418538
# John Bagot Glubb: 22/6620
# -0.468442418538
# Habis al-Majali: 23/6620
# -0.468442418538
# Hasan Salama: 24/6620
# -0.468442418538
# Arab Liberation Army: 25/6620
# -0.468442418538
# Fawzi al-Qawuqji: 26/6620
# -0.468442418538
# Menachem Begin: 27/6620
# -0.071403319902
# Ariel Sharon: 28/6620
# 2.13611957315
# Rafael Eitan: 29/6620
# -0.071403319902
# David Ivry: 30/6620
# -0.071403319902
# Ze'ev Almog: 31/6620
# -0.071403319902
# Bachir Gemayel: 32/6620
# -0.071403319902
# Fadi Frem: 33/6620
# -0.071403319902
# Elie Hobeika: 34/6620
# -0.071403319902
# Fawzi Mahfuz: 35/6620
# -0.071403319902
# Saad Haddad: 36/6620
# -0.071403319902
# Yasser Arafat: 37/6620
# 0.0655065773299
# Hafez al-Assad: 38/6620
# -0.492218797533
# Mustafa Tlass: 39/6620
# -0.492218797533
# George Hawi: 40/6620
# 0.0655065773299
# Elias Atallah: 41/6620
# 0.0655065773299
# Abbas al-Musawi: 42/6620
# 0.0655065773299
# Ibrahim Kulaylat: 43/6620
# 0.0655065773299
# Nabih Berri: 44/6620
# 0.0655065773299
# Monte Melkonian: 45/6620
# 0.56550657733
# Mahsum Korkmaz: 46/6620
# 0.0655065773299
# Muhsin Ibrahim: 47/6620
# 0.0655065773299
# Ragheb Harb: 48/6620
# 0.0655065773299
# Murat Karayılan: 49/6620
# 0.0655065773299
# Inaam Raad: 50/6620
# 0.0655065773299
# Said Shaaban: 51/6620
# 0.0655065773299
# Chandrika Kumaratunga: 52/6620
# -0.5
# Velupillai Prabhakaran: 53/6620
# -1.93960155244
# Murtala Mohammed: 54/6620
# -0.0844029930714
# Jonathan Uchendu: 55/6620
# 0.578553187827
# Lieutenant colonel (United Kingdom): 56/6620
# 0.0713969247245
# Philip Robert Anstruther: 57/6620
# -0.506615840969
# Commandant-general: 58/6620
# 0.500606766003
# Francois Gerhardus Joubert: 59/6620
# 0.500606766003
# George Kenney: 60/6620
# 0.50052148216
# William Halsey Jr.: 61/6620
# 1.84813112702
# Frederick C. Sherman: 62/6620
# 0.50052148216
# Mineichi Koga: 63/6620
# -0.14275591729
# Jinichi Kusaka: 64/6620
# -0.952988269372
# Gerard Muirhead-Gould: 65/6620
# -0.0611617657351
# Hankyu Sasaki: 66/6620
# 0.0552337949251
# Humayun: 67/6620
# 0.985451505266
# Bairam Khan: 68/6620
# 0.985451505266
# Autaritus: 69/6620
# -0.57179239756
# Hamilcar Barca: 70/6620
# 1.06589694125
# Lieutenant general: 71/6620
# 0.264064281882
# Sarath Fonseka: 72/6620
# 2.93368865038
# Brigadier: 73/6620
# 0.052760887833
# Shavendra Silva: 74/6620
# 1.43368865038
# Major general: 75/6620
# 1.96437319965
# Kamal Gunaratne: 76/6620
# 1.0
# Colonel: 77/6620
# 0.973364584534
# G.V. Ravipriya: 78/6620
# 1.0
# Pottu Amman (Tamil militant): 79/6620
# -1.0
# Theepan: 80/6620
# -1.0
# Sivanadan Somasekaran: 81/6620
# -1.0
# Decius: 82/6620
# -0.5
# Herennius Etruscus: 83/6620
# -0.5
# Cniva: 84/6620
# 1.0
# Thrasybulus: 85/6620
# 2.49845408976
# Thrasyllus: 86/6620
# 1.00664500254
# Mindarus: 87/6620
# -1.51647937633
# Leo Phokas the Elder: 88/6620
# -0.504708375642
# Simeon I of Bulgaria: 89/6620
# 0.998699056953
# Mark Antony: 90/6620
# -0.378776890175
# Gaius Sosius: 91/6620
# -0.521226635176
# Cleopatra: 92/6620
# 0.534845218175
# Marcus Vipsanius Agrippa: 93/6620
# 2.00047080343
# Augustus: 94/6620
# 3.36612188773
# Lucius Arruntius the Elder: 95/6620
# 0.515225231907
# Marcus Lurius: 96/6620
# 0.515225231907
# Belisarius: 97/6620
# 1.61420350892
# John the Armenian: 98/6620
# 1.00961020035
# Gelimer: 99/6620
# -1.02159885089
# Ammatas: 100/6620
# -0.487018287101
# Trajan: 101/6620
# 1.44525025168
# Tsar: 102/6620
# 0.496995305768
# Kaloyan of Bulgaria: 103/6620
# 0.496995305768
# Baldwin I, Latin Emperor: 104/6620
# -0.503004694232
# Licinius: 105/6620
# -0.476839401577
# Constantine the Great: 106/6620
# 2.00500476374
# Fritigern: 107/6620
# 0.456165635255
# Alatheus: 108/6620
# 0.456165635255
# Saphrax: 109/6620
# 0.456165635255
# Valens: 110/6620
# -0.462134910809
# Marcus Atilius Regulus: 111/6620
# 0.431917749267
# Bostar: 112/6620
# -0.451195195888
# Hamilcar (Drepanum): 113/6620
# -0.958420148495
# Hasdrubal: 114/6620
# -0.904297406918
# Lysander: 115/6620
# 0.99197810174
# Aracus (admiral): 116/6620
# 0.501095400823
# Conon: 117/6620
# -0.0142087704451
# Adeimantus (son of Leucolophides): 118/6620
# -0.507104385223
# Gerald FitzGerald, 15th Earl of Desmond: 119/6620
# -0.5
# Thomas Butler, 10th Earl of Ormond: 120/6620
# 0.5
# Quintus Fabius Maximus Verrucosus: 121/6620
# -0.503211454813
# Hannibal: 122/6620
# 5.4609276435
# Ilghazi: 123/6620
# -0.056980905341
# Roger of Salerno: 124/6620
# 0.0
# Charles I of Albret: 125/6620
# -0.557193278078
# Jean Le Maingre: 126/6620
# -1.04186207775
# Charles, Duke of Orléans: 127/6620
# -0.557193278078
# Henry V of England: 128/6620
# 1.05125456817
# Edward of Norwich, 2nd Duke of York: 129/6620
# 0.551254568166
# Humphrey, Duke of Gloucester: 130/6620
# 0.551254568166
# Louis XII of France: 131/6620
# 0.4371588303
# Gian Giacomo Trivulzio: 132/6620
# 0.888137574311
# Louis II de la Trémoille: 133/6620
# 0.357127862177
# Charles II d'Amboise: 134/6620
# 0.4371588303
# Bartolomeo d'Alviano: 135/6620
# -0.0147574896779
# Hanno, son of Hannibal: 136/6620
# -1.03348911905
# Hannibal Gisco: 137/6620
# -0.548808494715
# Lucius Postumius Megellus (consul 262 BC): 138/6620
# 0.508542310503
# Quintus Mamilius Vitulus: 139/6620
# 0.508542310503
# Qutuz: 140/6620
# 0.466870407982
# Baibars: 141/6620
# 0.466870407982
# Kitbuqa: 142/6620
# -0.0234410743836
# Theodore (brother of Heraclius): 143/6620
# -0.0617003159166
# Khalid ibn al-Walid: 144/6620
# 5.61683495709
# Abu Ubaidah ibn al-Jarrah: 145/6620
# 1.51077592356
# 'Amr ibn al-'As: 146/6620
# 0.904586693451
# Shurahbil ibn Hasana: 147/6620
# 1.49399061154
# Yazid ibn Abi Sufyan: 148/6620
# 0.993990611536
# Dhiraar bin Al-Azwar: 149/6620
# 0.993990611536
# Musaylimah: 150/6620
# -0.555718262743
# Abu Dujana: 151/6620
# 0.549775755079
# Abdallah al-Battal: 152/6620
# -0.5
# Al-Malik ibn Shu'aib: 153/6620
# -0.5
# Leo III the Isaurian: 154/6620
# 0.5
# Constantine V: 155/6620
# 1.42084812276
# Tang Jiahui: 156/6620
# 0.5
# Ashina Xin: 157/6620
# 0.5
# Wikipedia:Accuracy dispute: 158/6620
# -0.0201791798205
# Talk:Battle of Aksu (717): 159/6620
# 0.5
# Ashina Xian: 160/6620
# 0.5
# Alfonso VIII of Castile: 161/6620
# 0.0315967254685
# Diego López II de Haro: 162/6620
# 0.0315967254685
# Abu Yusuf Yaqub al-Mansur: 163/6620
# 0.5
# Pedro Fernández de Castro (died 1214): 164/6620
# 0.5
# Nicolas Le Nen: 165/6620
# 0.5
# Col. Hussein: 166/6620
# 0.5
# Lt Colonel Sean D Wester (USMC): 167/6620
# 0.5
# Shirkuh: 168/6620
# 0
# Saladin: 169/6620
# -0.575657205457
# Amalric of Jerusalem: 170/6620
# 0
# Abu Marwan Abd al-Malik I Saadi: 171/6620
# 0.445009220667
# Ahmad al-Mansur: 172/6620
# 0.445009220667
# Sebastian of Portugal: 173/6620
# -0.450953562734
# Abu Abdallah Mohammed II Saadi: 174/6620
# -0.450953562734
# Thomas Stukley: 175/6620
# -0.450953562734
# Vercingetorix: 176/6620
# -1.04140542515
# Commius: 177/6620
# -0.528955009952
# Julius Caesar: 178/6620
# 7.33541147929
# Afonso V of Portugal: 179/6620
# 0.417360928803
# Afonso I, Duke of Braganza: 180/6620
# 0.423367584534
# Peter, Duke of Coimbra: 181/6620
# -0.429246428669
# Guy of Lusignan: 182/6620
# 0.512338715425
# John I of Castile: 183/6620
# -0.585820507783
# Pedro Álvares Pereira: 184/6620
# -1.15503299052
# John I of Portugal: 185/6620
# 1.07997631471
# Nuno Álvares Pereira: 186/6620
# 1.14328494869
# Murray of Aberscross: 187/6620
# 0.5
# Donald Mackay, 11th of Strathnaver: 188/6620
# -0.5
# Ranulf de Glanvill: 189/6620
# 0.42084812276
# William the Lion: 190/6620
# -0.42671787139
# Baldwin I of Jerusalem: 191/6620
# 0.525233873901
# Mawdud: 192/6620
# 0.5
# Toghtekin: 193/6620
# -1.52539930663
# Dawit II: 194/6620
# -1.0
# Ahmad ibn Ibrahim al-Ghazi: 195/6620
# 0.442195022586
# Brasidas: 196/6620
# -0.562784555398
# Cleon: 197/6620
# 0.00854231050338
# Nicias: 198/6620
# -0.491457689497
# Thucydides: 199/6620
# -0.491457689497
# Tervel of Bulgaria: 200/6620
# 0.5
# Justinian II: 201/6620
# -0.5
# Telets of Bulgaria: 202/6620
# -0.5
# William Eure, 1st Baron Eure: 203/6620
# -0.539366369433
# Brian Layton: 204/6620
# -0.539366369433
# James Hamilton, Duke of Châtellerault: 205/6620
# 0.00273790570343
# Archibald Douglas, 6th Earl of Angus: 206/6620
# 0.00273790570343
# Sophron of Ephesus: 207/6620
# -0.5
# Ptolemy Andromachou: 208/6620
# -0.5
# Antigonus II Gonatas: 209/6620
# 0.5
# Oda Nobunaga: 210/6620
# 4.2111172206
# Tokugawa Ieyasu: 211/6620
# 1.31209692797
# Inaba Yoshimichi: 212/6620
# 0.474423948637
# Azai Nagamasa: 213/6620
# -0.864841212234
# Asakura Yoshikage: 214/6620
# -1.38106202307
# Timur: 215/6620
# 0.471620485556
# Shahrukh Mirza: 216/6620
# 0.471620485556
# Khalil Sultan: 217/6620
# 0.471620485556
# Miran Shah: 218/6620
# 0.471620485556
# Abu Bakr (Timurid): 219/6620
# 0.471620485556
# Sultan Huseyn: 220/6620
# 0.471620485556
# Pir Muhammad ibn Jahangir: 221/6620
# 0.471620485556
# Taj al-Din Shah-i Shahan Abu'l Fath: 222/6620
# 0.471620485556
# Bayezid I: 223/6620
# -0.0257632219095
# Süleyman Çelebi: 224/6620
# -0.477614386678
# Mehmed I: 225/6620
# -0.477614386678
# Stefan Lazarević: 226/6620
# 0.00105310280299
# Gannys: 227/6620
# 0.5
# Heraclius: 228/6620
# -0.692535696132
# Shahrbaraz: 229/6620
# 0.42084812276
# Shahin Vahmanzadegan: 230/6620
# 0.5
# Eslamu: 231/6620
# -0.58607339499
# Fatagar: 232/6620
# -0.58607339499
# Theophilos (emperor): 233/6620
# -0.516554874731
# Theophobos: 234/6620
# -0.516554874731
# Manuel the Armenian: 235/6620
# -0.516554874731
# Khaydhar ibn Kawus al-Afshin: 236/6620
# 0.510549901337
# Umar al-Aqta: 237/6620
# 0.510549901337
# Jaysh ibn Samsama: 238/6620
# 0.5
# Damian Dalassenos: 239/6620
# -0.5
# Teutobod: 240/6620
# 0.310706162768
# Gaius Marius: 241/6620
# 1.07814887359
# Germanic kingship: 242/6620
# 0.452596276551
# Boiorix: 243/6620
# 0.298891221917
# Quintus Servilius Caepio: 244/6620
# -0.458558228075
# Gnaeus Mallius Maximus: 245/6620
# -0.458558228075
# Francesco Bussone da Carmagnola: 246/6620
# 0.0
# Bardas Skleros: 247/6620
# 0.5
# Peter (stratopedarches): 248/6620
# 0.5
# Thomas le Botiller: 249/6620
# -0.5
# William MacGeoghegan: 250/6620
# 0.5
# Rhydderch Hael: 251/6620
# 0.5
# Peredur: 252/6620
# 0.5
# Gwenddoleu ap Ceidio: 253/6620
# -0.5
# Priarius: 254/6620
# -0.5
# Mallobaudes: 255/6620
# 0.5
# Nannienus: 256/6620
# 0.5
# Callicratidas: 257/6620
# 0.5
# John Kingston (sailor): 258/6620
# -0.388482773967
# Nicolas Béhuchet: 259/6620
# -0.140614816258
# Hugues Quiéret: 260/6620
# -0.140614816258
# Lucius Caecilius Metellus Denter: 261/6620
# -0.5
# Britomaris: 262/6620
# 0.5
# Richard I of England: 263/6620
# 1.48545150527
# Hugh III, Duke of Burgundy: 264/6620
# 0.5
# Garnier de Nablus: 265/6620
# 0.0268872101588
# Robert IV of Sablé: 266/6620
# 0.985451505266
# James of Avesnes: 267/6620
# 0.5
# Al-Adil I: 268/6620
# -0.575657205457
# Al-Afdal ibn Salah ad-Din: 269/6620
# -0.0328751350917
# Al-Muzaffar Umar: 270/6620
# -0.0841995159602
# Tancred, Prince of Galilee: 271/6620
# 2.02279693671
# Fakhr al-Mulk Radwan: 272/6620
# -1.02539930663
# Eurybiades: 273/6620
# 0.597021150637
# Themistocles: 274/6620
# 1.13846292256
# Adeimantus of Corinth: 275/6620
# 0.0869813530246
# Achaemenes (satrap): 276/6620
# -0.608841607794
# Ariabignes: 277/6620
# -0.608841607794
# Artemisia I of Caria: 278/6620
# -0.608841607794
# Damasithymus: 279/6620
# -0.608841607794
# Al-Afdal Shahanshah: 280/6620
# -0.567069033635
# Godfrey of Bouillon: 281/6620
# 2.45559562904
# Raymond IV, Count of Toulouse: 282/6620
# 2.02279693671
# Robert Curthose: 283/6620
# 2.02279693671
# Robert II, Count of Flanders: 284/6620
# 2.02279693671
# Eustace III, Count of Boulogne: 285/6620
# 0.558144704652
# Gaston IV, Viscount of Béarn: 286/6620
# 1.07754668503
# Publius Decius Mus (consul 279 BC): 287/6620
# 0.496995305768
# Pyrrhus of Epirus: 288/6620
# -0.53871182749
# Pompeius Strabo: 289/6620
# 0.485451505266
# Judacilius: 290/6620
# -0.491457689497
# Fernando Sánchez de Tovar: 291/6620
# -0.569212482733
# Pero Gonzalez de Sevilla: 292/6620
# -0.569212482733
# Martim Anes de Barundo: 293/6620
# -0.569212482733
# Henry of Grosmont, 1st Duke of Lancaster: 294/6620
# 0.5
# Charles, Duke of Brittany: 295/6620
# -1.15330261771
# John IV, Duke of Brittany: 296/6620
# 0.503923912343
# John Chandos: 297/6620
# 1.03145919208
# Mushkin Niusalavurd: 298/6620
# 0.43001330423
# Mihr Narseh: 299/6620
# 0.43001330423
# Izad Gushnasp: 300/6620
# 0.43001330423
# Ashtat: 301/6620
# 0.43001330423
# Vardan Mamikonian: 302/6620
# -0.435914668251
# Jakob Henriksson Hästesko: 303/6620
# -0.527553470075
# Daniel Rantzau: 304/6620
# -0.0166338652164
# Hengist and Horsa: 305/6620
# 0
# Vortigern: 306/6620
# 0
# Vortimer: 307/6620
# 0
# Catigern: 308/6620
# 0
# Husayn ibn Numayr al-Sakuni: 309/6620
# 0.5
# Udi Adam: 310/6620
# -0.5
# Gal Hirsch: 311/6620
# -0.5
# Romanos III Argyros: 312/6620
# -0.592707253402
# Shibl al-Dawla Nasr: 313/6620
# 0.586891709269
# Baldwin II of Jerusalem: 314/6620
# 1.0
# Leo I, Prince of Armenia: 315/6620
# 0.5
# Joscelin I, Count of Edessa: 316/6620
# 0.0
# Pons, Count of Tripoli: 317/6620
# 0.5
# Alfonso VI of León and Castile: 318/6620
# -0.5
# Álvar Fáñez: 319/6620
# -0.5
# Sancho Ramírez: 320/6620
# -0.5
# Yusuf ibn Tashfin: 321/6620
# 0.5
# Al-Mu'tamid ibn Abbad: 322/6620
# 0.5
# Abdallah ibn Buluggin: 323/6620
# 0.5
# Amr ibn Hishām: 324/6620
# -0.569455129973
# Utbah ibn Rabi'ah: 325/6620
# -0.569455129973
# Umayyah ibn Khalaf: 326/6620
# -0.569455129973
# Hind bint Utbah: 327/6620
# -0.569455129973
# Muhammad: 328/6620
# 1.19988729039
# Hamza ibn Abdul-Muttalib: 329/6620
# 0.647126402557
# Ali: 330/6620
# 1.71766123752
# Abu Bakr: 331/6620
# 1.11631294467
# Umar: 332/6620
# 1.11631294467
# Scipio Africanus: 333/6620
# 2.49013903162
# Hasdrubal Barca: 334/6620
# -0.961835335906
# Abe no Hirafu: 335/6620
# -0.646578849265
# Buyeo Pung: 336/6620
# -0.646578849265
# Liu Rengui: 337/6620
# 0.641066693824
# Munmu of Silla: 338/6620
# 0.641066693824
# Buyeo Yung: 339/6620
# 0.641066693824
# Wenceslaus I, Duke of Luxembourg: 340/6620
# -0.525795895619
# William I, Marquis of Namur: 341/6620
# -0.525795895619
# William II, Duke of Jülich: 342/6620
# 0.51979900049
# Edward, Duke of Guelders: 343/6620
# 0.51979900049
# Hasdrubal Gisco: 344/6620
# -0.511582676038
# Syphax: 345/6620
# -0.5
# Masinissa: 346/6620
# 1.00298593065
# Gaius Laelius: 347/6620
# 0.5
# Hulagu Khan: 348/6620
# 0.449416891158
# Arghun Aqa: 349/6620
# 0.449416891158
# Baiju: 350/6620
# 0.449416891158
# Buqa-Temür: 351/6620
# 0.449416891158
# Sunitai: 352/6620
# 0.449416891158
# Guo Kan: 353/6620
# 0.858887647998
# Koke Ilge: 354/6620
# 0.449416891158
# Al-Musta'sim: 355/6620
# -0.455371801406
# Capital punishment: 356/6620
# -4.83901061884
# Mujaheduddin: 357/6620
# -0.455371801406
# Sulaiman Shah: 358/6620
# -0.455371801406
# Qarasunqur: 359/6620
# -0.455371801406
# Al-Ashraf Musa, Sultan of Egypt: 360/6620
# -0.455371801406
# Nang Wa: 361/6620
# -0.583864676763
# Shen Yin Shu: 362/6620
# -0.583864676763
# Helü: 363/6620
# 0.578012765694
# Fugai: 364/6620
# 0.578012765694
# Wu Zixu: 365/6620
# 0.578012765694
# Sun Tzu: 366/6620
# 0.578012765694
# Matthias Corvinus: 367/6620
# -0.52236673129
# Stephen III of Moldavia: 368/6620
# 2.06326414772
# Modu Chanyu: 369/6620
# 0.485451505266
# Emperor Gaozu of Han: 370/6620
# -0.0700220559111
# List of Khazar rulers: 371/6620
# 0.5
# Abd ar-Rahman ibn Rabiah: 372/6620
# -0.5
# Al-Jarrah ibn Abdallah: 373/6620
# 0.5
# Charles the Bald: 374/6620
# -0.057754442556
# Nominoe: 375/6620
# 0.548804804112
# Mohamud Muse Hersi: 376/6620
# 0.5
# Abdulrahman Said Dhegaweyne: 377/6620
# 0.5
# Abdi Hasan Awale Qeybdiid: 378/6620
# 0.5
# Mohamed Mohamud Agaweine: 379/6620
# -0.5
# Daou al-Salhine al-Jadak: 380/6620
# 0.452596276551
# Musa Yunis: 381/6620
# 0.452596276551
# Saif al-Islam Gaddafi: 382/6620
# -0.97310672281
# Tarik Sulayman: 383/6620
# -0.543313448018
# Rajah Sulayman: 384/6620
# -0.543313448018
# Miguel López de Legazpi: 385/6620
# 0.537343154959
# Edward II of England: 386/6620
# -0.0487185904037
# Humphrey de Bohun, 4th Earl of Hereford: 387/6620
# -0.98964204282
# Aymer de Valence, 2nd Earl of Pembroke: 388/6620
# -0.602737040835
# Gilbert de Clare, 8th Earl of Gloucester: 389/6620
# -0.548718590404
# Robert de Clifford, 1st Baron de Clifford: 390/6620
# -0.548718590404
# Robert the Bruce: 391/6620
# 0.58488347085
# Edward Bruce: 392/6620
# 0.124060977039
# Robert II Keith, Marischal of Scotland: 393/6620
# -0.0319058220954
# James Douglas, Lord of Douglas: 394/6620
# 0.542759491743
# Thomas Randolph, 1st Earl of Moray: 395/6620
# 0.542759491743
# Yan Emperor: 396/6620
# 0.0262017968678
# Yellow Emperor: 397/6620
# 1.02620179687
# Osman I: 398/6620
# 0.5
# Shapur I: 399/6620
# 1.5
# Richard Neville, 16th Earl of Warwick: 400/6620
# -0.0571034358698
# John Neville, 1st Marquess of Montagu: 401/6620
# 0.986016718255
# Henry Holland, 3rd Duke of Exeter: 402/6620
# -1.04479311029
# John de Vere, 13th Earl of Oxford: 403/6620
# 0.460871392972
# Edward IV of England: 404/6620
# 3.04187722093
# Richard III of England: 405/6620
# 0.512448326322
# William Hastings, 1st Baron Hastings: 406/6620
# 1.03622128846
# Suleiman II (Rûm): 407/6620
# -0.535763819116
# David Soslan: 408/6620
# 0.529780248061
# Zakarids-Mkhargrzeli: 409/6620
# 0.529780248061
# Shalva of Akhaltsikhe: 410/6620
# 0.529780248061
# Nouri al-Maliki: 411/6620
# -0.034580563787
# Ali Ghaidan Majid: 412/6620
# -0.034580563787
# Mohan al-Furayji: 413/6620
# -0.034580563787
# Fadhil Jalil al-Barwari: 414/6620
# -0.034580563787
# Muqtada al-Sadr: 415/6620
# 0.52859516069
# Shiek Ali al-Sauidi: 416/6620
# 0.0285951606897
# Akram al-Kabi: 417/6620
# 0.0285951606897
# Yusuf al-Mosawi: 418/6620
# 0.0285951606897
# John Stewart, Earl of Buchan: 419/6620
# -0.625227989288
# Gilbert Motier de La Fayette: 420/6620
# 0.441304378315
# List of Marshals of France: 421/6620
# 0.441304378315
# Thomas of Lancaster, 1st Duke of Clarence: 422/6620
# -0.447239112167
# Thomas Beaufort, Duke of Exeter: 423/6620
# -0.447239112167
# John Beaufort, 1st Duke of Somerset: 424/6620
# -0.447239112167
# Zhang Fei: 425/6620
# 1.04880480411
# Zhang He: 426/6620
# -0.0311341856853
# Baldwin IV of Jerusalem: 427/6620
# 0.045371182389
# Baldwin of Ibelin: 428/6620
# 0
# Balian of Ibelin: 429/6620
# -0.973112789841
# Hugh II of Saint Omer: 430/6620
# 0
# Gökböri: 431/6620
# 0.880631328004
# Charles I of Naples: 432/6620
# 0.5
# Manfred, King of Sicily: 433/6620
# -0.5
# Quintus Fulvius Flaccus (consul 237 BC): 434/6620
# -0.0547750403194
# Hanno the Elder: 435/6620
# -0.987934456472
# Tiberius Sempronius Gracchus (consul 215 BC): 436/6620
# 0.497569492331
# Manius Curius Dentatus: 437/6620
# 0.5
# John II Komnenos: 438/6620
# 0.5
# Telerig of Bulgaria: 439/6620
# -0.42671787139
# Seron (Syrian governor): 440/6620
# -0.564993428085
# Judas Maccabeus: 441/6620
# 2.2987893318
# Cestius Gallus: 442/6620
# -0.5
# Simon bar Giora: 443/6620
# 0.0460944199319
# Lysias (Syrian chancellor): 444/6620
# -1.0849810811
# Eleazar Avaran: 445/6620
# 0.541441771925
# Mirza Aziz Koka: 446/6620
# 0.5
# Sunshu Ao: 447/6620
# 0.5
# Zi Zhong: 448/6620
# 0.5
# Zi Fan: 449/6620
# 0.5
# Xun Linfu: 450/6620
# -0.5
# Shi Hui (Spring and Autumn period): 451/6620
# -0.5
# Zhao Shuo: 452/6620
# -0.5
# Divico: 453/6620
# -0.532652720588
# Odet of Foix, Viscount of Lautrec: 454/6620
# -0.519913167543
# Anne de Montmorency: 455/6620
# -0.504482690434
# Georg von Frundsberg: 456/6620
# 1.53542131626
# Fernando d'Avalos: 457/6620
# 1.53542131626
# Prospero Colonna: 458/6620
# 1.03216989089
# Abdul Fatah Younis: 459/6620
# -1.50600938846
# Shoshenq I: 460/6620
# 0.5
# Edward III of England: 461/6620
# 2.34864148498
# Godemar du Foy: 462/6620
# -0.484668799667
# John Babonić: 463/6620
# 0.5
# Ban of Slavonia: 464/6620
# 0.5
# Paul II Šubić of Bribir: 465/6620
# 0.5
# Mladen II Šubić of Bribir: 466/6620
# -0.5
# Ban of Croatia: 467/6620
# -0.5
# George II Šubić of Bribir: 468/6620
# -0.5
# John of Islay, Earl of Ross: 469/6620
# -0.5
# Aonghas Óg: 470/6620
# 0.5
# James Tuchet, 5th Baron Audley: 471/6620
# -0.537577357652
# John Sutton, 1st Baron Dudley: 472/6620
# -0.537577357652
# Richard Neville, 5th Earl of Salisbury: 473/6620
# 0.515789727488
# Thomas Neville: 474/6620
# 0.531596725468
# Algirdas: 475/6620
# 0.476227037861
# Fyodor Koriatovych: 476/6620
# 0.476227037861
# Demetrius, Prince of the Tatars: 477/6620
# -0.482226052871
# Tonyukuk: 478/6620
# 0.5
# Robert Fyssher: 479/6620
# 0.443998349359
# Le Seigneur de Tais: 480/6620
# -0.449940135527
# Jakob Bagge: 481/6620
# 0.452602089329
# Jacob Brockenhuus: 482/6620
# -0.45856405328
# Andrew Harclay, 1st Earl of Carlisle: 483/6620
# 0.435006571915
# John Peche: 484/6620
# 0.435006571915
# Thomas, 2nd Earl of Lancaster: 485/6620
# -0.940923452417
# Roger de Clifford, 2nd Baron de Clifford: 486/6620
# -0.440923452417
# John Howard, 1st Duke of Norfolk: 487/6620
# -0.523772962139
# Henry Percy, 4th Earl of Northumberland: 488/6620
# -0.523772962139
# John de la Pole, 1st Earl of Lincoln: 489/6620
# -1.00599901501
# Thomas Howard, 2nd Duke of Norfolk: 490/6620
# -0.0114461311097
# Francis Lovell, 1st Viscount Lovell: 491/6620
# -0.523772962139
# Henry VII of England: 492/6620
# 0.99400098499
# Jasper Tudor, Duke of Bedford: 493/6620
# 0.49400098499
# Gilbert Talbot (soldier): 494/6620
# 0.517773947129
# Philibert de Chandée, 1st Earl of Bath: 495/6620
# 0.517773947129
# Rhys ap Thomas: 496/6620
# 0.517773947129
# Otto IV, Holy Roman Emperor: 497/6620
# -0.517714549684
# William Longespée, 3rd Earl of Salisbury: 498/6620
# 0.0569924844388
# Renaud I, Count of Dammartin: 499/6620
# -0.517714549684
# Ferdinand, Count of Flanders: 500/6620
# -0.517714549684
# Theobald I, Duke of Lorraine: 501/6620
# -0.517714549684
# Henry I, Duke of Brabant: 502/6620
# -0.517714549684
# Philip II of France: 503/6620
# 0.416590347226
# Robert II, Count of Dreux: 504/6620
# 0.51171036449
# Philip of Dreux: 505/6620
# 0.51171036449
# Odo III, Duke of Burgundy: 506/6620
# 0.51171036449
# William IV, Count of Ponthieu: 507/6620
# 0.51171036449
# Thomas de Rokeby: 508/6620
# 0.5
# Henry Percy, 1st Earl of Northumberland: 509/6620
# -0.0313084920037
# Pál Kinizsi: 510/6620
# 0.495034473425
# Bartholomew Drágfi: 511/6620
# 0.495034473425
# Stephen V Báthory: 512/6620
# 0.495034473425
# Vuk Grgurević: 513/6620
# 0.495034473425
# Demetrius Jaksics: 514/6620
# 0.495034473425
# Basarab Laiotă cel Bătrân: 515/6620
# -0.057812913863
# Basarab Țepeluș cel Tânăr: 516/6620
# -0.50104376946
# Suleiman Mahmoud: 517/6620
# -0.00300469423196
# Mutassim Gaddafi: 518/6620
# -0.452870133216
# William de Bohun, 1st Earl of Northampton: 519/6620
# 0.371128471462
# Carlo Grimaldi: 520/6620
# -0.376755876443
# Seguin de Badefol: 521/6620
# 0.485451505266
# Petit Meschin: 522/6620
# 0.485451505266
# James I, Count of La Marche: 523/6620
# -0.491457689497
# Charles de Mornay: 524/6620
# 0.532212842522
# Julian (emperor): 525/6620
# 1.52628484537
# Æthelstan: 526/6620
# 0.5
# Edmund I: 527/6620
# 0.5
# Olaf Guthfrithson: 528/6620
# -0.5
# Constantine II of Scotland: 529/6620
# -0.5
# Owain ap Dyfnwal (fl. 934): 530/6620
# -0.5
# Sten Sture the Elder: 531/6620
# 0.477920298894
# Christian I of Denmark: 532/6620
# -0.483920936824
# Charles the Bold: 533/6620
# -0.945252698241
# Raes van Heers: 534/6620
# -0.466538574835
# Edmund Mortimer (1376-1409): 535/6620
# -0.517844412733
# Owain Glyndŵr: 536/6620
# 1.01184031983
# Shōni Sukeyoshi: 537/6620
# 0.5
# 少弐資能: 538/6620
# 0.5
# Ōtomo Yoriyasu: 539/6620
# 0.5
# 大友頼泰: 540/6620
# 0.5
# Kikuchi Takefusa: 541/6620
# 0.5
# Takezaki Suenaga: 542/6620
# 0.5
# Hindun: 543/6620
# -0.5
# 忻都 - 维基百科，自由的百科全书: 544/6620
# -0.5
# Liu Fuheng: 545/6620
# -0.5
# Kim Bang-gyeong: 546/6620
# -0.5
# 김방경 - 위키백과, 우리 모두의 백과사전: 547/6620
# -0.5
# Yi Sun-sin: 548/6620
# 2.69625151877
# Won Gyun: 549/6620
# 1.14701699992
# Yi Eokgi: 550/6620
# 0.667947573296
# Jeong Un: 551/6620
# 0.565215054853
# 정운 - 위키백과, 우리 모두의 백과사전: 552/6620
# 0.565215054853
# Wakisaka Yasuharu: 553/6620
# -1.30380414215
# Kuki Yoshitaka: 554/6620
# -0.727718446353
# Tōdō Takatora: 555/6620
# -1.26697305794
# Katō Yoshiaki: 556/6620
# -0.281901970614
# Æthelred, Lord of the Mercians: 557/6620
# 0.0
# Hastein: 558/6620
# -0.5
# Lan Yu (general): 559/6620
# 0.5
# Uskhal Khan Tögüs Temür: 560/6620
# -0.5
# Maximilian III, Archduke of Austria: 561/6620
# -0.970808418812
# Jan Zamoyski: 562/6620
# 0.501152501539
# Tachibana Muneshige: 563/6620
# 0.405636057216
# Ukita Hideie: 564/6620
# 0.731775778216
# Kobayakawa Takakage: 565/6620
# 1.37984322508
# Li Rusong: 566/6620
# -0.468403274532
# Rhys Gryg: 567/6620
# 0.5
# Stephen Bauzan: 568/6620
# -0.5
# Walter Manny, 1st Baron Manny: 569/6620
# 0.5
# Guy, Bastard of Flanders: 570/6620
# -0.5
# Raoul II of Brienne, Count of Eu: 571/6620
# -0.422792208712
# Publius Ostorius Scapula: 572/6620
# 0.5
# Caratacus: 573/6620
# -1.05869562168
# Atahualpa: 574/6620
# -0.092151023753
# Francisco Pizarro: 575/6620
# 1.48553675162
# Hernando Pizarro: 576/6620
# 1.05736492159
# Gonzalo Pizarro: 577/6620
# 1.56036961582
# Juan Pizarro (conquistador): 578/6620
# 1.48553675162
# Hernando de Soto: 579/6620
# 1.08633308052
# Fínghin Mac Carthaigh: 580/6620
# 0.5
# John FitzGerald, 1st Baron Desmond: 581/6620
# -0.5
# Hermogenes (magister officiorum): 582/6620
# 0.0436007595109
# Sunicas: 583/6620
# 0.0436007595109
# Al-Harith ibn Jabalah: 584/6620
# -0.487995965958
# Azarethes: 585/6620
# 0.481991990482
# Al-Mundhir III ibn al-Nu'man: 586/6620
# 0.481991990482
# Aimery IV of Narbonne: 587/6620
# 0.488657731528
# Guillaume da Durfort: 588/6620
# 0.488657731528
# Guglielmino Ubertini: 589/6620
# -0.494665448622
# Pandolfo II Malatesta: 590/6620
# 0.427670480738
# Konrad von Landau: 591/6620
# -0.433564149354
# Boudica: 592/6620
# -0.162021854036
# Quintus Petillius Cerialis: 593/6620
# -0.440923452417
# Murong Bao: 594/6620
# -0.564328760313
# Murong Nong: 595/6620
# -0.564328760313
# Murong Lin: 596/6620
# -0.564328760313
# Murong De: 597/6620
# -0.564328760313
# Emperor Daowu of Northern Wei: 598/6620
# 0.558409905184
# Gaius Terentius Varro: 599/6620
# -0.532112229902
# Lucius Aemilius Paullus (consul 219 BC): 600/6620
# -0.532112229902
# Maharbal: 601/6620
# 0.526123222219
# Mago Barca: 602/6620
# 0.0209837181477
# Gisgo: 603/6620
# 0.526123222219
# Hanno, son of Bomilcar: 604/6620
# 0.526123222219
# Hasdrubal (quartermaster): 605/6620
# 0.526123222219
# Marcus Claudius Marcellus: 606/6620
# 0.485451505266
# Lucius Manlius Vulso Longus: 607/6620
# 0.501215992325
# Hanno the Great: 608/6620
# -1.00722495261
# Appius Claudius Pulcher (consul 212 BC): 609/6620
# -0.533129592018
# Francesco I Sforza: 610/6620
# 1.43336725146
# Micheletto Attendolo: 611/6620
# 0.0280834568882
# William Kirkcaldy of Grange: 612/6620
# 1.0147692529
# James Hepburn, 4th Earl of Bothwell: 613/6620
# -0.503004694232
# Necho II: 614/6620
# -0.542325243158
# Nebuchadnezzar II: 615/6620
# 2.03635305579
# Marcus Licinius Crassus: 616/6620
# -0.492283149229
# Publius Licinius Crassus (son of triumvir): 617/6620
# -0.492283149229
# Gaius Cassius Longinus: 618/6620
# -1.47650869877
# Surena: 619/6620
# 0.486276523307
# Hasan ibn al-Nu'man: 620/6620
# 0.5
# Tiberios III: 621/6620
# -0.5
# Hasdrubal the Boetharch: 622/6620
# -0.5
# Scipio Aemilianus: 623/6620
# 1.0
# Manius Manilius: 624/6620
# 0.5
# Alberico da Barbiano: 625/6620
# 0.5
# Muzio Sforza: 626/6620
# -0.0295631264638
# Galeotto I Malatesta: 627/6620
# 0.458119558182
# John Hawkwood: 628/6620
# 0.0565116595446
# Hanneken von Baumgarten: 629/6620
# -0.464092582825
# Azzo VII d'Este: 630/6620
# 0.5
# Ezzelino III da Romano: 631/6620
# -0.5
# Nicolaas Zannekin: 632/6620
# -0.503004694232
# Philip VI of France: 633/6620
# 0.496995305768
# Giovanni Ordelaffi: 634/6620
# -0.526600239852
# Da Polenta family: 635/6620
# -0.526600239852
# Giovanni dell'Ischia: 636/6620
# -0.526600239852
# Francesco Novello da Carrara: 637/6620
# 0.52060424237
# Jean Bureau: 638/6620
# 0.493846160668
# John Talbot, 1st Earl of Shrewsbury: 639/6620
# -1.55855093241
# Leptines of Syracuse: 640/6620
# 0.536482319111
# Mieszko I of Poland: 641/6620
# 0.482155587267
# Czcibor: 642/6620
# 0.482155587267
# Odo I, Margrave of the Saxon Ostmark: 643/6620
# -0.488159680167
# Nasar: 644/6620
# 0.923899619029
# Ibn al-Hawas: 645/6620
# -0.62597778934
# Roger I of Sicily: 646/6620
# 0.620332996853
# Serlo II of Hauteville: 647/6620
# 0.620332996853
# Alfonso d'Avalos: 648/6620
# -0.511645917167
# Francis, Count of Enghien: 649/6620
# 1.00563832404
# Louis d'Armagnac, Duke of Nemours: 650/6620
# -0.524257761446
# Yves d'Alègre: 651/6620
# -0.524257761446
# Pierre Terrail, seigneur de Bayard: 652/6620
# -0.524257761446
# Gonzalo Fernández de Córdoba: 653/6620
# 1.44261728876
# Pedro Navarro, Count of Oliveto: 654/6620
# 0.0339036529133
# Fabrizio Colonna: 655/6620
# 0.0339036529133
# Prince Henry the Navigator: 656/6620
# 0.5
# Chares of Athens: 657/6620
# -1.0109976371
# Lysicles (4th century BC): 658/6620
# -0.510997637099
# Athens: 659/6620
# -0.510997637099
# Theagenes (general): 660/6620
# -0.510997637099
# Philip II of Macedon: 661/6620
# 0.504989784676
# Alexander the Great: 662/6620
# 4.36214640505
# Archelaus (general): 663/6620
# -1.63678582564
# Sulla: 664/6620
# 1.62497348883
# Constantine I of Georgia: 665/6620
# -0.5
# Ibrahim I of Shirvan: 666/6620
# -0.5
# Syed Ahmed Orlat: 667/6620
# -0.5
# Qara Yusuf: 668/6620
# 0.5
# Yar Ahmed Qaramanli: 669/6620
# 0.5
# Jagath Jayasuriya: 670/6620
# 0.933688650378
# Prasanna Silva: 671/6620
# 0.5
# Vinayagam: 672/6620
# -0.5
# Selim I: 673/6620
# 1.48689701003
# Hasan Pasha (Ottoman commander): 674/6620
# 0.482155587267
# Ismail I: 675/6620
# -0.488159680167
# Abd al-Baqi Yazdi: 676/6620
# -0.488159680167
# Hossein Beg Laleh Shamlu: 677/6620
# -0.488159680167
# Saru Pira Ustajlu: 678/6620
# -0.488159680167
# Durmish Khan Shamlu: 679/6620
# -0.488159680167
# Nur-Ali Khalifa: 680/6620
# -0.488159680167
# Mohammad Khan Ustajlu: 681/6620
# -0.488159680167
# Sayyed Sharif al-Din Ali Shirazi: 682/6620
# -0.488159680167
# John of Montfort: 683/6620
# -0.5
# Bai Qi: 684/6620
# 1.01820211576
# Lian Po: 685/6620
# -0.492612183151
# Zhao Kuo: 686/6620
# -0.492612183151
# Cheng Dechen: 687/6620
# -0.5
# Zishang: 688/6620
# -0.5
# Zixi (Zhou dynasty): 689/6620
# -0.5
# Hu Mao: 690/6620
# 0.5
# Hu Yan: 691/6620
# 0.5
# Xian Zhen: 692/6620
# 0.5
# Xi Zhen: 693/6620
# 0.5
# Xu Chen (Zhou dynasty): 694/6620
# 0.5
# Luan Zhi: 695/6620
# 0.5
# Konishi Yukinaga: 696/6620
# 1.68405316475
# Shimazu Yoshihiro: 697/6620
# 0.94836996682
# Choe Ho: 698/6620
# -0.413168853002
# Bae Seol: 699/6620
# -0.413168853002
# Chalcuchimac: 700/6620
# 1.00498978468
# Quizquiz: 701/6620
# 0.504989784676
# Rumiñawi (Inca warrior): 702/6620
# 0.5
# Inca Empire: 703/6620
# -0.5
# Atoc: 704/6620
# -0.5
# Hango (general): 705/6620
# -0.5
# Ullco Colla: 706/6620
# -0.5
# Albert of Schwarzburg: 707/6620
# 0.489699880164
# Mehmed Beg: 708/6620
# -0.495707989001
# Philip V of Macedon: 709/6620
# -1.03826546475
# Attalus I: 710/6620
# 0.544710409938
# Theophiliscus: 711/6620
# 0.544710409938
# Bertrand du Guesclin: 712/6620
# 1.4990115322
# John Devereux, 1st Baron Devereux: 713/6620
# -0.46526772134
# Bernhard von Zinnenberg: 714/6620
# 0.469395127702
# Casimir IV Jagiellon: 715/6620
# -0.475386192264
# Jan Taszka Koniecpolski: 716/6620
# -0.475386192264
# Piotr of Szczekociny: 717/6620
# -0.475386192264
# Mullah Mutalib: 718/6620
# -0.5
# Mullah Ismael: 719/6620
# -0.5
# Shin Rip: 720/6620
# -0.557292576077
# Byeon Gi: 721/6620
# -0.557292576077
# Kim Yeo-mul: 722/6620
# -0.557292576077
# Yi Il: 723/6620
# -1.494982849
# Yi Jong-jang: 724/6620
# -0.557292576077
# Sō Yoshitoshi: 725/6620
# 0.899102063726
# Matsura Shigenobu: 726/6620
# 0.551354125601
# Arima Harunobu: 727/6620
# 0.551354125601
# Ōmura Yoshiaki: 728/6620
# 0.551354125601
# Gnaeus Cornelius Scipio Calvus: 729/6620
# 0.984061386211
# Walter Sans Avoir: 730/6620
# -0.564993428085
# Kilij Arslan I: 731/6620
# -0.330827508721
# Rudolf of Benevento: 732/6620
# -0.530317715855
# Gerard, Duke of Lorraine: 733/6620
# -0.530317715855
# Humphrey of Hauteville: 734/6620
# 0.524326271863
# Robert Guiscard: 735/6620
# 1.52743508078
# Richard I of Capua: 736/6620
# 0.524326271863
# Brian Boru: 737/6620
# 0.993938776838
# Murchad mac Briain: 738/6620
# 0.493938776838
# Sigtrygg Silkbeard: 739/6620
# -0.999947940709
# Máel Mórda mac Murchada: 740/6620
# -0.999947940709
# Sigurd the Stout: 741/6620
# -0.499947940709
# Brodir and Ospak of Man: 742/6620
# -0.499947940709
# Pharnabazus II: 743/6620
# -0.00492221426662
# Peisander (general): 744/6620
# -0.498904599177
# Jean III de Grailly, captal de Buch: 745/6620
# -0.0211475894896
# John I Albert: 746/6620
# -0.5
# Stanisław Chodecki: 747/6620
# -0.5
# Provenzano Salvani: 748/6620
# -0.604674993111
# Giambertoldo: 749/6620
# 0.598914694976
# Conrad III of Germany: 750/6620
# -1.5
# Manuel I Komnenos: 751/6620
# 0.0
# Lucius Mummius Achaicus: 752/6620
# 0.454147999165
# Diaeus: 753/6620
# -0.460113210188
# Titus Manlius Torquatus (dictator): 754/6620
# 0.484932397048
# Hasdrubal the Bald: 755/6620
# -0.490938286576
# Hampsicora: 756/6620
# -0.490938286576
# Agesilaus II: 757/6620
# 0.5
# Tolmides: 758/6620
# -0.5
# Sparton: 759/6620
# 0.5
# James Stewart, 1st Earl of Moray: 760/6620
# 0.435006571915
# John Stewart, 4th Earl of Atholl: 761/6620
# 0.435006571915
# James Douglas, 4th Earl of Morton: 762/6620
# 0.435006571915
# George Gordon, 4th Earl of Huntly: 763/6620
# 0.0768504947119
# Pietro Tiepolo: 764/6620
# -0.592902775789
# Roman Catholic Archdiocese of Milan: 765/6620
# -0.592902775789
# Frederick II, Holy Roman Emperor: 766/6620
# 0.0870880785294
# Henry IV of France: 767/6620
# 1.00172173322
# Anne de Joyeuse: 768/6620
# -0.503004694232
# Munuza: 769/6620
# -0.605302564434
# Al Qama: 770/6620
# -0.605302564434
# Pelagius of Asturias: 771/6620
# 0.599545354679
# Alexander, 2nd Lord Forbes of Pitsligo: 772/6620
# -0.509117299084
# Adam Gordon of Auchindoun: 773/6620
# 0.503108808922
# Antipater: 774/6620
# 0.927548501479
# Craterus: 775/6620
# 2.41319392002
# Antiphilus (general): 776/6620
# -0.471110813974
# Menon IV of Pharsalus: 777/6620
# -0.471110813974
# Louis, Count of Vendôme: 778/6620
# -0.537577357652
# Thomas Montagu, 4th Earl of Salisbury: 779/6620
# 1.05455854499
# Gerard de Ridefort: 780/6620
# -0.407009242082
# Roger de Moulins: 781/6620
# -0.419347957507
# Otto II, Holy Roman Emperor: 782/6620
# -0.5
# Landulf IV of Benevento: 783/6620
# -0.5
# Abu al-Qasim (Kalbid): 784/6620
# 0.5
# Abu al-Qasim (Kalbite) — Wikipédia: 785/6620
# 0.5
# Emirate of Sicily: 786/6620
# 0.5
# Owain Gwynedd: 787/6620
# 0.5
# Cadwaladr ap Gruffydd: 788/6620
# 0.5
# Gruffydd ap Rhys: 789/6620
# 0.5
# Robert fitz Martin: 790/6620
# -0.5
# Maurice FitzGerald, Lord of Lanstephan: 791/6620
# -0.5
# Avidius Cassius: 792/6620
# 0.5
# Vologases IV: 793/6620
# -0.5
# Merena: 794/6620
# 0
# Artaxerxes II of Persia: 795/6620
# -0.0557182627432
# Gobrias: 796/6620
# -0.0557182627432
# Tissaphernes: 797/6620
# -0.0557182627432
# Cyrus the Younger: 798/6620
# 0.0497757550786
# Clearchus of Sparta: 799/6620
# -0.448042073966
# Ariaeus: 800/6620
# 0.0497757550786
# Lamba Doria: 801/6620
# 0.518729631193
# Andrea Dandolo (admiral): 802/6620
# -0.524727670296
# Titus Quinctius Flamininus: 803/6620
# 0.981596646277
# Ubba: 804/6620
# -0.5
# Odda, Ealdorman of Devon: 805/6620
# 0.5
# Alcibiades: 806/6620
# 0.491809087219
# Theramenes: 807/6620
# 0.491809087219
# Hermocrates: 808/6620
# 0.00218217095594
# Gar Trinring Tsendro: 809/6620
# 0.416937186838
# Xue Rengui: 810/6620
# -0.422792208712
# Ashina Daozi: 811/6620
# -0.422792208712
# Guo Daifeng: 812/6620
# -0.422792208712
# Abdul Qayyum Zakir: 813/6620
# -0.5
# Sancho d'Avila: 814/6620
# 1.02544716575
# Mas'ud I of Ghazni: 815/6620
# -0.556305035676
# Ali Daya: 816/6620
# -0.556305035676
# Ahmad Shirazi: 817/6620
# -0.556305035676
# Abu Sahl Zawzani: 818/6620
# -0.556305035676
# Abd al-Razzaq Maymandi: 819/6620
# -0.556305035676
# Begtoghdi: 820/6620
# -0.556305035676
# Subashi (general): 821/6620
# -0.556305035676
# Chaghri Beg: 822/6620
# 0.550364026211
# Tughril: 823/6620
# 0.550364026211
# Faramurz: 824/6620
# 0.550364026211
# Minamoto no Yoshitsune: 825/6620
# 1.54863542108
# Taira no Munemori: 826/6620
# -1.03166323338
# Taira no Tomomori: 827/6620
# -0.0316632333767
# Perozes: 828/6620
# -0.537577357652
# Pityaxes: 829/6620
# -0.537577357652
# Baresmanas: 830/6620
# -0.537577357652
# Pharas the Herulian: 831/6620
# 0.531596725468
# Taddeo d'Este: 832/6620
# -0.5
# Niccolò Piccinino: 833/6620
# 1.0
# William the Silent: 834/6620
# -1.06938489522
# Thomas Morgan (died 1595): 835/6620
# 0.984578014241
# Francisco de Valdez: 836/6620
# -1.00121101321
# Julian Romero: 837/6620
# 0.00776281155236
# Pagondas: 838/6620
# 0.489002362901
# Hippocrates of Athens: 839/6620
# -0.495010215324
# Alexios Doukas Philanthropenos: 840/6620
# 0.472459313104
# John Palaiologos (brother of Michael VIII): 841/6620
# -0.630258485936
# Fillippo Sanudo: 842/6620
# -0.478454221538
# Guglielmo II da Verona: 843/6620
# -0.478454221538
# Publius Cornelius Scipio: 844/6620
# -0.51097059422
# Chen Tai: 845/6620
# 0.441304378315
# Deng Ai: 846/6620
# 0.441304378315
# Hu Fen: 847/6620
# 0.441304378315
# Jiang Wei: 848/6620
# -0.415642386699
# Xiahou Ba: 849/6620
# -0.447239112167
# Zhang Yi (Bogong): 850/6620
# -0.447239112167
# Mazyadid dynasty: 851/6620
# -0.556980905341
# David IV of Georgia: 852/6620
# 0.551041642157
# Demetrius I of Georgia: 853/6620
# 0.551041642157
# Francisco de Almeida: 854/6620
# 0.468336766623
# Amir Husain Al-Kurdi: 855/6620
# -0.474326398436
# Malik Ayyaz: 856/6620
# -0.474326398436
# Kunhali Marakkar: 857/6620
# -0.474326398436
# Giovanni Andrea Doria: 858/6620
# -0.0297523950964
# Juan de la Cerda, 4th Duke of Medinaceli: 859/6620
# -0.544011746079
# Álvaro de Sande: 860/6620
# -0.544011746079
# Piali Pasha: 861/6620
# -0.0312602919392
# Dragut: 862/6620
# 0.40458850958
# Major general (United States): 863/6620
# 0.5
# Major (United States): 864/6620
# 0.5
# Sviatoslav I of Kiev: 865/6620
# -1.0579100199
# John I Tzimiskes: 866/6620
# 1.04592363904
# Bohemond I of Antioch: 867/6620
# 1.40055973331
# Adhemar of Le Puy: 868/6620
# 1.39745092439
# Danishmend Gazi: 869/6620
# -0.438708860417
# Mesud I: 870/6620
# 0.5
# Adherbal (admiral): 871/6620
# 0.496995305768
# Hamilcar: 872/6620
# 0.496995305768
# Publius Claudius Pulcher (consul 249 BC): 873/6620
# -0.503004694232
# Francis, Duke of Guise: 874/6620
# 0.882536372055
# Louis, Prince of Condé (1530–1569): 875/6620
# -1.50068438185
# Gaspard II de Coligny: 876/6620
# -0.998227165849
# Hector Roy Mackenzie: 877/6620
# -0.0289550099519
# John Balliol: 878/6620
# -0.503004694232
# John de Warenne, 6th Earl of Surrey: 879/6620
# -0.0342042532848
# Domhnall II, Earl of Mar: 880/6620
# -0.574665313838
# Edward Balliol: 881/6620
# 0.568779581557
# Henry de Beaumont: 882/6620
# 0.568779581557
# Burchard von Hornhausen: 883/6620
# -0.537577357652
# Treniota: 884/6620
# 0.531596725468
# Alexios I Komnenos: 885/6620
# 0.511849709842
# George Palaiologos: 886/6620
# -0.00911729908368
# Sikelgaita: 887/6620
# 0.503108808922
# Pompey: 888/6620
# 0.908476362702
# Richard de Clare, Steward of Forest of Essex: 889/6620
# -0.5
# Valerian (emperor): 890/6620
# -0.5
# Successianus: 891/6620
# -0.5
# Robin of Redesdale: 892/6620
# 0.5
# William Herbert, 1st Earl of Pembroke (died 1469): 893/6620
# -0.5
# Humphrey Stafford, 1st Earl of Devon: 894/6620
# -0.5
# Alfred the Great: 895/6620
# 0.5
# Guthrum: 896/6620
# -0.5
# Bacchides (general): 897/6620
# 0.403250759798
# Iphicrates: 898/6620
# 0.0
# Timotheus (general): 899/6620
# -0.5
# Aurelian: 900/6620
# 0.952596276551
# Zenobia: 901/6620
# -0.958558228075
# Zabdas: 902/6620
# -0.958558228075
# Gorgias (general): 903/6620
# -0.528955009952
# Nicanor (Seleucid general): 904/6620
# -0.528955009952
# Hegesandridas: 905/6620
# 0.5
# Edward I of England: 906/6620
# 0.866838924487
# Gilbert de Clare, 7th Earl of Gloucester: 907/6620
# 0.994019367817
# Simon de Montfort, 6th Earl of Leicester: 908/6620
# 0.0631934509369
# Peter de Montfort: 909/6620
# -0.468403274532
# Lucius Aemilius Papus: 910/6620
# -0.0059455730451
# Stilicho: 911/6620
# 0.994026101036
# Sarus the Goth: 912/6620
# 0.5
# Uldin: 913/6620
# 0.5
# Radagaisus: 914/6620
# -0.5
# Theodore Trithyrius: 915/6620
# -1.00300469423
# Hasan ibn Ali: 916/6620
# 0.0177739471286
# William Wallace: 917/6620
# 0.077279081555
# Cao Ren: 918/6620
# 0.0136963243704
# Yu Jin: 919/6620
# 0.478667489481
# Pang De: 920/6620
# 0.478667489481
# Xu Huang: 921/6620
# 0.446879560677
# Guan Yu: 922/6620
# 0.0641360044445
# Louis IX of France: 923/6620
# 0.093274136668
# Guillaume de Sonnac: 924/6620
# -0.5
# Al-Muazzam Turanshah: 925/6620
# 0.5
# Shane O'Neill (son of Conn): 926/6620
# -0.00300469423196
# Sir Hugh O'Donnell: 927/6620
# 0.496995305768
# John de Bermingham, 1st Earl of Louth: 928/6620
# 0.412859634541
# Edmund Butler, Earl of Carrick: 929/6620
# 0.412859634541
# Earl of Carrick (Ireland): 930/6620
# 0.412859634541
# Earl of Carrick: 931/6620
# -0.418698514703
# Fu Jian (337–385): 932/6620
# -0.588489790392
# Fu Rong: 933/6620
# -0.588489790392
# Xie An: 934/6620
# 0.582656429268
# Xie Xuan: 935/6620
# 0.582656429268
# Huan Chong: 936/6620
# 0.582656429268
# John Clifford, 9th Baron Clifford: 937/6620
# 0.462422642348
# John Neville, Baron Neville: 938/6620
# 0
# James IV of Scotland: 939/6620
# 0.00463124831241
# Alexander Home, 3rd Lord Home: 940/6620
# -0.518330571207
# William Graham, 1st Earl of Montrose: 941/6620
# -0.518330571207
# Adam Hepburn, 2nd Earl of Bothwell: 942/6620
# -0.518330571207
# Matthew Stewart, 2nd Earl of Lennox: 943/6620
# -0.518330571207
# Archibald Campbell, 2nd Earl of Argyll: 944/6620
# -0.518330571207
# Catherine of Aragon: 945/6620
# 0.512326831029
# Thomas Howard, 3rd Duke of Norfolk: 946/6620
# 0.512326831029
# Lord Edmund Howard: 947/6620
# 0.512326831029
# Thomas Dacre, 2nd Baron Dacre: 948/6620
# 0.512326831029
# Edward Stanley, 1st Baron Monteagle: 949/6620
# 0.512326831029
# Marmaduke Constable: 950/6620
# 0.512326831029
# Charles I, Duke of Bourbon: 951/6620
# 0.495853267427
# Arthur III, Duke of Brittany: 952/6620
# 0.495853267427
# Sir Thomas Kyriell: 953/6620
# -0.501862624538
# Francesco II Gonzaga, Marquess of Mantua: 954/6620
# -0.535317720224
# Charles VIII of France: 955/6620
# 0.529333450548
# Gaius Vibius Pansa Caetronianus: 956/6620
# 0.892133973644
# Aulus Hirtius: 957/6620
# 0.892133973644
# Enzo of Sardinia: 958/6620
# 0.469957079858
# Ottaviano degli Ubaldini: 959/6620
# -0.475948883228
# Thomas Müntzer: 960/6620
# 0.482155587267
# Philip I, Landgrave of Hesse: 961/6620
# 0.511840319833
# George, Duke of Saxony: 962/6620
# 0.511840319833
# Minamoto no Yoritomo: 963/6620
# 1.07829679106
# Taira no Koremori: 964/6620
# -1.08606750739
# Harald Hardrada: 965/6620
# -0.479077407862
# Tostig Godwinson: 966/6620
# -0.0146155381322
# Morcar: 967/6620
# -0.468403274532
# Edwin, Earl of Mercia: 968/6620
# -0.468403274532
# Antigonus I Monophthalmus: 969/6620
# 0.489850365263
# Eumenes: 970/6620
# -0.483029137811
# Han Xin: 971/6620
# 0.980512181169
# Xiang Yu: 972/6620
# 0.128551525979
# Pietro Loredan: 973/6620
# 0.5
# Alberic I of Spoleto: 974/6620
# 0.5
# Nicholas Picingli: 975/6620
# 0.5
# Pope John X: 976/6620
# 0.5
# Ludovico II, Marquess of Saluzzo: 977/6620
# -0.513676403748
# Willekin von Endorp: 978/6620
# -0.5
# Darius III: 979/6620
# -1.08362416735
# Bessus: 980/6620
# -0.527481029757
# Mazaeus: 981/6620
# -0.527481029757
# Orontes II: 982/6620
# -0.527481029757
# Atropates: 983/6620
# -0.527481029757
# Hephaestion: 984/6620
# 2.4546087747
# Parmenion: 985/6620
# 1.53552607187
# Ptolemy I Soter: 986/6620
# 2.01548803841
# Perdiccas: 987/6620
# 0.995318502129
# Cleitus the Black: 988/6620
# 0.98532435878
# Nearchus: 989/6620
# 0.521486050974
# Seleucus I Nicator: 990/6620
# 1.99106610414
# Ariston of Paionia: 991/6620
# 0.521486050974
# Simmias of Macedon: 992/6620
# 0.521486050974
# Coenus (general): 993/6620
# 0.995318502129
# Ariston of Macedon: 994/6620
# 0.521486050974
# Glaucias of Macedon: 995/6620
# 0.521486050974
# Sopolis of Macedon: 996/6620
# 0.521486050974
# Francesco Ferruccio: 997/6620
# -0.533851227956
# Philibert of Chalon: 998/6620
# 0.527864729232
# Fabrizio Maramaldo: 999/6620
# 0.527864729232
# Demetrius I of Macedon: 1000/6620
# -0.132230393086
# Dionysius I of Syracuse: 1001/6620
# 1.01489183431
# Himilco (general): 1002/6620
# -0.0513256526911
# Antoine de Goignies: 1003/6620
# -0.518526142466
# Maximilien de Hénin-Liétard: 1004/6620
# -0.0248588963384
# William II de La Marck: 1005/6620
# -0.518526142466
# Maarten Schenck van Nydeggen: 1006/6620
# -0.518526142466
# Emanuel Philibert de Lalaing: 1007/6620
# -0.518526142466
# Philip, Count of Egmont: 1008/6620
# -1.02926052187
# Charles Philippe de Croÿ, Marquis d’Havré: 1009/6620
# -0.518526142466
# Henry Balfour (soldier): 1010/6620
# -0.518526142466
# John of Austria: 1011/6620
# 0.533840674897
# Alexander Farnese, Duke of Parma: 1012/6620
# 0.00784280203626
# Cristóbal de Mondragón: 1013/6620
# 0.512522547388
# Ottavio Gonzaga: 1014/6620
# 0.512522547388
# Peter Ernst I von Mansfeld-Vorderort: 1015/6620
# 0.512522547388
# Francisco Verdugo: 1016/6620
# 0.512522547388
# John FitzAlan, 14th Earl of Arundel: 1017/6620
# -0.57179239756
# La Hire: 1018/6620
# 1.11865782908
# Jean Poton de Xaintrailles: 1019/6620
# 1.11865782908
# Marcus Minucius Rufus: 1020/6620
# -0.468403274532
# Magister equitum: 1021/6620
# -0.468403274532
# Archibald Campbell, 7th Earl of Argyll: 1022/6620
# -0.57179239756
# George Gordon, 1st Marquess of Huntly: 1023/6620
# 0.565896941246
# Francis Hay, 9th Earl of Erroll: 1024/6620
# 0.565896941246
# Máel Sechnaill mac Domnaill: 1025/6620
# 0.5
# Sorley Boy MacDonnell: 1026/6620
# -0.5
# Joseph Kabila: 1027/6620
# 0.441304378315
# Babacar Gaye: 1028/6620
# 0.441304378315
# Ignace Murwanashyaka: 1029/6620
# 0.441304378315
# José Eduardo dos Santos: 1030/6620
# 0.441304378315
# Robert Mugabe: 1031/6620
# 0.441304378315
# Laurent Nkunda: 1032/6620
# -0.447239112167
# Lamoral, Count of Egmont: 1033/6620
# 0.929986408467
# Paul de Thermes: 1034/6620
# -0.486456481493
# Gaius Claudius Nero: 1035/6620
# 0.961622358422
# Ulrich von Jungingen: 1036/6620
# -0.528530471446
# Władysław II Jagiełło: 1037/6620
# 1.04031070233
# Vytautas: 1038/6620
# 0.0616737091592
# Roderic: 1039/6620
# -0.51717036461
# Tariq ibn Ziyad: 1040/6620
# 0.511165801488
# Chunyu Qiong: 1041/6620
# -0.551324380869
# Guo Tu: 1042/6620
# -0.551324380869
# Cao Hong: 1043/6620
# -0.512383260167
# Tian Ji: 1044/6620
# 0.959417948116
# Sun Bin: 1045/6620
# 0.959417948116
# Pang Juan: 1046/6620
# -0.971407968764
# Maximilian I, Holy Roman Emperor: 1047/6620
# 0.335624757942
# Philippe de Crèvecœur d'Esquerdes: 1048/6620
# -0.458866239029
# Henry VIII of England: 1049/6620
# 1.43279869234
# Henry Bourchier, 2nd Earl of Essex: 1050/6620
# 0.432798692337
# Jacques de La Palice: 1051/6620
# -0.382896667001
# Charles IV, Duke of Alençon: 1052/6620
# -0.438708860417
# Louis I d'Orléans, duc de Longueville: 1053/6620
# -0.438708860417
# Petar Svačić: 1054/6620
# -0.5
# Coloman, King of Hungary: 1055/6620
# 0.5
# Eumenes II: 1056/6620
# 0.996995305768
# Dexagoridas: 1057/6620
# -0.5
# Gorgopas (2nd century BC): 1058/6620
# -0.5
# Marinus Brandt: 1059/6620
# -0.531663233377
# Robert Bowes (lawyer): 1060/6620
# -0.523772962139
# Katō Kiyomasa: 1061/6620
# 0.882207420566
# Kuroda Nagamasa: 1062/6620
# 1.33369814838
# Ishida Mitsunari: 1063/6620
# -0.628223146657
# Kikkawa Hiroie: 1064/6620
# -0.57915187724
# Kobayakawa Hideaki: 1065/6620
# -0.57915187724
# Kwon Yul: 1066/6620
# 0.0447516571641
# Jo Gyeong: 1067/6620
# 0.57328212861
# Seon Geoi: 1068/6620
# 0.57328212861
# Kim Cheon Il: 1069/6620
# 0.57328212861
# Heo Uk: 1070/6620
# 0.57328212861
# Cheo Yung: 1071/6620
# 0.57328212861
# Archibald Douglas (died 1333): 1072/6620
# -0.521887252237
# Thomas of Brotherton, 1st Earl of Norfolk: 1073/6620
# 0.515886438589
# Walter V, Count of Brienne: 1074/6620
# -0.5
# Al-Husayn ibn Zikrawayh: 1075/6620
# -0.5
# Muhammad ibn Sulayman al-Katib: 1076/6620
# 0.5
# Husayn ibn Hamdan: 1077/6620
# 0.5
# Cao Xiu: 1078/6620
# -1.11344537001
# Zhao Yun: 1079/6620
# 0.536354388916
# Huang Zhong: 1080/6620
# 0.548804804112
# Liu Bei: 1081/6620
# 1.10615191873
# Raymond III, Count of Tripoli: 1082/6620
# -1.03180841153
# Bohemond III of Antioch: 1083/6620
# -0.558695621685
# Constantine Kalamanos: 1084/6620
# -0.558695621685
# Thoros II, Prince of Armenia: 1085/6620
# -0.558695621685
# Hugh VIII of Lusignan: 1086/6620
# -0.558695621685
# Joscelin III, Count of Edessa: 1087/6620
# -1.03180841153
# Nur ad-Din (died 1174): 1088/6620
# 1.48555958017
# Qutb ad-Din Mawdud: 1089/6620
# 0.552760887833
# Alexander Stewart, Earl of Mar: 1090/6620
# -0.5
# Donald of Islay, Lord of the Isles: 1091/6620
# 0
# Mosul: 1092/6620
# 1.0
# Sökmen (Artuqid): 1093/6620
# -0.025399306631
# William the Conqueror: 1094/6620
# 0.494186589697
# Alan Rufus: 1095/6620
# 0.494186589697
# William FitzOsbern, 1st Earl of Hereford: 1096/6620
# 0.494186589697
# Eustace II, Count of Boulogne: 1097/6620
# 0.494186589697
# Harold Godwinson: 1098/6620
# -0.0291507984639
# Gyrth Godwinson: 1099/6620
# -0.500195788512
# Leofwine Godwinson: 1100/6620
# -0.500195788512
# Raynald of Châtillon: 1101/6620
# 0.0722583925478
# Humphrey IV of Toron: 1102/6620
# -0.473112789841
# Aimery of Cyprus: 1103/6620
# -0.473112789841
# Reginald of Sidon: 1104/6620
# -0.473112789841
# Þórður kakali Sighvatsson: 1105/6620
# 0.5
# Henry Beaufort, 3rd Duke of Somerset: 1106/6620
# -1.04279770396
# Thomas de Ros, 9th Baron de Ros: 1107/6620
# -0.993556828033
# Robert Hungerford, 3rd Baron Hungerford: 1108/6620
# -0.993556828033
# Ralph Percy: 1109/6620
# -0.493556828033
# Louis of Nassau: 1110/6620
# -1.64129669931
# Adolf of Nassau (1540–1568): 1111/6620
# 0.466329956373
# Jean de Ligne, Duke of Arenberg: 1112/6620
# -0.472316723303
# John, King of Denmark: 1113/6620
# -0.5
# Frederick I of Denmark: 1114/6620
# -0.5
# Publius Valerius Laevinus: 1115/6620
# -0.470276527102
# Ismail Khan: 1116/6620
# 0.5
# Tommy Franks: 1117/6620
# -0.00300469423196
# Yahya Rahim Safavi: 1118/6620
# 0.5
# Flaccus: 1119/6620
# -0.486089345626
# Hannibal Mago: 1120/6620
# 1.5
# Hamilcar I of Carthage: 1121/6620
# -0.576632415466
# Gelo: 1122/6620
# 0.570753571331
# Theron of Acragas: 1123/6620
# 0.570753571331
# Henry Percy (Hotspur): 1124/6620
# -0.53942386292
# George I, Earl of March: 1125/6620
# 1.00028823346
# Archibald Douglas, 4th Earl of Douglas: 1126/6620
# -1.003636636
# Jan Žižka: 1127/6620
# 2.1814075591
# Diviš Bořek of Miletínek: 1128/6620
# 1.48494627989
# Čeněk of Wartenberg: 1129/6620
# -0.523457141354
# Artabanus V of Parthia: 1130/6620
# -0.5
# Ardashir I: 1131/6620
# 0.5
# Dou Jiande: 1132/6620
# -0.541880441818
# Wang Shichong: 1133/6620
# -0.01028371635
# Duan Da: 1134/6620
# -0.541880441818
# Shan Xiongxin: 1135/6620
# -0.541880441818
# Emperor Taizong of Tang: 1136/6620
# 0.535907417175
# Li Yuanji: 1137/6620
# 0.535907417175
# Liu Dewei: 1138/6620
# 0.535907417175
# Huang Junhan: 1139/6620
# 0.535907417175
# Yuwen Shiji: 1140/6620
# 0.535907417175
# Shi Wanbao: 1141/6620
# 0.535907417175
# Li Shiji: 1142/6620
# 0.535907417175
# Emperor Gaozu of Tang: 1143/6620
# 0.5
# ...
# 0.5
# Yadegar Mokhammad of Kazan: 6257/6620
# -0.5
# Yapancha beg: 6258/6620
# -0.5
# Zaynash morza: 6259/6620
# -0.5
# Qolsharif: 6260/6620
# -0.5
# Afonso Pereira de Lacerda: 6261/6620
# 0.5
# Diogo de Melo Coutinho: 6262/6620
# 0.5
# Gabriel, comte de Montgomery: 6263/6620
# 0
# Pieter Adriaanszoon van der Werff: 6264/6620
# 0.512981712899
# Afonso I of Portugal: 6265/6620
# 0.5
# Hervey de Glanvill: 6266/6620
# 0.5
# Arnout IV, Count of Aarschot: 6267/6620
# 0.5
# Christian of Ghistelles: 6268/6620
# 0.5
# Simon of Dover: 6269/6620
# 0.5
# Saher of Archelle: 6270/6620
# 0.5
# Louis XIV of France: 6271/6620
# 1.22100350865
# Jacques de Fariaux, baron de Maulde: 6272/6620
# -0.828481470308
# Alaal-Din: 6273/6620
# -0.5
# Leonis Pereira: 6274/6620
# 0.5
# Jean Parisot de Valette: 6275/6620
# 0.563399552533
# Jean de la Cassière: 6276/6620
# 0.563399552533
# Mathurin Romegas: 6277/6620
# 0.563399552533
# Goncales de Medran: 6278/6620
# 0.563399552533
# Melchior de Robles: 6279/6620
# 0.563399552533
# García de Toledo Osorio, 4th Marquis of Villafranca: 6280/6620
# 0.563399552533
# Decimus Junius Brutus Albinus: 6281/6620
# 0.465419436213
# Trebonius: 6282/6620
# 0.465419436213
# Lucius Domitius Ahenobarbus (consul 54 BC): 6283/6620
# -0.47140483931
# Kamiizumi Nobutsuna: 6284/6620
# -0.47703818048
# Nagano Narimori: 6285/6620
# -0.47703818048
# Niho Takayasu: 6286/6620
# 0.5
# Ōtomo Sōrin: 6287/6620
# -0.5
# Tachibana Dōsetsu: 6288/6620
# -0.5
# Tawara Chikakata: 6289/6620
# -0.5
# Usuki Akihaya: 6290/6620
# -0.5
# Oi Sadataka: 6291/6620
# -0.458558228075
# Yi Bok-nam: 6292/6620
# -0.430640994345
# Yi Chun-won: 6293/6620
# -0.430640994345
# Kim Gyeong-ro: 6294/6620
# -0.430640994345
# Ma Eung-bang: 6295/6620
# -0.430640994345
# Oh Eung-jeong: 6296/6620
# -0.430640994345
# Im Hyeon: 6297/6620
# -0.430640994345
# Yi Deok-hoe: 6298/6620
# -0.430640994345
# Jeong Gi-won: 6299/6620
# -0.430640994345
# Hwang Dae-jung: 6300/6620
# -0.430640994345
# Shin Ho: 6301/6620
# -0.430640994345
# Jo Gyeong-nam: 6302/6620
# -0.430640994345
# Yang Hao (Ming dynasty): 6303/6620
# -0.959171465792
# Jiang Biao: 6304/6620
# -0.430640994345
# Mao Cheng Xian: 6305/6620
# -0.430640994345
# Aristagoras: 6306/6620
# -0.5
# Megabates: 6307/6620
# -0.5
# Manuel Boutoumites: 6308/6620
# 0.445250251676
# Charles V, Holy Roman Emperor: 6309/6620
# -0.5
# Charles III, Duke of Savoy: 6310/6620
# -0.5
# Suganuma Sadamichi: 6311/6620
# -0.400754813597
# Satake Yoshiaki: 6312/6620
# -0.579492178073
# Ōta Sukemasa: 6313/6620
# -0.579492178073
# Nagano Narimasa: 6314/6620
# -0.579492178073
# Oda Ujiharu: 6315/6620
# -0.579492178073
# Utsunomiya Hirotsuna: 6316/6620
# -0.579492178073
# Satomi Yoshihiro: 6317/6620
# -0.579492178073
# Nasu Suketane: 6318/6620
# -0.579492178073
# Yura Narishige: 6319/6620
# -0.579492178073
# Mita Tsunahide: 6320/6620
# -0.579492178073
# Oda Nobukatsu: 6321/6620
# 0.449674671
# Gamō Ujisato: 6322/6620
# 0.449674671
# Sanada Masayuki: 6323/6620
# 0.449674671
# Chōsokabe Motochika: 6324/6620
# 0.949674671
# Shimazu Hisayasu: 6325/6620
# 0.449674671
# Hōjō Ujimasa: 6326/6620
# -0.455630170309
# Hōjō Ujinao: 6327/6620
# -0.455630170309
# Narita Ujinaga: 6328/6620
# -0.455630170309
# Kaihime: 6329/6620
# -0.455630170309
# Niccolò di Pitigliano: 6330/6620
# 0.544121504599
# Andrea Gritti: 6331/6620
# 0.544121504599
# Henry II of France: 6332/6620
# -0.5
# Yun Doo-su: 6333/6620
# -0.527093537548
# Ryu Seong-ryong: 6334/6620
# -0.527093537548
# Kim Myeong-won: 6335/6620
# -0.527093537548
# Yi Won-ik: 6336/6620
# -0.527093537548
# Hwang Won: 6337/6620
# -0.527093537548
# Kim Ung-seo: 6338/6620
# -0.527093537548
# Go Eop-baek: 6339/6620
# -0.527093537548
# Zu Chengxun: 6340/6620
# -0.527093537548
# Tian Cong: 6341/6620
# -0.527093537548
# Abu'l-Hasan Asaf Khan: 6342/6620
# 0.5
# Munim Khan: 6343/6620
# 0.5
# Mesih Pasha: 6344/6620
# -0.59583717759
# Pierre d'Aubusson: 6345/6620
# 0.590035412442
# Suleiman the Magnificent: 6346/6620
# -0.176505863223
# Çoban Mustafa Pasha: 6347/6620
# 0.401867462268
# Kurtoğlu Muslihiddin Reis: 6348/6620
# 0.401867462268
# Philippe Villiers de L'Isle-Adam: 6349/6620
# -0.407658821108
# Ares (General): 6350/6620
# -0.455696468544
# Vitiges: 6351/6620
# -0.566903635857
# Claude de La Chatre: 6352/6620
# 0.446342904935
# Mayor Johnanneau: 6353/6620
# -0.452290543657
# Captain Lafleur: 6354/6620
# -0.452290543657
# Ankokuji Ekei: 6355/6620
# 0.5
# Antonio Loredan: 6356/6620
# 0.599477611216
# Pietro Mocenigo: 6357/6620
# 0.599477611216
# Triadan Gritti: 6358/6620
# 0.599477611216
# Ivan Crnojević: 6359/6620
# 0.599477611216
# Mago II of Carthage: 6360/6620
# -0.581554171423
# Spitamenes: 6361/6620
# -0.5
# Mahmud Pasha Angelović: 6362/6620
# 0.5
# David of Trebizond: 6363/6620
# -0.5
# Sinan Pasha (Ottoman admiral): 6364/6620
# 0.406497027792
# Gaspard de Vallier: 6365/6620
# -0.412309113845
# Kim Gwi-hoe: 6366/6620
# -0.528530471446
# Jang Un-ik: 6367/6620
# -0.528530471446
# Ma Gui (general): 6368/6620
# -0.528530471446
# Qian Wanli: 6369/6620
# -0.528530471446
# Asano Yoshinaga: 6370/6620
# 0.522536755201
# Mōri Hidemoto: 6371/6620
# 0.522536755201
# Nabeshima Naoshige: 6372/6620
# 0.522536755201
# Hachisuka Iemasa: 6373/6620
# 0.522536755201
# Pargalı Ibrahim Pasha: 6374/6620
# -0.578373325492
# Nicholas, Count of Salm: 6375/6620
# 0.572500733455
# Philip, Duke of Palatinate-Neuburg: 6376/6620
# 0.572500733455
# Wilhelm von Roggendorf: 6377/6620
# 0.572500733455
# Josephus: 6378/6620
# -0.503004694232
# Jazzar Pasha: 6379/6620
# -0.584367946032
# Sidney Smith (Royal Navy officer): 6380/6620
# -1.06813193302
# David Hendrik Chassé: 6381/6620
# -0.5
# Étienne Maurice Gérard: 6382/6620
# 0.5
# François-Nicolas-Benoît Haxo: 6383/6620
# 0.5
# Victor Deguise: 6384/6620
# -0.543313448018
# Archibald Paris (Royal Marines officer): 6385/6620
# -0.543313448018
# Armand Philippon: 6386/6620
# -0.430578078384
# Ulrich Frédéric Woldemar, Comte de Lowendal: 6387/6620
# 0.445250251676
# Domingo Ugartechea: 6388/6620
# -0.537577357652
# Stephen F. Austin: 6389/6620
# 0.531596725468
# Edward Burleson: 6390/6620
# 0.531596725468
# Benjamin Milam: 6391/6620
# 0.531596725468
# Justinus van Nassau: 6392/6620
# -0.0123272127613
# Ambrogio Spinola, 1st Marquis of the Balbases: 6393/6620
# 0.916169472333
# Carlos Coloma: 6394/6620
# 0.504989784676
# Jean-Louis Dubreton: 6395/6620
# 0.588740572477
# Nana Sahib: 6396/6620
# 0.441304378315
# Tatya Tope: 6397/6620
# 0.441304378315
# Hugh Wheeler (East India Company officer): 6398/6620
# -0.447239112167
# Captain (British Army and Royal Marines): 6399/6620
# -0.447239112167
# John Moore (British Major): 6400/6620
# -0.447239112167
# Mariot Arbuthnot: 6401/6620
# 0.427219757651
# William Moultrie: 6402/6620
# -0.433111915371
# James Hogun: 6403/6620
# -0.433111915371
# Abraham Whipple: 6404/6620
# -0.433111915371
# Louis Lebègue Duportail: 6405/6620
# -0.433111915371
# Jean Léonard Barrié: 6406/6620
# -0.432227688247
# William Hull: 6407/6620
# -0.528188102789
# Charles Pearson (British Army officer): 6408/6620
# 0.526640687473
# Edmund P. Gaines: 6409/6620
# 0.506443171967
# Siege of Fort Harrison: 6410/6620
# -0.589956335555
# Stone Eater: 6411/6620
# -0.589956335555
# Green Clay: 6412/6620
# 0.483353938369
# William Dudley (colonel): 6413/6620
# 0.483353938369
# David Wooster: 6414/6620
# 0.452194839255
# Charles Preston: 6415/6620
# -0.458155928624
# William Phillips (British Army officer): 6416/6620
# 0.450961925907
# Arthur St. Clair: 6417/6620
# -0.954975970921
# James Rhea: 6418/6620
# 0.430632833411
# Winamac: 6419/6620
# -0.436536188049
# Five Medals: 6420/6620
# -0.436536188049
# George Monro (British Army officer): 6421/6620
# -0.448745431834
# Koxinga: 6422/6620
# 0.5
# Frederick Coyett: 6423/6620
# -0.5
# Barthold Nicolai Landsberg: 6424/6620
# 0.552760887833
# Matthijs Dulken: 6425/6620
# -0.50978422653
# Hendrik van den Bergh (count): 6426/6620
# -0.50978422653
# Christoph Bernhard von Galen: 6427/6620
# -0.104149099055
# Gustaff Tungel: 6428/6620
# -0.401613772401
# Carl von Rabenhaupt: 6429/6620
# 0.5
# Nikolay Muravyov-Karsky: 6430/6620
# 0.490478359295
# Fenwick Williams: 6431/6620
# -0.496486726673
# Mehmet Vasıf Pasha Gürcü: 6432/6620
# -0.496486726673
# George White (British Army officer): 6433/6620
# 0.52334878947
# Ivan Fedyuninsky: 6434/6620
# 0.48412699538
# Mikhail Khozin: 6435/6620
# 0.48412699538
# Archibald H. Gillespie: 6436/6620
# -0.449635973789
# Begum Hazrat Mahal: 6437/6620
# 0.4371588303
# Birjis Qadr: 6438/6620
# 0.4371588303
# John Eardley Inglis: 6439/6620
# -0.443082027531
# Henry Havelock: 6440/6620
# -0.443082027531
# Colin Campbell, 1st Baron Clyde: 6441/6620
# -0.443082027531
# James George Smith Neill: 6442/6620
# -0.443082027531
# Robert Baden-Powell, 1st Baron Baden-Powell: 6443/6620
# -0.432312250018
# Bryan Mahon: 6444/6620
# -0.432312250018
# Joseph Anthelme Fournier: 6445/6620
# -0.5
# Hans von Zwehl: 6446/6620
# 0.5
# Diwan Mulraj Chopra: 6447/6620
# 0.5
# Ferdinand II, Holy Roman Emperor: 6448/6620
# -0.564064339403
# Tiryaki Hasan Pasha: 6449/6620
# 0.558144704652
# Octavius Ignatius, Prince of Arenberg and Barbançon: 6450/6620
# -0.409964587558
# Menno van Coehoorn: 6451/6620
# 0.0407540140527
# Alexander II of Russia: 6452/6620
# 0.463821835705
# Carol I of Romania: 6453/6620
# 0.463821835705
# Grand Duke Nicholas Nikolaevich of Russia (1831–1891): 6454/6620
# 0.463821835705
# Eduard Totleben: 6455/6620
# -0.00325453964306
# Nogi Maresuke: 6456/6620
# 0.456165635255
# Franklin Gardner: 6457/6620
# -0.436106586794
# Joaquín Rea: 6458/6620
# -0.509932147021
# Thomas Childs: 6459/6620
# 0.503923912343
# Calixto García: 6460/6620
# 0.482155587267
# José Toral y Velázquez: 6461/6620
# -0.488159680167
# Alija Izetbegović: 6462/6620
# -0.0738351002244
# Sefer Halilović: 6463/6620
# -0.0738351002244
# Rasim Delić: 6464/6620
# -0.0738351002244
# Jovan Divjak: 6465/6620
# -0.0738351002244
# Enver Hadžihasanović: 6466/6620
# -0.0738351002244
# Mustafa Hajrulahović Talijan: 6467/6620
# -0.0738351002244
# Mušan Topalović: 6468/6620
# -0.0738351002244
# Leighton W. Smith Jr.: 6469/6620
# -0.0738351002244
# Milutin Kukanjac: 6470/6620
# 0.0679465169243
# Radovan Karadžić: 6471/6620
# 0.0679465169243
# Stanislav Galić: 6472/6620
# 0.0679465169243
# Dragomir Milošević: 6473/6620
# 0.0679465169243
# Curt von Stedingk: 6474/6620
# -0.621418737395
# Maurice, Count de Benyovszky: 6475/6620
# -0.621418737395
# Augustine Prévost: 6476/6620
# 0.615747375121
# John Maitland (British Army officer): 6477/6620
# 0.615747375121
# Aimable Pélissier: 6478/6620
# 0.461097989963
# Edmund Lyons, 1st Baron Lyons: 6479/6620
# 0.461097989963
# James Simpson (British Army officer): 6480/6620
# 0.461097989963
# William John Codrington: 6481/6620
# 0.461097989963
# Vladimir Kornilov: 6482/6620
# -0.467076375348
# Pavel Nakhimov: 6483/6620
# -0.467076375348
# Anthonie II Schetz: 6484/6620
# -0.446219250328
# Sigismund III Vasa: 6485/6620
# 0.431981631152
# Mikhail Shein: 6486/6620
# -0.437889255506
# Jean-Jacques Uhrich — Wikipédia: 6487/6620
# -0.474980810751
# Jean François Leval: 6488/6620
# -0.560226031488
# Francisco Copons: 6489/6620
# 0.554295459996
# John Byrne Skerrett: 6490/6620
# 0.554295459996
# Gastone Gambara: 6491/6620
# -0.516409267558
# Leslie Morshead: 6492/6620
# 0.510404199772
# Ronald Scobie: 6493/6620
# 0.510404199772
# Jean François Carteaux: 6494/6620
# 0.477763493548
# Jean François Cornu de La Poype: 6495/6620
# 0.477763493548
# Marquess of Normanby: 6496/6620
# -0.483763986987
# Jan Piotr Sapieha: 6497/6620
# -0.577631996907
# Aleksander Józef Lisowski: 6498/6620
# -0.577631996907
# Grigory Dolgorukov: 6499/6620
# 0.571756724642
# Aleksey Golokhvastov: 6500/6620
# 0.571756724642
# Tang Ching-sung: 6501/6620
# -0.595384149435
# Marc-Edmond Dominé: 6502/6620
# 0.589580360559
# William Oliphant (died after 1313): 6503/6620
# -0.5
# Sanada Yukitaka: 6504/6620
# 0.40860520053
# Yokota Takatoshi: 6505/6620
# 0.40860520053
# John Ancrum Winslow: 6506/6620
# 0.496995305768
# Raphael Semmes: 6507/6620
# -0.503004694232
# Tom Phillips (Royal Navy officer): 6508/6620
# -0.503004694232
# William Tennant (Royal Navy officer): 6509/6620
# -0.503004694232
# Niichi Nakanishi: 6510/6620
# 0.496995305768
# Shichizo Miyauchi: 6511/6620
# 0.496995305768
# Hachiro Shoji: 6512/6620
# 0.496995305768
# Luo Ruiqing: 6513/6620
# 0.4189128696
# Zhou Enlai: 6514/6620
# 0.4189128696
# Brij Mohan Kaul: 6515/6620
# -0.424775423401
# Jawaharlal Nehru: 6516/6620
# -0.424775423401
# V. K. Krishna Menon: 6517/6620
# -0.424775423401
# Pran Nath Thapar: 6518/6620
# -0.424775423401
# Gamal Abdel Nasser: 6519/6620
# -1.07937699142
# Abdel Hakim Amer: 6520/6620
# -1.07937699142
# Abdul Munim Riad: 6521/6620
# -0.567744722986
# Asad Ghanma: 6522/6620
# -0.567744722986
# Salah Jadid: 6523/6620
# -0.567744722986
# Nureddin al-Atassi: 6524/6620
# -0.567744722986
# Abdul Rahman Arif: 6525/6620
# -0.567744722986
# Mubarak Abdullah Al-Jaber Al-Sabah: 6526/6620
# -0.567744722986
# Saleh Mohammed Al-Sabah: 6527/6620
# -0.567744722986
# Fahad Al-Ahmed Al-Jaber Al-Sabah: 6528/6620
# -0.567744722986
# Levi Eshkol: 6529/6620
# 0.56183624311
# Israel Tal: 6530/6620
# 1.61924897348
# Mordechai Hod: 6531/6620
# 0.56183624311
# Yeshayahu Gavish: 6532/6620
# 0.56183624311
# Ezer Weizman: 6533/6620
# 0.56183624311
# Shlomo Erell: 6534/6620
# 0.56183624311
# Otozō Yamada: 6535/6620
# -0.454988869521
# Zhang Jinghui: 6536/6620
# -0.454988869521
# Francis Drake: 6537/6620
# 0.498670424338
# John Hawkins (naval commander): 6538/6620
# 0.498670424338
# Juan Martínez de Recalde: 6539/6620
# -0.504679745352
# Richard Butler (general): 6540/6620
# -0.498055652129
# William Darke: 6541/6620
# -0.498055652129
# Asaf Simhoni: 6542/6620
# 0.505624669645
# Haim Bar-Lev: 6543/6620
# 1.05741273037
# Avraham Yoffe: 6544/6620
# 0.505624669645
# Anthony Eden: 6545/6620
# 0.505624669645
# Gerald Templer: 6546/6620
# 0.505624669645
# Charles Keightley: 6547/6620
# 0.505624669645
# Hugh Stockwell: 6548/6620
# 0.505624669645
# Manley Laurence Power: 6549/6620
# 0.505624669645
# René Coty: 6550/6620
# 0.505624669645
# Guy Mollet: 6551/6620
# 0.505624669645
# Pierre Barjot: 6552/6620
# 0.505624669645
# André Beaufre: 6553/6620
# 0.505624669645
# Jacques Massu: 6554/6620
# 0.505624669645
# Martti Miettinen: 6555/6620
# 0.5
# Leopold I of Belgium: 6556/6620
# 0.465294518431
# Amédée de Failly: 6557/6620
# 0.465294518431
# Charles Niellon: 6558/6620
# 0.465294518431
# Tito Speri: 6559/6620
# -0.5
# Julius Jacob von Haynau: 6560/6620
# 0.5
# Khalifa Haftar: 6561/6620
# -0.5
# Filipp Golikov: 6562/6620
# -0.571466122328
# Paul Hausser: 6563/6620
# 0.56556958688
# Eberhard von Mackensen: 6564/6620
# 0.56556958688
# Theodor Eicke: 6565/6620
# 0.56556958688
# Haim Nadel: 6566/6620
# 0.452596276551
# Timur Shah Durrani: 6567/6620
# 0.463381836157
# Najib ad-Dawlah: 6568/6620
# 0.463381836157
# Sadashivrao Bhau: 6569/6620
# -0.469364042478
# Vishwasrao: 6570/6620
# -0.469364042478
# Malhar Rao Holkar: 6571/6620
# -0.469364042478
# Mahadaji Shinde: 6572/6620
# -0.469364042478
# Ibrahim Khan Gardi: 6573/6620
# -0.469364042478
# Jankoji Rao Scindia: 6574/6620
# -0.469364042478
# Bhoite: 6575/6620
# -0.469364042478
# Fahri Korutürk: 6576/6620
# 0.478667489481
# Bülent Ecevit: 6577/6620
# 0.478667489481
# Necmettin Erbakan: 6578/6620
# 0.478667489481
# Rauf Denktaş: 6579/6620
# 0.478667489481
# Nikos Sampson: 6580/6620
# -0.484668799667
# Glafcos Clerides: 6581/6620
# -0.484668799667
# Dimitrios Ioannidis: 6582/6620
# -0.484668799667
# Stephen Decatur: 6583/6620
# 0.496995305768
# John Surman Carden: 6584/6620
# -0.503004694232
# Ludwig von Falkenhausen: 6585/6620
# -0.436976239864
# Karl von Fasbender: 6586/6620
# -0.436976239864
# Georg Karl Wichura: 6587/6620
# -0.436976239864
# Ferdinand von Sammern-Frankenegg: 6588/6620
# 0.460416585554
# Jürgen Stroop: 6589/6620
# 0.460416585554
# Arpad Wigand: 6590/6620
# 0.460416585554
# Ludwig Hahn: 6591/6620
# 0.460416585554
# Mordechai Anielewicz: 6592/6620
# -0.466393782237
# Paweł Frenkiel: 6593/6620
# -0.466393782237
# Tadeusz Bór-Komorowski: 6594/6620
# -0.533067201049
# Tadeusz Pełczyński: 6595/6620
# -0.533067201049
# Antoni Chruściel: 6596/6620
# -0.533067201049
# Karol Ziemski: 6597/6620
# -0.533067201049
# Edward Pfeiffer: 6598/6620
# -0.533067201049
# Leopold Okulicki: 6599/6620
# -0.533067201049
# Jan Mazurkiewicz: 6600/6620
# -0.533067201049
# Zygmunt Berling: 6601/6620
# -0.533067201049
# Nikolaus von Vormann: 6602/6620
# 0.527079553123
# Reiner Stahel: 6603/6620
# 0.527079553123
# Erich von dem Bach-Zelewski: 6604/6620
# 0.527079553123
# Heinz Reinefarth: 6605/6620
# 0.527079553123
# Bronislav Kaminski: 6606/6620
# 0.527079553123
# Oskar Dirlewanger: 6607/6620
# 0.527079553123
# Petro Dyachenko: 6608/6620
# 0.527079553123
# Iosif Igelström: 6609/6620
# -0.519781777994
# Stanisław Mokronowski: 6610/6620
# 0.513779158368
# Jan Kiliński: 6611/6620
# 0.513779158368
# James W. Forsyth: 6612/6620
# 0.438085265927
# Spotted Elk: 6613/6620
# -0.444011113321
# Anwar Sadat: 6614/6620
# -0.557725374863
# Yusuf Shakkour: 6615/6620
# -0.557725374863
# Mohamed Abdel Ghani el-Gamasy: 6616/6620
# -0.557725374863
# Ali Aslan: 6617/6620
# -0.557725374863
# Golda Meir: 6618/6620
# 0.551788060724
# Yitzhak Hofi: 6619/6620
# 0.551788060724
# Harold Franklyn: 6620/6620
# -0.430649428825

# %%
df_totalwar = pd.DataFrame(war_list).sort_values('WAR', ascending = False).reset_index(drop = True)

# %%
df_run = df_run.dropna(subset = ['belligerent'])

# %%
df_totalwar = df_totalwar[df_totalwar.General != 'Capital punishment']
df_totalwar = df_totalwar[df_totalwar.General != 'Lieutenant general']

# %%
import seaborn as sns

# %%
sns.distplot(df_totalwar['WAR'], kde = False, bins = 30)
plt.title("Distribution of Generals' War")
plt.ylabel('Number of Generals')
plt.annotate('Napoleon', xy = (16.713, 1), xytext = (17.713, 400), arrowprops = dict(facecolor = 'black'))
plt.annotate('Julius Caesar', xy = (7.364545, 1), xytext = (8.364545, 400), arrowprops = dict(facecolor = 'black'))
plt.tight_layout()
plt.savefig('/home/ethanarsht/Downloads/distplot.png')

# %%
def index():
    output_file('docs/index.html')
    source = ColumnDataSource(data = dict(battles = df_totalwar.Battles,
                                          war = df_totalwar.WAR,
                                          general = df_totalwar.General))

    hover = HoverTool(tooltips = [('General', '@general'),
                                  ('Battles', '@battles'),
                                  ('WAR', '@war'),
                                      ])
    p = figure(title = "Click a circle for a profile of that general's career WAR",
               plot_height = 600, 
               plot_width = 800,

               tools = [hover, "tap", 'box_zoom', ResetTool()])
    p.circle(x = 'war', y = 'battles', size = 10, source = source)
    p.xaxis.axis_label = 'WAR'
    p.yaxis.axis_label = 'Battles'

    link = "{}.html".format('@general')

    if link == 'https://ethanarsht.github.io/military_rankings/Thomas de Courtenay, 5th/13th Earl of Devon':
            link = 'https://ethanarsht.github.io/military_rankings/Thomas de Courtenay'
    url = link
    taptool = p.select(type=TapTool)
    taptool.callback = OpenURL(url=url)
    save(p)

# %%
index()

# %%
def bokeh(commander):
    global df_battles
    
    df_battles = pd.DataFrame()
    commander_war(commander)
    
#     df_battles = df_battles[df_battles.General == commander]
    df_battles.Year = df_battles.Year.fillna(-5000)
    df_battles.Year = df_battles.Year.astype(float, errors = 'ignore')
    df_battles = df_battles.sort_values('Year')
    wl = pd.DataFrame(df_battles.Outcome.value_counts())
    
    if 'V' in wl.index:
        wins = wl.loc['V', 'Outcome']
    else:
        wins = 0
    if 'D' in wl.index:
        losses = wl.loc['D', 'Outcome']
    else:
        losses = 0
    if 'I' in wl.index:
        draws = wl.loc['I', 'Outcome']
    else:
        draws = 0
    df_battles = df_battles.reset_index(drop = True)
    for i, row in df_battles.iterrows():
        df_battles.ix[i, 'cumulative'] = sum(df_battles.Value[0:i+1])
    
    
    source = ColumnDataSource(data = dict(battle = df_battles.Battle,
                              general = df_battles.General,
                              outcome = df_battles.Outcome,
                              value = df_battles.Value,
                              year = df_battles.Year,
                              cumulative = df_battles.cumulative))
    if all(x != -5000 for x in df_battles.Year):
        hover = HoverTool(tooltips = [('Battle', '@battle'),
                                  ('Outcome', '@outcome'),
                                  ('WAR', '@value'),
                                  ('Cumulative WAR', '@cumulative'),
                                  ('Year', '@year')])
    else:
        hover = HoverTool(tooltips = [('Battle', '@battle'),
                                  ('Outcome', '@outcome'),
                                  ('WAR', '@value'),
                                  ('Cumulative WAR', '@cumulative')
                                  ])
    
    x = list(df_battles.Battle)
    y = list(df_battles.Value)
    y_cum = list(df_battles.cumulative)
    
    if commander == 'Thomas de Courtenay, 5th/13th Earl of Devon':
        commander = 'Thomas de Courtenay'
    
    output_file('docs/{}.html'.format(commander))
    
    p = figure(title = commander + ' ({} - {} - {})'.format(wins, draws, losses), 
               plot_width=800, 
               plot_height=600, 
               x_range = x, 
               tools = [hover, 'tap'])
    p.xaxis.axis_label = "Click on a bar for more info on the battle it represents"
    
    url = 'https://en.wikipedia.org/wiki/{}'.format('@battle')
    taptool = p.select(type=TapTool)
    taptool.callback = OpenURL(url=url)

    p.line(x = 'battle', y = 'cumulative', source = source, line_width = 5)
#     g1_r = p.add_glyph(source_or_glyph = source, glyph = g_2)
#     g1_tap = TapTool(renderers = [g1_r],
#                     callback = OpenURL(url=url))
#     p.add_tools(g1_tap)
    
    color_mapper = CategoricalColorMapper(factors=['V', 'D', 'I'], palette=['Blue', 'Red', 'Yellow'])
    p.vbar(x = 'battle', 
           top = 'value', 
           width = 0.9, 
           color={'field': 'outcome', 'transform': color_mapper},
           alpha = 0.5,
           source = source)
    
#     url_2 = 'en.wikipedia.org/wiki/@battle'
#     g2_r = p.add_glyph(source_or_glyph = source, glyph = g_2)
#     g2_tap = TapTool(renderers = [g2_r],
#                      callback = OpenURL(url=url_2))
#     p.add_tools(g2_tap)
    
    
    p.xaxis.major_label_orientation = math.pi/2
    

#     show(p)
    save(p)

# %%
count = 0
for general in df_run.belligerent.unique()[1:]:
    battle_list = []
    count += 1
    print(str(count) + '/' + str(len(df_run.belligerent.unique())))
    print(general)
    bokeh(general)
# Out:
# 1/6619
# Yisrael Galili
# 0.462461721355
# 2/6619
# Yaakov Dori
# 0.462461721355
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# 3/6619
# Yigael Yadin
# 0.462461721355
# 4/6619
# Mickey Marcus
# 0.462461721355
# 5/6619
# Yigal Allon
# 0.462461721355
# 6/6619
# Yitzhak Rabin
# 1.02429796446
# 7/6619
# David Shaltiel
# 0.462461721355
# 8/6619
# Moshe Dayan
# 2.08171069483
# 9/6619
# Shimon Avidan
# 0.462461721355
# 10/6619
# Moshe Carmel
# 0.462461721355
# 11/6619
# Yitzhak Sadeh
# 0.462461721355
# 12/6619
# Abdul Rahman Hassan Azzam
# -0.468442418538
# 13/6619
# Farouk of Egypt
# -0.468442418538
# 14/6619
# Abdullah I of Jordan
# -0.468442418538
# 15/6619
# Muzahim al-Pachachi
# -0.468442418538
# 16/6619
# Husni al-Za'im
# -0.468442418538
# 17/6619
# Amin al-Husseini
# -0.468442418538
# 18/6619
# Ahmed Ali al-Mwawi
# -0.468442418538
# 19/6619
# Mohammed Naguib
# -0.468442418538
# 20/6619
# John Bagot Glubb
# -0.468442418538
# 21/6619
# Habis al-Majali
# -0.468442418538
# 22/6619
# Hasan Salama
# -0.468442418538
# 23/6619
# Arab Liberation Army
# -0.468442418538
# 24/6619
# Fawzi al-Qawuqji
# -0.468442418538
# 25/6619
# Menachem Begin
# -0.071403319902
# 26/6619
# Ariel Sharon
# 2.13611957315
# 27/6619
# Rafael Eitan
# -0.071403319902
# 28/6619
# David Ivry
# -0.071403319902
# 29/6619
# Ze'ev Almog
# -0.071403319902
# 30/6619
# Bachir Gemayel
# -0.071403319902
# 31/6619
# Fadi Frem
# -0.071403319902
# 32/6619
# Elie Hobeika
# -0.071403319902
# 33/6619
# Fawzi Mahfuz
# -0.071403319902
# 34/6619
# Saad Haddad
# -0.071403319902
# 35/6619
# Yasser Arafat
# 0.0655065773299
# 36/6619
# Hafez al-Assad
# -0.492218797533
# 37/6619
# Mustafa Tlass
# -0.492218797533
# 38/6619
# George Hawi
# 0.0655065773299
# 39/6619
# Elias Atallah
# 0.0655065773299
# 40/6619
# Abbas al-Musawi
# 0.0655065773299
# 41/6619
# Ibrahim Kulaylat
# 0.0655065773299
# 42/6619
# Nabih Berri
# 0.0655065773299
# 43/6619
# Monte Melkonian
# 0.56550657733
# 44/6619
# Mahsum Korkmaz
# 0.0655065773299
# 45/6619
# Muhsin Ibrahim
# 0.0655065773299
# 46/6619
# Ragheb Harb
# 0.0655065773299
# 47/6619
# Murat Karayılan
# 0.0655065773299
# 48/6619
# Inaam Raad
# 0.0655065773299
# 49/6619
# Said Shaaban
# 0.0655065773299
# 50/6619
# Chandrika Kumaratunga
# -0.5
# 51/6619
# Velupillai Prabhakaran
# -1.93960155244
# 52/6619
# Murtala Mohammed
# -0.0844029930714
# 53/6619
# Jonathan Uchendu
# 0.578553187827
# 54/6619
# Lieutenant colonel (United Kingdom)
# 0.0713969247245
# 55/6619
# Philip Robert Anstruther
# -0.506615840969
# 56/6619
# Commandant-general
# 0.500606766003
# 57/6619
# Francois Gerhardus Joubert
# 0.500606766003
# 58/6619
# George Kenney
# 0.50052148216
# 59/6619
# William Halsey Jr.
# 1.84813112702
# 60/6619
# Frederick C. Sherman
# 0.50052148216
# 61/6619
# Mineichi Koga
# -0.14275591729
# 62/6619
# Jinichi Kusaka
# -0.952988269372
# 63/6619
# Gerard Muirhead-Gould
# -0.0611617657351
# 64/6619
# Hankyu Sasaki
# 0.0552337949251
# 65/6619
# Humayun
# 0.985451505266
# 66/6619
# Bairam Khan
# 0.985451505266
# 67/6619
# Autaritus
# -0.57179239756
# 68/6619
# Hamilcar Barca
# 1.06589694125
# 69/6619
# Lieutenant general
# 0.264064281882
# 70/6619
# Sarath Fonseka
# 2.93368865038
# 71/6619
# Brigadier
# 0.052760887833
# 72/6619
# Shavendra Silva
# 1.43368865038
# 73/6619
# Major general
# 1.96437319965
# 74/6619
# Kamal Gunaratne
# 1.0
# 75/6619
# Colonel
# 0.973364584534
# 76/6619
# G.V. Ravipriya
# 1.0
# 77/6619
# Pottu Amman (Tamil militant)
# -1.0
# 78/6619
# Theepan
# -1.0
# 79/6619
# Sivanadan Somasekaran
# -1.0
# 80/6619
# Decius
# -0.5
# 81/6619
# Herennius Etruscus
# -0.5
# 82/6619
# Cniva
# 1.0
# 83/6619
# Thrasybulus
# 2.49845408976
# 84/6619
# Thrasyllus
# 1.00664500254
# 85/6619
# Mindarus
# -1.51647937633
# 86/6619
# Leo Phokas the Elder
# -0.504708375642
# 87/6619
# Simeon I of Bulgaria
# 0.998699056953
# 88/6619
# Mark Antony
# -0.378776890175
# 89/6619
# Gaius Sosius
# -0.521226635176
# 90/6619
# Cleopatra
# 0.534845218175
# 91/6619
# Marcus Vipsanius Agrippa
# 2.00047080343
# 92/6619
# Augustus
# 3.36612188773
# 93/6619
# Lucius Arruntius the Elder
# 0.515225231907
# 94/6619
# Marcus Lurius
# 0.515225231907
# 95/6619
# Belisarius
# 1.61420350892
# 96/6619
# John the Armenian
# 1.00961020035
# 97/6619
# Gelimer
# -1.02159885089
# 98/6619
# Ammatas
# -0.487018287101
# 99/6619
# Trajan
# 1.44525025168
# 100/6619
# Tsar
# 0.496995305768
# 101/6619
# Kaloyan of Bulgaria
# 0.496995305768
# 102/6619
# Baldwin I, Latin Emperor
# -0.503004694232
# 103/6619
# Licinius
# -0.476839401577
# 104/6619
# Constantine the Great
# 2.00500476374
# 105/6619
# Fritigern
# 0.456165635255
# 106/6619
# Alatheus
# 0.456165635255
# 107/6619
# Saphrax
# 0.456165635255
# 108/6619
# Valens
# -0.462134910809
# 109/6619
# Marcus Atilius Regulus
# 0.431917749267
# 110/6619
# Bostar
# -0.451195195888
# 111/6619
# Hamilcar (Drepanum)
# -0.958420148495
# 112/6619
# Hasdrubal
# -0.904297406918
# 113/6619
# Lysander
# 0.99197810174
# 114/6619
# Aracus (admiral)
# 0.501095400823
# 115/6619
# Conon
# -0.0142087704451
# 116/6619
# Adeimantus (son of Leucolophides)
# -0.507104385223
# 117/6619
# Gerald FitzGerald, 15th Earl of Desmond
# -0.5
# 118/6619
# Thomas Butler, 10th Earl of Ormond
# 0.5
# 119/6619
# Quintus Fabius Maximus Verrucosus
# -0.503211454813
# 120/6619
# Hannibal
# 5.4609276435
# 121/6619
# Ilghazi
# -0.056980905341
# 122/6619
# Roger of Salerno
# 0.0
# 123/6619
# Charles I of Albret
# -0.557193278078
# 124/6619
# Jean Le Maingre
# -1.04186207775
# 125/6619
# Charles, Duke of Orléans
# -0.557193278078
# 126/6619
# Henry V of England
# 1.05125456817
# 127/6619
# Edward of Norwich, 2nd Duke of York
# 0.551254568166
# 128/6619
# Humphrey, Duke of Gloucester
# 0.551254568166
# 129/6619
# Louis XII of France
# 0.4371588303
# 130/6619
# Gian Giacomo Trivulzio
# 0.888137574311
# 131/6619
# Louis II de la Trémoille
# 0.357127862177
# 132/6619
# Charles II d'Amboise
# 0.4371588303
# 133/6619
# Bartolomeo d'Alviano
# -0.0147574896779
# 134/6619
# Hanno, son of Hannibal
# -1.03348911905
# 135/6619
# Hannibal Gisco
# -0.548808494715
# 136/6619
# Lucius Postumius Megellus (consul 262 BC)
# 0.508542310503
# 137/6619
# Quintus Mamilius Vitulus
# 0.508542310503
# 138/6619
# Qutuz
# 0.466870407982
# 139/6619
# Baibars
# 0.466870407982
# 140/6619
# Kitbuqa
# -0.0234410743836
# 141/6619
# Theodore (brother of Heraclius)
# -0.0617003159166
# 142/6619
# Khalid ibn al-Walid
# 5.61683495709
# 143/6619
# Abu Ubaidah ibn al-Jarrah
# 1.51077592356
# 144/6619
# 'Amr ibn al-'As
# 0.904586693451
# 145/6619
# Shurahbil ibn Hasana
# 1.49399061154
# 146/6619
# Yazid ibn Abi Sufyan
# 0.993990611536
# 147/6619
# Dhiraar bin Al-Azwar
# 0.993990611536
# 148/6619
# Musaylimah
# -0.555718262743
# 149/6619
# Abu Dujana
# 0.549775755079
# 150/6619
# Abdallah al-Battal
# -0.5
# 151/6619
# Al-Malik ibn Shu'aib
# -0.5
# 152/6619
# Leo III the Isaurian
# 0.5
# 153/6619
# Constantine V
# 1.42084812276
# 154/6619
# Tang Jiahui
# 0.5
# 155/6619
# Ashina Xin
# 0.5
# 156/6619
# Wikipedia:Accuracy dispute
# -0.0201791798205
# 157/6619
# Talk:Battle of Aksu (717)
# 0.5
# 158/6619
# Ashina Xian
# 0.5
# 159/6619
# Alfonso VIII of Castile
# 0.0315967254685
# 160/6619
# Diego López II de Haro
# 0.0315967254685
# 161/6619
# Abu Yusuf Yaqub al-Mansur
# 0.5
# 162/6619
# Pedro Fernández de Castro (died 1214)
# 0.5
# 163/6619
# Nicolas Le Nen
# 0.5
# 164/6619
# Col. Hussein
# 0.5
# 165/6619
# Lt Colonel Sean D Wester (USMC)
# 0.5
# 166/6619
# Shirkuh
# 0
# 167/6619
# Saladin
# -0.575657205457
# 168/6619
# Amalric of Jerusalem
# 0
# 169/6619
# Abu Marwan Abd al-Malik I Saadi
# 0.445009220667
# 170/6619
# Ahmad al-Mansur
# 0.445009220667
# 171/6619
# Sebastian of Portugal
# -0.450953562734
# 172/6619
# Abu Abdallah Mohammed II Saadi
# -0.450953562734
# 173/6619
# Thomas Stukley
# -0.450953562734
# 174/6619
# Vercingetorix
# -1.04140542515
# 175/6619
# Commius
# -0.528955009952
# 176/6619
# Julius Caesar
# 7.33541147929
# 177/6619
# Afonso V of Portugal
# 0.417360928803
# 178/6619
# Afonso I, Duke of Braganza
# 0.423367584534
# 179/6619
# Peter, Duke of Coimbra
# -0.429246428669
# 180/6619
# Guy of Lusignan
# 0.512338715425
# 181/6619
# John I of Castile
# -0.585820507783
# 182/6619
# Pedro Álvares Pereira
# -1.15503299052
# 183/6619
# John I of Portugal
# 1.07997631471
# 184/6619
# Nuno Álvares Pereira
# 1.14328494869
# 185/6619
# Murray of Aberscross
# 0.5
# 186/6619
# Donald Mackay, 11th of Strathnaver
# -0.5
# 187/6619
# Ranulf de Glanvill
# 0.42084812276
# 188/6619
# William the Lion
# -0.42671787139
# 189/6619
# Baldwin I of Jerusalem
# 0.525233873901
# 190/6619
# Mawdud
# 0.5
# 191/6619
# Toghtekin
# -1.52539930663
# 192/6619
# Dawit II
# -1.0
# 193/6619
# Ahmad ibn Ibrahim al-Ghazi
# 0.442195022586
# 194/6619
# Brasidas
# -0.562784555398
# 195/6619
# Cleon
# 0.00854231050338
# 196/6619
# Nicias
# -0.491457689497
# 197/6619
# Thucydides
# -0.491457689497
# 198/6619
# Tervel of Bulgaria
# 0.5
# 199/6619
# Justinian II
# -0.5
# 200/6619
# Telets of Bulgaria
# -0.5
# 201/6619
# William Eure, 1st Baron Eure
# -0.539366369433
# 202/6619
# Brian Layton
# -0.539366369433
# 203/6619
# James Hamilton, Duke of Châtellerault
# 0.00273790570343
# 204/6619
# Archibald Douglas, 6th Earl of Angus
# 0.00273790570343
# 205/6619
# Sophron of Ephesus
# -0.5
# 206/6619
# Ptolemy Andromachou
# -0.5
# 207/6619
# Antigonus II Gonatas
# 0.5
# 208/6619
# Oda Nobunaga
# 4.2111172206
# 209/6619
# Tokugawa Ieyasu
# 1.31209692797
# 210/6619
# Inaba Yoshimichi
# 0.474423948637
# 211/6619
# Azai Nagamasa
# -0.864841212234
# 212/6619
# Asakura Yoshikage
# -1.38106202307
# 213/6619
# Timur
# 0.471620485556
# 214/6619
# Shahrukh Mirza
# 0.471620485556
# 215/6619
# Khalil Sultan
# 0.471620485556
# 216/6619
# Miran Shah
# 0.471620485556
# 217/6619
# Abu Bakr (Timurid)
# 0.471620485556
# 218/6619
# Sultan Huseyn
# 0.471620485556
# 219/6619
# Pir Muhammad ibn Jahangir
# 0.471620485556
# 220/6619
# Taj al-Din Shah-i Shahan Abu'l Fath
# 0.471620485556
# 221/6619
# Bayezid I
# -0.0257632219095
# 222/6619
# Süleyman Çelebi
# -0.477614386678
# 223/6619
# Mehmed I
# -0.477614386678
# 224/6619
# Stefan Lazarević
# 0.00105310280299
# 225/6619
# Gannys
# 0.5
# 226/6619
# Heraclius
# -0.692535696132
# 227/6619
# Shahrbaraz
# 0.42084812276
# 228/6619
# Shahin Vahmanzadegan
# 0.5
# 229/6619
# Eslamu
# -0.58607339499
# 230/6619
# Fatagar
# -0.58607339499
# 231/6619
# Theophilos (emperor)
# -0.516554874731
# 232/6619
# Theophobos
# -0.516554874731
# 233/6619
# Manuel the Armenian
# -0.516554874731
# 234/6619
# Khaydhar ibn Kawus al-Afshin
# 0.510549901337
# 235/6619
# Umar al-Aqta
# 0.510549901337
# 236/6619
# Jaysh ibn Samsama
# 0.5
# 237/6619
# Damian Dalassenos
# -0.5
# 238/6619
# Teutobod
# 0.310706162768
# 239/6619
# Gaius Marius
# 1.07814887359
# 240/6619
# Germanic kingship
# 0.452596276551
# 241/6619
# Boiorix
# 0.298891221917
# 242/6619
# Quintus Servilius Caepio
# -0.458558228075
# 243/6619
# Gnaeus Mallius Maximus
# -0.458558228075
# 244/6619
# Francesco Bussone da Carmagnola
# 0.0
# 245/6619
# Bardas Skleros
# 0.5
# 246/6619
# Peter (stratopedarches)
# 0.5
# 247/6619
# Thomas le Botiller
# -0.5
# 248/6619
# William MacGeoghegan
# 0.5
# 249/6619
# Rhydderch Hael
# 0.5
# 250/6619
# Peredur
# 0.5
# 251/6619
# Gwenddoleu ap Ceidio
# -0.5
# 252/6619
# Priarius
# -0.5
# 253/6619
# Mallobaudes
# 0.5
# 254/6619
# Nannienus
# 0.5
# 255/6619
# Callicratidas
# 0.5
# 256/6619
# John Kingston (sailor)
# -0.388482773967
# 257/6619
# Nicolas Béhuchet
# -0.140614816258
# 258/6619
# Hugues Quiéret
# -0.140614816258
# 259/6619
# Lucius Caecilius Metellus Denter
# -0.5
# 260/6619
# Britomaris
# 0.5
# 261/6619
# Richard I of England
# 1.48545150527
# 262/6619
# Hugh III, Duke of Burgundy
# 0.5
# 263/6619
# Garnier de Nablus
# 0.0268872101588
# 264/6619
# Robert IV of Sablé
# 0.985451505266
# 265/6619
# James of Avesnes
# 0.5
# 266/6619
# Al-Adil I
# -0.575657205457
# 267/6619
# Al-Afdal ibn Salah ad-Din
# -0.0328751350917
# 268/6619
# Al-Muzaffar Umar
# -0.0841995159602
# 269/6619
# Tancred, Prince of Galilee
# 2.02279693671
# 270/6619
# Fakhr al-Mulk Radwan
# -1.02539930663
# 271/6619
# Eurybiades
# 0.597021150637
# 272/6619
# Themistocles
# 1.13846292256
# 273/6619
# Adeimantus of Corinth
# 0.0869813530246
# 274/6619
# Achaemenes (satrap)
# -0.608841607794
# 275/6619
# Ariabignes
# -0.608841607794
# 276/6619
# Artemisia I of Caria
# -0.608841607794
# 277/6619
# Damasithymus
# -0.608841607794
# 278/6619
# Al-Afdal Shahanshah
# -0.567069033635
# 279/6619
# Godfrey of Bouillon
# 2.45559562904
# 280/6619
# Raymond IV, Count of Toulouse
# 2.02279693671
# 281/6619
# Robert Curthose
# 2.02279693671
# 282/6619
# Robert II, Count of Flanders
# 2.02279693671
# 283/6619
# Eustace III, Count of Boulogne
# 0.558144704652
# 284/6619
# Gaston IV, Viscount of Béarn
# 1.07754668503
# 285/6619
# Publius Decius Mus (consul 279 BC)
# 0.496995305768
# 286/6619
# Pyrrhus of Epirus
# -0.53871182749
# 287/6619
# Pompeius Strabo
# 0.485451505266
# 288/6619
# Judacilius
# -0.491457689497
# 289/6619
# Fernando Sánchez de Tovar
# -0.569212482733
# 290/6619
# Pero Gonzalez de Sevilla
# -0.569212482733
# 291/6619
# Martim Anes de Barundo
# -0.569212482733
# 292/6619
# Henry of Grosmont, 1st Duke of Lancaster
# 0.5
# 293/6619
# Charles, Duke of Brittany
# -1.15330261771
# 294/6619
# John IV, Duke of Brittany
# 0.503923912343
# 295/6619
# John Chandos
# 1.03145919208
# 296/6619
# Mushkin Niusalavurd
# 0.43001330423
# 297/6619
# Mihr Narseh
# 0.43001330423
# 298/6619
# Izad Gushnasp
# 0.43001330423
# 299/6619
# Ashtat
# 0.43001330423
# 300/6619
# Vardan Mamikonian
# -0.435914668251
# 301/6619
# Jakob Henriksson Hästesko
# -0.527553470075
# 302/6619
# Daniel Rantzau
# -0.0166338652164
# 303/6619
# Hengist and Horsa
# 0
# 304/6619
# Vortigern
# 0
# 305/6619
# Vortimer
# 0
# 306/6619
# Catigern
# 0
# 307/6619
# Husayn ibn Numayr al-Sakuni
# 0.5
# 308/6619
# Udi Adam
# -0.5
# 309/6619
# Gal Hirsch
# -0.5
# 310/6619
# Romanos III Argyros
# -0.592707253402
# 311/6619
# Shibl al-Dawla Nasr
# 0.586891709269
# 312/6619
# Baldwin II of Jerusalem
# 1.0
# 313/6619
# Leo I, Prince of Armenia
# 0.5
# 314/6619
# Joscelin I, Count of Edessa
# 0.0
# 315/6619
# Pons, Count of Tripoli
# 0.5
# 316/6619
# Alfonso VI of León and Castile
# -0.5
# 317/6619
# Álvar Fáñez
# -0.5
# 318/6619
# Sancho Ramírez
# -0.5
# 319/6619
# Yusuf ibn Tashfin
# 0.5
# 320/6619
# Al-Mu'tamid ibn Abbad
# 0.5
# 321/6619
# Abdallah ibn Buluggin
# 0.5
# 322/6619
# Amr ibn Hishām
# -0.569455129973
# 323/6619
# Utbah ibn Rabi'ah
# -0.569455129973
# 324/6619
# Umayyah ibn Khalaf
# -0.569455129973
# 325/6619
# Hind bint Utbah
# -0.569455129973
# 326/6619
# Muhammad
# 1.19988729039
# 327/6619
# Hamza ibn Abdul-Muttalib
# 0.647126402557
# 328/6619
# Ali
# 1.71766123752
# 329/6619
# Abu Bakr
# 1.11631294467
# 330/6619
# Umar
# 1.11631294467
# 331/6619
# Scipio Africanus
# 2.49013903162
# 332/6619
# Hasdrubal Barca
# -0.961835335906
# 333/6619
# Abe no Hirafu
# -0.646578849265
# 334/6619
# Buyeo Pung
# -0.646578849265
# 335/6619
# Liu Rengui
# 0.641066693824
# 336/6619
# Munmu of Silla
# 0.641066693824
# 337/6619
# Buyeo Yung
# 0.641066693824
# 338/6619
# Wenceslaus I, Duke of Luxembourg
# -0.525795895619
# 339/6619
# William I, Marquis of Namur
# -0.525795895619
# 340/6619
# William II, Duke of Jülich
# 0.51979900049
# 341/6619
# Edward, Duke of Guelders
# 0.51979900049
# 342/6619
# Hasdrubal Gisco
# -0.511582676038
# 343/6619
# Syphax
# -0.5
# 344/6619
# Masinissa
# 1.00298593065
# 345/6619
# Gaius Laelius
# 0.5
# 346/6619
# Hulagu Khan
# 0.449416891158
# 347/6619
# Arghun Aqa
# 0.449416891158
# 348/6619
# Baiju
# 0.449416891158
# 349/6619
# Buqa-Temür
# 0.449416891158
# 350/6619
# Sunitai
# 0.449416891158
# 351/6619
# Guo Kan
# 0.858887647998
# 352/6619
# Koke Ilge
# 0.449416891158
# 353/6619
# Al-Musta'sim
# -0.455371801406
# 354/6619
# Capital punishment
# -4.83901061884
# 355/6619
# Mujaheduddin
# -0.455371801406
# 356/6619
# Sulaiman Shah
# -0.455371801406
# 357/6619
# Qarasunqur
# -0.455371801406
# 358/6619
# Al-Ashraf Musa, Sultan of Egypt
# -0.455371801406
# 359/6619
# Nang Wa
# -0.583864676763
# 360/6619
# Shen Yin Shu
# -0.583864676763
# 361/6619
# Helü
# 0.578012765694
# 362/6619
# Fugai
# 0.578012765694
# 363/6619
# Wu Zixu
# 0.578012765694
# 364/6619
# Sun Tzu
# 0.578012765694
# 365/6619
# Matthias Corvinus
# -0.52236673129
# 366/6619
# Stephen III of Moldavia
# 2.06326414772
# 367/6619
# Modu Chanyu
# 0.485451505266
# 368/6619
# Emperor Gaozu of Han
# -0.0700220559111
# 369/6619
# List of Khazar rulers
# 0.5
# 370/6619
# Abd ar-Rahman ibn Rabiah
# -0.5
# 371/6619
# Al-Jarrah ibn Abdallah
# 0.5
# 372/6619
# Charles the Bald
# -0.057754442556
# 373/6619
# Nominoe
# 0.548804804112
# 374/6619
# Mohamud Muse Hersi
# 0.5
# 375/6619
# Abdulrahman Said Dhegaweyne
# 0.5
# 376/6619
# Abdi Hasan Awale Qeybdiid
# 0.5
# 377/6619
# Mohamed Mohamud Agaweine
# -0.5
# 378/6619
# Daou al-Salhine al-Jadak
# 0.452596276551
# 379/6619
# Musa Yunis
# 0.452596276551
# 380/6619
# Saif al-Islam Gaddafi
# -0.97310672281
# 381/6619
# Tarik Sulayman
# -0.543313448018
# 382/6619
# Rajah Sulayman
# -0.543313448018
# 383/6619
# Miguel López de Legazpi
# 0.537343154959
# 384/6619
# Edward II of England
# -0.0487185904037
# 385/6619
# Humphrey de Bohun, 4th Earl of Hereford
# -0.98964204282
# 386/6619
# Aymer de Valence, 2nd Earl of Pembroke
# -0.602737040835
# 387/6619
# Gilbert de Clare, 8th Earl of Gloucester
# -0.548718590404
# 388/6619
# Robert de Clifford, 1st Baron de Clifford
# -0.548718590404
# 389/6619
# Robert the Bruce
# 0.58488347085
# 390/6619
# Edward Bruce
# 0.124060977039
# 391/6619
# Robert II Keith, Marischal of Scotland
# -0.0319058220954
# 392/6619
# James Douglas, Lord of Douglas
# 0.542759491743
# 393/6619
# Thomas Randolph, 1st Earl of Moray
# 0.542759491743
# 394/6619
# Yan Emperor
# 0.0262017968678
# 395/6619
# Yellow Emperor
# 1.02620179687
# 396/6619
# Osman I
# 0.5
# 397/6619
# Shapur I
# 1.5
# 398/6619
# Richard Neville, 16th Earl of Warwick
# -0.0571034358698
# 399/6619
# John Neville, 1st Marquess of Montagu
# 0.986016718255
# 400/6619
# Henry Holland, 3rd Duke of Exeter
# -1.04479311029
# 401/6619
# John de Vere, 13th Earl of Oxford
# 0.460871392972
# 402/6619
# Edward IV of England
# 3.04187722093
# 403/6619
# Richard III of England
# 0.512448326322
# 404/6619
# William Hastings, 1st Baron Hastings
# 1.03622128846
# 405/6619
# Suleiman II (Rûm)
# -0.535763819116
# 406/6619
# David Soslan
# 0.529780248061
# 407/6619
# Zakarids-Mkhargrzeli
# 0.529780248061
# 408/6619
# Shalva of Akhaltsikhe
# 0.529780248061
# 409/6619
# Nouri al-Maliki
# -0.034580563787
# 410/6619
# Ali Ghaidan Majid
# -0.034580563787
# 411/6619
# Mohan al-Furayji
# -0.034580563787
# 412/6619
# Fadhil Jalil al-Barwari
# -0.034580563787
# 413/6619
# Muqtada al-Sadr
# 0.52859516069
# 414/6619
# Shiek Ali al-Sauidi
# 0.0285951606897
# 415/6619
# Akram al-Kabi
# 0.0285951606897
# 416/6619
# Yusuf al-Mosawi
# 0.0285951606897
# 417/6619
# John Stewart, Earl of Buchan
# -0.625227989288
# 418/6619
# Gilbert Motier de La Fayette
# 0.441304378315
# 419/6619
# List of Marshals of France
# 0.441304378315
# 420/6619
# Thomas of Lancaster, 1st Duke of Clarence
# -0.447239112167
# 421/6619
# Thomas Beaufort, Duke of Exeter
# -0.447239112167
# 422/6619
# John Beaufort, 1st Duke of Somerset
# -0.447239112167
# 423/6619
# Zhang Fei
# 1.04880480411
# 424/6619
# Zhang He
# -0.0311341856853
# 425/6619
# Baldwin IV of Jerusalem
# 0.045371182389
# 426/6619
# Baldwin of Ibelin
# 0
# 427/6619
# Balian of Ibelin
# -0.973112789841
# 428/6619
# Hugh II of Saint Omer
# 0
# 429/6619
# Gökböri
# 0.880631328004
# 430/6619
# Charles I of Naples
# 0.5
# 431/6619
# Manfred, King of Sicily
# -0.5
# 432/6619
# Quintus Fulvius Flaccus (consul 237 BC)
# -0.0547750403194
# 433/6619
# Hanno the Elder
# -0.987934456472
# 434/6619
# Tiberius Sempronius Gracchus (consul 215 BC)
# 0.497569492331
# 435/6619
# Manius Curius Dentatus
# 0.5
# 436/6619
# John II Komnenos
# 0.5
# 437/6619
# Telerig of Bulgaria
# -0.42671787139
# 438/6619
# Seron (Syrian governor)
# -0.564993428085
# 439/6619
# Judas Maccabeus
# 2.2987893318
# 440/6619
# Cestius Gallus
# -0.5
# 441/6619
# Simon bar Giora
# 0.0460944199319
# 442/6619
# Lysias (Syrian chancellor)
# -1.0849810811
# 443/6619
# Eleazar Avaran
# 0.541441771925
# 444/6619
# Mirza Aziz Koka
# 0.5
# 445/6619
# Sunshu Ao
# 0.5
# 446/6619
# Zi Zhong
# 0.5
# 447/6619
# Zi Fan
# 0.5
# 448/6619
# Xun Linfu
# -0.5
# 449/6619
# Shi Hui (Spring and Autumn period)
# -0.5
# 450/6619
# Zhao Shuo
# -0.5
# 451/6619
# Divico
# -0.532652720588
# 452/6619
# Odet of Foix, Viscount of Lautrec
# -0.519913167543
# 453/6619
# Anne de Montmorency
# -0.504482690434
# 454/6619
# Georg von Frundsberg
# 1.53542131626
# 455/6619
# Fernando d'Avalos
# 1.53542131626
# 456/6619
# Prospero Colonna
# 1.03216989089
# 457/6619
# Abdul Fatah Younis
# -1.50600938846
# 458/6619
# Shoshenq I
# 0.5
# 459/6619
# Edward III of England
# 2.34864148498
# 460/6619
# Godemar du Foy
# -0.484668799667
# 461/6619
# John Babonić
# 0.5
# 462/6619
# Ban of Slavonia
# 0.5
# 463/6619
# Paul II Šubić of Bribir
# 0.5
# 464/6619
# Mladen II Šubić of Bribir
# -0.5
# 465/6619
# Ban of Croatia
# -0.5
# 466/6619
# George II Šubić of Bribir
# -0.5
# 467/6619
# John of Islay, Earl of Ross
# -0.5
# 468/6619
# Aonghas Óg
# 0.5
# 469/6619
# James Tuchet, 5th Baron Audley
# -0.537577357652
# 470/6619
# John Sutton, 1st Baron Dudley
# -0.537577357652
# 471/6619
# Richard Neville, 5th Earl of Salisbury
# 0.515789727488
# 472/6619
# Thomas Neville
# 0.531596725468
# 473/6619
# Algirdas
# 0.476227037861
# 474/6619
# Fyodor Koriatovych
# 0.476227037861
# 475/6619
# Demetrius, Prince of the Tatars
# -0.482226052871
# 476/6619
# Tonyukuk
# 0.5
# 477/6619
# Robert Fyssher
# 0.443998349359
# 478/6619
# Le Seigneur de Tais
# -0.449940135527
# 479/6619
# Jakob Bagge
# 0.452602089329
# 480/6619
# Jacob Brockenhuus
# -0.45856405328
# 481/6619
# Andrew Harclay, 1st Earl of Carlisle
# 0.435006571915
# 482/6619
# John Peche
# 0.435006571915
# 483/6619
# Thomas, 2nd Earl of Lancaster
# -0.940923452417
# 484/6619
# Roger de Clifford, 2nd Baron de Clifford
# -0.440923452417
# 485/6619
# John Howard, 1st Duke of Norfolk
# -0.523772962139
# 486/6619
# Henry Percy, 4th Earl of Northumberland
# -0.523772962139
# 487/6619
# John de la Pole, 1st Earl of Lincoln
# -1.00599901501
# 488/6619
# Thomas Howard, 2nd Duke of Norfolk
# -0.0114461311097
# 489/6619
# Francis Lovell, 1st Viscount Lovell
# -0.523772962139
# 490/6619
# Henry VII of England
# 0.99400098499
# 491/6619
# Jasper Tudor, Duke of Bedford
# 0.49400098499
# 492/6619
# Gilbert Talbot (soldier)
# 0.517773947129
# 493/6619
# Philibert de Chandée, 1st Earl of Bath
# 0.517773947129
# 494/6619
# Rhys ap Thomas
# 0.517773947129
# 495/6619
# Otto IV, Holy Roman Emperor
# -0.517714549684
# 496/6619
# William Longespée, 3rd Earl of Salisbury
# 0.0569924844388
# 497/6619
# Renaud I, Count of Dammartin
# -0.517714549684
# 498/6619
# Ferdinand, Count of Flanders
# -0.517714549684
# 499/6619
# Theobald I, Duke of Lorraine
# -0.517714549684
# 500/6619
# Henry I, Duke of Brabant
# -0.517714549684
# 501/6619
# Philip II of France
# 0.416590347226
# 502/6619
# Robert II, Count of Dreux
# 0.51171036449
# 503/6619
# Philip of Dreux
# 0.51171036449
# 504/6619
# Odo III, Duke of Burgundy
# 0.51171036449
# 505/6619
# William IV, Count of Ponthieu
# 0.51171036449
# 506/6619
# Thomas de Rokeby
# 0.5
# 507/6619
# Henry Percy, 1st Earl of Northumberland
# -0.0313084920037
# 508/6619
# Pál Kinizsi
# 0.495034473425
# 509/6619
# Bartholomew Drágfi
# 0.495034473425
# 510/6619
# Stephen V Báthory
# 0.495034473425
# 511/6619
# Vuk Grgurević
# 0.495034473425
# 512/6619
# Demetrius Jaksics
# 0.495034473425
# 513/6619
# Basarab Laiotă cel Bătrân
# -0.057812913863
# 514/6619
# Basarab Țepeluș cel Tânăr
# -0.50104376946
# 515/6619
# Suleiman Mahmoud
# -0.00300469423196
# 516/6619
# Mutassim Gaddafi
# -0.452870133216
# 517/6619
# William de Bohun, 1st Earl of Northampton
# 0.371128471462
# 518/6619
# Carlo Grimaldi
# -0.376755876443
# 519/6619
# Seguin de Badefol
# 0.485451505266
# 520/6619
# Petit Meschin
# 0.485451505266
# 521/6619
# James I, Count of La Marche
# -0.491457689497
# 522/6619
# Charles de Mornay
# 0.532212842522
# 523/6619
# Julian (emperor)
# 1.52628484537
# 524/6619
# Æthelstan
# 0.5
# 525/6619
# Edmund I
# 0.5
# 526/6619
# Olaf Guthfrithson
# -0.5
# 527/6619
# Constantine II of Scotland
# -0.5
# 528/6619
# Owain ap Dyfnwal (fl. 934)
# -0.5
# 529/6619
# Sten Sture the Elder
# 0.477920298894
# 530/6619
# Christian I of Denmark
# -0.483920936824
# 531/6619
# Charles the Bold
# -0.945252698241
# 532/6619
# Raes van Heers
# -0.466538574835
# 533/6619
# Edmund Mortimer (1376-1409)
# -0.517844412733
# 534/6619
# Owain Glyndŵr
# 1.01184031983
# 535/6619
# Shōni Sukeyoshi
# 0.5
# 536/6619
# 少弐資能
# 0.5
# 537/6619
# Ōtomo Yoriyasu
# 0.5
# 538/6619
# 大友頼泰
# 0.5
# 539/6619
# Kikuchi Takefusa
# 0.5
# 540/6619
# Takezaki Suenaga
# 0.5
# 541/6619
# Hindun
# -0.5
# 542/6619
# 忻都 - 维基百科，自由的百科全书
# -0.5
# 543/6619
# Liu Fuheng
# -0.5
# 544/6619
# Kim Bang-gyeong
# -0.5
# 545/6619
# 김방경 - 위키백과, 우리 모두의 백과사전
# -0.5
# 546/6619
# Yi Sun-sin
# 2.69625151877
# 547/6619
# Won Gyun
# 1.14701699992
# 548/6619
# Yi Eokgi
# 0.667947573296
# 549/6619
# Jeong Un
# 0.565215054853
# 550/6619
# 정운 - 위키백과, 우리 모두의 백과사전
# 0.565215054853
# 551/6619
# Wakisaka Yasuharu
# -1.30380414215
# 552/6619
# Kuki Yoshitaka
# -0.727718446353
# 553/6619
# Tōdō Takatora
# -1.26697305794
# 554/6619
# Katō Yoshiaki
# -0.281901970614
# 555/6619
# Æthelred, Lord of the Mercians
# 0.0
# 556/6619
# Hastein
# -0.5
# 557/6619
# Lan Yu (general)
# 0.5
# 558/6619
# Uskhal Khan Tögüs Temür
# -0.5
# 559/6619
# Maximilian III, Archduke of Austria
# -0.970808418812
# 560/6619
# Jan Zamoyski
# 0.501152501539
# 561/6619
# Tachibana Muneshige
# 0.405636057216
# 562/6619
# Ukita Hideie
# 0.731775778216
# 563/6619
# Kobayakawa Takakage
# 1.37984322508
# 564/6619
# Li Rusong
# -0.468403274532
# 565/6619
# Rhys Gryg
# 0.5
# 566/6619
# Stephen Bauzan
# -0.5
# 567/6619
# Walter Manny, 1st Baron Manny
# 0.5
# 568/6619
# Guy, Bastard of Flanders
# -0.5
# 569/6619
# Raoul II of Brienne, Count of Eu
# -0.422792208712
# 570/6619
# Publius Ostorius Scapula
# 0.5
# 571/6619
# Caratacus
# -1.05869562168
# 572/6619
# Atahualpa
# -0.092151023753
# 573/6619
# Francisco Pizarro
# 1.48553675162
# 574/6619
# Hernando Pizarro
# 1.05736492159
# 575/6619
# Gonzalo Pizarro
# 1.56036961582
# 576/6619
# Juan Pizarro (conquistador)
# 1.48553675162
# 577/6619
# Hernando de Soto
# 1.08633308052
# 578/6619
# Fínghin Mac Carthaigh
# 0.5
# 579/6619
# John FitzGerald, 1st Baron Desmond
# -0.5
# 580/6619
# Hermogenes (magister officiorum)
# 0.0436007595109
# 581/6619
# Sunicas
# 0.0436007595109
# 582/6619
# Al-Harith ibn Jabalah
# -0.487995965958
# 583/6619
# Azarethes
# 0.481991990482
# 584/6619
# Al-Mundhir III ibn al-Nu'man
# 0.481991990482
# 585/6619
# Aimery IV of Narbonne
# 0.488657731528
# 586/6619
# Guillaume da Durfort
# 0.488657731528
# 587/6619
# Guglielmino Ubertini
# -0.494665448622
# 588/6619
# Pandolfo II Malatesta
# 0.427670480738
# 589/6619
# Konrad von Landau
# -0.433564149354
# 590/6619
# Boudica
# -0.162021854036
# 591/6619
# Quintus Petillius Cerialis
# -0.440923452417
# 592/6619
# Murong Bao
# -0.564328760313
# 593/6619
# Murong Nong
# -0.564328760313
# 594/6619
# Murong Lin
# -0.564328760313
# 595/6619
# Murong De
# -0.564328760313
# 596/6619
# Emperor Daowu of Northern Wei
# 0.558409905184
# 597/6619
# Gaius Terentius Varro
# -0.532112229902
# 598/6619
# Lucius Aemilius Paullus (consul 219 BC)
# -0.532112229902
# 599/6619
# Maharbal
# 0.526123222219
# 600/6619
# Mago Barca
# 0.0209837181477
# 601/6619
# Gisgo
# 0.526123222219
# 602/6619
# Hanno, son of Bomilcar
# 0.526123222219
# 603/6619
# Hasdrubal (quartermaster)
# 0.526123222219
# 604/6619
# Marcus Claudius Marcellus
# 0.485451505266
# 605/6619
# Lucius Manlius Vulso Longus
# 0.501215992325
# 606/6619
# Hanno the Great
# -1.00722495261
# 607/6619
# Appius Claudius Pulcher (consul 212 BC)
# -0.533129592018
# 608/6619
# Francesco I Sforza
# 1.43336725146
# 609/6619
# Micheletto Attendolo
# 0.0280834568882
# 610/6619
# William Kirkcaldy of Grange
# 1.0147692529
# 611/6619
# James Hepburn, 4th Earl of Bothwell
# -0.503004694232
# 612/6619
# Necho II
# -0.542325243158
# 613/6619
# Nebuchadnezzar II
# 2.03635305579
# 614/6619
# Marcus Licinius Crassus
# -0.492283149229
# 615/6619
# Publius Licinius Crassus (son of triumvir)
# -0.492283149229
# 616/6619
# Gaius Cassius Longinus
# -1.47650869877
# 617/6619
# Surena
# 0.486276523307
# 618/6619
# Hasan ibn al-Nu'man
# 0.5
# 619/6619
# Tiberios III
# -0.5
# 620/6619
# Hasdrubal the Boetharch
# -0.5
# 621/6619
# Scipio Aemilianus
# 1.0
# 622/6619
# Manius Manilius
# 0.5
# 623/6619
# Alberico da Barbiano
# 0.5
# 624/6619
# Muzio Sforza
# -0.0295631264638
# 625/6619
# Galeotto I Malatesta
# 0.458119558182
# 626/6619
# John Hawkwood
# 0.0565116595446
# 627/6619
# Hanneken von Baumgarten
# -0.464092582825
# 628/6619
# Azzo VII d'Este
# 0.5
# 629/6619
# Ezzelino III da Romano
# -0.5
# 630/6619
# Nicolaas Zannekin
# -0.503004694232
# 631/6619
# Philip VI of France
# 0.496995305768
# 632/6619
# Giovanni Ordelaffi
# -0.526600239852
# 633/6619
# Da Polenta family
# -0.526600239852
# 634/6619
# Giovanni dell'Ischia
# -0.526600239852
# 635/6619
# Francesco Novello da Carrara
# 0.52060424237
# 636/6619
# Jean Bureau
# 0.493846160668
# 637/6619
# John Talbot, 1st Earl of Shrewsbury
# -1.55855093241
# 638/6619
# Leptines of Syracuse
# 0.536482319111
# 639/6619
# Mieszko I of Poland
# 0.482155587267
# 640/6619
# Czcibor
# 0.482155587267
# 641/6619
# Odo I, Margrave of the Saxon Ostmark
# -0.488159680167
# 642/6619
# Nasar
# 0.923899619029
# 643/6619
# Ibn al-Hawas
# -0.62597778934
# 644/6619
# Roger I of Sicily
# 0.620332996853
# 645/6619
# Serlo II of Hauteville
# 0.620332996853
# 646/6619
# Alfonso d'Avalos
# -0.511645917167
# 647/6619
# Francis, Count of Enghien
# 1.00563832404
# 648/6619
# Louis d'Armagnac, Duke of Nemours
# -0.524257761446
# 649/6619
# Yves d'Alègre
# -0.524257761446
# 650/6619
# Pierre Terrail, seigneur de Bayard
# -0.524257761446
# 651/6619
# Gonzalo Fernández de Córdoba
# 1.44261728876
# 652/6619
# Pedro Navarro, Count of Oliveto
# 0.0339036529133
# 653/6619
# Fabrizio Colonna
# 0.0339036529133
# 654/6619
# Prince Henry the Navigator
# 0.5
# 655/6619
# Chares of Athens
# -1.0109976371
# 656/6619
# Lysicles (4th century BC)
# -0.510997637099
# 657/6619
# Athens
# -0.510997637099
# 658/6619
# Theagenes (general)
# -0.510997637099
# 659/6619
# Philip II of Macedon
# 0.504989784676
# 660/6619
# Alexander the Great
# 4.36214640505
# 661/6619
# Archelaus (general)
# -1.63678582564
# 662/6619
# Sulla
# 1.62497348883
# 663/6619
# Constantine I of Georgia
# -0.5
# 664/6619
# Ibrahim I of Shirvan
# -0.5
# 665/6619
# Syed Ahmed Orlat
# -0.5
# 666/6619
# Qara Yusuf
# 0.5
# 667/6619
# Yar Ahmed Qaramanli
# 0.5
# 668/6619
# Jagath Jayasuriya
# 0.933688650378
# 669/6619
# Prasanna Silva
# 0.5
# 670/6619
# Vinayagam
# -0.5
# 671/6619
# Selim I
# 1.48689701003
# 672/6619
# Hasan Pasha (Ottoman commander)
# 0.482155587267
# 673/6619
# Ismail I
# -0.488159680167
# 674/6619
# Abd al-Baqi Yazdi
# -0.488159680167
# 675/6619
# Hossein Beg Laleh Shamlu
# -0.488159680167
# 676/6619
# Saru Pira Ustajlu
# -0.488159680167
# 677/6619
# Durmish Khan Shamlu
# -0.488159680167
# 678/6619
# Nur-Ali Khalifa
# -0.488159680167
# 679/6619
# Mohammad Khan Ustajlu
# -0.488159680167
# 680/6619
# Sayyed Sharif al-Din Ali Shirazi
# -0.488159680167
# 681/6619
# John of Montfort
# -0.5
# 682/6619
# Bai Qi
# 1.01820211576
# 683/6619
# Lian Po
# -0.492612183151
# 684/6619
# Zhao Kuo
# -0.492612183151
# 685/6619
# Cheng Dechen
# -0.5
# 686/6619
# Zishang
# -0.5
# 687/6619
# Zixi (Zhou dynasty)
# -0.5
# 688/6619
# Hu Mao
# 0.5
# 689/6619
# Hu Yan
# 0.5
# 690/6619
# Xian Zhen
# 0.5
# 691/6619
# Xi Zhen
# 0.5
# 692/6619
# Xu Chen (Zhou dynasty)
# 0.5
# 693/6619
# Luan Zhi
# 0.5
# 694/6619
# Konishi Yukinaga
# 1.68405316475
# 695/6619
# Shimazu Yoshihiro
# 0.94836996682
# 696/6619
# Choe Ho
# -0.413168853002
# 697/6619
# Bae Seol
# -0.413168853002
# 698/6619
# Chalcuchimac
# 1.00498978468
# 699/6619
# Quizquiz
# 0.504989784676
# 700/6619
# Rumiñawi (Inca warrior)
# 0.5
# 701/6619
# Inca Empire
# -0.5
# 702/6619
# Atoc
# -0.5
# 703/6619
# Hango (general)
# -0.5
# 704/6619
# Ullco Colla
# -0.5
# 705/6619
# Albert of Schwarzburg
# 0.489699880164
# 706/6619
# Mehmed Beg
# -0.495707989001
# 707/6619
# Philip V of Macedon
# -1.03826546475
# 708/6619
# Attalus I
# 0.544710409938
# 709/6619
# Theophiliscus
# 0.544710409938
# 710/6619
# Bertrand du Guesclin
# 1.4990115322
# 711/6619
# John Devereux, 1st Baron Devereux
# -0.46526772134
# 712/6619
# Bernhard von Zinnenberg
# 0.469395127702
# 713/6619
# Casimir IV Jagiellon
# -0.475386192264
# 714/6619
# Jan Taszka Koniecpolski
# -0.475386192264
# 715/6619
# Piotr of Szczekociny
# -0.475386192264
# 716/6619
# Mullah Mutalib
# -0.5
# 717/6619
# Mullah Ismael
# -0.5
# 718/6619
# Shin Rip
# -0.557292576077
# 719/6619
# Byeon Gi
# -0.557292576077
# 720/6619
# Kim Yeo-mul
# -0.557292576077
# 721/6619
# Yi Il
# -1.494982849
# 722/6619
# Yi Jong-jang
# -0.557292576077
# 723/6619
# Sō Yoshitoshi
# 0.899102063726
# 724/6619
# Matsura Shigenobu
# 0.551354125601
# 725/6619
# Arima Harunobu
# 0.551354125601
# 726/6619
# Ōmura Yoshiaki
# 0.551354125601
# 727/6619
# Gnaeus Cornelius Scipio Calvus
# 0.984061386211
# 728/6619
# Walter Sans Avoir
# -0.564993428085
# 729/6619
# Kilij Arslan I
# -0.330827508721
# 730/6619
# Rudolf of Benevento
# -0.530317715855
# 731/6619
# Gerard, Duke of Lorraine
# -0.530317715855
# 732/6619
# Humphrey of Hauteville
# 0.524326271863
# 733/6619
# Robert Guiscard
# 1.52743508078
# 734/6619
# Richard I of Capua
# 0.524326271863
# 735/6619
# Brian Boru
# 0.993938776838
# 736/6619
# Murchad mac Briain
# 0.493938776838
# 737/6619
# Sigtrygg Silkbeard
# -0.999947940709
# 738/6619
# Máel Mórda mac Murchada
# -0.999947940709
# 739/6619
# Sigurd the Stout
# -0.499947940709
# 740/6619
# Brodir and Ospak of Man
# -0.499947940709
# 741/6619
# Pharnabazus II
# -0.00492221426662
# 742/6619
# Peisander (general)
# -0.498904599177
# 743/6619
# Jean III de Grailly, captal de Buch
# -0.0211475894896
# 744/6619
# John I Albert
# -0.5
# 745/6619
# Stanisław Chodecki
# -0.5
# 746/6619
# Provenzano Salvani
# -0.604674993111
# 747/6619
# Giambertoldo
# 0.598914694976
# 748/6619
# Conrad III of Germany
# -1.5
# 749/6619
# Manuel I Komnenos
# 0.0
# 750/6619
# Lucius Mummius Achaicus
# 0.454147999165
# 751/6619
# Diaeus
# -0.460113210188
# 752/6619
# Titus Manlius Torquatus (dictator)
# 0.484932397048
# 753/6619
# Hasdrubal the Bald
# -0.490938286576
# 754/6619
# Hampsicora
# -0.490938286576
# 755/6619
# Agesilaus II
# 0.5
# 756/6619
# Tolmides
# -0.5
# 757/6619
# Sparton
# 0.5
# 758/6619
# James Stewart, 1st Earl of Moray
# 0.435006571915
# 759/6619
# John Stewart, 4th Earl of Atholl
# 0.435006571915
# 760/6619
# James Douglas, 4th Earl of Morton
# 0.435006571915
# 761/6619
# George Gordon, 4th Earl of Huntly
# 0.0768504947119
# 762/6619
# Pietro Tiepolo
# -0.592902775789
# 763/6619
# Roman Catholic Archdiocese of Milan
# -0.592902775789
# 764/6619
# Frederick II, Holy Roman Emperor
# 0.0870880785294
# 765/6619
# Henry IV of France
# 1.00172173322
# 766/6619
# Anne de Joyeuse
# -0.503004694232
# 767/6619
# Munuza
# -0.605302564434
# 768/6619
# Al Qama
# -0.605302564434
# 769/6619
# Pelagius of Asturias
# 0.599545354679
# 770/6619
# Alexander, 2nd Lord Forbes of Pitsligo
# -0.509117299084
# 771/6619
# Adam Gordon of Auchindoun
# 0.503108808922
# 772/6619
# Antipater
# 0.927548501479
# 773/6619
# Craterus
# 2.41319392002
# 774/6619
# Antiphilus (general)
# -0.471110813974
# 775/6619
# Menon IV of Pharsalus
# -0.471110813974
# 776/6619
# Louis, Count of Vendôme
# -0.537577357652
# 777/6619
# Thomas Montagu, 4th Earl of Salisbury
# 1.05455854499
# 778/6619
# Gerard de Ridefort
# -0.407009242082
# 779/6619
# Roger de Moulins
# -0.419347957507
# 780/6619
# Otto II, Holy Roman Emperor
# -0.5
# 781/6619
# Landulf IV of Benevento
# -0.5
# 782/6619
# Abu al-Qasim (Kalbid)
# 0.5
# 783/6619
# Abu al-Qasim (Kalbite) — Wikipédia
# 0.5
# 784/6619
# Emirate of Sicily
# 0.5
# 785/6619
# Owain Gwynedd
# 0.5
# 786/6619
# Cadwaladr ap Gruffydd
# 0.5
# 787/6619
# Gruffydd ap Rhys
# 0.5
# 788/6619
# Robert fitz Martin
# -0.5
# 789/6619
# Maurice FitzGerald, Lord of Lanstephan
# -0.5
# 790/6619
# Avidius Cassius
# 0.5
# 791/6619
# Vologases IV
# -0.5
# 792/6619
# Merena
# 0
# 793/6619
# Artaxerxes II of Persia
# -0.0557182627432
# 794/6619
# Gobrias
# -0.0557182627432
# 795/6619
# Tissaphernes
# -0.0557182627432
# 796/6619
# Cyrus the Younger
# 0.0497757550786
# 797/6619
# Clearchus of Sparta
# -0.448042073966
# 798/6619
# Ariaeus
# 0.0497757550786
# 799/6619
# Lamba Doria
# 0.518729631193
# 800/6619
# Andrea Dandolo (admiral)
# -0.524727670296
# 801/6619
# Titus Quinctius Flamininus
# 0.981596646277
# 802/6619
# Ubba
# -0.5
# 803/6619
# Odda, Ealdorman of Devon
# 0.5
# 804/6619
# Alcibiades
# 0.491809087219
# 805/6619
# Theramenes
# 0.491809087219
# 806/6619
# Hermocrates
# 0.00218217095594
# 807/6619
# Gar Trinring Tsendro
# 0.416937186838
# 808/6619
# Xue Rengui
# -0.422792208712
# 809/6619
# Ashina Daozi
# -0.422792208712
# 810/6619
# Guo Daifeng
# -0.422792208712
# 811/6619
# Abdul Qayyum Zakir
# -0.5
# 812/6619
# Sancho d'Avila
# 1.02544716575
# 813/6619
# Mas'ud I of Ghazni
# -0.556305035676
# 814/6619
# Ali Daya
# -0.556305035676
# 815/6619
# Ahmad Shirazi
# -0.556305035676
# 816/6619
# Abu Sahl Zawzani
# -0.556305035676
# 817/6619
# Abd al-Razzaq Maymandi
# -0.556305035676
# 818/6619
# Begtoghdi
# -0.556305035676
# 819/6619
# Subashi (general)
# -0.556305035676
# 820/6619
# Chaghri Beg
# 0.550364026211
# 821/6619
# Tughril
# 0.550364026211
# 822/6619
# Faramurz
# 0.550364026211
# 823/6619
# Minamoto no Yoshitsune
# 1.54863542108
# 824/6619
# Taira no Munemori
# -1.03166323338
# 825/6619
# Taira no Tomomori
# -0.0316632333767
# 826/6619
# Perozes
# -0.537577357652
# 827/6619
# Pityaxes
# -0.537577357652
# 828/6619
# Baresmanas
# -0.537577357652
# 829/6619
# Pharas the Herulian
# 0.531596725468
# 830/6619
# Taddeo d'Este
# -0.5
# 831/6619
# Niccolò Piccinino
# 1.0
# 832/6619
# William the Silent
# -1.06938489522
# 833/6619
# Thomas Morgan (died 1595)
# 0.984578014241
# 834/6619
# Francisco de Valdez
# -1.00121101321
# 835/6619
# Julian Romero
# 0.00776281155236
# 836/6619
# Pagondas
# 0.489002362901
# 837/6619
# Hippocrates of Athens
# -0.495010215324
# 838/6619
# Alexios Doukas Philanthropenos
# 0.472459313104
# 839/6619
# John Palaiologos (brother of Michael VIII)
# -0.630258485936
# 840/6619
# Fillippo Sanudo
# -0.478454221538
# 841/6619
# Guglielmo II da Verona
# -0.478454221538
# 842/6619
# Publius Cornelius Scipio
# -0.51097059422
# 843/6619
# Chen Tai
# 0.441304378315
# 844/6619
# Deng Ai
# 0.441304378315
# 845/6619
# Hu Fen
# 0.441304378315
# 846/6619
# Jiang Wei
# -0.415642386699
# 847/6619
# Xiahou Ba
# -0.447239112167
# 848/6619
# Zhang Yi (Bogong)
# -0.447239112167
# 849/6619
# Mazyadid dynasty
# -0.556980905341
# 850/6619
# David IV of Georgia
# 0.551041642157
# 851/6619
# Demetrius I of Georgia
# 0.551041642157
# 852/6619
# Francisco de Almeida
# 0.468336766623
# 853/6619
# Amir Husain Al-Kurdi
# -0.474326398436
# 854/6619
# Malik Ayyaz
# -0.474326398436
# 855/6619
# Kunhali Marakkar
# -0.474326398436
# 856/6619
# Giovanni Andrea Doria
# -0.0297523950964
# 857/6619
# Juan de la Cerda, 4th Duke of Medinaceli
# -0.544011746079
# 858/6619
# Álvaro de Sande
# -0.544011746079
# 859/6619
# Piali Pasha
# -0.0312602919392
# 860/6619
# Dragut
# 0.40458850958
# 861/6619
# Major general (United States)
# 0.5
# 862/6619
# Major (United States)
# 0.5
# 863/6619
# Sviatoslav I of Kiev
# -1.0579100199
# 864/6619
# John I Tzimiskes
# 1.04592363904
# 865/6619
# Bohemond I of Antioch
# 1.40055973331
# 866/6619
# Adhemar of Le Puy
# 1.39745092439
# 867/6619
# Danishmend Gazi
# -0.438708860417
# 868/6619
# Mesud I
# 0.5
# 869/6619
# Adherbal (admiral)
# 0.496995305768
# 870/6619
# Hamilcar
# 0.496995305768
# 871/6619
# Publius Claudius Pulcher (consul 249 BC)
# -0.503004694232
# 872/6619
# Francis, Duke of Guise
# 0.882536372055
# 873/6619
# Louis, Prince of Condé (1530–1569)
# -1.50068438185
# 874/6619
# Gaspard II de Coligny
# -0.998227165849
# 875/6619
# Hector Roy Mackenzie
# -0.0289550099519
# 876/6619
# John Balliol
# -0.503004694232
# 877/6619
# John de Warenne, 6th Earl of Surrey
# -0.0342042532848
# 878/6619
# Domhnall II, Earl of Mar
# -0.574665313838
# 879/6619
# Edward Balliol
# 0.568779581557
# 880/6619
# Henry de Beaumont
# 0.568779581557
# 881/6619
# Burchard von Hornhausen
# -0.537577357652
# 882/6619
# Treniota
# 0.531596725468
# 883/6619
# Alexios I Komnenos
# 0.511849709842
# 884/6619
# George Palaiologos
# -0.00911729908368
# 885/6619
# Sikelgaita
# 0.503108808922
# 886/6619
# Pompey
# 0.908476362702
# 887/6619
# Richard de Clare, Steward of Forest of Essex
# -0.5
# 888/6619
# Valerian (emperor)
# -0.5
# 889/6619
# Successianus
# -0.5
# 890/6619
# Robin of Redesdale
# 0.5
# 891/6619
# William Herbert, 1st Earl of Pembroke (died 1469)
# -0.5
# 892/6619
# Humphrey Stafford, 1st Earl of Devon
# -0.5
# 893/6619
# Alfred the Great
# 0.5
# 894/6619
# Guthrum
# -0.5
# 895/6619
# Bacchides (general)
# 0.403250759798
# 896/6619
# Iphicrates
# 0.0
# 897/6619
# Timotheus (general)
# -0.5
# 898/6619
# Aurelian
# 0.952596276551
# 899/6619
# Zenobia
# -0.958558228075
# 900/6619
# Zabdas
# -0.958558228075
# 901/6619
# Gorgias (general)
# -0.528955009952
# 902/6619
# Nicanor (Seleucid general)
# -0.528955009952
# 903/6619
# Hegesandridas
# 0.5
# 904/6619
# Edward I of England
# 0.866838924487
# 905/6619
# Gilbert de Clare, 7th Earl of Gloucester
# 0.994019367817
# 906/6619
# Simon de Montfort, 6th Earl of Leicester
# 0.0631934509369
# 907/6619
# Peter de Montfort
# -0.468403274532
# 908/6619
# Lucius Aemilius Papus
# -0.0059455730451
# 909/6619
# Stilicho
# 0.994026101036
# 910/6619
# Sarus the Goth
# 0.5
# 911/6619
# Uldin
# 0.5
# 912/6619
# Radagaisus
# -0.5
# 913/6619
# Theodore Trithyrius
# -1.00300469423
# 914/6619
# Hasan ibn Ali
# 0.0177739471286
# 915/6619
# William Wallace
# 0.077279081555
# 916/6619
# Cao Ren
# 0.0136963243704
# 917/6619
# Yu Jin
# 0.478667489481
# 918/6619
# Pang De
# 0.478667489481
# 919/6619
# Xu Huang
# 0.446879560677
# 920/6619
# Guan Yu
# 0.0641360044445
# 921/6619
# Louis IX of France
# 0.093274136668
# 922/6619
# Guillaume de Sonnac
# -0.5
# 923/6619
# Al-Muazzam Turanshah
# 0.5
# 924/6619
# Shane O'Neill (son of Conn)
# -0.00300469423196
# 925/6619
# Sir Hugh O'Donnell
# 0.496995305768
# 926/6619
# John de Bermingham, 1st Earl of Louth
# 0.412859634541
# 927/6619
# Edmund Butler, Earl of Carrick
# 0.412859634541
# 928/6619
# Earl of Carrick (Ireland)
# 0.412859634541
# 929/6619
# Earl of Carrick
# -0.418698514703
# 930/6619
# Fu Jian (337–385)
# -0.588489790392
# 931/6619
# Fu Rong
# -0.588489790392
# 932/6619
# Xie An
# 0.582656429268
# 933/6619
# Xie Xuan
# 0.582656429268
# 934/6619
# Huan Chong
# 0.582656429268
# 935/6619
# John Clifford, 9th Baron Clifford
# 0.462422642348
# 936/6619
# John Neville, Baron Neville
# 0
# 937/6619
# James IV of Scotland
# 0.00463124831241
# 938/6619
# Alexander Home, 3rd Lord Home
# -0.518330571207
# 939/6619
# William Graham, 1st Earl of Montrose
# -0.518330571207
# 940/6619
# Adam Hepburn, 2nd Earl of Bothwell
# -0.518330571207
# 941/6619
# Matthew Stewart, 2nd Earl of Lennox
# -0.518330571207
# 942/6619
# Archibald Campbell, 2nd Earl of Argyll
# -0.518330571207
# 943/6619
# Catherine of Aragon
# 0.512326831029
# 944/6619
# Thomas Howard, 3rd Duke of Norfolk
# 0.512326831029
# 945/6619
# Lord Edmund Howard
# 0.512326831029
# 946/6619
# Thomas Dacre, 2nd Baron Dacre
# 0.512326831029
# 947/6619
# Edward Stanley, 1st Baron Monteagle
# 0.512326831029
# 948/6619
# Marmaduke Constable
# 0.512326831029
# 949/6619
# Charles I, Duke of Bourbon
# 0.495853267427
# 950/6619
# Arthur III, Duke of Brittany
# 0.495853267427
# 951/6619
# Sir Thomas Kyriell
# -0.501862624538
# 952/6619
# Francesco II Gonzaga, Marquess of Mantua
# -0.535317720224
# 953/6619
# Charles VIII of France
# 0.529333450548
# 954/6619
# Gaius Vibius Pansa Caetronianus
# 0.892133973644
# 955/6619
# Aulus Hirtius
# 0.892133973644
# 956/6619
# Enzo of Sardinia
# 0.469957079858
# 957/6619
# Ottaviano degli Ubaldini
# -0.475948883228
# 958/6619
# Thomas Müntzer
# 0.482155587267
# 959/6619
# Philip I, Landgrave of Hesse
# 0.511840319833
# 960/6619
# George, Duke of Saxony
# 0.511840319833
# 961/6619
# Minamoto no Yoritomo
# 1.07829679106
# 962/6619
# Taira no Koremori
# -1.08606750739
# 963/6619
# Harald Hardrada
# -0.479077407862
# 964/6619
# Tostig Godwinson
# -0.0146155381322
# 965/6619
# Morcar
# -0.468403274532
# 966/6619
# Edwin, Earl of Mercia
# -0.468403274532
# 967/6619
# Antigonus I Monophthalmus
# 0.489850365263
# 968/6619
# Eumenes
# -0.483029137811
# 969/6619
# Han Xin
# 0.980512181169
# 970/6619
# Xiang Yu
# 0.128551525979
# 971/6619
# Pietro Loredan
# 0.5
# 972/6619
# Alberic I of Spoleto
# 0.5
# 973/6619
# Nicholas Picingli
# 0.5
# 974/6619
# Pope John X
# 0.5
# 975/6619
# Ludovico II, Marquess of Saluzzo
# -0.513676403748
# 976/6619
# Willekin von Endorp
# -0.5
# 977/6619
# Darius III
# -1.08362416735
# 978/6619
# Bessus
# -0.527481029757
# 979/6619
# Mazaeus
# -0.527481029757
# 980/6619
# Orontes II
# -0.527481029757
# 981/6619
# Atropates
# -0.527481029757
# 982/6619
# Hephaestion
# 2.4546087747
# 983/6619
# Parmenion
# 1.53552607187
# 984/6619
# Ptolemy I Soter
# 2.01548803841
# 985/6619
# Perdiccas
# 0.995318502129
# 986/6619
# Cleitus the Black
# 0.98532435878
# 987/6619
# Nearchus
# 0.521486050974
# 988/6619
# Seleucus I Nicator
# 1.99106610414
# 989/6619
# Ariston of Paionia
# 0.521486050974
# 990/6619
# Simmias of Macedon
# 0.521486050974
# 991/6619
# Coenus (general)
# 0.995318502129
# 992/6619
# Ariston of Macedon
# 0.521486050974
# 993/6619
# Glaucias of Macedon
# 0.521486050974
# 994/6619
# Sopolis of Macedon
# 0.521486050974
# 995/6619
# Francesco Ferruccio
# -0.533851227956
# 996/6619
# Philibert of Chalon
# 0.527864729232
# 997/6619
# Fabrizio Maramaldo
# 0.527864729232
# 998/6619
# Demetrius I of Macedon
# -0.132230393086
# 999/6619
# Dionysius I of Syracuse
# 1.01489183431
# 1000/6619
# Himilco (general)
# -0.0513256526911
# 1001/6619
# Antoine de Goignies
# -0.518526142466
# 1002/6619
# Maximilien de Hénin-Liétard
# -0.0248588963384
# 1003/6619
# William II de La Marck
# -0.518526142466
# 1004/6619
# Maarten Schenck van Nydeggen
# -0.518526142466
# 1005/6619
# Emanuel Philibert de Lalaing
# -0.518526142466
# 1006/6619
# Philip, Count of Egmont
# -1.02926052187
# 1007/6619
# Charles Philippe de Croÿ, Marquis d’Havré
# -0.518526142466
# 1008/6619
# Henry Balfour (soldier)
# -0.518526142466
# 1009/6619
# John of Austria
# 0.533840674897
# 1010/6619
# Alexander Farnese, Duke of Parma
# 0.00784280203626
# 1011/6619
# Cristóbal de Mondragón
# 0.512522547388
# 1012/6619
# Ottavio Gonzaga
# 0.512522547388
# 1013/6619
# Peter Ernst I von Mansfeld-Vorderort
# 0.512522547388
# 1014/6619
# Francisco Verdugo
# 0.512522547388
# 1015/6619
# John FitzAlan, 14th Earl of Arundel
# -0.57179239756
# 1016/6619
# La Hire
# 1.11865782908
# 1017/6619
# Jean Poton de Xaintrailles
# 1.11865782908
# 1018/6619
# Marcus Minucius Rufus
# -0.468403274532
# 1019/6619
# Magister equitum
# -0.468403274532
# 1020/6619
# Archibald Campbell, 7th Earl of Argyll
# -0.57179239756
# 1021/6619
# George Gordon, 1st Marquess of Huntly
# 0.565896941246
# 1022/6619
# Francis Hay, 9th Earl of Erroll
# 0.565896941246
# 1023/6619
# Máel Sechnaill mac Domnaill
# 0.5
# 1024/6619
# Sorley Boy MacDonnell
# -0.5
# 1025/6619
# Joseph Kabila
# 0.441304378315
# 1026/6619
# Babacar Gaye
# 0.441304378315
# 1027/6619
# Ignace Murwanashyaka
# 0.441304378315
# 1028/6619
# José Eduardo dos Santos
# 0.441304378315
# 1029/6619
# Robert Mugabe
# 0.441304378315
# 1030/6619
# Laurent Nkunda
# -0.447239112167
# 1031/6619
# Lamoral, Count of Egmont
# 0.929986408467
# 1032/6619
# Paul de Thermes
# -0.486456481493
# 1033/6619
# Gaius Claudius Nero
# 0.961622358422
# 1034/6619
# Ulrich von Jungingen
# -0.528530471446
# 1035/6619
# Władysław II Jagiełło
# 1.04031070233
# 1036/6619
# Vytautas
# 0.0616737091592
# 1037/6619
# Roderic
# -0.51717036461
# 1038/6619
# Tariq ibn Ziyad
# 0.511165801488
# 1039/6619
# Chunyu Qiong
# -0.551324380869
# 1040/6619
# Guo Tu
# -0.551324380869
# 1041/6619
# Cao Hong
# -0.512383260167
# 1042/6619
# Tian Ji
# 0.959417948116
# 1043/6619
# Sun Bin
# 0.959417948116
# 1044/6619
# Pang Juan
# -0.971407968764
# 1045/6619
# Maximilian I, Holy Roman Emperor
# 0.335624757942
# 1046/6619
# Philippe de Crèvecœur d'Esquerdes
# -0.458866239029
# 1047/6619
# Henry VIII of England
# 1.43279869234
# 1048/6619
# Henry Bourchier, 2nd Earl of Essex
# 0.432798692337
# 1049/6619
# Jacques de La Palice
# -0.382896667001
# 1050/6619
# Charles IV, Duke of Alençon
# -0.438708860417
# 1051/6619
# Louis I d'Orléans, duc de Longueville
# -0.438708860417
# 1052/6619
# Petar Svačić
# -0.5
# 1053/6619
# Coloman, King of Hungary
# 0.5
# 1054/6619
# Eumenes II
# 0.996995305768
# 1055/6619
# Dexagoridas
# -0.5
# 1056/6619
# Gorgopas (2nd century BC)
# -0.5
# 1057/6619
# Marinus Brandt
# -0.531663233377
# 1058/6619
# Robert Bowes (lawyer)
# -0.523772962139
# 1059/6619
# Katō Kiyomasa
# 0.882207420566
# 1060/6619
# Kuroda Nagamasa
# 1.33369814838
# 1061/6619
# Ishida Mitsunari
# -0.628223146657
# 1062/6619
# Kikkawa Hiroie
# -0.57915187724
# 1063/6619
# Kobayakawa Hideaki
# -0.57915187724
# 1064/6619
# Kwon Yul
# 0.0447516571641
# 1065/6619
# Jo Gyeong
# 0.57328212861
# 1066/6619
# Seon Geoi
# 0.57328212861
# 1067/6619
# Kim Cheon Il
# 0.57328212861
# 1068/6619
# Heo Uk
# 0.57328212861
# 1069/6619
# Cheo Yung
# 0.57328212861
# 1070/6619
# Archibald Douglas (died 1333)
# -0.521887252237
# 1071/6619
# Thomas of Brotherton, 1st Earl of Norfolk
# 0.515886438589
# 1072/6619
# Walter V, Count of Brienne
# -0.5
# 1073/6619
# Al-Husayn ibn Zikrawayh
# -0.5
# 1074/6619
# Muhammad ibn Sulayman al-Katib
# 0.5
# 1075/6619
# Husayn ibn Hamdan
# 0.5
# 1076/6619
# Cao Xiu
# -1.11344537001
# 1077/6619
# Zhao Yun
# 0.536354388916
# 1078/6619
# Huang Zhong
# 0.548804804112
# 1079/6619
# Liu Bei
# 1.10615191873
# 1080/6619
# Raymond III, Count of Tripoli
# -1.03180841153
# 1081/6619
# Bohemond III of Antioch
# -0.558695621685
# 1082/6619
# Constantine Kalamanos
# -0.558695621685
# 1083/6619
# Thoros II, Prince of Armenia
# -0.558695621685
# 1084/6619
# Hugh VIII of Lusignan
# -0.558695621685
# 1085/6619
# Joscelin III, Count of Edessa
# -1.03180841153
# 1086/6619
# Nur ad-Din (died 1174)
# 1.48555958017
# 1087/6619
# Qutb ad-Din Mawdud
# 0.552760887833
# 1088/6619
# Alexander Stewart, Earl of Mar
# -0.5
# 1089/6619
# Donald of Islay, Lord of the Isles
# 0
# 1090/6619
# Mosul
# 1.0
# 1091/6619
# Sökmen (Artuqid)
# -0.025399306631
# 1092/6619
# William the Conqueror
# 0.494186589697
# 1093/6619
# Alan Rufus
# 0.494186589697
# 1094/6619
# William FitzOsbern, 1st Earl of Hereford
# 0.494186589697
# 1095/6619
# Eustace II, Count of Boulogne
# 0.494186589697
# 1096/6619
# Harold Godwinson
# -0.0291507984639
# 1097/6619
# Gyrth Godwinson
# -0.500195788512
# 1098/6619
# Leofwine Godwinson
# -0.500195788512
# 1099/6619
# Raynald of Châtillon
# 0.0722583925478
# 1100/6619
# Humphrey IV of Toron
# -0.473112789841
# 1101/6619
# Aimery of Cyprus
# -0.473112789841
# 1102/6619
# Reginald of Sidon
# -0.473112789841
# 1103/6619
# Þórður kakali Sighvatsson
# 0.5
# 1104/6619
# Henry Beaufort, 3rd Duke of Somerset
# -1.04279770396
# 1105/6619
# Thomas de Ros, 9th Baron de Ros
# -0.993556828033
# 1106/6619
# Robert Hungerford, 3rd Baron Hungerford
# -0.993556828033
# 1107/6619
# Ralph Percy
# -0.493556828033
# 1108/6619
# Louis of Nassau
# -1.64129669931
# 1109/6619
# Adolf of Nassau (1540–1568)
# 0.466329956373
# 1110/6619
# Jean de Ligne, Duke of Arenberg
# -0.472316723303
# 1111/6619
# John, King of Denmark
# -0.5
# 1112/6619
# Frederick I of Denmark
# -0.5
# 1113/6619
# Publius Valerius Laevinus
# -0.470276527102
# 1114/6619
# Ismail Khan
# 0.5
# 1115/6619
# Tommy Franks
# -0.00300469423196
# 1116/6619
# Yahya Rahim Safavi
# 0.5
# 1117/6619
# Flaccus
# -0.486089345626
# 1118/6619
# Hannibal Mago
# 1.5
# 1119/6619
# Hamilcar I of Carthage
# -0.576632415466
# 1120/6619
# Gelo
# 0.570753571331
# 1121/6619
# Theron of Acragas
# 0.570753571331
# 1122/6619
# Henry Percy (Hotspur)
# -0.53942386292
# 1123/6619
# George I, Earl of March
# 1.00028823346
# 1124/6619
# Archibald Douglas, 4th Earl of Douglas
# -1.003636636
# 1125/6619
# Jan Žižka
# 2.1814075591
# 1126/6619
# Diviš Bořek of Miletínek
# 1.48494627989
# 1127/6619
# Čeněk of Wartenberg
# -0.523457141354
# 1128/6619
# Artabanus V of Parthia
# -0.5
# 1129/6619
# Ardashir I
# 0.5
# 1130/6619
# Dou Jiande
# -0.541880441818
# 1131/6619
# Wang Shichong
# -0.01028371635
# 1132/6619
# Duan Da
# -0.541880441818
# 1133/6619
# Shan Xiongxin
# -0.541880441818
# 1134/6619
# Emperor Taizong of Tang
# 0.535907417175
# 1135/6619
# Li Yuanji
# 0.535907417175
# 1136/6619
# Liu Dewei
# 0.535907417175
# 1137/6619
# Huang Junhan
# 0.535907417175
# 1138/6619
# Yuwen Shiji
# 0.535907417175
# 1139/6619
# Shi Wanbao
# 0.535907417175
# 1140/6619
# Li Shiji
# 0.535907417175
# 1141/6619
# Emperor Gaozu of Tang
# 0.5
# 1142/6619
# Li Jiancheng
# 0.5
# 1143/6619
# Kim Yu-sin
# 0.412859634541
# 1144/6619
# Kim Heum-sun
# 0.412859634541
# 1145/6619
# Kim Pumil
# 0.412859634541
# 1146/6619
# Gyebaek
# -0.418698514703
# 1147/6619
# Cyrus the Great
# 1.59277711114
# 1148/6619
# Harpagus
# -0.0325743059443
# 1149/6619
# Taira no Tadanori
# -0.528955009952
# 1150/6619
# Taira no Shigehira
# -0.0289550099519
# 1151/6619
# Taira no Noritsune
# -1.02895500995
# 1152/6619
# Minamoto no Noriyori
# 0.52296181952
# 1153/6619
# Frederick I, Holy Roman Emperor
# 0.00498978467603
# 1154/6619
# Frederick VI, Duke of Swabia
# 0.985451505266
# 1155/6619
# Géza, son of Géza II of Hungary
# 0.5
# 1156/6619
# Děpolt II
# 0.985451505266
# 1157/6619
# Demosthenes (general)
# 1.5
# 1158/6619
# Northern Chanyu (1st century)
# -0.503004694232
# 1159/6619
# Dou Xian
# 0.496995305768
# 1160/6619
# Lucius Afranius (consul)
# -0.518526142466
# 1161/6619
# Marcus Petreius
# -0.576181931761
# 1162/6619
# Marcus Terentius Varro
# -0.518526142466
# ...
# Kim Jun-min
# 0.558814601558
# 6245/6619
# Jeong Gi-ryong
# 0.0302841301114
# 6246/6619
# Im Gye-yeong
# 0.558814601558
# 6247/6619
# Choi Gyeong-hoe
# 0.558814601558
# 6248/6619
# Yu Sung-in
# 0.558814601558
# 6249/6619
# Hwang Jin
# -0.478814347916
# 6250/6619
# Kim Cheon-il
# -0.478814347916
# 6251/6619
# Ivan the Terrible
# 0.5
# 6252/6619
# Alexander Gorbatyi-Shuisky
# 0.5
# 6253/6619
# Andrey Kurbsky
# 0.5
# 6254/6619
# Shahghali
# 0.5
# 6255/6619
# Yadegar Mokhammad of Kazan
# -0.5
# 6256/6619
# Yapancha beg
# -0.5
# 6257/6619
# Zaynash morza
# -0.5
# 6258/6619
# Qolsharif
# -0.5
# 6259/6619
# Afonso Pereira de Lacerda
# 0.5
# 6260/6619
# Diogo de Melo Coutinho
# 0.5
# 6261/6619
# Gabriel, comte de Montgomery
# 0
# 6262/6619
# Pieter Adriaanszoon van der Werff
# 0.512981712899
# 6263/6619
# Afonso I of Portugal
# 0.5
# 6264/6619
# Hervey de Glanvill
# 0.5
# 6265/6619
# Arnout IV, Count of Aarschot
# 0.5
# 6266/6619
# Christian of Ghistelles
# 0.5
# 6267/6619
# Simon of Dover
# 0.5
# 6268/6619
# Saher of Archelle
# 0.5
# 6269/6619
# Louis XIV of France
# 1.22100350865
# 6270/6619
# Jacques de Fariaux, baron de Maulde
# -0.828481470308
# 6271/6619
# Alaal-Din
# -0.5
# 6272/6619
# Leonis Pereira
# 0.5
# 6273/6619
# Jean Parisot de Valette
# 0.563399552533
# 6274/6619
# Jean de la Cassière
# 0.563399552533
# 6275/6619
# Mathurin Romegas
# 0.563399552533
# 6276/6619
# Goncales de Medran
# 0.563399552533
# 6277/6619
# Melchior de Robles
# 0.563399552533
# 6278/6619
# García de Toledo Osorio, 4th Marquis of Villafranca
# 0.563399552533
# 6279/6619
# Decimus Junius Brutus Albinus
# 0.465419436213
# 6280/6619
# Trebonius
# 0.465419436213
# 6281/6619
# Lucius Domitius Ahenobarbus (consul 54 BC)
# -0.47140483931
# 6282/6619
# Kamiizumi Nobutsuna
# -0.47703818048
# 6283/6619
# Nagano Narimori
# -0.47703818048
# 6284/6619
# Niho Takayasu
# 0.5
# 6285/6619
# Ōtomo Sōrin
# -0.5
# 6286/6619
# Tachibana Dōsetsu
# -0.5
# 6287/6619
# Tawara Chikakata
# -0.5
# 6288/6619
# Usuki Akihaya
# -0.5
# 6289/6619
# Oi Sadataka
# -0.458558228075
# 6290/6619
# Yi Bok-nam
# -0.430640994345
# 6291/6619
# Yi Chun-won
# -0.430640994345
# 6292/6619
# Kim Gyeong-ro
# -0.430640994345
# 6293/6619
# Ma Eung-bang
# -0.430640994345
# 6294/6619
# Oh Eung-jeong
# -0.430640994345
# 6295/6619
# Im Hyeon
# -0.430640994345
# 6296/6619
# Yi Deok-hoe
# -0.430640994345
# 6297/6619
# Jeong Gi-won
# -0.430640994345
# 6298/6619
# Hwang Dae-jung
# -0.430640994345
# 6299/6619
# Shin Ho
# -0.430640994345
# 6300/6619
# Jo Gyeong-nam
# -0.430640994345
# 6301/6619
# Yang Hao (Ming dynasty)
# -0.959171465792
# 6302/6619
# Jiang Biao
# -0.430640994345
# 6303/6619
# Mao Cheng Xian
# -0.430640994345
# 6304/6619
# Aristagoras
# -0.5
# 6305/6619
# Megabates
# -0.5
# 6306/6619
# Manuel Boutoumites
# 0.445250251676
# 6307/6619
# Charles V, Holy Roman Emperor
# -0.5
# 6308/6619
# Charles III, Duke of Savoy
# -0.5
# 6309/6619
# Suganuma Sadamichi
# -0.400754813597
# 6310/6619
# Satake Yoshiaki
# -0.579492178073
# 6311/6619
# Ōta Sukemasa
# -0.579492178073
# 6312/6619
# Nagano Narimasa
# -0.579492178073
# 6313/6619
# Oda Ujiharu
# -0.579492178073
# 6314/6619
# Utsunomiya Hirotsuna
# -0.579492178073
# 6315/6619
# Satomi Yoshihiro
# -0.579492178073
# 6316/6619
# Nasu Suketane
# -0.579492178073
# 6317/6619
# Yura Narishige
# -0.579492178073
# 6318/6619
# Mita Tsunahide
# -0.579492178073
# 6319/6619
# Oda Nobukatsu
# 0.449674671
# 6320/6619
# Gamō Ujisato
# 0.449674671
# 6321/6619
# Sanada Masayuki
# 0.449674671
# 6322/6619
# Chōsokabe Motochika
# 0.949674671
# 6323/6619
# Shimazu Hisayasu
# 0.449674671
# 6324/6619
# Hōjō Ujimasa
# -0.455630170309
# 6325/6619
# Hōjō Ujinao
# -0.455630170309
# 6326/6619
# Narita Ujinaga
# -0.455630170309
# 6327/6619
# Kaihime
# -0.455630170309
# 6328/6619
# Niccolò di Pitigliano
# 0.544121504599
# 6329/6619
# Andrea Gritti
# 0.544121504599
# 6330/6619
# Henry II of France
# -0.5
# 6331/6619
# Yun Doo-su
# -0.527093537548
# 6332/6619
# Ryu Seong-ryong
# -0.527093537548
# 6333/6619
# Kim Myeong-won
# -0.527093537548
# 6334/6619
# Yi Won-ik
# -0.527093537548
# 6335/6619
# Hwang Won
# -0.527093537548
# 6336/6619
# Kim Ung-seo
# -0.527093537548
# 6337/6619
# Go Eop-baek
# -0.527093537548
# 6338/6619
# Zu Chengxun
# -0.527093537548
# 6339/6619
# Tian Cong
# -0.527093537548
# 6340/6619
# Abu'l-Hasan Asaf Khan
# 0.5
# 6341/6619
# Munim Khan
# 0.5
# 6342/6619
# Mesih Pasha
# -0.59583717759
# 6343/6619
# Pierre d'Aubusson
# 0.590035412442
# 6344/6619
# Suleiman the Magnificent
# -0.176505863223
# 6345/6619
# Çoban Mustafa Pasha
# 0.401867462268
# 6346/6619
# Kurtoğlu Muslihiddin Reis
# 0.401867462268
# 6347/6619
# Philippe Villiers de L'Isle-Adam
# -0.407658821108
# 6348/6619
# Ares (General)
# -0.455696468544
# 6349/6619
# Vitiges
# -0.566903635857
# 6350/6619
# Claude de La Chatre
# 0.446342904935
# 6351/6619
# Mayor Johnanneau
# -0.452290543657
# 6352/6619
# Captain Lafleur
# -0.452290543657
# 6353/6619
# Ankokuji Ekei
# 0.5
# 6354/6619
# Antonio Loredan
# 0.599477611216
# 6355/6619
# Pietro Mocenigo
# 0.599477611216
# 6356/6619
# Triadan Gritti
# 0.599477611216
# 6357/6619
# Ivan Crnojević
# 0.599477611216
# 6358/6619
# Mago II of Carthage
# -0.581554171423
# 6359/6619
# Spitamenes
# -0.5
# 6360/6619
# Mahmud Pasha Angelović
# 0.5
# 6361/6619
# David of Trebizond
# -0.5
# 6362/6619
# Sinan Pasha (Ottoman admiral)
# 0.406497027792
# 6363/6619
# Gaspard de Vallier
# -0.412309113845
# 6364/6619
# Kim Gwi-hoe
# -0.528530471446
# 6365/6619
# Jang Un-ik
# -0.528530471446
# 6366/6619
# Ma Gui (general)
# -0.528530471446
# 6367/6619
# Qian Wanli
# -0.528530471446
# 6368/6619
# Asano Yoshinaga
# 0.522536755201
# 6369/6619
# Mōri Hidemoto
# 0.522536755201
# 6370/6619
# Nabeshima Naoshige
# 0.522536755201
# 6371/6619
# Hachisuka Iemasa
# 0.522536755201
# 6372/6619
# Pargalı Ibrahim Pasha
# -0.578373325492
# 6373/6619
# Nicholas, Count of Salm
# 0.572500733455
# 6374/6619
# Philip, Duke of Palatinate-Neuburg
# 0.572500733455
# 6375/6619
# Wilhelm von Roggendorf
# 0.572500733455
# 6376/6619
# Josephus
# -0.503004694232
# 6377/6619
# Jazzar Pasha
# -0.584367946032
# 6378/6619
# Sidney Smith (Royal Navy officer)
# -1.06813193302
# 6379/6619
# David Hendrik Chassé
# -0.5
# 6380/6619
# Étienne Maurice Gérard
# 0.5
# 6381/6619
# François-Nicolas-Benoît Haxo
# 0.5
# 6382/6619
# Victor Deguise
# -0.543313448018
# 6383/6619
# Archibald Paris (Royal Marines officer)
# -0.543313448018
# 6384/6619
# Armand Philippon
# -0.430578078384
# 6385/6619
# Ulrich Frédéric Woldemar, Comte de Lowendal
# 0.445250251676
# 6386/6619
# Domingo Ugartechea
# -0.537577357652
# 6387/6619
# Stephen F. Austin
# 0.531596725468
# 6388/6619
# Edward Burleson
# 0.531596725468
# 6389/6619
# Benjamin Milam
# 0.531596725468
# 6390/6619
# Justinus van Nassau
# -0.0123272127613
# 6391/6619
# Ambrogio Spinola, 1st Marquis of the Balbases
# 0.916169472333
# 6392/6619
# Carlos Coloma
# 0.504989784676
# 6393/6619
# Jean-Louis Dubreton
# 0.588740572477
# 6394/6619
# Nana Sahib
# 0.441304378315
# 6395/6619
# Tatya Tope
# 0.441304378315
# 6396/6619
# Hugh Wheeler (East India Company officer)
# -0.447239112167
# 6397/6619
# Captain (British Army and Royal Marines)
# -0.447239112167
# 6398/6619
# John Moore (British Major)
# -0.447239112167
# 6399/6619
# Mariot Arbuthnot
# 0.427219757651
# 6400/6619
# William Moultrie
# -0.433111915371
# 6401/6619
# James Hogun
# -0.433111915371
# 6402/6619
# Abraham Whipple
# -0.433111915371
# 6403/6619
# Louis Lebègue Duportail
# -0.433111915371
# 6404/6619
# Jean Léonard Barrié
# -0.432227688247
# 6405/6619
# William Hull
# -0.528188102789
# 6406/6619
# Charles Pearson (British Army officer)
# 0.526640687473
# 6407/6619
# Edmund P. Gaines
# 0.506443171967
# 6408/6619
# Siege of Fort Harrison
# -0.589956335555
# 6409/6619
# Stone Eater
# -0.589956335555
# 6410/6619
# Green Clay
# 0.483353938369
# 6411/6619
# William Dudley (colonel)
# 0.483353938369
# 6412/6619
# David Wooster
# 0.452194839255
# 6413/6619
# Charles Preston
# -0.458155928624
# 6414/6619
# William Phillips (British Army officer)
# 0.450961925907
# 6415/6619
# Arthur St. Clair
# -0.954975970921
# 6416/6619
# James Rhea
# 0.430632833411
# 6417/6619
# Winamac
# -0.436536188049
# 6418/6619
# Five Medals
# -0.436536188049
# 6419/6619
# George Monro (British Army officer)
# -0.448745431834
# 6420/6619
# Koxinga
# 0.5
# 6421/6619
# Frederick Coyett
# -0.5
# 6422/6619
# Barthold Nicolai Landsberg
# 0.552760887833
# 6423/6619
# Matthijs Dulken
# -0.50978422653
# 6424/6619
# Hendrik van den Bergh (count)
# -0.50978422653
# 6425/6619
# Christoph Bernhard von Galen
# -0.104149099055
# 6426/6619
# Gustaff Tungel
# -0.401613772401
# 6427/6619
# Carl von Rabenhaupt
# 0.5
# 6428/6619
# Nikolay Muravyov-Karsky
# 0.490478359295
# 6429/6619
# Fenwick Williams
# -0.496486726673
# 6430/6619
# Mehmet Vasıf Pasha Gürcü
# -0.496486726673
# 6431/6619
# George White (British Army officer)
# 0.52334878947
# 6432/6619
# Ivan Fedyuninsky
# 0.48412699538
# 6433/6619
# Mikhail Khozin
# 0.48412699538
# 6434/6619
# Archibald H. Gillespie
# -0.449635973789
# 6435/6619
# Begum Hazrat Mahal
# 0.4371588303
# 6436/6619
# Birjis Qadr
# 0.4371588303
# 6437/6619
# John Eardley Inglis
# -0.443082027531
# 6438/6619
# Henry Havelock
# -0.443082027531
# 6439/6619
# Colin Campbell, 1st Baron Clyde
# -0.443082027531
# 6440/6619
# James George Smith Neill
# -0.443082027531
# 6441/6619
# Robert Baden-Powell, 1st Baron Baden-Powell
# -0.432312250018
# 6442/6619
# Bryan Mahon
# -0.432312250018
# 6443/6619
# Joseph Anthelme Fournier
# -0.5
# 6444/6619
# Hans von Zwehl
# 0.5
# 6445/6619
# Diwan Mulraj Chopra
# 0.5
# 6446/6619
# Ferdinand II, Holy Roman Emperor
# -0.564064339403
# 6447/6619
# Tiryaki Hasan Pasha
# 0.558144704652
# 6448/6619
# Octavius Ignatius, Prince of Arenberg and Barbançon
# -0.409964587558
# 6449/6619
# Menno van Coehoorn
# 0.0407540140527
# 6450/6619
# Alexander II of Russia
# 0.463821835705
# 6451/6619
# Carol I of Romania
# 0.463821835705
# 6452/6619
# Grand Duke Nicholas Nikolaevich of Russia (1831–1891)
# 0.463821835705
# 6453/6619
# Eduard Totleben
# -0.00325453964306
# 6454/6619
# Nogi Maresuke
# 0.456165635255
# 6455/6619
# Franklin Gardner
# -0.436106586794
# 6456/6619
# Joaquín Rea
# -0.509932147021
# 6457/6619
# Thomas Childs
# 0.503923912343
# 6458/6619
# Calixto García
# 0.482155587267
# 6459/6619
# José Toral y Velázquez
# -0.488159680167
# 6460/6619
# Alija Izetbegović
# -0.0738351002244
# 6461/6619
# Sefer Halilović
# -0.0738351002244
# 6462/6619
# Rasim Delić
# -0.0738351002244
# 6463/6619
# Jovan Divjak
# -0.0738351002244
# 6464/6619
# Enver Hadžihasanović
# -0.0738351002244
# 6465/6619
# Mustafa Hajrulahović Talijan
# -0.0738351002244
# 6466/6619
# Mušan Topalović
# -0.0738351002244
# 6467/6619
# Leighton W. Smith Jr.
# -0.0738351002244
# 6468/6619
# Milutin Kukanjac
# 0.0679465169243
# 6469/6619
# Radovan Karadžić
# 0.0679465169243
# 6470/6619
# Stanislav Galić
# 0.0679465169243
# 6471/6619
# Dragomir Milošević
# 0.0679465169243
# 6472/6619
# Curt von Stedingk
# -0.621418737395
# 6473/6619
# Maurice, Count de Benyovszky
# -0.621418737395
# 6474/6619
# Augustine Prévost
# 0.615747375121
# 6475/6619
# John Maitland (British Army officer)
# 0.615747375121
# 6476/6619
# Aimable Pélissier
# 0.461097989963
# 6477/6619
# Edmund Lyons, 1st Baron Lyons
# 0.461097989963
# 6478/6619
# James Simpson (British Army officer)
# 0.461097989963
# 6479/6619
# William John Codrington
# 0.461097989963
# 6480/6619
# Vladimir Kornilov
# -0.467076375348
# 6481/6619
# Pavel Nakhimov
# -0.467076375348
# 6482/6619
# Anthonie II Schetz
# -0.446219250328
# 6483/6619
# Sigismund III Vasa
# 0.431981631152
# 6484/6619
# Mikhail Shein
# -0.437889255506
# 6485/6619
# Jean-Jacques Uhrich — Wikipédia
# -0.474980810751
# 6486/6619
# Jean François Leval
# -0.560226031488
# 6487/6619
# Francisco Copons
# 0.554295459996
# 6488/6619
# John Byrne Skerrett
# 0.554295459996
# 6489/6619
# Gastone Gambara
# -0.516409267558
# 6490/6619
# Leslie Morshead
# 0.510404199772
# 6491/6619
# Ronald Scobie
# 0.510404199772
# 6492/6619
# Jean François Carteaux
# 0.477763493548
# 6493/6619
# Jean François Cornu de La Poype
# 0.477763493548
# 6494/6619
# Marquess of Normanby
# -0.483763986987
# 6495/6619
# Jan Piotr Sapieha
# -0.577631996907
# 6496/6619
# Aleksander Józef Lisowski
# -0.577631996907
# 6497/6619
# Grigory Dolgorukov
# 0.571756724642
# 6498/6619
# Aleksey Golokhvastov
# 0.571756724642
# 6499/6619
# Tang Ching-sung
# -0.595384149435
# 6500/6619
# Marc-Edmond Dominé
# 0.589580360559
# 6501/6619
# William Oliphant (died after 1313)
# -0.5
# 6502/6619
# Sanada Yukitaka
# 0.40860520053
# 6503/6619
# Yokota Takatoshi
# 0.40860520053
# 6504/6619
# John Ancrum Winslow
# 0.496995305768
# 6505/6619
# Raphael Semmes
# -0.503004694232
# 6506/6619
# Tom Phillips (Royal Navy officer)
# -0.503004694232
# 6507/6619
# William Tennant (Royal Navy officer)
# -0.503004694232
# 6508/6619
# Niichi Nakanishi
# 0.496995305768
# 6509/6619
# Shichizo Miyauchi
# 0.496995305768
# 6510/6619
# Hachiro Shoji
# 0.496995305768
# 6511/6619
# Luo Ruiqing
# 0.4189128696
# 6512/6619
# Zhou Enlai
# 0.4189128696
# 6513/6619
# Brij Mohan Kaul
# -0.424775423401
# 6514/6619
# Jawaharlal Nehru
# -0.424775423401
# 6515/6619
# V. K. Krishna Menon
# -0.424775423401
# 6516/6619
# Pran Nath Thapar
# -0.424775423401
# 6517/6619
# Gamal Abdel Nasser
# -1.07937699142
# 6518/6619
# Abdel Hakim Amer
# -1.07937699142
# 6519/6619
# Abdul Munim Riad
# -0.567744722986
# 6520/6619
# Asad Ghanma
# -0.567744722986
# 6521/6619
# Salah Jadid
# -0.567744722986
# 6522/6619
# Nureddin al-Atassi
# -0.567744722986
# 6523/6619
# Abdul Rahman Arif
# -0.567744722986
# 6524/6619
# Mubarak Abdullah Al-Jaber Al-Sabah
# -0.567744722986
# 6525/6619
# Saleh Mohammed Al-Sabah
# -0.567744722986
# 6526/6619
# Fahad Al-Ahmed Al-Jaber Al-Sabah
# -0.567744722986
# 6527/6619
# Levi Eshkol
# 0.56183624311
# 6528/6619
# Israel Tal
# 1.61924897348
# 6529/6619
# Mordechai Hod
# 0.56183624311
# 6530/6619
# Yeshayahu Gavish
# 0.56183624311
# 6531/6619
# Ezer Weizman
# 0.56183624311
# 6532/6619
# Shlomo Erell
# 0.56183624311
# 6533/6619
# Otozō Yamada
# -0.454988869521
# 6534/6619
# Zhang Jinghui
# -0.454988869521
# 6535/6619
# Francis Drake
# 0.498670424338
# 6536/6619
# John Hawkins (naval commander)
# 0.498670424338
# 6537/6619
# Juan Martínez de Recalde
# -0.504679745352
# 6538/6619
# Richard Butler (general)
# -0.498055652129
# 6539/6619
# William Darke
# -0.498055652129
# 6540/6619
# Asaf Simhoni
# 0.505624669645
# 6541/6619
# Haim Bar-Lev
# 1.05741273037
# 6542/6619
# Avraham Yoffe
# 0.505624669645
# 6543/6619
# Anthony Eden
# 0.505624669645
# 6544/6619
# Gerald Templer
# 0.505624669645
# 6545/6619
# Charles Keightley
# 0.505624669645
# 6546/6619
# Hugh Stockwell
# 0.505624669645
# 6547/6619
# Manley Laurence Power
# 0.505624669645
# 6548/6619
# René Coty
# 0.505624669645
# 6549/6619
# Guy Mollet
# 0.505624669645
# 6550/6619
# Pierre Barjot
# 0.505624669645
# 6551/6619
# André Beaufre
# 0.505624669645
# 6552/6619
# Jacques Massu
# 0.505624669645
# 6553/6619
# Martti Miettinen
# 0.5
# 6554/6619
# Leopold I of Belgium
# 0.465294518431
# 6555/6619
# Amédée de Failly
# 0.465294518431
# 6556/6619
# Charles Niellon
# 0.465294518431
# 6557/6619
# Tito Speri
# -0.5
# 6558/6619
# Julius Jacob von Haynau
# 0.5
# 6559/6619
# Khalifa Haftar
# -0.5
# 6560/6619
# Filipp Golikov
# -0.571466122328
# 6561/6619
# Paul Hausser
# 0.56556958688
# 6562/6619
# Eberhard von Mackensen
# 0.56556958688
# 6563/6619
# Theodor Eicke
# 0.56556958688
# 6564/6619
# Haim Nadel
# 0.452596276551
# 6565/6619
# Timur Shah Durrani
# 0.463381836157
# 6566/6619
# Najib ad-Dawlah
# 0.463381836157
# 6567/6619
# Sadashivrao Bhau
# -0.469364042478
# 6568/6619
# Vishwasrao
# -0.469364042478
# 6569/6619
# Malhar Rao Holkar
# -0.469364042478
# 6570/6619
# Mahadaji Shinde
# -0.469364042478
# 6571/6619
# Ibrahim Khan Gardi
# -0.469364042478
# 6572/6619
# Jankoji Rao Scindia
# -0.469364042478
# 6573/6619
# Bhoite
# -0.469364042478
# 6574/6619
# Fahri Korutürk
# 0.478667489481
# 6575/6619
# Bülent Ecevit
# 0.478667489481
# 6576/6619
# Necmettin Erbakan
# 0.478667489481
# 6577/6619
# Rauf Denktaş
# 0.478667489481
# 6578/6619
# Nikos Sampson
# -0.484668799667
# 6579/6619
# Glafcos Clerides
# -0.484668799667
# 6580/6619
# Dimitrios Ioannidis
# -0.484668799667
# 6581/6619
# Stephen Decatur
# 0.496995305768
# 6582/6619
# John Surman Carden
# -0.503004694232
# 6583/6619
# Ludwig von Falkenhausen
# -0.436976239864
# 6584/6619
# Karl von Fasbender
# -0.436976239864
# 6585/6619
# Georg Karl Wichura
# -0.436976239864
# 6586/6619
# Ferdinand von Sammern-Frankenegg
# 0.460416585554
# 6587/6619
# Jürgen Stroop
# 0.460416585554
# 6588/6619
# Arpad Wigand
# 0.460416585554
# 6589/6619
# Ludwig Hahn
# 0.460416585554
# 6590/6619
# Mordechai Anielewicz
# -0.466393782237
# 6591/6619
# Paweł Frenkiel
# -0.466393782237
# 6592/6619
# Tadeusz Bór-Komorowski
# -0.533067201049
# 6593/6619
# Tadeusz Pełczyński
# -0.533067201049
# 6594/6619
# Antoni Chruściel
# -0.533067201049
# 6595/6619
# Karol Ziemski
# -0.533067201049
# 6596/6619
# Edward Pfeiffer
# -0.533067201049
# 6597/6619
# Leopold Okulicki
# -0.533067201049
# 6598/6619
# Jan Mazurkiewicz
# -0.533067201049
# 6599/6619
# Zygmunt Berling
# -0.533067201049
# 6600/6619
# Nikolaus von Vormann
# 0.527079553123
# 6601/6619
# Reiner Stahel
# 0.527079553123
# 6602/6619
# Erich von dem Bach-Zelewski
# 0.527079553123
# 6603/6619
# Heinz Reinefarth
# 0.527079553123
# 6604/6619
# Bronislav Kaminski
# 0.527079553123
# 6605/6619
# Oskar Dirlewanger
# 0.527079553123
# 6606/6619
# Petro Dyachenko
# 0.527079553123
# 6607/6619
# Iosif Igelström
# -0.519781777994
# 6608/6619
# Stanisław Mokronowski
# 0.513779158368
# 6609/6619
# Jan Kiliński
# 0.513779158368
# 6610/6619
# James W. Forsyth
# 0.438085265927
# 6611/6619
# Spotted Elk
# -0.444011113321
# 6612/6619
# Anwar Sadat
# -0.557725374863
# 6613/6619
# Yusuf Shakkour
# -0.557725374863
# 6614/6619
# Mohamed Abdel Ghani el-Gamasy
# -0.557725374863
# 6615/6619
# Ali Aslan
# -0.557725374863
# 6616/6619
# Golda Meir
# 0.551788060724
# 6617/6619
# Yitzhak Hofi
# 0.551788060724
# 6618/6619
# Harold Franklyn
# -0.430649428825

# %%
mka = df_run.loc[8965, 'belligerent']

# %%
mka

# %%
df_battles

# %%
battle_list = []
bokeh(u'Ariel Sharon')

# %%
df_warchart = pd.DataFrame({'Labels': ['Win = 1', 'Replacement-Level Performance = .51', 'WAR From Battle = .49'],
              'Values': [1, .51, .49]})

# %%
df_warchart = df_warchart.sort_values('Values', ascending = True)

# %%
df_warchart

# %%
df_warchart = df_warchart.iloc[::-1]

# %%
fig = plt.figure(figsize = (12,9))
plt.style.use('fivethirtyeight')
plt.bar(df_warchart.index, df_warchart.Values, width = 1, color = ['red', 'blue', 'yellow'])
plt.xticks(df_warchart.index + .5, df_warchart.Labels, rotation = 45)
plt.xticks()
plt.title("Bonaparte's WAR in Battle of Borodino")
plt.tight_layout()
plt.savefig('napoleon_war_sample')

# ax.set_axis_bgcolor('gray')

# %%
df_warchart_two = pd.DataFrame({'Labels': ['Win = -1', 'Replacement-Level Performance = .49', 'WAR From Battle = -.51'],
              'Values': [-1, -.49, -.51]})

# %%
fig = plt.figure(figsize = (12,9))
plt.style.use('fivethirtyeight')
plt.bar(df_warchart_two.index, df_warchart_two.Values, width = 1, color = ['red', 'blue', 'white'])
plt.xticks(df_warchart_two.index, df_warchart_two.Labels, rotation = 45)
plt.title("Kutuzov's WAR in Battle of Borodino")
plt.tight_layout()
plt.savefig('/home/ethanarsht/Downloads/kutuzov_war_sample')

# ax.set_axis_bgcolor('gray')
