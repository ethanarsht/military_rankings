# %%
# -*- coding: utf-8 -*-

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from html.parser import HTMLParser as parse
from time import sleep
import scipy
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
import random
import matplotlib.pyplot as plt
import math
% matplotlib inline

# %%
import lxml
import requests
import html5lib
pd.options.display.max_rows = 50

# %%
from bokeh.models import HoverTool, CategoricalColorMapper, OpenURL, TapTool, ResetTool
from bokeh.plotting import ColumnDataSource, figure, output_file, show, save, output_notebook
from bokeh.io import curdoc
from bokeh.models.glyphs import VBar

# %%
table_pages = ['https://en.wikipedia.org/wiki/List_of_battles_before_301',
               'https://en.wikipedia.org/wiki/List_of_battles_301%E2%80%931300',
               'https://en.wikipedia.org/wiki/List_of_battles_1301%E2%80%931600',
               'https://en.wikipedia.org/wiki/List_of_battles_since_2001']

# %%
list_pages = ['https://en.wikipedia.org/wiki/List_of_battles_1601%E2%80%931800',
               'https://en.wikipedia.org/wiki/List_of_battles_1801%E2%80%931900',
               'https://en.wikipedia.org/wiki/List_of_battles_1901%E2%80%932000',]

# %%
def list_battles(url):
    req = requests.get(url)
    print req.status_code
    era = req.content
    era_soup = BeautifulSoup(era)
    bullets = era_soup.find_all('li')
    
    for bullet in bullets:
        print bullet
        if 'title' in str(bullet):
#             if 'expedition' or 'recapture' or 'capture' or 'war' or 'action' or 'battle' or 'siege' or 'operation' or 'fall' in str(bullet).lower():
#                 if 'List+of+battles' not in str(bullet):
                    if 'footer' not in str(bullet):
                        link = bullet.a['href']
                        link_list.append(link)

                        title = bullet.a['title']
                        title_list.append(title)
                    else:
                        print 'NEXT ENTRY: ' + str(bullet)
#                 else:
#                     print 'NEXT ENTRY: ' + str(bullet)
#             else:
#                 print 'NEXT ENTRY: ' + str(bullet)
        else: 
            print 'NEXT ENTRY' + str(bullet)

# %%
title_list = []
link_list = []
for url in list_pages:
    list_battles(url)

# %%
link_list

# %%
df_late_battles = pd.concat([pd.Series(link_list), pd.Series(title_list)], axis = 1).drop_duplicates()

# %%
df_late_battles = df_late_battles.rename(columns = {0:'url', 1:'Battle'})

# %%
df_late_battles

# %%
df_late_battles[~df_late_battles['Battle'].str.contains('Battle' or 'Operation')]

# %%
df_late_battles.to_csv('battle_list_1600-', encoding = 'utf-8')

# %%
df_late_battles = pd.read_csv('battle_list_1600-.csv', encoding = 'utf-8')

# %%
df_late_battles.head()

# %%
df_late_battles = df_late_battles.drop(['Column1', 'Column4'], axis = 1)
df_late_battles.columns = df_late_battles.iloc[0]
df_late_battles = df_late_battles.drop(0)

# %%
battle_list = []
link_list = []

# %%
def early_battles(link):
    req = requests.get(link)
    print req.status_code
    era = req.content
    era_soup = BeautifulSoup(era)
    tables = era_soup.find_all('table', {'class': 'wikitable'})

    for table in tables:
        cells = table.find_all('td')
        for cell in cells:
            if cell.a is not None:
                a = ['Fall', 'Battle', 'Siege', 'Capture', 'Operation', 'Action', 'Recapture']
                if any(x in str(cell.a['href']) for x in a):
                    battle_list.append(cell.a['title'])
                    link_list.append(cell.a['href'])

# %%
for page in table_pages:
    print page
    early_battles(page)

# %%
df_battles = pd.DataFrame({'battle': battle_list,
                          'link':link_list})

# %%
df_battles = df_battles.rename(columns = {'link':'url', 'battle':'Battle'})

# %%
len(df_battles)

# %%
len(df_late_battles)

# %%
df_battles.head()

# %%
df_url = pd.concat([df_late_battles, df_battles]).reset_index(drop = True)

# %%
len(df_url)

# %%
len(df_url.drop_duplicates())

# %%
s_req = requests.get('https://en.wikipedia.org/Alexander_the_Great')

soup = BeautifulSoup(s_req.text)

ul = soup.find('ul', {'class':'redirectText'})

# %%
if ul is not None:
    print 'works'

# %%
df_battle_all = pd.DataFrame()
df_battle = pd.DataFrame()
def table_scrape(url, name):
#     sleep(1)
    print name
    link = 'https://en.wikipedia.org' + url
    b_req = requests.get(link)

    soup = BeautifulSoup(b_req.text)
    
    bell = soup.find('table', {'class':'infobox vevent'})
    
    if bell is not None:

        details = pd.DataFrame(parse.make2d(bell))
    else:
        return b_req
    

    if 'Belligerents' in str(bell):
    
        clean_rows = details.drop_duplicates(0).set_index(0,drop = True).loc[['Date', 'Location', 'Result'],:]

        clean_col = clean_rows.transpose().reset_index(drop = True)

        df_x_bells = pd.DataFrame()

        html_table = bell.find_all('tr')
        bell_list = []
        bell_y_list = []

        for index, cell in zip(range(0, len(html_table)), html_table):
            if 'Commanders and leaders' in str(cell):
                leaders = html_table[index + 1]
                cells = leaders.find_all('td')
                count = 0
                for cell in cells:
                    count += 1
                    anchors = cell.find_all('a')
                    for anchor in anchors:
                        if 'title' in str(anchor):
                            if 'class="image"' in str(anchor):
                                cl = 'image'
                            elif 'class="thumbborder"' in str(anchor):
                                cl = 'thumb'
                            elif 'cite_note' in str(anchor):
                                cl = 'cite'
                            elif 'disambiguation needed' in str(anchor):
                                cl = 'disam'
                            elif 'cnote_g' in str(anchor):
                                cl = 'cnote'
                            else:
                                title = anchor['title']
                                if any(title == x for x in ['Napoleon I','Alexander III of Macedon']):
                                    print 'napoleon or alex redirect'

                                ref = anchor['href']
                                link = 'https://en.wikipedia.org' + ref

                                if len(ref) <= 10:
                                    t_req = requests.get(link)
                                elif any(ref[8] + ref[9] + ref[10] == x for x in ['pt.', 'tr.', 'ko.', 'ja.', 'th.','da.', 'es.', 'de.', 'it.', 'fr.', 'zh.']):
                                    print 'Not English!'
                                    link = ref
                                    t_req = requests.get(link)
                                elif soup.find('ul', {'class':'redirectText'}) is not None:
                                    print 'REDIRECT'
                                    print title
                                    ul = soup.find('ul', {'class':'redirectText'})
                                    a = ul.a
                                    redirect = a['href']
                                    link = 'https://en.wikipedia.org' + redirect
                                    t_req = requests.get(link)
                                else:
                                    t_req = requests.get(link)

                                t_soup = BeautifulSoup(t_req.text)

                                c_name = t_soup.find('title')
                                c_name = str(c_name)

                                if c_name:
                                    c_name = c_name.replace(' - Wikipedia', '').replace('<title>', '').replace('</title>', '')
                                else:
                                    if count == 1:
                                        bell_list.append(title)
                                    elif count == 2:
                                        bell_y_list.append(title)
                                if 'ex.php?title=' in ref:
                                    ref = ref.replace('ex.php?title=', '')
                                    ref = ref.replace('&action=edit&redlink=1', '')

                                omit_list = ['Capital punishment', 
                                             'Military advisor', 
                                             'Wounded in action', 
                                             'Prisoner of war', 
                                             'Killed in action', 
                                             'Surrender (military)', 
                                             'Surrendered',
                                             'Common military ranks in English']

                                if all(c_name != x for x in omit_list):


                                    if count == 1:

                                        bell_list.append(c_name)
                                    elif count == 2:
                                        bell_y_list.append(c_name)



        for bell in bell_list:
            clean_col['belligerent'] = bell
            df_x_bells = pd.concat([df_x_bells, clean_col])
            df_x_bells = df_x_bells.reset_index(drop = True)


        df_y_bells = pd.DataFrame()
        for bell in bell_y_list:
            clean_col['belligerent'] = bell
            df_y_bells = pd.concat([df_y_bells, clean_col])
            df_y_bells = df_y_bells.reset_index(drop = True)

        df_y_bells = df_y_bells.rename(columns = {0:'Location'})

        if 'Strength' in str(details[0]):
            strength_finder = details[details[0] == 'Strength']


            strength_row = strength_finder.index + 1

            strength = details.loc[strength_row]

            strength_x = strength.iloc[0,0]

            strength_y = strength.iloc[0,1]
        else:
            strength_x = 'unknown'
            strength_y = 'unknown'

        df_x_bells['own'] = strength_x

        df_x_bells['opp'] = strength_y

        df_y_bells['own'] = strength_y

        df_y_bells['opp'] = strength_x

        if 'Casualties and losses' not in str(details[0]):
            df_x_bells['taken'] = np.NaN
            df_x_bells['inflicted'] = np.NaN
            df_y_bells['taken'] = np.NaN
            df_y_bells['inflicted'] = np.NaN

        else:

            casualties_finder = details[details[0] == 'Casualties and losses']

            casualties_row = casualties_finder.index + 1

            casualties = details.loc[casualties_row]

            casualties_x = casualties.iloc[0,0]

            casualties_y = casualties.iloc[0,1]

            df_x_bells['taken'] = casualties_x

            df_x_bells['inflicted'] = casualties_y

            df_y_bells['taken'] = casualties_y

            df_y_bells['inflicted'] = casualties_x



        df_x_bells['Battle'] = name

        df_y_bells['Battle'] = name

        df_x_bells['pos'] = 'L'

        df_y_bells['pos'] = 'R'

        df_battle = pd.concat([df_x_bells, df_y_bells]).reset_index(drop = True)

        df_battle_all = pd.concat([df_battle_all, df_battle]).reset_index(drop = True).drop_duplicates()

        global df_battle_all
    else:
        print 'Filtered: ' + name

# %%
count = 0
for num, rows in {1:df_url[:200],
             2:df_url[200:400], 
             3:df_url[400:600], 
             4:df_url[600:800],
             5:df_url[800:1000],
             6:df_url[1000:1200],
             7:df_url[1200:1400],
             8:df_url[1400:1600],
             9:df_url[1600:1800],
             10:df_url[1800:2000],
             11:df_url[2000:2200],
             12:df_url[2200:2400],
             13:df_url[2400:2600],
             14:df_url[2600:2800],
             15:df_url[2800:3000],
             16:df_url[3000:3200],
             17:df_url[3200:3400],
             18:df_url[3400:]}.iteritems():
    df_battle = pd.DataFrame()
    df_batch = rows
    for index, row in df_batch.iterrows():
        count += 1
        global count
        print str(count) + '/' + str(len(df_url))
        table_scrape(row['url'], row['Battle'])
    df_battle_all.to_csv('rows_{}.csv'.format(num), encoding = 'utf-8')
    print 'NEW FRAME' + str(num)

# %%
row_list = ['rows_1.csv',
 'rows_2.csv',
 'rows_3.csv',
 'rows_4.csv',
 'rows_5.csv',
 'rows_6.csv',
 'rows_7.csv',
 'rows_8.csv',
 'rows_9.csv',
 'rows_10.csv',
 'rows_11.csv',
 'rows_12.csv',
 'rows_13.csv',
 'rows_14.csv',
 'rows_15.csv',
 'rows_16.csv',
 'rows_17.csv',
 'rows_18.csv']

# %%
df_comm = pd.DataFrame()
for sheet in row_list:
    df_rows = pd.read_csv(sheet)
    df_comm = pd.concat([df_comm, df_rows]).reset_index(drop = True)

# %%
df_comm = df_comm.drop('Unnamed: 0', axis = 1)

# %%
len(df_comm)

# %%
len(df_comm)

# %%
df_comm.to_csv('battles_dirty.csv', encoding = 'utf-8')

# %%
df_comm = pd.read_csv('battles_dirty.csv').drop('Unnamed: 0', axis = 1)

# %%
df_comm = df_comm.drop_duplicates()

# %%
df_comm.head()

# %%
len(df_comm)

# %%
df_comm[df_comm.belligerent.str.contains('Nasser')]

# %%
len(df_comm.drop_duplicates())

# %%
df_comm = df_comm.drop_duplicates().reset_index(drop = True)

# %%
df_comm.to_csv('battles_deduped.csv')

# %%
len(df_comm[df_comm.belligerent.str.contains('Napoleon')])

# %%
df_comm[df_comm.belligerent.str.contains('Scipio')]

# %%
df_results = pd.read_csv('result_column.csv')

# %%
df_results[df_results.Battle == 'Battle_of_Camarón']

# %%
df_comm.head()

# %%
df_results.head()

# %%
df_more_results = pd.merge(df_comm, df_results, how = 'outer', on = ['Battle', 'belligerent', 'pos', 'Result'])

# %%
df_more_results = df_more_results[df_more_results.VorD.isnull()]

# %%
df_more_results = df_more_results.drop_duplicates(subset = ['Battle', 'Date', 'VorD'])

# %%
df_more_results.head()

# %%
df_more_results.to_csv('adding_results_10.21.csv', encoding = 'utf-8')

# %%
df_comm[df_comm.Battle == 'Battle_of_Camarón']

# %%
df_comm[df_comm.belligerent == 'Ambroise de Loré']

# %%
df_vl = pd.merge(df_comm, df_results, how = 'outer', on = ['Battle', 'belligerent', 'Result', 'pos'])

# %%
df_vl

# %%
df_vl = df_vl.sort('VorD')

# %%
df_vl[df_vl.belligerent == 'Ambroise de Loré']

# %%
df_vl[df_vl.belligerent == 'Saracens']

# %%
df_vl.to_csv('additional_results.csv')

# %%
df_10_21_fill = df_vl[df_vl.VorD.isnull()]

# %%
df_ar = pd.read_csv('additional_results.csv', encoding = 'utf-8')

# %%
df_strength = df_ar.drop(['Unnamed: 0', 'Location', 'Result', 'inflicted', 'taken', 'opp'], axis = 1)

# %%
df_strength = df_strength.sort('Battle').reset_index(drop = True)

# %%
df_strength_dd = df_strength.drop_duplicates(['own', 'pos'], keep = 'first')

# %%
df_strength_dd.own = df_strength_dd.own.str.replace('\r',' ').str.replace('\n', ' ').replace('\n', ' ')

# %%
df_strength_dd = df_strength_dd.sort('Battle').reset_index(drop = True)

# %%
df_strength_dd

# %%
df_strength_dd.to_csv('strength_entry.csv', encoding = 'utf-8')

# %%
df_strength_new = df_strength.drop_duplicates(['own', 'pos', 'Battle'], keep = 'first')

# %%
df_strength_fill = pd.read_excel('strength_entry.xlsx', encoding = 'utf-8')

# %%
df_battles = pd.read_csv('battles_deduped.csv', encoding = 'utf-8').drop('Unnamed: 0', axis = 1)

# %%
df_battles = df_battles.drop(['taken', 'inflicted'], axis = 1)

# %%
df_strength_fill.Battle = df_strength_fill.Battle.str.replace(u"â€“",u'–')

# %%
df_some_strength = pd.merge(df_battles, df_strength_fill, how = 'outer', on = ['Battle', 'pos']).drop(['own_y', 'belligerent_y', 'Date_y'], axis = 1).rename(columns = {'Date_x':'Date','own_x':'own', 'belligerent_x':'belligerent'})

# %%
df_some_strength[df_some_strength.Battle.str.contains('Battle_of_Jena')]

# %%
df_test = df_some_strength.iloc[:,9:]

# %%
df_str_two = df_some_strength[df_some_strength['Infantry'].isnull() & df_some_strength['Cavalry'].isnull() & df_some_strength['Artillery'].isnull() & df_some_strength['Ships'].isnull() & df_some_strength['Airforce'].isnull() & df_some_strength['Special'].isnull()]

# %%
df_str_two.head()

# %%
df_str_two = df_str_two.drop_duplicates(['Battle', 'Date', 'Location', 'Result', 'pos']).drop('VorD', axis = 1)

# %%
len(df_str_two)

# %%
df_merger = df_strength.drop(['Date', 'belligerent', 'own'], axis = 1)

# %%
df_merger = df_merger.drop_duplicates()

# %%
df_str_two.head()

# %%
df_str_two = pd.merge(df_str_two, df_merger, on = ['Battle', 'pos'], how = 'outer').dropna(subset = ['Date', 'Location', 'Result'])

# %%
df_str_two = df_str_two.dropna(subset = ['VorD'])

# %%
df_str_two.to_csv('strength_entry_two.csv')

# %%
df_str_two

# %%
df_partial = pd.read_excel('PARTIAL_strength_entry_two.xlsx', encoding = 'utf-8')

# %%
df_str_two.head()

# %%
df_str_two = df_str_two.drop(['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special'], axis = 1)

# %%
df_partial = df_partial.drop(['Date', 'Location', 'Result', 'belligerent','own', 'Column1'],axis = 1)

# %%
df_partial.columns

# %%
df_str_two.head()

# %%
df_finish = pd.merge(df_str_two, df_partial, on = ['Battle', 'pos', 'VorD'], how = 'outer')

# %%
drop_list = list(df_finish[df_finish['Date'].isnull()].index)

# %%
df_finish = df_finish.drop(drop_list)

# %%
df_finish.to_csv('last_strength_entry.csv', encoding = 'utf-8')

# %%
df_some_strength

# %%
df_some_strength[df_some_strength.Battle.str.contains('Siege of La Rochelle')]

# %%
df_more_strength = pd.read_excel('last_strength_entry.xlsx')

# %%
df_more_strength.head()

# %%
df_some_strength.head()

# %%
df_more_strength = pd.merge(df_more_strength, df_str_two, on = ['Battle', 'pos'], how = 'outer').drop(['own_y', 'Infantry_y', 'Cavalry_y', 'Artillery_y', 'Ships_y', 'Airforce_y', 'Special_y', 'Date_y', 'Location_y', 'Result_y', 'belligerent_y'], axis = 1).dropna(subset = ['Date_x'])

# %%
df_more_strength.columns = df_more_strength.columns.str.replace('_x', '')

# %%
df_more_strength.head()

# %%
df_some_strength.head()

# %%
df_more_strength

# %%
df_fill_two = pd.merge(df_battles, df_more_strength, on = ['Battle', 'pos'], how = 'outer').drop(['Date_y', 
                                                                                    'Location_y', 
                                                                                    'belligerent_y', 
                                                                                    'Result_y', 'own_y', 
                                                                                    'opp_y'], axis = 1)

# %%
df_fill_two.columns = df_fill_two.columns.str.replace('_x', '')

# %%
df_some_strength = df_some_strength[df_some_strength['Infantry'].notnull() | df_some_strength['Cavalry'].notnull() | df_some_strength['Artillery'].notnull() | df_some_strength['Ships'].notnull() | df_some_strength['Airforce'].notnull() | df_some_strength['Special'].notnull()]

# %%
len(df_some_strength)

# %%
df_fill_two = df_fill_two[df_fill_two['Infantry'].notnull() | df_fill_two['Cavalry'].notnull() | df_fill_two['Artillery'].notnull() | df_fill_two['Ships'].notnull() | df_fill_two['Airforce'].notnull() | df_fill_two['Special'].notnull()]

# %%
df_some_strength

# %%
df_fill_two

# %%
df_all_strength = pd.concat([df_fill_two, df_some_strength]).reset_index(drop = True)

# %%
len(df_battles)

# %%
df_char = df_all_strength[df_all_strength.Date.isnull()]

# %%
df_char.to_excel('special_character_fix.xlsx')

# %%
df_all_strength[df_all_strength.Battle.str.contains('Battle_of_Tenn')]

# %%
df_all_strength.to_excel('all_strength_probably.xlsx')

# %%
df_battles[df_battles.Battle.str.contains('dlingen')]

# %%
df_char.Battle

# %%
df_strength_all = pd.read_excel('all_strength_probably.xlsx')

# %%
df_strength_all.loc[9988, 'Infantry'] = 2000

# %%
df_strength_all = df_strength_all.drop_duplicates()

# %%
df_left = df_strength_all[df_strength_all.pos == 'L']

# %%
df_left = df_left.drop(['Date', 'Location', 'Result', 'belligerent', 'opp', 'own'], axis = 1)

# %%
df_left = df_left.drop_duplicates(subset = ['Battle'])

# %%
df_left = df_left.dropna(subset = ['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special'], how = 'all')

# %%
df_right = df_strength_all[df_strength_all.pos == 'R']

# %%
df_right = df_right.drop_duplicates(subset = ['Battle'])

# %%
df_right = df_right.drop(['Date', 'Location', 'Result', 'belligerent', 'opp', 'own', 'VorD'], axis = 1)

# %%
df_right = df_right.dropna(subset = ['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special'], how = 'all')

# %%
df_model = pd.merge(df_left, df_right, on = 'Battle', how = 'outer').dropna(subset = ['pos_x', 'pos_y']).reset_index(drop = True)

# %%
df_v = df_model[df_model.VorD == 'V']

# %%
v_list = list(df_v.index)

# %%
ran_list = random.sample(v_list, 374)

# %%
df_switch = df_model.iloc[ran_list]

# %%
df_switch['Infantry_hold'] = df_switch['Infantry_x']
df_switch['Cavalry_hold'] = df_switch['Cavalry_x']
df_switch['Artillery_hold'] = df_switch['Artillery_x']
df_switch['Ships_hold'] = df_switch['Ships_x']
df_switch['Airforce_hold'] = df_switch['Airforce_x']
df_switch['Special_hold'] = df_switch['Special_x']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_switch['Infantry_x'] = df_switch['Infantry_y']
df_switch['Cavalry_x'] = df_switch['Cavalry_y']
df_switch['Artillery_x'] = df_switch['Artillery_y']
df_switch['Ships_x'] = df_switch['Ships_y']
df_switch['Airforce_x'] = df_switch['Airforce_y']
df_switch['Special_x'] = df_switch['Special_y']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_switch['Infantry_y'] = df_switch['Infantry_hold']
df_switch['Cavalry_y'] = df_switch['Cavalry_hold']
df_switch['Artillery_y'] = df_switch['Artillery_hold']
df_switch['Ships_y'] = df_switch['Ships_hold']
df_switch['Airforce_y'] = df_switch['Airforce_hold']
df_switch['Special_y'] = df_switch['Special_hold']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_switch = df_switch.drop(['Infantry_hold', 'Cavalry_hold', 'Artillery_hold', 'Ships_hold', 'Airforce_hold', 'Special_hold'], axis = 1)

# %%
df_switch.VorD = 'D'

# %%
df_model = df_model.drop(ran_list)

# %%
df_model = pd.concat([df_model, df_switch])

# %%
df_model.loc[2378, 'Infantry_y'] = 25000

# %%
df_model.loc[2363, 'Infantry_x'] = 500

# %%
df_model = df_model[df_model.Infantry_x != 1.0]
df_model = df_model[df_model.Infantry_y != 1.0]

# %%
df_model = df_model.fillna(0)

# %%
df_model['infantry_diff'] = (df_model['Infantry_x'] - df_model['Infantry_y']) / (df_model['Infantry_x'] + df_model['Infantry_y'])
df_model['cavalry_diff'] = (df_model['Cavalry_x'] - df_model['Cavalry_y']) / (df_model['Cavalry_x'] + df_model['Cavalry_y'])
df_model['artillery_diff'] = (df_model['Artillery_x'] - df_model['Artillery_y']) / (df_model['Artillery_x'] + df_model['Artillery_y'])
df_model['ships_diff'] = (df_model['Ships_x'] - df_model['Ships_y']) / (df_model['Ships_x'] + df_model['Ships_y'])
df_model['airforce_diff'] = (df_model['Airforce_x'] - df_model['Airforce_y']) / (df_model['Airforce_x'] + df_model['Airforce_y'])
df_model['special_diff'] = (df_model['Special_x'] - df_model['Special_y']) / (df_model['Special_x'] + df_model['Special_y'])

# %%
df_diff = pd.concat([df_model['VorD'], df_model['Battle'], df_model['infantry_diff'],df_model['cavalry_diff'],df_model['artillery_diff'], df_model['ships_diff'],
                    df_model['airforce_diff'], df_model['special_diff']], axis = 1)

# %%
df_diff = df_diff[df_diff.VorD != 'I']

# %%
df_diff = df_diff.drop(174)

# %%
df_diff = df_diff.fillna(0)

# %%
df_x = pd.DataFrame(df_diff.iloc[:, 2:])

# %%
df_x = df_x.drop('artillery_diff', axis = 1)

# %%
df_y = pd.DataFrame(df_diff.iloc[:, 0])

# %%
df_y.VorD = df_y.VorD.replace('V', 1).replace('D', 0).replace('L', 0).replace('v', 1)

# %%
df_y.VorD = df_y.VorD.astype('float')

# %%
df_x = df_x.iloc[:, :-1]

# %%
lr = LogisticRegression()
lr.fit(df_x, df_y)
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr.score(df_x, df_y)
# Out:
# 0.54352226720647778

# %%
df_strength_all.loc[60, 'VorD'] = 'V'
df_strength_all.loc[61, 'VorD'] = 'V'

# %%
df_strength_all.loc[3479:3485, 'VorD'] = 'V'

# %%
df_strength_all.loc[3485, 'VorD'] = 'D'

# %%
df_strength_all.loc[3802:3803, 'VorD'] = 'V'
df_strength_all.loc[3804:3807, 'VorD'] = 'D'

# %%
df_strength_all.loc[4142:4143, 'VorD'] = 'D'

# %%
df_strength_all.VorD = df_strength_all.VorD.str.replace('L', 'D')

# %%
df_strength_all.VorD = df_strength_all.VorD.str.replace('v', 'V')

# %%
df_strength_all.VorD = df_strength_all.VorD.str.replace('W', 'V')

# %%
null_fill = df_strength_all[df_strength_all.VorD.isnull()]

# %%
null_fill['VorD'] = ['V', 'D', 'D', 'V', 'V', 'D', 'V', 'V', 'V', 'V', 'D', 'D', 'D', 'D', 'V', 'V', 'V', 'V', 'V',
                    'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D','D', 'D', 'D', 'D', 'V', 'V', 'V', 'V', 'V', 'D', 'D', 'D', 'D',
                    'V', 'V', 'D', 'D', 'D', 'D', np.NaN, 'D', np.NaN]
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_strength_all.VorD.loc[null_fill.index] = null_fill['VorD']
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_strength_all = df_strength_all[df_strength_all.belligerent != 'Sweden']

# %%
import re

# %%
year_list = []
for i, row in df_strength_all.iterrows():
    d = row['Date']
    if isinstance(d, str):
        if re.search(r'[12]\d{3}', d):
            year = re.search(r'[12]\d{3}', d).group(0)
            year = int(year)
            if 'BC' in d:
                year = year * -1
            year_list.append({'Year':year, 'Index':i})
        elif re.search(r'[12]\d{2}', d):
            year = re.search(r'[12]\d{2}', d).group(0)
            year = int(year)
            if 'BC' in d:
                year = year * -1
            year_list.append({'Year':year, 'Index':i})

# %%
df_years = pd.DataFrame(year_list).set_index('Index', drop = True)

# %%
df_strength_all['year'] = pd.Series()

# %%
df_strength_all['year'].loc[df_years.index] = df_years.Year
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_strength_all.to_csv('current_run.csv', encoding = 'utf-8')

# %%
df_strength_all = pd.read_csv('current_run.csv', encoding = 'utf-8').drop('Unnamed: 0', axis = 1)

# %%
df_run = df_strength_all[df_strength_all.VorD.notnull()]

# %%
df_run.Battle = df_run.Battle.str.replace('_'," ")
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
arras_1 = {'Battle':['Battle of Arras', 'Battle of Arras'], 
           'Date':['21 May 1940', '21 May 1940'],
           'Location':['Arras', 'Arras'], 
           'Result':['German victory', 'German victory'] ,
           'belligerent':['Erwin Rommel', 'Harold Franklyn'],
           'opp':['manual', 'manual'],
           'own':['manual', 'manual'], 
           'pos':['R', 'L'],
           'VorD':['V', 'D'],
           'Infantry':[7500.0, 2000.0],
           'Cavalry':[225.0, 74.0],
           'Artillery':[np.NaN, np.NaN],
           'Ships': [np.NaN, np.NaN],
           'Airforce': [np.NaN, np.NaN],
           'Special': [np.NaN, np.NaN],
           'year':[1940, 1940]}

# %%
df_run = pd.concat([df_run,pd.DataFrame(arras_1, index = [10515,10516])])

# %%
df_run
# Out:
#        Airforce  Artillery                            Battle  Cavalry  \
# 0           NaN        3.0  1898 invasion of GuantÃ¡namo Bay      NaN
# 1           NaN        7.0  1898 invasion of GuantÃ¡namo Bay      NaN
# 2           NaN        NaN  1898 invasion of GuantÃ¡namo Bay      NaN
# 3           NaN        NaN             1948 Arab–Israeli War      NaN
# 4           NaN        NaN             1948 Arab–Israeli War      NaN
# 5           NaN        NaN             1948 Arab–Israeli War      NaN
# 6           NaN        NaN             1948 Arab–Israeli War      NaN
# 7           NaN        NaN             1948 Arab–Israeli War      NaN
# 8           NaN        NaN             1948 Arab–Israeli War      NaN
# 9           NaN        NaN             1948 Arab–Israeli War      NaN
# 10          NaN        NaN             1948 Arab–Israeli War      NaN
# 11          NaN        NaN             1948 Arab–Israeli War      NaN
# 12          NaN        NaN             1948 Arab–Israeli War      NaN
# 13          NaN        NaN             1948 Arab–Israeli War      NaN
# 14          NaN        NaN             1948 Arab–Israeli War      NaN
# 15          NaN        NaN             1948 Arab–Israeli War      NaN
# 16          NaN        NaN             1948 Arab–Israeli War      NaN
# 17          NaN        NaN             1948 Arab–Israeli War      NaN
# 18          NaN        NaN             1948 Arab–Israeli War      NaN
# 19          NaN        NaN             1948 Arab–Israeli War      NaN
# 20          NaN        NaN             1948 Arab–Israeli War      NaN
# 21          NaN        NaN             1948 Arab–Israeli War      NaN
# 22          NaN        NaN             1948 Arab–Israeli War      NaN
# 23          NaN        NaN             1948 Arab–Israeli War      NaN
# 24          NaN        NaN             1948 Arab–Israeli War      NaN
# ...         ...        ...                               ...      ...
# 10492       NaN        NaN            Warsaw Uprising (1794)      NaN
# 10493       NaN        NaN            Warsaw Uprising (1794)      NaN
# 10494       NaN       22.0             Wounded Knee Massacre      NaN
# 10495       NaN        NaN             Wounded Knee Massacre      NaN
# 10496     594.0     1720.0                    Yom Kippur War   7500.0
# 10497     594.0     1720.0                    Yom Kippur War   7500.0
# 10498     594.0     1720.0                    Yom Kippur War   7500.0
# 10499     594.0     1720.0                    Yom Kippur War   7500.0
# 10500     594.0     1720.0                    Yom Kippur War   7500.0
# 10501     594.0     1720.0                    Yom Kippur War   7500.0
# 10502     594.0     1720.0                    Yom Kippur War   7500.0
# 10503     594.0     1720.0                    Yom Kippur War   7500.0
# 10504     594.0     1720.0                    Yom Kippur War   7500.0
# 10505     440.0      945.0                    Yom Kippur War   4700.0
# 10506     440.0      945.0                    Yom Kippur War   4700.0
# 10507     440.0      945.0                    Yom Kippur War   4700.0
# 10508     440.0      945.0                    Yom Kippur War   4700.0
# 10509     440.0      945.0                    Yom Kippur War   4700.0
# 10510     440.0      945.0                    Yom Kippur War   4700.0
# 10511     440.0      945.0                    Yom Kippur War   4700.0
# 10512     440.0      945.0                    Yom Kippur War   4700.0
# 10513     440.0      945.0                    Yom Kippur War   4700.0
# 10514     440.0      945.0                    Yom Kippur War   4700.0
# 10515       NaN        NaN                   Battle of Arras    225.0
# 10516       NaN        NaN                   Battle of Arras     74.0
#
#                                                     Date  Infantry  \
# 0                                                    NaN    5000.0
# 1                                                    NaN    5000.0
# 2                                                    NaN     923.0
# 3      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 4      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 5      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 6      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 7      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 8      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 9      15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 10     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 11     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 12     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 13     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 14     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...  117500.0
# 15     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 16     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 17     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 18     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 19     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 20     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 21     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 22     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 23     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# 24     15 May 1948 – 10 March 1949\r\r\r\n(9 months, ...   58800.0
# ...                                                  ...       ...
# 10492                                17 to 19 April 1794    5775.0
# 10493                                17 to 19 April 1794    5775.0
# 10494                                   29 December 1890     438.0
# 10495                                   29 December 1890     120.0
# 10496                                 October 6–25, 1973  990750.0
# 10497                                 October 6–25, 1973  990750.0
# 10498                                 October 6–25, 1973  990750.0
# 10499                                 October 6–25, 1973  990750.0
# 10500                                 October 6–25, 1973  990750.0
# 10501                                 October 6–25, 1973  990750.0
# 10502                                 October 6–25, 1973  990750.0
# 10503                                 October 6–25, 1973  990750.0
# 10504                                 October 6–25, 1973  990750.0
# 10505                                 October 6–25, 1973  395000.0
# 10506                                 October 6–25, 1973  395000.0
# 10507                                 October 6–25, 1973  395000.0
# 10508                                 October 6–25, 1973  395000.0
# 10509                                 October 6–25, 1973  395000.0
# 10510                                 October 6–25, 1973  395000.0
# 10511                                 October 6–25, 1973  395000.0
# 10512                                 October 6–25, 1973  395000.0
# 10513                                 October 6–25, 1973  395000.0
# 10514                                 October 6–25, 1973  395000.0
# 10515                                        21 May 1940    7500.0
# 10516                                        21 May 1940    2000.0
#
#                                                 Location  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Former British Mandate of Palestine, Sinai Pen...
# 4      Former British Mandate of Palestine, Sinai Pen...
# 5      Former British Mandate of Palestine, Sinai Pen...
# 6      Former British Mandate of Palestine, Sinai Pen...
# 7      Former British Mandate of Palestine, Sinai Pen...
# 8      Former British Mandate of Palestine, Sinai Pen...
# 9      Former British Mandate of Palestine, Sinai Pen...
# 10     Former British Mandate of Palestine, Sinai Pen...
# 11     Former British Mandate of Palestine, Sinai Pen...
# 12     Former British Mandate of Palestine, Sinai Pen...
# 13     Former British Mandate of Palestine, Sinai Pen...
# 14     Former British Mandate of Palestine, Sinai Pen...
# 15     Former British Mandate of Palestine, Sinai Pen...
# 16     Former British Mandate of Palestine, Sinai Pen...
# 17     Former British Mandate of Palestine, Sinai Pen...
# 18     Former British Mandate of Palestine, Sinai Pen...
# 19     Former British Mandate of Palestine, Sinai Pen...
# 20     Former British Mandate of Palestine, Sinai Pen...
# 21     Former British Mandate of Palestine, Sinai Pen...
# 22     Former British Mandate of Palestine, Sinai Pen...
# 23     Former British Mandate of Palestine, Sinai Pen...
# 24     Former British Mandate of Palestine, Sinai Pen...
# ...                                                  ...
# 10492                                     Warsaw, Poland
# 10493                                     Warsaw, Poland
# 10494                   Wounded Knee Creek, South Dakota
# 10495                   Wounded Knee Creek, South Dakota
# 10496  Both banks of the Suez Canal, Golan Heights an...
# 10497  Both banks of the Suez Canal, Golan Heights an...
# 10498  Both banks of the Suez Canal, Golan Heights an...
# 10499  Both banks of the Suez Canal, Golan Heights an...
# 10500  Both banks of the Suez Canal, Golan Heights an...
# 10501  Both banks of the Suez Canal, Golan Heights an...
# 10502  Both banks of the Suez Canal, Golan Heights an...
# 10503  Both banks of the Suez Canal, Golan Heights an...
# 10504  Both banks of the Suez Canal, Golan Heights an...
# 10505  Both banks of the Suez Canal, Golan Heights an...
# 10506  Both banks of the Suez Canal, Golan Heights an...
# 10507  Both banks of the Suez Canal, Golan Heights an...
# 10508  Both banks of the Suez Canal, Golan Heights an...
# 10509  Both banks of the Suez Canal, Golan Heights an...
# 10510  Both banks of the Suez Canal, Golan Heights an...
# 10511  Both banks of the Suez Canal, Golan Heights an...
# 10512  Both banks of the Suez Canal, Golan Heights an...
# 10513  Both banks of the Suez Canal, Golan Heights an...
# 10514  Both banks of the Suez Canal, Golan Heights an...
# 10515                                              Arras
# 10516                                              Arras
#
#                                                   Result  Ships  Special VorD  \
# 0                                                    NaN    2.0      NaN    D
# 1                                                    NaN    2.0      NaN    D
# 2                                                    NaN    6.0      NaN    V
# 3      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 4      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 5      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 6      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 7      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 8      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 9      Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 10     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 11     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 12     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 13     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 14     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    V
# 15     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 16     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 17     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 18     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 19     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 20     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 21     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 22     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 23     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# 24     Israeli victory\r\r\r\nJordanian partial victo...    NaN      NaN    D
# ...                                                  ...    ...      ...  ...
# 10492                                     Polish victory    NaN      NaN    V
# 10493                                     Polish victory    NaN      NaN    V
# 10494                              United States victory    NaN      NaN    V
# 10495                              United States victory    NaN      NaN    D
# 10496  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10497  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10498  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10499  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10500  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10501  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10502  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10503  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10504  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...  104.0      NaN    D
# 10505  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10506  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10507  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10508  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10509  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10510  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10511  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10512  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10513  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10514  Israeli military victory[19]\r\r\r\n\r\r\r\nPo...    NaN      NaN    V
# 10515                                     German victory    NaN      NaN    V
# 10516                                     German victory    NaN      NaN    D
#
#                          belligerent  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                   David Ben-Gurion
# 4                     Yisrael Galili
# 5                        Yaakov Dori
# 6                       Yigael Yadin
# 7                      Mickey Marcus
# 8                        Yigal Allon
# 9                      Yitzhak Rabin
# 10                    David Shaltiel
# 11                       Moshe Dayan
# 12                     Shimon Avidan
# 13                      Moshe Carmel
# 14                     Yitzhak Sadeh
# 15         Abdul Rahman Hassan Azzam
# 16                   Farouk of Egypt
# 17              Abdullah I of Jordan
# 18               Muzahim al-Pachachi
# 19                    Husni al-Za'im
# 20                  Amin al-Husseini
# 21                Ahmed Ali al-Mwawi
# 22                   Mohammed Naguib
# 23                  John Bagot Glubb
# 24                   Habis al-Majali
# ...                              ...
# 10492          Stanisław Mokronowski
# 10493                   Jan Kiliński
# 10494               James W. Forsyth
# 10495                    Spotted Elk
# 10496                    Anwar Sadat
# 10497                 Hafez al-Assad
# 10498               Ahmad Ismail Ali
# 10499                  Mustafa Tlass
# 10500                 Saad el-Shazly
# 10501                 Yusuf Shakkour
# 10502  Mohamed Abdel Ghani el-Gamasy
# 10503                      Ali Aslan
# 10504                    Omar Abrash
# 10505                     Golda Meir
# 10506                    Moshe Dayan
# 10507                   David Elazar
# 10508                     Israel Tal
# 10509                   Shmuel Gonen
# 10510                   Yitzhak Hofi
# 10511                    Benny Peled
# 10512                   Haim Bar-Lev
# 10513                 Albert Mandler
# 10514                   Ariel Sharon
# 10515                   Erwin Rommel
# 10516                Harold Franklyn
#
#                                                      opp  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Egypt: 10,000 initially, rising to 20,000[cita...
# 4      Egypt: 10,000 initially, rising to 20,000[cita...
# 5      Egypt: 10,000 initially, rising to 20,000[cita...
# 6      Egypt: 10,000 initially, rising to 20,000[cita...
# 7      Egypt: 10,000 initially, rising to 20,000[cita...
# 8      Egypt: 10,000 initially, rising to 20,000[cita...
# 9      Egypt: 10,000 initially, rising to 20,000[cita...
# 10     Egypt: 10,000 initially, rising to 20,000[cita...
# 11     Egypt: 10,000 initially, rising to 20,000[cita...
# 12     Egypt: 10,000 initially, rising to 20,000[cita...
# 13     Egypt: 10,000 initially, rising to 20,000[cita...
# 14     Egypt: 10,000 initially, rising to 20,000[cita...
# 15     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 16     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 17     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 18     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 19     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 20     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 21     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 22     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 23     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# 24     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...
# ...                                                  ...
# 10492                                  8,000 soldiers[1]
# 10493                                  8,000 soldiers[1]
# 10494                                         120 men[2]
# 10495  500 effectives:\r\r\r\n7th U.S. Cavalry:\r\r\r...
# 10496  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10497  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10498  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10499  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10500  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10501  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10502  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10503  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10504  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...
# 10505  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10506  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10507  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10508  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10509  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10510  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10511  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10512  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10513  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10514  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...
# 10515                                             manual
# 10516                                             manual
#
#                                                      own pos    year
# 0                                                    NaN   R     NaN
# 1                                                    NaN   R     NaN
# 2                                                    NaN   L     NaN
# 3      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 4      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 5      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 6      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 7      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 8      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 9      Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 10     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 11     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 12     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 13     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 14     Israel: 29,677 (initially)\r\r\r\n117,500 (fin...   L  1948.0
# 15     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 16     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 17     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 18     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 19     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 20     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 21     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 22     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 23     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# 24     Egypt: 10,000 initially, rising to 20,000[cita...   R  1948.0
# ...                                                  ...  ..     ...
# 10492     3,000–3,500 soldiers,\r\r\r\n~2,500 militia[1]   L  1794.0
# 10493     3,000–3,500 soldiers,\r\r\r\n~2,500 militia[1]   L  1794.0
# 10494  500 effectives:\r\r\r\n7th U.S. Cavalry:\r\r\r...   L  1890.0
# 10495                                         120 men[2]   R  1890.0
# 10496  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10497  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10498  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10499  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10500  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10501  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10502  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10503  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10504  Egypt:\r\r\r\n\r\r\r\n\r\r\r\n650,000[23]–800,...   R  1973.0
# 10505  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10506  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10507  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10508  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10509  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10510  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10511  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10512  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10513  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10514  375,000[23]–415,000 troops\r\r\r\n1,700 tanks[...   L  1973.0
# 10515                                             manual   R  1940.0
# 10516                                             manual   L  1940.0
#
# [10515 rows x 16 columns]

# %%
df_run = df_run.dropna(subset = ['belligerent'])

# %%
df_lookup = df_strength_all.drop_duplicates(subset = ['Battle', 'pos'])

# %%
df_lookup.Battle = df_lookup.Battle.str.replace('_', ' ')
# Out:
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_lookup = pd.concat([df_lookup, pd.DataFrame(arras_1, index = [10515,10516])])

# %%
war_list = []
battle_list = []
def commander_war(general):
#     print general
    war = 0
    global df_battles
    df_dbg = df_run[df_run.belligerent == general]
    df_battles = pd.DataFrame()
    for battle in df_dbg.Battle.unique():


        row = df_dbg[df_dbg.Battle == battle].reset_index(drop = True)
        
        battle = row.loc[0,'Battle']

        df_str = df_lookup[df_lookup.Battle == battle].reset_index(drop = True)
        
        outcome = pd.DataFrame(row.loc[:,'VorD']).iloc[0,0]
        
        
        if row.loc[0, 'pos'] == 'L':
            opp_row = df_str[df_str.pos == 'R']
        if row.loc[0, 'pos'] == 'R':
            opp_row = df_str[df_str.pos == 'L']
            
       
            
        year = row.loc[0, 'year']

        own = row.drop(['Battle', 'Date', 'Location', 'Result', 'belligerent', 'opp', 'own', 'pos', 'VorD', 'year'], axis = 1)

        opp = opp_row.drop(['Battle', 'Date', 'Location', 'Result', 'belligerent', 'opp', 'own', 'pos', 'VorD', 'year'], axis = 1)
        
        opp = opp.rename(columns = {'Infantry':'infantry_opp', 
                                    'Cavalry':'cavalry_opp', 
                                    'Artillery':'artillery_opp', 
                                    'Ships':'ships_opp', 
                                    'Airforce':'airforce_opp',
                                    'Special':'special_opp'})

        opp = opp.reset_index(drop= True)

        pred_row = pd.concat([own, opp], axis = 1)
        
        pred_diff = pd.DataFrame()
        
        pred_diff['infantry_diff'] = (pred_row['Infantry'] - pred_row['infantry_opp']) / (pred_row['Infantry'] + pred_row['infantry_opp'])
        pred_diff['cavalry_dfff'] = (pred_row['Cavalry'] - pred_row['cavalry_opp']) / (pred_row['Cavalry'] + pred_row['cavalry_opp'])
        pred_diff['artillery_diff'] = (pred_row['Artillery'] - pred_row['artillery_opp']) / (pred_row['Artillery'] + pred_row['artillery_opp'])
        pred_diff['ships_diff'] = (pred_row['Ships'] - pred_row['ships_opp']) / (pred_row['Ships'] + pred_row['ships_opp'])
        pred_diff['airforce_diff'] = (pred_row['Airforce'] - pred_row['airforce_opp']) / (pred_row['Airforce'] + pred_row['airforce_opp'])
        pred_diff['special_diff'] = (pred_row['Special'] - pred_row['special_opp']) / (pred_row['Special'] + pred_row['special_opp'])

#         pred_diff = pred_diff.drop(['Infantry', 'Cavalry', 'Artillery', 'Ships', 'Airforce', 'Special', 'infantry_opp', 'cavalry_opp', 'artillery_opp', 'ships_opp', 'airforce_opp', 'special_opp'], axis = 1)

        pred_diff = pred_diff.fillna(0)

        pred_diff = pred_diff.drop(['artillery_diff', 'special_diff'], axis = 1)
        if battle == 'Siege of Kojinyama':
            print(pred_diff)
            
        df_pred = pd.DataFrame(lr.predict_proba(pred_diff))
        
#         if row.loc[0, 'Infantry'] == 1.0:
        

        if len(df_str) == 1:
            if row.loc[0, 'VorD'] == 'V':
                value = 0.5
#                 print 'UNKNOWN'
            elif row.loc[0, 'VorD'] == 'D':
                value = -.5
#                 print 'UNKNOWN'
            elif row.loc[0, 'VorD'] == 'I':
                value = 0
#                 print 'UNKNOWN'
        else:
            if df_str.Infantry.loc[0] == 1.0 or df_str.Infantry.loc[1] == 1.0:
                if row.loc[0, 'VorD'] == 'V':
                    value = 0.5
#                     print 'UNKNOWN'
                elif row.loc[0, 'VorD'] == 'D':
                    value = -.5
#                     print 'UNKNOWN'
                elif row.loc[0, 'VorD'] == 'I':
                    value = 0
#                     print 'UNKNOWN'
            else:
                if row.loc[0, 'VorD'] == 'V':
                    value = df_pred.iloc[0,0]
                elif row.loc[0, 'VorD'] == 'D':
                    value = 0 - df_pred.iloc[0,1]
                elif row.loc[0, 'VorD'] == 'I':
                    value = .5 - df_pred.iloc[0,1]
        
        

#         print u' '.join(battle).encode('utf-8').strip(' ') +': ' + str(value).encode('utf-8')

        
        
        
        war = war + value
        battle_list.append({'General':general,
                            'Battle': battle,
                            'Value': value,
                            'Year': year,
                            'Outcome': outcome})
        df_battles = pd.DataFrame(battle_list)
        warper = float(war)/float(len(df_dbg))
        
#     print 'Total: ' + str(war)
#     print u' '.join(general).encode('utf-8').strip(' ') + ': ' + str(war)
#     if len(df_dbg) > 4:
#         war_list.append({'General':general,
#                      'WAR':war})
    war_list.append({'General': general,
                    'WAR': war,
                    'Battles': len(df_dbg),
                    'War per Battle': warper})
    print(war)

# %%
war_list = []
count = 0
for general in df_run.belligerent.unique():
    count += 1
    print(str(general) + ': ' + str(count) + '/' + str(len(df_run.belligerent.unique())))
    commander_war(general)
# Out:
# David Ben-Gurion: 1/6619
# 0.970291472969
# Yisrael Galili: 2/6619
# 0.463603409202
# Yaakov Dori: 3/6619
# 0.463603409202
# Yigael Yadin: 4/6619
# 0.463603409202
# Mickey Marcus: 5/6619
# 0.463603409202
# Yigal Allon: 6/6619
# 0.463603409202
# Yitzhak Rabin: 7/6619
# 1.02621149925
# David Shaltiel: 8/6619
# 0.463603409202
# Moshe Dayan: 9/6619
# 2.08558615492
# Shimon Avidan: 10/6619
# 0.463603409202
# Moshe Carmel: 11/6619
# 0.463603409202
# Yitzhak Sadeh: 12/6619
# 0.463603409202
# Abdul Rahman Hassan Azzam: 13/6619
# -0.467433739452
# Farouk of Egypt: 14/6619
# -0.467433739452
# Abdullah I of Jordan: 15/6619
# -0.467433739452
# Muzahim al-Pachachi: 16/6619
# -0.467433739452
# Husni al-Za'im: 17/6619
# -0.467433739452
# Amin al-Husseini: 18/6619
# -0.467433739452
# Ahmed Ali al-Mwawi: 19/6619
# -0.467433739452
# Mohammed Naguib: 20/6619
# -0.467433739452
# John Bagot Glubb: 21/6619
# -0.467433739452
# Habis al-Majali: 22/6619
# -0.467433739452
# Hasan Salama: 23/6619
# -0.467433739452
# Arab Liberation Army: 24/6619
# -0.467433739452
# Fawzi al-Qawuqji: 25/6619
# -0.467433739452
# Menachem Begin: 26/6619
# -0.0701015379998
# Ariel Sharon: 27/6619
# 2.14098677522
# Rafael Eitan: 28/6619
# -0.0701015379998
# David Ivry: 29/6619
# -0.0701015379998
# Ze'ev Almog: 30/6619
# -0.0701015379998
# Bachir Gemayel: 31/6619
# -0.0701015379998
# Fadi Frem: 32/6619
# -0.0701015379998
# Elie Hobeika: 33/6619
# -0.0701015379998
# Fawzi Mahfuz: 34/6619
# -0.0701015379998
# Saad Haddad: 35/6619
# -0.0701015379998
# Yasser Arafat: 36/6619
# 0.0663245359605
# Hafez al-Assad: 37/6619
# -0.490164816048
# Mustafa Tlass: 38/6619
# -0.490164816048
# George Hawi: 39/6619
# 0.0663245359605
# Elias Atallah: 40/6619
# 0.0663245359605
# Abbas al-Musawi: 41/6619
# 0.0663245359605
# Ibrahim Kulaylat: 42/6619
# 0.0663245359605
# Nabih Berri: 43/6619
# 0.0663245359605
# Monte Melkonian: 44/6619
# 0.566324535961
# Mahsum Korkmaz: 45/6619
# 0.0663245359605
# Muhsin Ibrahim: 46/6619
# 0.0663245359605
# Ragheb Harb: 47/6619
# 0.0663245359605
# Murat Karayılan: 48/6619
# 0.0663245359605
# Inaam Raad: 49/6619
# 0.0663245359605
# Said Shaaban: 50/6619
# 0.0663245359605
# Chandrika Kumaratunga: 51/6619
# -0.5
# Velupillai Prabhakaran: 52/6619
# -1.93865968152
# Murtala Mohammed: 53/6619
# -0.0831969365005
# Jonathan Uchendu: 54/6619
# 0.579450115839
# Lieutenant colonel (United Kingdom): 55/6619
# 0.0733825143504
# Philip Robert Anstruther: 56/6619
# -0.50552854705
# Commandant-general: 57/6619
# 0.501680112904
# Francois Gerhardus Joubert: 58/6619
# 0.501680112904
# George Kenney: 59/6619
# 0.501643828375
# William Halsey Jr.: 60/6619
# 1.85688958319
# Frederick C. Sherman: 61/6619
# 0.501643828375
# Mineichi Koga: 62/6619
# -0.140386823189
# Jinichi Kusaka: 63/6619
# -0.948779749562
# Gerard Muirhead-Gould: 64/6619
# -0.0599331379722
# Hankyu Sasaki: 65/6619
# 0.0561363538749
# Humayun: 66/6619
# 0.986553589731
# Bairam Khan: 67/6619
# 0.986553589731
# Autaritus: 68/6619
# -0.570601370509
# Hamilcar Barca: 69/6619
# 1.0668254232
# Lieutenant general: 70/6619
# 0.27081087883
# Sarath Fonseka: 71/6619
# 2.93487260365
# Brigadier: 72/6619
# 0.0537210212537
# Shavendra Silva: 73/6619
# 1.43487260365
# Major general: 74/6619
# 1.96870865006
# Kamal Gunaratne: 75/6619
# 1.0
# Colonel: 76/6619
# 0.9754786188
# G.V. Ravipriya: 77/6619
# 1.0
# Pottu Amman (Tamil militant): 78/6619
# -1.0
# Theepan: 79/6619
# -1.0
# Sivanadan Somasekaran: 80/6619
# -1.0
# Decius: 81/6619
# -0.5
# Herennius Etruscus: 82/6619
# -0.5
# Cniva: 83/6619
# 1.0
# Thrasybulus: 84/6619
# 2.50167359618
# Thrasyllus: 85/6619
# 1.00876958905
# Mindarus: 86/6619
# -1.51321766536
# Leo Phokas the Elder: 87/6619
# -0.503624721109
# Simeon I of Bulgaria: 88/6619
# 0.999776131479
# Mark Antony: 89/6619
# -0.371376216232
# Gaius Sosius: 90/6619
# -0.520103032937
# Cleopatra: 91/6619
# 0.537994257541
# Marcus Vipsanius Agrippa: 92/6619
# 2.00474211882
# Augustus: 93/6619
# 3.37397653594
# Lucius Arruntius the Elder: 94/6619
# 0.516259487661
# Marcus Lurius: 95/6619
# 0.516259487661
# Belisarius: 96/6619
# 1.61920912834
# John the Armenian: 97/6619
# 1.01173550764
# Gelimer: 98/6619
# -1.01941355656
# Ammatas: 99/6619
# -0.485969866005
# Trajan: 100/6619
# 1.44641823965
# Tsar: 101/6619
# 0.498075682929
# Kaloyan of Bulgaria: 102/6619
# 0.498075682929
# Baldwin I, Latin Emperor: 103/6619
# -0.501924317071
# Licinius: 104/6619
# -0.474742724996
# Constantine the Great: 105/6619
# 2.00714359301
# Fritigern: 106/6619
# 0.457317287169
# Alatheus: 107/6619
# 0.457317287169
# Saphrax: 108/6619
# 0.457317287169
# Valens: 109/6619
# -0.46114033075
# Marcus Atilius Regulus: 110/6619
# 0.435256191316
# Bostar: 111/6619
# -0.450225760301
# Hamilcar (Drepanum): 112/6619
# -0.956358483707
# Hasdrubal: 113/6619
# -0.902354090844
# Lysander: 114/6619
# 0.994138834766
# Aracus (admiral): 115/6619
# 0.502164115616
# Conon: 116/6619
# -0.0120249848936
# Adeimantus (son of Leucolophides): 117/6619
# -0.506012492447
# Gerald FitzGerald, 15th Earl of Desmond: 118/6619
# -0.5
# Thomas Butler, 10th Earl of Ormond: 119/6619
# 0.5
# Quintus Fabius Maximus Verrucosus: 120/6619
# -0.499992027407
# Hannibal: 121/6619
# 5.47617505452
# Ilghazi: 122/6619
# -0.0558097277421
# Roger of Salerno: 123/6619
# 0.0
# Charles I of Albret: 124/6619
# -0.556021799557
# Jean Le Maingre: 125/6619
# -1.0396470534
# Charles, Duke of Orléans: 126/6619
# -0.556021799557
# Henry V of England: 127/6619
# 1.05221825632
# Edward of Norwich, 2nd Duke of York: 128/6619
# 0.552218256325
# Humphrey, Duke of Gloucester: 129/6619
# 0.552218256325
# Louis XII of France: 130/6619
# 0.438338139055
# Gian Giacomo Trivulzio: 131/6619
# 0.890631898479
# Louis II de la Trémoille: 132/6619
# 0.360753134506
# Charles II d'Amboise: 133/6619
# 0.438338139055
# Bartolomeo d'Alviano: 134/6619
# -0.0103714290161
# Hanno, son of Hannibal: 135/6619
# -1.03126274066
# Hannibal Gisco: 136/6619
# -0.545467626625
# Lucius Postumius Megellus (consul 262 BC): 137/6619
# 0.509599820277
# Quintus Mamilius Vitulus: 138/6619
# 0.509599820277
# Qutuz: 139/6619
# 0.46800488839
# Baibars: 140/6619
# 0.46800488839
# Kitbuqa: 141/6619
# -0.0212608096181
# Theodore (brother of Heraclius): 142/6619
# -0.059446344862
# Khalid ibn al-Walid: 143/6619
# 5.6253172811
# Abu Ubaidah ibn al-Jarrah: 144/6619
# 1.51397718398
# 'Amr ibn al-'As: 145/6619
# 0.908151474357
# Shurahbil ibn Hasana: 146/6619
# 1.49615136586
# Yazid ibn Abi Sufyan: 147/6619
# 0.996151365857
# Dhiraar bin Al-Azwar: 148/6619
# 0.996151365857
# Musaylimah: 149/6619
# -0.554548883884
# Abu Dujana: 150/6619
# 0.550742917723
# Abdallah al-Battal: 151/6619
# -0.5
# Al-Malik ibn Shu'aib: 152/6619
# -0.5
# Leo III the Isaurian: 153/6619
# 0.5
# Constantine V: 154/6619
# 1.42204813466
# Tang Jiahui: 155/6619
# 0.5
# Ashina Xin: 156/6619
# 0.5
# Wikipedia:Accuracy dispute: 157/6619
# -0.019066940296
# Talk:Battle of Aksu (717): 158/6619
# 0.5
# Ashina Xian: 159/6619
# 0.5
# Alfonso VIII of Castile: 160/6619
# 0.0326053179775
# Diego López II de Haro: 161/6619
# 0.0326053179775
# Abu Yusuf Yaqub al-Mansur: 162/6619
# 0.5
# Pedro Fernández de Castro (died 1214): 163/6619
# 0.5
# Nicolas Le Nen: 164/6619
# 0.5
# Col. Hussein: 165/6619
# 0.5
# Lt Colonel Sean D Wester (USMC): 166/6619
# 0.5
# Shirkuh: 167/6619
# 0
# Saladin: 168/6619
# -0.572140709085
# Amalric of Jerusalem: 169/6619
# 0
# Abu Marwan Abd al-Malik I Saadi: 170/6619
# 0.446177555691
# Ahmad al-Mansur: 171/6619
# 0.446177555691
# Sebastian of Portugal: 172/6619
# -0.449984692179
# Abu Abdallah Mohammed II Saadi: 173/6619
# -0.449984692179
# Thomas Stukley: 174/6619
# -0.449984692179
# Vercingetorix: 175/6619
# -1.03917971441
# Commius: 176/6619
# -0.527827526332
# Julius Caesar: 177/6619
# 7.35055149856
# Afonso V of Portugal: 178/6619
# 0.419667910766
# Afonso I, Duke of Braganza: 179/6619
# 0.424564587452
# Peter, Duke of Coimbra: 180/6619
# -0.428329935863
# Guy of Lusignan: 181/6619
# 0.514297640124
# John I of Castile: 182/6619
# -0.584487498207
# Pedro Álvares Pereira: 183/6619
# -1.15236807694
# John I of Portugal: 184/6619
# 1.08074393879
# Nuno Álvares Pereira: 185/6619
# 1.14484292218
# Murray of Aberscross: 186/6619
# 0.5
# Donald Mackay, 11th of Strathnaver: 187/6619
# -0.5
# Ranulf de Glanvill: 188/6619
# 0.422048134663
# William the Lion: 189/6619
# -0.425807679899
# Baldwin I of Jerusalem: 190/6619
# 0.528367876177
# Mawdud: 191/6619
# 0.5
# Toghtekin: 192/6619
# -1.52427791277
# Dawit II: 193/6619
# -1.0
# Ahmad ibn Ibrahim al-Ghazi: 194/6619
# 0.445508218413
# Brasidas: 195/6619
# -0.560483799276
# Cleon: 196/6619
# 0.00959982027683
# Nicias: 197/6619
# -0.490400179723
# Thucydides: 198/6619
# -0.490400179723
# Tervel of Bulgaria: 199/6619
# 0.5
# Justinian II: 200/6619
# -0.5
# Telets of Bulgaria: 201/6619
# -0.5
# William Eure, 1st Baron Eure: 202/6619
# -0.538221748352
# Brian Layton: 203/6619
# -0.538221748352
# James Hamilton, Duke of Châtellerault: 204/6619
# 0.00487286823847
# Archibald Douglas, 6th Earl of Angus: 205/6619
# 0.00487286823847
# Sophron of Ephesus: 206/6619
# -0.5
# Ptolemy Andromachou: 207/6619
# -0.5
# Antigonus II Gonatas: 208/6619
# 0.5
# Oda Nobunaga: 209/6619
# 4.22122244549
# Tokugawa Ieyasu: 210/6619
# 1.32205006444
# Inaba Yoshimichi: 211/6619
# 0.475545648007
# Azai Nagamasa: 212/6619
# -0.860834688664
# Asakura Yoshikage: 213/6619
# -1.37810508681
# Timur: 214/6619
# 0.472746991624
# Shahrukh Mirza: 215/6619
# 0.472746991624
# Khalil Sultan: 216/6619
# 0.472746991624
# Miran Shah: 217/6619
# 0.472746991624
# Abu Bakr (Timurid): 218/6619
# 0.472746991624
# Sultan Huseyn: 219/6619
# 0.472746991624
# Pir Muhammad ibn Jahangir: 220/6619
# 0.472746991624
# Taj al-Din Shah-i Shahan Abu'l Fath: 221/6619
# 0.472746991624
# Bayezid I: 222/6619
# -0.0224964619447
# Süleyman Çelebi: 223/6619
# -0.476585745516
# Mehmed I: 224/6619
# -0.476585745516
# Stefan Lazarević: 225/6619
# 0.00319602775961
# Gannys: 226/6619
# 0.5
# Heraclius: 227/6619
# -0.687907056089
# Shahrbaraz: 228/6619
# 0.422048134663
# Shahin Vahmanzadegan: 229/6619
# 0.5
# Eslamu: 230/6619
# -0.584847935399
# Fatagar: 231/6619
# -0.584847935399
# Theophilos (emperor): 232/6619
# -0.515449138639
# Theophobos: 233/6619
# -0.515449138639
# Manuel the Armenian: 234/6619
# -0.515449138639
# Khaydhar ibn Kawus al-Afshin: 235/6619
# 0.511603321106
# Umar al-Aqta: 236/6619
# 0.511603321106
# Jaysh ibn Samsama: 237/6619
# 0.5
# Damian Dalassenos: 238/6619
# -0.5
# Teutobod: 239/6619
# 0.314240361784
# Gaius Marius: 240/6619
# 1.08119101433
# Germanic kingship: 241/6619
# 0.453753402745
# Boiorix: 242/6619
# 0.302441720287
# Quintus Servilius Caepio: 243/6619
# -0.45757177377
# Gnaeus Mallius Maximus: 244/6619
# -0.45757177377
# Francesco Bussone da Carmagnola: 245/6619
# 0.0
# Bardas Skleros: 246/6619
# 0.5
# Peter (stratopedarches): 247/6619
# 0.5
# Thomas le Botiller: 248/6619
# -0.5
# William MacGeoghegan: 249/6619
# 0.5
# Rhydderch Hael: 250/6619
# 0.5
# Peredur: 251/6619
# 0.5
# Gwenddoleu ap Ceidio: 252/6619
# -0.5
# Priarius: 253/6619
# -0.5
# Mallobaudes: 254/6619
# 0.5
# Nannienus: 255/6619
# 0.5
# Callicratidas: 256/6619
# 0.5
# John Kingston (sailor): 257/6619
# -0.387771448075
# Nicolas Béhuchet: 258/6619
# -0.138161615128
# Hugues Quiéret: 259/6619
# -0.138161615128
# Lucius Caecilius Metellus Denter: 260/6619
# -0.5
# Britomaris: 261/6619
# 0.5
# Richard I of England: 262/6619
# 1.48655358973
# Hugh III, Duke of Burgundy: 263/6619
# 0.5
# Garnier de Nablus: 264/6619
# 0.0277440503931
# Robert IV of Sablé: 265/6619
# 0.986553589731
# James of Avesnes: 266/6619
# 0.5
# Al-Adil I: 267/6619
# -0.572140709085
# Al-Afdal ibn Salah ad-Din: 268/6619
# -0.0315791400651
# Al-Muzaffar Umar: 269/6619
# -0.0817405293621
# Tancred, Prince of Galilee: 270/6619
# 2.02594721907
# Fakhr al-Mulk Radwan: 271/6619
# -1.02427791277
# Eurybiades: 272/6619
# 0.598860417893
# Themistocles: 273/6619
# 1.14128864412
# Adeimantus of Corinth: 274/6619
# 0.0877778372481
# Achaemenes (satrap): 275/6619
# -0.606431379438
# Ariabignes: 276/6619
# -0.606431379438
# Artemisia I of Caria: 277/6619
# -0.606431379438
# Damasithymus: 278/6619
# -0.606431379438
# Al-Afdal Shahanshah: 279/6619
# -0.564807696051
# Godfrey of Bouillon: 280/6619
# 2.45993103517
# Raymond IV, Count of Toulouse: 281/6619
# 2.02594721907
# Robert Curthose: 282/6619
# 2.02594721907
# Robert II, Count of Flanders: 283/6619
# 2.02594721907
# Eustace III, Count of Boulogne: 284/6619
# 0.55909200563
# Gaston IV, Viscount of Béarn: 285/6619
# 1.07952897941
# Publius Decius Mus (consul 279 BC): 286/6619
# 0.498075682929
# Pyrrhus of Epirus: 287/6619
# -0.536443290644
# Pompeius Strabo: 288/6619
# 0.486553589731
# Judacilius: 289/6619
# -0.490400179723
# Fernando Sánchez de Tovar: 290/6619
# -0.567880578729
# Pero Gonzalez de Sevilla: 291/6619
# -0.567880578729
# Martim Anes de Barundo: 292/6619
# -0.567880578729
# Henry of Grosmont, 1st Duke of Lancaster: 293/6619
# 0.5
# Charles, Duke of Brittany: 294/6619
# -1.14982738501
# John IV, Duke of Brittany: 295/6619
# 0.504990703694
# John Chandos: 296/6619
# 1.03354349662
# Mushkin Niusalavurd: 297/6619
# 0.431202036573
# Mihr Narseh: 298/6619
# 0.431202036573
# Izad Gushnasp: 299/6619
# 0.431202036573
# Ashtat: 300/6619
# 0.431202036573
# Vardan Mamikonian: 301/6619
# -0.434981753075
# Jakob Henriksson Hästesko: 302/6619
# -0.526356312522
# Daniel Rantzau: 303/6619
# -0.0145328294117
# Hengist and Horsa: 304/6619
# 0
# Vortigern: 305/6619
# 0
# Vortimer: 306/6619
# 0
# Catigern: 307/6619
# 0
# Husayn ibn Numayr al-Sakuni: 308/6619
# 0.5
# Udi Adam: 309/6619
# -0.5
# Gal Hirsch: 310/6619
# -0.5
# Romanos III Argyros: 311/6619
# -0.591492273091
# Shibl al-Dawla Nasr: 312/6619
# 0.587767312727
# Baldwin II of Jerusalem: 313/6619
# 1.0
# Leo I, Prince of Armenia: 314/6619
# 0.5
# Joscelin I, Count of Edessa: 315/6619
# 0.0
# Pons, Count of Tripoli: 316/6619
# 0.5
# Alfonso VI of León and Castile: 317/6619
# -0.5
# Álvar Fáñez: 318/6619
# -0.5
# Sancho Ramírez: 319/6619
# -0.5
# Yusuf ibn Tashfin: 320/6619
# 0.5
# Al-Mu'tamid ibn Abbad: 321/6619
# 0.5
# Abdallah ibn Buluggin: 322/6619
# 0.5
# Amr ibn Hishām: 323/6619
# -0.568154173176
# Utbah ibn Rabi'ah: 324/6619
# -0.568154173176
# Umayyah ibn Khalaf: 325/6619
# -0.568154173176
# Hind bint Utbah: 326/6619
# -0.568154173176
# Muhammad: 327/6619
# 1.20235962529
# Hamza ibn Abdul-Muttalib: 328/6619
# 0.648638604036
# Ali: 329/6619
# 1.72117200214
# Abu Bakr: 330/6619
# 1.11809415671
# Umar: 331/6619
# 1.11809415671
# Scipio Africanus: 332/6619
# 2.49338143424
# Hasdrubal Barca: 333/6619
# -0.957579366444
# Abe no Hirafu: 334/6619
# -0.645249740239
# Buyeo Pung: 335/6619
# -0.645249740239
# Liu Rengui: 336/6619
# 0.641718047393
# Munmu of Silla: 337/6619
# 0.641718047393
# Buyeo Yung: 338/6619
# 0.641718047393
# Wenceslaus I, Duke of Luxembourg: 339/6619
# -0.524673816644
# William I, Marquis of Namur: 340/6619
# -0.524673816644
# William II, Duke of Jülich: 341/6619
# 0.520833152695
# Edward, Duke of Guelders: 342/6619
# 0.520833152695
# Hasdrubal Gisco: 343/6619
# -0.509372023375
# Syphax: 344/6619
# -0.5
# Masinissa: 345/6619
# 1.00409590022
# Gaius Laelius: 346/6619
# 0.5
# Hulagu Khan: 347/6619
# 0.45057878571
# Arghun Aqa: 348/6619
# 0.45057878571
# Baiju: 349/6619
# 0.45057878571
# Buqa-Temür: 350/6619
# 0.45057878571
# Sunitai: 351/6619
# 0.45057878571
# Guo Kan: 352/6619
# 0.861262258543
# Koke Ilge: 353/6619
# 0.45057878571
# Al-Musta'sim: 354/6619
# -0.454392664539
# Capital punishment: 355/6619
# -4.82663983819
# Mujaheduddin: 356/6619
# -0.454392664539
# Sulaiman Shah: 357/6619
# -0.454392664539
# Qarasunqur: 358/6619
# -0.454392664539
# Al-Ashraf Musa, Sultan of Egypt: 359/6619
# -0.454392664539
# Nang Wa: 360/6619
# -0.582659225662
# Shen Yin Shu: 361/6619
# -0.582659225662
# Helü: 362/6619
# 0.5789110614
# Fugai: 363/6619
# 0.5789110614
# Wu Zixu: 364/6619
# 0.5789110614
# Sun Tzu: 365/6619
# 0.5789110614
# Matthias Corvinus: 366/6619
# -0.521250624787
# Stephen III of Moldavia: 367/6619
# 2.06527941185
# Modu Chanyu: 368/6619
# 0.486553589731
# Emperor Gaozu of Han: 369/6619
# -0.0677652296263
# List of Khazar rulers: 370/6619
# 0.5
# Abd ar-Rahman ibn Rabiah: 371/6619
# -0.5
# Al-Jarrah ibn Abdallah: 372/6619
# 0.5
# Charles the Bald: 373/6619
# -0.0555060774193
# Nominoe: 374/6619
# 0.549774239699
# Mohamud Muse Hersi: 375/6619
# 0.5
# Abdulrahman Said Dhegaweyne: 376/6619
# 0.5
# Abdi Hasan Awale Qeybdiid: 377/6619
# 0.5
# Mohamed Mohamud Agaweine: 378/6619
# -0.5
# Daou al-Salhine al-Jadak: 379/6619
# 0.453753402745
# Musa Yunis: 380/6619
# 0.453753402745
# Saif al-Islam Gaddafi: 381/6619
# -0.971018184039
# Tarik Sulayman: 382/6619
# -0.542162605653
# Rajah Sulayman: 383/6619
# -0.542162605653
# Miguel López de Legazpi: 384/6619
# 0.53833891293
# Edward II of England: 385/6619
# -0.0475594798237
# Humphrey de Bohun, 4th Earl of Hereford: 386/6619
# -0.987537872274
# Aymer de Valence, 2nd Earl of Pembroke: 387/6619
# -0.59934847348
# Gilbert de Clare, 8th Earl of Gloucester: 388/6619
# -0.547559479824
# Robert de Clifford, 1st Baron de Clifford: 389/6619
# -0.547559479824
# Robert the Bruce: 390/6619
# 0.587913958871
# Edward Bruce: 391/6619
# 0.125934359494
# Robert II Keith, Marischal of Scotland: 392/6619
# -0.0297277799214
# James Douglas, Lord of Douglas: 393/6619
# 0.543742928866
# Thomas Randolph, 1st Earl of Moray: 394/6619
# 0.543742928866
# Yan Emperor: 395/6619
# 0.0272222113619
# Yellow Emperor: 396/6619
# 1.02722221136
# Osman I: 397/6619
# 0.5
# Shapur I: 398/6619
# 1.5
# Richard Neville, 16th Earl of Warwick: 399/6619
# -0.0527100680951
# John Neville, 1st Marquess of Montagu: 400/6619
# 0.989258018292
# Henry Holland, 3rd Duke of Exeter: 401/6619
# -1.04256185966
# John de Vere, 13th Earl of Oxford: 402/6619
# 0.464162872044
# Edward IV of England: 403/6619
# 3.04501534173
# Richard III of England: 404/6619
# 0.515641684615
# William Hastings, 1st Baron Hastings: 405/6619
# 1.03829607781
# Suleiman II (Rûm): 406/6619
# -0.534625009588
# David Soslan: 407/6619
# 0.530792845902
# Zakarids-Mkhargrzeli: 408/6619
# 0.530792845902
# Shalva of Akhaltsikhe: 409/6619
# 0.530792845902
# Nouri al-Maliki: 410/6619
# -0.0334436905559
# Ali Ghaidan Majid: 411/6619
# -0.0334436905559
# Mohan al-Furayji: 412/6619
# -0.0334436905559
# Fadhil Jalil al-Barwari: 413/6619
# -0.0334436905559
# Muqtada al-Sadr: 414/6619
# 0.529610358089
# Shiek Ali al-Sauidi: 415/6619
# 0.0296103580889
# Akram al-Kabi: 416/6619
# 0.0296103580889
# Yusuf al-Mosawi: 417/6619
# 0.0296103580889
# John Stewart, Earl of Buchan: 418/6619
# -0.621785160884
# Gilbert Motier de La Fayette: 419/6619
# 0.442477972209
# List of Marshals of France: 420/6619
# 0.442477972209
# Thomas of Lancaster, 1st Duke of Clarence: 421/6619
# -0.446278978746
# Thomas Beaufort, Duke of Exeter: 422/6619
# -0.446278978746
# John Beaufort, 1st Duke of Somerset: 423/6619
# -0.446278978746
# Zhang Fei: 424/6619
# 1.0497742397
# Zhang He: 425/6619
# -0.0289306842694
# Baldwin IV of Jerusalem: 426/6619
# 0.0463486025459
# Baldwin of Ibelin: 427/6619
# 0
# Balian of Ibelin: 428/6619
# -0.972255949607
# Hugh II of Saint Omer: 429/6619
# 0
# Gökböri: 430/6619
# 0.883135699956
# Charles I of Naples: 431/6619
# 0.5
# Manfred, King of Sicily: 432/6619
# -0.5
# Quintus Fulvius Flaccus (consul 237 BC): 433/6619
# -0.0525257235528
# Hanno the Elder: 434/6619
# -0.985810079441
# Tiberius Sempronius Gracchus (consul 215 BC): 435/6619
# 0.49864875926
# Manius Curius Dentatus: 436/6619
# 0.5
# John II Komnenos: 437/6619
# 0.5
# Telerig of Bulgaria: 438/6619
# -0.425807679899
# Seron (Syrian governor): 439/6619
# -0.563811223682
# Judas Maccabeus: 440/6619
# 2.30458205223
# Cestius Gallus: 441/6619
# -0.5
# Simon bar Giora: 442/6619
# 0.0470701652196
# Lysias (Syrian chancellor): 443/6619
# -1.08268220402
# Eleazar Avaran: 444/6619
# 0.54242822623
# Mirza Aziz Koka: 445/6619
# 0.5
# Sunshu Ao: 446/6619
# 0.5
# Zi Zhong: 447/6619
# 0.5
# Zi Fan: 448/6619
# 0.5
# Xun Linfu: 449/6619
# -0.5
# Shi Hui (Spring and Autumn period): 450/6619
# -0.5
# Zhao Shuo: 451/6619
# -0.5
# Divico: 452/6619
# -0.531519031016
# Odet of Foix, Viscount of Lautrec: 453/6619
# -0.518801401261
# Anne de Montmorency: 454/6619
# -0.50132042013
# Georg von Frundsberg: 455/6619
# 1.53842587905
# Fernando d'Avalos: 456/6619
# 1.53842587905
# Prospero Colonna: 457/6619
# 1.03422246737
# Abdul Fatah Younis: 458/6619
# -1.50384863414
# Shoshenq I: 459/6619
# 0.5
# Edward III of England: 460/6619
# 2.35424321308
# Godemar du Foy: 461/6619
# -0.483625253846
# John Babonić: 462/6619
# 0.5
# Ban of Slavonia: 463/6619
# 0.5
# Paul II Šubić of Bribir: 464/6619
# 0.5
# Mladen II Šubić of Bribir: 465/6619
# -0.5
# Ban of Croatia: 466/6619
# -0.5
# George II Šubić of Bribir: 467/6619
# -0.5
# John of Islay, Earl of Ross: 468/6619
# -0.5
# Aonghas Óg: 469/6619
# 0.5
# James Tuchet, 5th Baron Audley: 470/6619
# -0.536435606761
# John Sutton, 1st Baron Dudley: 471/6619
# -0.536435606761
# Richard Neville, 5th Earl of Salisbury: 472/6619
# 0.5189640387
# Thomas Neville: 473/6619
# 0.532605317977
# Algirdas: 474/6619
# 0.477345606801
# Fyodor Koriatovych: 475/6619
# 0.477345606801
# Demetrius, Prince of the Tatars: 476/6619
# -0.481187623147
# Tonyukuk: 477/6619
# 0.5
# Robert Fyssher: 478/6619
# 0.445168133362
# Le Seigneur de Tais: 479/6619
# -0.448973639216
# Jakob Bagge: 480/6619
# 0.453798755518
# Jacob Brockenhuus: 481/6619
# -0.457617188465
# Andrew Harclay, 1st Earl of Carlisle: 482/6619
# 0.436188776318
# John Peche: 483/6619
# 0.436188776318
# Thomas, 2nd Earl of Lancaster: 484/6619
# -0.93997839245
# Roger de Clifford, 2nd Baron de Clifford: 485/6619
# -0.43997839245
# John Howard, 1st Duke of Norfolk: 486/6619
# -0.522654393199
# Henry Percy, 4th Earl of Northumberland: 487/6619
# -0.522654393199
# John de la Pole, 1st Earl of Lincoln: 488/6619
# -1.00384201635
# Thomas Howard, 2nd Duke of Norfolk: 489/6619
# -0.00927779017699
# Francis Lovell, 1st Viscount Lovell: 490/6619
# -0.522654393199
# Henry VII of England: 491/6619
# 0.996157983655
# Jasper Tudor, Duke of Bedford: 492/6619
# 0.496157983655
# Gilbert Talbot (soldier): 493/6619
# 0.518812376853
# Philibert de Chandée, 1st Earl of Bath: 494/6619
# 0.518812376853
# Rhys ap Thomas: 495/6619
# 0.518812376853
# Otto IV, Holy Roman Emperor: 496/6619
# -0.516616812829
# William Longespée, 3rd Earl of Salisbury: 497/6619
# 0.0589283370021
# Renaud I, Count of Dammartin: 498/6619
# -0.516616812829
# Ferdinand, Count of Flanders: 499/6619
# -0.516616812829
# Theobald I, Duke of Lorraine: 500/6619
# -0.516616812829
# Henry I, Duke of Brabant: 501/6619
# -0.516616812829
# Philip II of France: 502/6619
# 0.420023590358
# Robert II, Count of Dreux: 503/6619
# 0.512771502698
# Philip of Dreux: 504/6619
# 0.512771502698
# Odo III, Duke of Burgundy: 505/6619
# 0.512771502698
# William IV, Count of Ponthieu: 506/6619
# 0.512771502698
# Thomas de Rokeby: 507/6619
# 0.5
# Henry Percy, 1st Earl of Northumberland: 508/6619
# -0.0301770434006
# Pál Kinizsi: 509/6619
# 0.496118620447
# Bartholomew Drágfi: 510/6619
# 0.496118620447
# Stephen V Báthory: 511/6619
# 0.496118620447
# Vuk Grgurević: 512/6619
# 0.496118620447
# Demetrius Jaksics: 513/6619
# 0.496118620447
# Basarab Laiotă cel Bătrân: 514/6619
# -0.055563538916
# Basarab Țepeluș cel Tânăr: 515/6619
# -0.499967195625
# Suleiman Mahmoud: 516/6619
# -0.00192431707133
# Mutassim Gaddafi: 517/6619
# -0.448683215696
# William de Bohun, 1st Earl of Northampton: 518/6619
# 0.372480670436
# Carlo Grimaldi: 519/6619
# -0.376085995473
# Seguin de Badefol: 520/6619
# 0.486553589731
# Petit Meschin: 521/6619
# 0.486553589731
# James I, Count of La Marche: 522/6619
# -0.490400179723
# Charles de Mornay: 523/6619
# 0.533220070809
# Julian (emperor): 524/6619
# 1.52730507958
# Æthelstan: 525/6619
# 0.5
# Edmund I: 526/6619
# 0.5
# Olaf Guthfrithson: 527/6619
# -0.5
# Constantine II of Scotland: 528/6619
# -0.5
# Owain ap Dyfnwal (fl. 934): 529/6619
# -0.5
# Sten Sture the Elder: 530/6619
# 0.479035900527
# Christian I of Denmark: 531/6619
# -0.482878952227
# Charles the Bold: 532/6619
# -0.942166384206
# Raes van Heers: 533/6619
# -0.465534119977
# Edmund Mortimer (1376-1409): 534/6619
# -0.516736348954
# Owain Glyndŵr: 535/6619
# 1.01289109314
# Shōni Sukeyoshi: 536/6619
# 0.5
# 少弐資能: 537/6619
# 0.5
# Ōtomo Yoriyasu: 538/6619
# 0.5
# 大友頼泰: 539/6619
# 0.5
# Kikuchi Takefusa: 540/6619
# 0.5
# Takezaki Suenaga: 541/6619
# 0.5
# Hindun: 542/6619
# -0.5
# 忻都 - 维基百科，自由的百科全书: 543/6619
# -0.5
# Liu Fuheng: 544/6619
# -0.5
# Kim Bang-gyeong: 545/6619
# -0.5
# 김방경 - 위키백과, 우리 모두의 백과사전: 546/6619
# -0.5
# Yi Sun-sin: 547/6619
# 2.7010104032
# Won Gyun: 548/6619
# 1.15083883894
# Yi Eokgi: 549/6619
# 0.670639798101
# Jeong Un: 550/6619
# 0.56608484483
# 정운 - 위키백과, 우리 모두의 백과사전: 551/6619
# 0.56608484483
# Wakisaka Yasuharu: 552/6619
# -1.29879137619
# Kuki Yoshitaka: 553/6619
# -0.722931905529
# Tōdō Takatora: 554/6619
# -1.26206415676
# Katō Yoshiaki: 555/6619
# -0.278021402904
# Æthelred, Lord of the Mercians: 556/6619
# 0.0
# Hastein: 557/6619
# -0.5
# Lan Yu (general): 558/6619
# 0.5
# Uskhal Khan Tögüs Temür: 559/6619
# -0.5
# Maximilian III, Archduke of Austria: 560/6619
# -0.968722102789
# Jan Zamoyski: 561/6619
# 0.502224776354
# Tachibana Muneshige: 562/6619
# 0.40903085323
# Ukita Hideie: 563/6619
# 0.738670901271
# Kobayakawa Takakage: 564/6619
# 1.38432038011
# Li Rusong: 565/6619
# -0.467394682023
# Rhys Gryg: 566/6619
# 0.5
# Stephen Bauzan: 567/6619
# -0.5
# Walter Manny, 1st Baron Manny: 568/6619
# 0.5
# Guy, Bastard of Flanders: 569/6619
# -0.5
# Raoul II of Brienne, Count of Eu: 570/6619
# -0.421891879083
# Publius Ostorius Scapula: 571/6619
# 0.5
# Caratacus: 572/6619
# -1.05752202779
# Atahualpa: 573/6619
# -0.0909366165241
# Francisco Pizarro: 574/6619
# 1.48763670471
# Hernando Pizarro: 575/6619
# 1.06145155904
# Gonzalo Pizarro: 576/6619
# 1.56337587611
# Juan Pizarro (conquistador): 577/6619
# 1.48763670471
# Hernando de Soto: 578/6619
# 1.08721012539
# Fínghin Mac Carthaigh: 579/6619
# 0.5
# John FitzGerald, 1st Baron Desmond: 580/6619
# -0.5
# Hermogenes (magister officiorum): 581/6619
# 0.0455406377642
# Sunicas: 582/6619
# 0.0455406377642
# Al-Harith ibn Jabalah: 583/6619
# -0.487064680213
# Azarethes: 584/6619
# 0.483219444593
# Al-Mundhir III ibn al-Nu'man: 585/6619
# 0.483219444593
# Aimery IV of Narbonne: 586/6619
# 0.489820117396
# Guillaume da Durfort: 587/6619
# 0.489820117396
# Guglielmino Ubertini: 588/6619
# -0.493667702185
# Pandolfo II Malatesta: 589/6619
# 0.42900125803
# Konrad von Landau: 590/6619
# -0.432776361307
# Boudica: 591/6619
# -0.159620339212
# Quintus Petillius Cerialis: 592/6619
# -0.43997839245
# Murong Bao: 593/6619
# -0.563147444919
# Murong Nong: 594/6619
# -0.563147444919
# Murong Lin: 595/6619
# -0.563147444919
# Murong De: 596/6619
# -0.563147444919
# Emperor Daowu of Northern Wei: 597/6619
# 0.559356568969
# Gaius Terentius Varro: 598/6619
# -0.531022892845
# Lucius Aemilius Paullus (consul 219 BC): 599/6619
# -0.531022892845
# Maharbal: 600/6619
# 0.527187299708
# Mago Barca: 601/6619
# 0.0253201988246
# Gisgo: 602/6619
# 0.527187299708
# Hanno, son of Bomilcar: 603/6619
# 0.527187299708
# Hasdrubal (quartermaster): 604/6619
# 0.527187299708
# Marcus Claudius Marcellus: 605/6619
# 0.486553589731
# Lucius Manlius Vulso Longus: 606/6619
# 0.502284361933
# Hanno the Great: 607/6619
# -1.00613272341
# Appius Claudius Pulcher (consul 212 BC): 608/6619
# -0.53199511161
# Francesco I Sforza: 609/6619
# 1.43563749184
# Micheletto Attendolo: 610/6619
# 0.0301775892643
# William Kirkcaldy of Grange: 611/6619
# 1.01688805978
# James Hepburn, 4th Earl of Bothwell: 612/6619
# -0.501924317071
# Necho II: 613/6619
# -0.541175943943
# Nebuchadnezzar II: 614/6619
# 2.0373510427
# Marcus Licinius Crassus: 615/6619
# -0.491309106734
# Publius Licinius Crassus (son of triumvir): 616/6619
# -0.491309106734
# Gaius Cassius Longinus: 617/6619
# -1.47354418676
# Surena: 618/6619
# 0.487462207032
# Hasan ibn al-Nu'man: 619/6619
# 0.5
# Tiberios III: 620/6619
# -0.5
# Hasdrubal the Boetharch: 621/6619
# -0.5
# Scipio Aemilianus: 622/6619
# 1.0
# Manius Manilius: 623/6619
# 0.5
# Alberico da Barbiano: 624/6619
# 0.5
# Muzio Sforza: 625/6619
# -0.0284297821584
# Galeotto I Malatesta: 626/6619
# 0.459268159654
# John Hawkwood: 627/6619
# 0.0585430895426
# Hanneken von Baumgarten: 628/6619
# -0.463093595054
# Azzo VII d'Este: 629/6619
# 0.5
# Ezzelino III da Romano: 630/6619
# -0.5
# Nicolaas Zannekin: 631/6619
# -0.501924317071
# Philip VI of France: 632/6619
# 0.498075682929
# Giovanni Ordelaffi: 633/6619
# -0.525476775884
# Da Polenta family: 634/6619
# -0.525476775884
# Giovanni dell'Ischia: 635/6619
# -0.525476775884
# Francesco Novello da Carrara: 636/6619
# 0.521636684596
# Jean Bureau: 637/6619
# 0.494932576023
# John Talbot, 1st Earl of Shrewsbury: 638/6619
# -1.55630308586
# Leptines of Syracuse: 639/6619
# 0.53852681276
# Mieszko I of Poland: 640/6619
# 0.483263651046
# Czcibor: 641/6619
# 0.483263651046
# Odo I, Margrave of the Saxon Ostmark: 642/6619
# -0.487108906864
# Nasar: 643/6619
# 0.925160501239
# Ibn al-Hawas: 644/6619
# -0.624565026264
# Roger I of Sicily: 645/6619
# 0.620948378825
# Serlo II of Hauteville: 646/6619
# 0.620948378825
# Alfonso d'Avalos: 647/6619
# -0.510614152003
# Francis, Count of Enghien: 648/6619
# 1.00676668052
# Louis d'Armagnac, Duke of Nemours: 649/6619
# -0.523107038268
# Yves d'Alègre: 650/6619
# -0.523107038268
# Pierre Terrail, seigneur de Bayard: 651/6619
# -0.523107038268
# Gonzalo Fernández de Córdoba: 652/6619
# 1.44578463171
# Pedro Navarro, Count of Oliveto: 653/6619
# 0.0359526230333
# Fabrizio Colonna: 654/6619
# 0.0359526230333
# Prince Henry the Navigator: 655/6619
# 0.5
# Chares of Athens: 656/6619
# -1.00990210404
# Lysicles (4th century BC): 657/6619
# -0.509902104036
# Athens: 658/6619
# -0.509902104036
# Theagenes (general): 659/6619
# -0.509902104036
# Philip II of Macedon: 660/6619
# 0.506054449815
# Alexander the Great: 661/6619
# 4.36976626412
# Archelaus (general): 662/6619
# -1.63441259419
# Sulla: 663/6619
# 1.62684703075
# Constantine I of Georgia: 664/6619
# -0.5
# Ibrahim I of Shirvan: 665/6619
# -0.5
# Syed Ahmed Orlat: 666/6619
# -0.5
# Qara Yusuf: 667/6619
# 0.5
# Yar Ahmed Qaramanli: 668/6619
# 0.5
# Jagath Jayasuriya: 669/6619
# 0.934872603649
# Prasanna Silva: 670/6619
# 0.5
# Vinayagam: 671/6619
# -0.5
# Selim I: 672/6619
# 1.49014457355
# Hasan Pasha (Ottoman commander): 673/6619
# 0.483263651046
# Ismail I: 674/6619
# -0.487108906864
# Abd al-Baqi Yazdi: 675/6619
# -0.487108906864
# Hossein Beg Laleh Shamlu: 676/6619
# -0.487108906864
# Saru Pira Ustajlu: 677/6619
# -0.487108906864
# Durmish Khan Shamlu: 678/6619
# -0.487108906864
# Nur-Ali Khalifa: 679/6619
# -0.487108906864
# Mohammad Khan Ustajlu: 680/6619
# -0.487108906864
# Sayyed Sharif al-Din Ali Shirazi: 681/6619
# -0.487108906864
# John of Montfort: 682/6619
# -0.5
# Bai Qi: 683/6619
# 1.0203106762
# Lian Po: 684/6619
# -0.491552336488
# Zhao Kuo: 685/6619
# -0.491552336488
# Cheng Dechen: 686/6619
# -0.5
# Zishang: 687/6619
# -0.5
# Zixi (Zhou dynasty): 688/6619
# -0.5
# Hu Mao: 689/6619
# 0.5
# Hu Yan: 690/6619
# 0.5
# Xian Zhen: 691/6619
# 0.5
# Xi Zhen: 692/6619
# 0.5
# Xu Chen (Zhou dynasty): 693/6619
# 0.5
# Luan Zhi: 694/6619
# 0.5
# Konishi Yukinaga: 695/6619
# 1.69318351172
# Shimazu Yoshihiro: 696/6619
# 0.954884155504
# Choe Ho: 697/6619
# -0.412371855044
# Bae Seol: 698/6619
# -0.412371855044
# Chalcuchimac: 699/6619
# 1.00605444981
# Quizquiz: 700/6619
# 0.506054449815
# Rumiñawi (Inca warrior): 701/6619
# 0.5
# Inca Empire: 702/6619
# -0.5
# Atoc: 703/6619
# -0.5
# Hango (general): 704/6619
# -0.5
# Ullco Colla: 705/6619
# -0.5
# Albert of Schwarzburg: 706/6619
# 0.490800646438
# Mehmed Beg: 707/6619
# -0.494648465703
# Philip V of Macedon: 708/6619
# -1.03603346569
# Attalus I: 709/6619
# 0.545646869991
# Theophiliscus: 710/6619
# 0.545646869991
# Bertrand du Guesclin: 711/6619
# 1.50222218072
# John Devereux, 1st Baron Devereux: 712/6619
# -0.464266101411
# Bernhard von Zinnenberg: 713/6619
# 0.470469948831
# Casimir IV Jagiellon: 714/6619
# -0.474306845997
# Jan Taszka Koniecpolski: 715/6619
# -0.474306845997
# Piotr of Szczekociny: 716/6619
# -0.474306845997
# Mullah Mutalib: 717/6619
# -0.5
# Mullah Ismael: 718/6619
# -0.5
# Shin Rip: 719/6619
# -0.556120957016
# Byeon Gi: 720/6619
# -0.556120957016
# Kim Yeo-mul: 721/6619
# -0.556120957016
# Yi Il: 722/6619
# -1.49181781888
# Yi Jong-jang: 723/6619
# -0.556120957016
# Sō Yoshitoshi: 724/6619
# 0.903546541896
# Matsura Shigenobu: 725/6619
# 0.552317579302
# Arima Harunobu: 726/6619
# 0.552317579302
# Ōmura Yoshiaki: 727/6619
# 0.552317579302
# Gnaeus Cornelius Scipio Calvus: 728/6619
# 0.986206038831
# Walter Sans Avoir: 729/6619
# -0.563811223682
# Kilij Arslan I: 730/6619
# -0.327973302427
# Rudolf of Benevento: 731/6619
# -0.529187930024
# Gerard, Duke of Lorraine: 732/6619
# -0.529187930024
# Humphrey of Hauteville: 733/6619
# 0.525350743685
# Robert Guiscard: 734/6619
# 1.52952796347
# Richard I of Capua: 735/6619
# 0.525350743685
# Brian Boru: 736/6619
# 0.995025015844
# Murchad mac Briain: 737/6619
# 0.495025015844
# Sigtrygg Silkbeard: 738/6619
# -0.998873506707
# Máel Mórda mac Murchada: 739/6619
# -0.998873506707
# Sigurd the Stout: 740/6619
# -0.498873506707
# Brodir and Ospak of Man: 741/6619
# -0.498873506707
# Pharnabazus II: 742/6619
# -0.00276472194125
# Peisander (general): 743/6619
# -0.497835884384
# Jean III de Grailly, captal de Buch: 744/6619
# -0.0189710193999
# John I Albert: 745/6619
# -0.5
# Stanisław Chodecki: 746/6619
# -0.5
# Provenzano Salvani: 747/6619
# -0.603396679157
# Giambertoldo: 748/6619
# 0.599706807377
# Conrad III of Germany: 749/6619
# -1.5
# Manuel I Komnenos: 750/6619
# 0.0
# Lucius Mummius Achaicus: 751/6619
# 0.455442198711
# Diaeus: 752/6619
# -0.459262832737
# Titus Manlius Torquatus (dictator): 753/6619
# 0.486013367153
# Hasdrubal the Bald: 754/6619
# -0.489859760949
# Hampsicora: 755/6619
# -0.489859760949
# Agesilaus II: 756/6619
# 0.5
# Tolmides: 757/6619
# -0.5
# Sparton: 758/6619
# 0.5
# James Stewart, 1st Earl of Moray: 759/6619
# 0.436188776318
# John Stewart, 4th Earl of Atholl: 760/6619
# 0.436188776318
# James Douglas, 4th Earl of Morton: 761/6619
# 0.436188776318
# George Gordon, 4th Earl of Huntly: 762/6619
# 0.0788339844032
# Pietro Tiepolo: 763/6619
# -0.591687594878
# Roman Catholic Archdiocese of Milan: 764/6619
# -0.591687594878
# Frederick II, Holy Roman Emperor: 765/6619
# 0.0879631748703
# Henry IV of France: 766/6619
# 1.00383891713
# Anne de Joyeuse: 767/6619
# -0.501924317071
# Munuza: 768/6619
# -0.604075573705
# Al Qama: 769/6619
# -0.604075573705
# Pelagius of Asturias: 770/6619
# 0.600387835096
# Alexander, 2nd Lord Forbes of Pitsligo: 771/6619
# -0.50802528085
# Adam Gordon of Auchindoun: 772/6619
# 0.504177219781
# Antipater: 773/6619
# 0.929862515837
# Craterus: 774/6619
# 2.41871132683
# Antiphilus (general): 775/6619
# -0.470131203293
# Menon IV of Pharsalus: 776/6619
# -0.470131203293
# Louis, Count of Vendôme: 777/6619
# -0.536435606761
# Thomas Montagu, 4th Earl of Salisbury: 778/6619
# 1.05659454381
# Gerard de Ridefort: 779/6619
# -0.404158717893
# Roger de Moulins: 780/6619
# -0.418456358017
# Otto II, Holy Roman Emperor: 781/6619
# -0.5
# Landulf IV of Benevento: 782/6619
# -0.5
# Abu al-Qasim (Kalbid): 783/6619
# 0.5
# Abu al-Qasim (Kalbite) — Wikipédia: 784/6619
# 0.5
# Emirate of Sicily: 785/6619
# 0.5
# Owain Gwynedd: 786/6619
# 0.5
# Cadwaladr ap Gruffydd: 787/6619
# 0.5
# Gruffydd ap Rhys: 788/6619
# 0.5
# Robert fitz Martin: 789/6619
# -0.5
# Maurice FitzGerald, Lord of Lanstephan: 790/6619
# -0.5
# Avidius Cassius: 791/6619
# 0.5
# Vologases IV: 792/6619
# -0.5
# Merena: 793/6619
# 0
# Artaxerxes II of Persia: 794/6619
# -0.0545488838836
# Gobrias: 795/6619
# -0.0545488838836
# Tissaphernes: 796/6619
# -0.0545488838836
# Cyrus the Younger: 797/6619
# 0.050742917723
# Clearchus of Sparta: 798/6619
# -0.446009311771
# Ariaeus: 799/6619
# 0.050742917723
# Lamba Doria: 800/6619
# 0.519746601946
# Andrea Dandolo (admiral): 801/6619
# -0.523588008676
# Titus Quinctius Flamininus: 802/6619
# 0.982727767767
# Ubba: 803/6619
# -0.5
# Odda, Ealdorman of Devon: 804/6619
# 0.5
# Alcibiades: 805/6619
# 0.492904007136
# Theramenes: 806/6619
# 0.492904007136
# Hermocrates: 807/6619
# 0.00324777050555
# Gar Trinring Tsendro: 808/6619
# 0.418141730008
# Xue Rengui: 809/6619
# -0.421891879083
# Ashina Daozi: 810/6619
# -0.421891879083
# Guo Daifeng: 811/6619
# -0.421891879083
# Abdul Qayyum Zakir: 812/6619
# -0.5
# Sancho d'Avila: 813/6619
# 1.02628288088
# Mas'ud I of Ghazni: 814/6619
# -0.555134818859
# Ali Daya: 815/6619
# -0.555134818859
# Ahmad Shirazi: 816/6619
# -0.555134818859
# Abu Sahl Zawzani: 817/6619
# -0.555134818859
# Abd al-Razzaq Maymandi: 818/6619
# -0.555134818859
# Begtoghdi: 819/6619
# -0.555134818859
# Subashi (general): 820/6619
# -0.555134818859
# Chaghri Beg: 821/6619
# 0.551329808534
# Tughril: 822/6619
# 0.551329808534
# Faramurz: 823/6619
# 0.551329808534
# Minamoto no Yoshitsune: 824/6619
# 1.55065875382
# Taira no Munemori: 825/6619
# -1.03050558079
# Taira no Tomomori: 826/6619
# -0.0305055807889
# Perozes: 827/6619
# -0.536435606761
# Pityaxes: 828/6619
# -0.536435606761
# Baresmanas: 829/6619
# -0.536435606761
# Pharas the Herulian: 830/6619
# 0.532605317977
# Taddeo d'Este: 831/6619
# -0.5
# Niccolò Piccinino: 832/6619
# 1.0
# William the Silent: 833/6619
# -1.06493085265
# Thomas Morgan (died 1595): 834/6619
# 0.986744312901
# Francisco de Valdez: 835/6619
# -0.999062473593
# Julian Romero: 836/6619
# 0.012030127534
# Pagondas: 837/6619
# 0.490097895964
# Hippocrates of Athens: 838/6619
# -0.493945550185
# Alexios Doukas Philanthropenos: 839/6619
# 0.473606328571
# John Palaiologos (brother of Michael VIII): 840/6619
# -0.627886791955
# Fillippo Sanudo: 841/6619
# -0.477445741635
# Guglielmo II da Verona: 842/6619
# -0.477445741635
# Publius Cornelius Scipio: 843/6619
# -0.507824551841
# Chen Tai: 844/6619
# 0.442477972209
# Deng Ai: 845/6619
# 0.442477972209
# Hu Fen: 846/6619
# 0.442477972209
# Jiang Wei: 847/6619
# -0.413673660769
# Xiahou Ba: 848/6619
# -0.446278978746
# Zhang Yi (Bogong): 849/6619
# -0.446278978746
# Mazyadid dynasty: 850/6619
# -0.555809727742
# David IV of Georgia: 851/6619
# 0.552005831527
# Demetrius I of Georgia: 852/6619
# 0.552005831527
# Francisco de Almeida: 853/6619
# 0.469494419211
# Amir Husain Al-Kurdi: 854/6619
# -0.47333047201
# Malik Ayyaz: 855/6619
# -0.47333047201
# Kunhali Marakkar: 856/6619
# -0.47333047201
# Giovanni Andrea Doria: 857/6619
# -0.0275289484606
# Juan de la Cerda, 4th Duke of Medinaceli: 858/6619
# -0.542823258299
# Álvaro de Sande: 859/6619
# -0.542823258299
# Piali Pasha: 860/6619
# -0.0291148659135
# Dragut: 861/6619
# 0.407969225509
# Major general (United States): 862/6619
# 0.5
# Major (United States): 863/6619
# 0.5
# Sviatoslav I of Kiev: 864/6619
# -1.05565505266
# John I Tzimiskes: 865/6619
# 1.04797845166
# Bohemond I of Antioch: 866/6619
# 1.40501624932
# Adhemar of Le Puy: 867/6619
# 1.40083902954
# Danishmend Gazi: 868/6619
# -0.437769149675
# Mesud I: 869/6619
# 0.5
# Adherbal (admiral): 870/6619
# 0.498075682929
# Hamilcar: 871/6619
# 0.498075682929
# Publius Claudius Pulcher (consul 249 BC): 872/6619
# -0.501924317071
# Francis, Duke of Guise: 873/6619
# 0.884817901746
# Louis, Prince of Condé (1530–1569): 874/6619
# -1.49848203416
# Gaspard II de Coligny: 875/6619
# -0.994931157187
# Hector Roy Mackenzie: 876/6619
# -0.0278275263323
# John Balliol: 877/6619
# -0.501924317071
# John de Warenne, 6th Earl of Surrey: 878/6619
# -0.0318462592562
# Domhnall II, Earl of Mar: 879/6619
# -0.573470708788
# Edward Balliol: 880/6619
# 0.569700965586
# Henry de Beaumont: 881/6619
# 0.569700965586
# Burchard von Hornhausen: 882/6619
# -0.536435606761
# Treniota: 883/6619
# 0.532605317977
# Alexios I Komnenos: 884/6619
# 0.513973398268
# George Palaiologos: 885/6619
# -0.00802528084961
# Sikelgaita: 886/6619
# 0.504177219781
# Pompey: 887/6619
# 0.911852010446
# Richard de Clare, Steward of Forest of Essex: 888/6619
# -0.5
# Valerian (emperor): 889/6619
# -0.5
# Successianus: 890/6619
# -0.5
# Robin of Redesdale: 891/6619
# 0.5
# William Herbert, 1st Earl of Pembroke (died 1469): 892/6619
# -0.5
# Humphrey Stafford, 1st Earl of Devon: 893/6619
# -0.5
# Alfred the Great: 894/6619
# 0.5
# Guthrum: 895/6619
# -0.5
# Bacchides (general): 896/6619
# 0.404469797017
# Iphicrates: 897/6619
# 0.0
# Timotheus (general): 898/6619
# -0.5
# Aurelian: 899/6619
# 0.953753402745
# Zenobia: 900/6619
# -0.95757177377
# Zabdas: 901/6619
# -0.95757177377
# Gorgias (general): 902/6619
# -0.527827526332
# Nicanor (Seleucid general): 903/6619
# -0.527827526332
# Hegesandridas: 904/6619
# 0.5
# Edward I of England: 905/6619
# 0.870379119089
# Gilbert de Clare, 7th Earl of Gloucester: 906/6619
# 0.996169711217
# Simon de Montfort, 6th Earl of Leicester: 907/6619
# 0.065210635955
# Peter de Montfort: 908/6619
# -0.467394682023
# Lucius Aemilius Papus: 909/6619
# -0.00497376758014
# Stilicho: 910/6619
# 0.995112173701
# Sarus the Goth: 911/6619
# 0.5
# Uldin: 912/6619
# 0.5
# Radagaisus: 913/6619
# -0.5
# Theodore Trithyrius: 914/6619
# -1.00192431707
# Hasan ibn Ali: 915/6619
# 0.0188123768534
# William Wallace: 916/6619
# 0.0790327269068
# Cao Ren: 917/6619
# 0.0179322253442
# Yu Jin: 918/6619
# 0.479781773276
# Pang De: 919/6619
# 0.479781773276
# Xu Huang: 920/6619
# 0.45018923876
# Guan Yu: 921/6619
# 0.0661489858531
# Louis IX of France: 922/6619
# 0.0941331447818
# Guillaume de Sonnac: 923/6619
# -0.5
# Al-Muazzam Turanshah: 924/6619
# 0.5
# Shane O'Neill (son of Conn): 925/6619
# -0.00192431707133
# Sir Hugh O'Donnell: 926/6619
# 0.498075682929
# John de Bermingham, 1st Earl of Louth: 927/6619
# 0.414068719387
# Edmund Butler, Earl of Carrick: 928/6619
# 0.414068719387
# Earl of Carrick (Ireland): 929/6619
# 0.414068719387
# Earl of Carrick: 930/6619
# -0.417808569372
# Fu Jian (337–385): 931/6619
# -0.587279243964
# Fu Rong: 932/6619
# -0.587279243964
# Xie An: 933/6619
# 0.583542915389
# Xie Xuan: 934/6619
# 0.583542915389
# Huan Chong: 935/6619
# 0.583542915389
# John Clifford, 9th Baron Clifford: 936/6619
# 0.463564393239
# John Neville, Baron Neville: 937/6619
# 0
# James IV of Scotland: 938/6619
# 0.00676759201264
# Alexander Home, 3rd Lord Home: 939/6619
# -0.517221633819
# William Graham, 1st Earl of Montrose: 940/6619
# -0.517221633819
# Adam Hepburn, 2nd Earl of Bothwell: 941/6619
# -0.517221633819
# Matthew Stewart, 2nd Earl of Lennox: 942/6619
# -0.517221633819
# Archibald Campbell, 2nd Earl of Argyll: 943/6619
# -0.517221633819
# Catherine of Aragon: 944/6619
# 0.513376603022
# Thomas Howard, 3rd Duke of Norfolk: 945/6619
# 0.513376603022
# Lord Edmund Howard: 946/6619
# 0.513376603022
# Thomas Dacre, 2nd Baron Dacre: 947/6619
# 0.513376603022
# Edward Stanley, 1st Baron Monteagle: 948/6619
# 0.513376603022
# Marmaduke Constable: 949/6619
# 0.513376603022
# Charles I, Duke of Bourbon: 950/6619
# 0.496935844313
# Arthur III, Duke of Brittany: 951/6619
# 0.496935844313
# Sir Thomas Kyriell: 952/6619
# -0.500784458454
# Francesco II Gonzaga, Marquess of Mantua: 953/6619
# -0.53417963911
# Charles VIII of France: 954/6619
# 0.530347029727
# Gaius Vibius Pansa Caetronianus: 955/6619
# 0.89446633319
# Aulus Hirtius: 956/6619
# 0.89446633319
# Enzo of Sardinia: 957/6619
# 0.471086402858
# Ottaviano degli Ubaldini: 958/6619
# -0.474923818466
# Thomas Müntzer: 959/6619
# 0.483263651046
# Philip I, Landgrave of Hesse: 960/6619
# 0.512891093136
# George, Duke of Saxony: 961/6619
# 0.512891093136
# Minamoto no Yoritomo: 962/6619
# 1.08026711356
# Taira no Koremori: 963/6619
# -1.08378258706
# Harald Hardrada: 964/6619
# -0.475908434623
# Tostig Godwinson: 965/6619
# -0.0124463809286
# Morcar: 966/6619
# -0.467394682023
# Edwin, Earl of Mercia: 967/6619
# -0.467394682023
# Antigonus I Monophthalmus: 968/6619
# 0.494219158872
# Eumenes: 969/6619
# -0.481009041333
# Han Xin: 970/6619
# 0.982656557647
# Xiang Yu: 971/6619
# 0.130415963513
# Pietro Loredan: 972/6619
# 0.5
# Alberic I of Spoleto: 973/6619
# 0.5
# Nicholas Picingli: 974/6619
# 0.5
# Pope John X: 975/6619
# 0.5
# Ludovico II, Marquess of Saluzzo: 976/6619
# -0.512408680023
# Willekin von Endorp: 977/6619
# -0.5
# Darius III: 978/6619
# -1.08126920509
# Bessus: 979/6619
# -0.526356056137
# Mazaeus: 980/6619
# -0.526356056137
# Orontes II: 981/6619
# -0.526356056137
# Atropates: 982/6619
# -0.526356056137
# Hephaestion: 983/6619
# 2.4599442453
# Parmenion: 984/6619
# 1.53850476093
# Ptolemy I Soter: 985/6619
# 2.02160336143
# Perdiccas: 986/6619
# 0.997537859462
# Cleitus the Black: 987/6619
# 0.987396985161
# Nearchus: 988/6619
# 0.522516614739
# Seleucus I Nicator: 989/6619
# 1.99531694706
# Ariston of Paionia: 990/6619
# 0.522516614739
# Simmias of Macedon: 991/6619
# 0.522516614739
# Coenus (general): 992/6619
# 0.997537859462
# Ariston of Macedon: 993/6619
# 0.522516614739
# Glaucias of Macedon: 994/6619
# 0.522516614739
# Sopolis of Macedon: 995/6619
# 0.522516614739
# Francesco Ferruccio: 996/6619
# -0.532715554953
# Philibert of Chalon: 997/6619
# 0.528881523514
# Fabrizio Maramaldo: 998/6619
# 0.528881523514
# Demetrius I of Macedon: 999/6619
# -0.127522071702
# Dionysius I of Syracuse: 1000/6619
# 1.01912610026
# Himilco (general): 1001/6619
# -0.0480336324876
# Antoine de Goignies: 1002/6619
# -0.517416854252
# Maximilien de Hénin-Liétard: 1003/6619
# -0.0206151414273
# William II de La Marck: 1004/6619
# -0.517416854252
# Maarten Schenck van Nydeggen: 1005/6619
# -0.517416854252
# Emanuel Philibert de Lalaing: 1006/6619
# -0.517416854252
# Philip, Count of Egmont: 1007/6619
# -1.02702781289
# Charles Philippe de Croÿ, Marquis d’Havré: 1008/6619
# -0.517416854252
# Henry Balfour (soldier): 1009/6619
# -0.517416854252
# John of Austria: 1010/6619
# 0.537070655619
# Alexander Farnese, Duke of Parma: 1011/6619
# 0.0099772706481
# Cristóbal de Mondragón: 1012/6619
# 0.513571916022
# Ottavio Gonzaga: 1013/6619
# 0.513571916022
# Peter Ernst I von Mansfeld-Vorderort: 1014/6619
# 0.513571916022
# Francisco Verdugo: 1015/6619
# 0.513571916022
# John FitzAlan, 14th Earl of Arundel: 1016/6619
# -0.570601370509
# La Hire: 1017/6619
# 1.12054644446
# Jean Poton de Xaintrailles: 1018/6619
# 1.12054644446
# Marcus Minucius Rufus: 1019/6619
# -0.467394682023
# Magister equitum: 1020/6619
# -0.467394682023
# Archibald Campbell, 7th Earl of Argyll: 1021/6619
# -0.570601370509
# George Gordon, 1st Marquess of Huntly: 1022/6619
# 0.566825423203
# Francis Hay, 9th Earl of Erroll: 1023/6619
# 0.566825423203
# Máel Sechnaill mac Domnaill: 1024/6619
# 0.5
# Sorley Boy MacDonnell: 1025/6619
# -0.5
# Joseph Kabila: 1026/6619
# 0.442477972209
# Babacar Gaye: 1027/6619
# 0.442477972209
# Ignace Murwanashyaka: 1028/6619
# 0.442477972209
# José Eduardo dos Santos: 1029/6619
# 0.442477972209
# Robert Mugabe: 1030/6619
# 0.442477972209
# Laurent Nkunda: 1031/6619
# -0.446278978746
# Lamoral, Count of Egmont: 1032/6619
# 0.932298933548
# Paul de Thermes: 1033/6619
# -0.48544893212
# Gaius Claudius Nero: 1034/6619
# 0.96384289107
# Ulrich von Jungingen: 1035/6619
# -0.527403708656
# Władysław II Jagiełło: 1036/6619
# 1.04237744956
# Vytautas: 1037/6619
# 0.0636937279507
# Roderic: 1038/6619
# -0.516063515637
# Tariq ibn Ziyad: 1039/6619
# 0.512217959839
# Chunyu Qiong: 1040/6619
# -0.550161389297
# Guo Tu: 1041/6619
# -0.550161389297
# Cao Hong: 1042/6619
# -0.509157474873
# Tian Ji: 1043/6619
# 0.961640076168
# Sun Bin: 1044/6619
# 0.961640076168
# Pang Juan: 1045/6619
# -0.969318999094
# Maximilian I, Holy Roman Emperor: 1046/6619
# 0.339127684723
# Philippe de Crèvecœur d'Esquerdes: 1047/6619
# -0.457879081287
# Henry VIII of England: 1048/6619
# 1.4339838161
# Henry Bourchier, 2nd Earl of Essex: 1049/6619
# 0.433983816102
# Jacques de La Palice: 1050/6619
# -0.38000703532
# Charles IV, Duke of Alençon: 1051/6619
# -0.437769149675
# Louis I d'Orléans, duc de Longueville: 1052/6619
# -0.437769149675
# Petar Svačić: 1053/6619
# -0.5
# Coloman, King of Hungary: 1054/6619
# 0.5
# Eumenes II: 1055/6619
# 0.998075682929
# Dexagoridas: 1056/6619
# -0.5
# Gorgopas (2nd century BC): 1057/6619
# -0.5
# Marinus Brandt: 1058/6619
# -0.530505580789
# Robert Bowes (lawyer): 1059/6619
# -0.522654393199
# Katō Kiyomasa: 1060/6619
# 0.88669612258
# Kuroda Nagamasa: 1061/6619
# 1.33933477274
# Ishida Mitsunari: 1062/6619
# -0.624789547976
# Kikkawa Hiroie: 1063/6619
# -0.577951865337
# Kobayakawa Hideaki: 1064/6619
# -0.577951865337
# Kwon Yul: 1065/6619
# 0.0467886114452
# Jo Gyeong: 1066/6619
# 0.574192320101
# Seon Geoi: 1067/6619
# 0.574192320101
# Kim Cheon Il: 1068/6619
# 0.574192320101
# Heo Uk: 1069/6619
# 0.574192320101
# Cheo Yung: 1070/6619
# 0.574192320101
# Archibald Douglas (died 1333): 1071/6619
# -0.520771989537
# Thomas of Brotherton, 1st Earl of Norfolk: 1072/6619
# 0.516928825737
# Walter V, Count of Brienne: 1073/6619
# -0.5
# Al-Husayn ibn Zikrawayh: 1074/6619
# -0.5
# Muhammad ibn Sulayman al-Katib: 1075/6619
# 0.5
# Husayn ibn Hamdan: 1076/6619
# 0.5
# Cao Xiu: 1077/6619
# -1.11110378814
# Zhao Yun: 1078/6619
# 0.538422051623
# Huang Zhong: 1079/6619
# 0.549774239699
# Liu Bei: 1080/6619
# 1.10914829967
# Raymond III, Count of Tripoli: 1081/6619
# -1.0297779774
# Bohemond III of Antioch: 1082/6619
# -0.557522027791
# Constantine Kalamanos: 1083/6619
# -0.557522027791
# Thoros II, Prince of Armenia: 1084/6619
# -0.557522027791
# Hugh VIII of Lusignan: 1085/6619
# -0.557522027791
# Joscelin III, Count of Edessa: 1086/6619
# -1.0297779774
# Nur ad-Din (died 1174): 1087/6619
# 1.48770483736
# Qutb ad-Din Mawdud: 1088/6619
# 0.553721021254
# Alexander Stewart, Earl of Mar: 1089/6619
# -0.5
# Donald of Islay, Lord of the Isles: 1090/6619
# 0
# Mosul: 1091/6619
# 1.0
# Sökmen (Artuqid): 1092/6619
# -0.0242779127726
# William the Conqueror: 1093/6619
# 0.495272356479
# Alan Rufus: 1094/6619
# 0.495272356479
# William FitzOsbern, 1st Earl of Hereford: 1095/6619
# 0.495272356479
# Eustace II, Count of Boulogne: 1096/6619
# 0.495272356479
# Harold Godwinson: 1097/6619
# -0.0269483959667
# Gyrth Godwinson: 1098/6619
# -0.499120869634
# Leofwine Godwinson: 1099/6619
# -0.499120869634
# Raynald of Châtillon: 1100/6619
# 0.074092652939
# Humphrey IV of Toron: 1101/6619
# -0.472255949607
# Aimery of Cyprus: 1102/6619
# -0.472255949607
# Reginald of Sidon: 1103/6619
# -0.472255949607
# Þórður kakali Sighvatsson: 1104/6619
# 0.5
# Henry Beaufort, 3rd Duke of Somerset: 1105/6619
# -1.03949743232
# Thomas de Ros, 9th Baron de Ros: 1106/6619
# -0.992495077509
# Robert Hungerford, 3rd Baron Hungerford: 1107/6619
# -0.992495077509
# Ralph Percy: 1108/6619
# -0.492495077509
# Louis of Nassau: 1109/6619
# -1.63534454197
# Adolf of Nassau (1540–1568): 1110/6619
# 0.46762723366
# Jean de Ligne, Duke of Arenberg: 1111/6619
# -0.471461588499
# John, King of Denmark: 1112/6619
# -0.5
# Frederick I of Denmark: 1113/6619
# -0.5
# Publius Valerius Laevinus: 1114/6619
# -0.469313296782
# Ismail Khan: 1115/6619
# 0.5
# Tommy Franks: 1116/6619
# -0.00192431707133
# Yahya Rahim Safavi: 1117/6619
# 0.5
# Flaccus: 1118/6619
# -0.485042846759
# Hannibal Mago: 1119/6619
# 1.5
# Hamilcar I of Carthage: 1120/6619
# -0.575435412548
# Gelo: 1121/6619
# 0.571670064137
# Theron of Acragas: 1122/6619
# 0.571670064137
# Henry Percy (Hotspur): 1123/6619
# -0.53720228173
# George I, Earl of March: 1124/6619
# 1.00242827458
# Archibald Douglas, 4th Earl of Douglas: 1125/6619
# -1.00148682337
# Jan Žižka: 1126/6619
# 2.1851325575
# Diviš Bořek of Miletínek: 1127/6619
# 1.48803336837
# Čeněk of Wartenberg: 1128/6619
# -0.522176857818
# Artabanus V of Parthia: 1129/6619
# -0.5
# Ardashir I: 1130/6619
# 0.5
# Dou Jiande: 1131/6619
# -0.540731840346
# Wang Shichong: 1132/6619
# -0.00812652236877
# Duan Da: 1133/6619
# -0.540731840346
# Shan Xiongxin: 1134/6619
# -0.540731840346
# Emperor Taizong of Tang: 1135/6619
# 0.536906404946
# Li Yuanji: 1136/6619
# 0.536906404946
# Liu Dewei: 1137/6619
# 0.536906404946
# Huang Junhan: 1138/6619
# 0.536906404946
# Yuwen Shiji: 1139/6619
# 0.536906404946
# Shi Wanbao: 1140/6619
# 0.536906404946
# Li Shiji: 1141/6619
# 0.536906404946
# Emperor Gaozu of Tang: 1142/6619
# 0.5
# ...
# -0.443815642919
# Burchard II (bishop of Halberstadt): 1361/6619
# -0.443815642919
# Magnus, Duke of Saxony: 1362/6619
# -0.443815642919
# Lothair Udo II, Margrave of the Nordmark: 1363/6619
# -0.443815642919
# Archibald Campbell, 5th Earl of Argyll: 1364/6619
# -0.522654393199
# Jacopo Caldora: 1365/6619
# 0.471570217842
# Braccio da Montone: 1366/6619
# -0.475408032136
# Haakon IV of Norway: 1367/6619
# 0
# Alexander Stewart, 4th High Steward of Scotland: 1368/6619
# 0
# Muhammad al-Nasir: 1369/6619
# -0.536435606761
# Rodrigo Jiménez de Rada: 1370/6619
# 0.532605317977
# Sancho VII of Navarre: 1371/6619
# 0.532605317977
# Peter II of Aragon: 1372/6619
# -0.0434827874101
# Diego de Almagro: 1373/6619
# 0.016376740881
# Rodrigo Orgóñez: 1374/6619
# 0.016376740881
# Alonso de Alvarado: 1375/6619
# 0.5757391714
# Pedro de Valdivia: 1376/6619
# 0.122992956307
# Otto I, Holy Roman Emperor: 1377/6619
# 0.5
# Conrad, Duke of Lorraine: 1378/6619
# 0.5
# Burchard III, Duke of Swabia: 1379/6619
# 0.5
# Horka (title): 1380/6619
# -0.5
# Bulcsú: 1381/6619
# -0.5
# Lehel: 1382/6619
# -0.5
# Taksony of Hungary: 1383/6619
# -0.5
# Guido da Landriano: 1384/6619
# 0.490097895964
# Baidar: 1385/6619
# 0.498075682929
# Kadan: 1386/6619
# 0.498075682929
# Orda Khan: 1387/6619
# 0.498075682929
# Henry II the Pious: 1388/6619
# -0.501924317071
# Mieszko II the Fat: 1389/6619
# -0.501924317071
# Sverker II of Sweden: 1390/6619
# -0.530576830911
# Eric X of Sweden: 1391/6619
# 0.526740840932
# Kemal Reis: 1392/6619
# 0.975200687196
# Ottoman Navy: 1393/6619
# -0.519138380934
# Müezzinzade Ali Pasha: 1394/6619
# -0.519138380934
# Mahomet Sirocco: 1395/6619
# -0.519138380934
# Occhiali: 1396/6619
# -1.08725363841
# Holy League (1571): 1397/6619
# 0.515294309838
# Navy: 1398/6619
# 0.515294309838
# Sebastiano Venier: 1399/6619
# 0.515294309838
# Marcantonio Colonna: 1400/6619
# 0.515294309838
# Agostino Barbarigo (admiral): 1401/6619
# 0.515294309838
# Álvaro de Bazán, 1st Marquis of Santa Cruz: 1402/6619
# 0.515294309838
# Nikola Skobaljić: 1403/6619
# 0.5
# Cleombrotus I: 1404/6619
# -0.521363707946
# Epaminondas: 1405/6619
# 0.517520893071
# Constantine Dalassenos (thalassokrator): 1406/6619
# 0.5
# Henry III of England: 1407/6619
# -1.13427554739
# Richard, 1st Earl of Cornwall: 1408/6619
# -0.536435606761
# Nicholas de Segrave, 1st Baron Segrave: 1409/6619
# 0.532605317977
# Swedish jarls: 1410/6619
# -0.5
# Charles the Deaf: 1411/6619
# -0.5
# Juan Adolf van Haamstede: 1412/6619
# -0.5
# Lodewijk van Boisot: 1413/6619
# 1.0093987061
# Ulrich II von Rosenberg: 1414/6619
# 0.483145238592
# Prokop the Great: 1415/6619
# 0.0197288237431
# Jan Čapek ze Sán: 1416/6619
# -0.486990440173
# Prokop the Lesser: 1417/6619
# -0.486990440173
# Jan Roháč z Dubé: 1418/6619
# 0.0197288237431
# Ahmed Khan bin Küchük: 1419/6619
# -0.5
# James Douglas, 9th Earl of Douglas: 1420/6619
# -0.5
# Alexander Stewart, Duke of Albany: 1421/6619
# -0.5
# Simeon Bekbulatovich: 1422/6619
# -0.589101528308
# Clas Åkesson Tott: 1423/6619
# 0.585370049547
# Robert Welles, 8th Baron Willoughby de Eresby: 1424/6619
# -0.5
# Zhao Ponu: 1425/6619
# 0.5
# Henry VI of England: 1426/6619
# -0.45757177377
# Humphrey Stafford, 1st Duke of Buckingham: 1427/6619
# -0.45757177377
# Richard of York, 3rd Duke of York: 1428/6619
# -0.513641279277
# Septimius Severus: 1429/6619
# 0.498075682929
# Clodius Albinus: 1430/6619
# -0.501924317071
# Valdemar II of Denmark: 1431/6619
# 0.5
# Vitslav I, Prince of Rügen: 1432/6619
# 0.5
# Theoderich von Treyden: 1433/6619
# 0.5
# Lucius Cornelius Scipio Asiaticus: 1434/6619
# 0.498075682929
# Antiochus III the Great: 1435/6619
# -0.967014908489
# Zeuxis (general): 1436/6619
# -0.501924317071
# Seleucus IV Philopator: 1437/6619
# -0.501924317071
# Godigisel: 1438/6619
# 0.5
# Respendial: 1439/6619
# 0.5
# Olaf Tryggvason: 1440/6619
# 0.100901848172
# Byrhtnoth: 1441/6619
# -0.5
# Laches (general): 1442/6619
# -0.516736348954
# Nicostratus (Athenian commander): 1443/6619
# -0.516736348954
# Agis II: 1444/6619
# 0.512891093136
# Romanos IV Diogenes: 1445/6619
# -0.540731840346
# Theodore Alyates: 1446/6619
# -0.540731840346
# Andronikos Doukas (cousin of Michael VII): 1447/6619
# -0.540731840346
# Alp Arslan: 1448/6619
# 0.536906404946
# Artuk Bey: 1449/6619
# 0.536906404946
# Suleiman ibn Qutulmish: 1450/6619
# 0.536906404946
# Sayf al-Dawla: 1451/6619
# 0.5
# Bardas Phokas the Elder: 1452/6619
# -0.5
# Artaphernes (son of Artaphernes): 1453/6619
# -0.0462465972546
# Hippias (tyrant): 1454/6619
# -0.546246597255
# Miltiades: 1455/6619
# 0.54242822623
# Callimachus (polemarch): 1456/6619
# 0.54242822623
# Aristides: 1457/6619
# 0.54242822623
# Xanthippus: 1458/6619
# 1.09680753307
# Pericles: 1459/6619
# 0.54242822623
# Arimnestos: 1460/6619
# 0.54242822623
# Kardam of Bulgaria: 1461/6619
# 0.5
# Constantine VI: 1462/6619
# -0.5
# Vineh of Bulgaria: 1463/6619
# 0.0
# Gian Giacomo Medici: 1464/6619
# 0.483089759762
# Piero Strozzi: 1465/6619
# 0.0130650642173
# Valerius Valens: 1466/6619
# -0.5
# Eric XIV of Sweden: 1467/6619
# -0.548916423864
# Frederick II of Denmark: 1468/6619
# 0.545101809947
# Francis I of France: 1469/6619
# -0.0497657228473
# Charles III, Duke of Bourbon: 1470/6619
# 0.452293759425
# Marx Röist: 1471/6619
# -0.456110103621
# Maximilian Sforza: 1472/6619
# 0.069932061645
# Matthäus Schiner: 1473/6619
# -0.456110103621
# Vukašin Mrnjavčević: 1474/6619
# -0.600635645252
# Uglješa Mrnjavčević: 1475/6619
# -0.600635645252
# Lala Şahin Pasha: 1476/6619
# 0.596937244862
# Evrenos: 1477/6619
# 1.07671901814
# Al-Ashraf Qansuh Al-Ghuri: 1478/6619
# -0.512652101718
# Marwan I: 1479/6619
# -0.02457871027
# Abbas ibn Ziyad: 1480/6619
# 0.498075682929
# Al-Dahhak ibn Qays al-Fihri: 1481/6619
# -0.501924317071
# Oswald of Northumbria: 1482/6619
# -0.5
# Penda of Mercia: 1483/6619
# 0.0
# Eowa of Mercia: 1484/6619
# 0.5
# Cynddylan: 1485/6619
# 0.5
# Li Guang: 1486/6619
# 0
# Gallienus: 1487/6619
# 1.0
# Agis III: 1488/6619
# -0.467394682023
# Thutmose III: 1489/6619
# 0.5
# Josiah: 1490/6619
# -0.5
# Guillaume Cale: 1491/6619
# -0.541722443128
# Charles II of Navarre: 1492/6619
# 0.537898207561
# Ambrosius Aurelianus: 1493/6619
# 0
# Thomas de Scales, 7th Baron Scales: 1494/6619
# -1.05752202779
# Takeda Shingen: 1495/6619
#    infantry_diff  cavalry_dfff  ships_diff  airforce_diff
# 0            0.0           0.0         0.0            0.0
# 6.07537023958
# Takeda Katsuyori: 1496/6619
# 0.0245246421094
# Obata Masamori: 1497/6619
# 0.444190272258
# Baba Nobuharu: 1498/6619
# 0.976795590235
# Yamagata Masakage: 1499/6619
# 0.976795590235
# Ii Naotora: 1500/6619
# -0.447994168473
# Matsudaira Ietada (Fukōzu): 1501/6619
# -0.447994168473
# Natsume Yoshinobu: 1502/6619
# -0.447994168473
# Hattori Hanzō: 1503/6619
# -1.03392544909
# Maxentius: 1504/6619
# -0.500611314366
# Hōjō Ujiteru: 1505/6619
# -0.536435606761
# Hōjō Ujikuni: 1506/6619
# -0.124344147334
# Ashikaga Takauji: 1507/6619
# 0.463564393239
# Ashikaga Tadayoshi: 1508/6619
# 0.463564393239
# Kō no Moroyasu: 1509/6619
# 0.463564393239
# Kusunoki Masashige: 1510/6619
# -0.467394682023
# Nitta Yoshisada: 1511/6619
# -0.467394682023
# Tang of Shang: 1512/6619
# 0.5
# Jie of Xia: 1513/6619
# -0.5
# Khamis Gaddafi: 1514/6619
# -0.513446410269
# Sue Harukata: 1515/6619
# -0.551682159363
# Mōri Motonari: 1516/6619
# 1.14008243076
# Mōri Takamoto: 1517/6619
# 1.04787166946
# Kikkawa Motoharu: 1518/6619
# 0.547871669458
# Wei Qing: 1519/6619
# 0.460827813027
# Huo Qubing: 1520/6619
# 0.460827813027
# Chanyu: 1521/6619
# -0.46465507616
# Tuqi King: 1522/6619
# -0.46465507616
# Zhao Xin: 1523/6619
# -0.46465507616
# Sharif Sheikh Ahmed: 1524/6619
# 0.967698747137
# Abdihakim Mohamoud Haji-Faqi: 1525/6619
# 0.467698747137
# Hussein Arab Isse: 1526/6619
# 0.467698747137
# Abdikarim Yusuf Adam: 1527/6619
# 0.467698747137
# Omar Muhammad Farah: 1528/6619
# 0.467698747137
# Omar Mo'allim Nur: 1529/6619
# 0.467698747137
# Fredrick Mugisha: 1530/6619
# 0.467698747137
# Nathan Mugisha: 1531/6619
# 0.467698747137
# African Union Mission to Somalia: 1532/6619
# 0.467698747137
# Cyprien Hakiza: 1533/6619
# 0.467698747137
# Ibrahim Haji Jama Mee'aad: 1534/6619
# -0.471533168988
# Ahmed Abdi Godane: 1535/6619
# -0.471533168988
# Mukhtar Robow: 1536/6619
# -0.471533168988
# Hussein Ali Fidow: 1537/6619
# -0.471533168988
# Ali Mohamed Hussein: 1538/6619
# -0.471533168988
# Ali Dhere: 1539/6619
# -0.471533168988
# Abu Mansoor Al-Amriki: 1540/6619
# -0.471533168988
# Hassan Dahir Aweys: 1541/6619
# 0.0284668310119
# Sheikh Mohamed Ibrahim Hayle: 1542/6619
# -0.471533168988
# Fuad Qalaf: 1543/6619
# -0.471533168988
# Rajah Abu Khalid: 1544/6619
# -0.471533168988
# Fazul Abdullah Mohammed: 1545/6619
# -0.471533168988
# Batu Khan: 1546/6619
# 0.446418239652
# Shiban: 1547/6619
# 0.446418239652
# Berke: 1548/6619
# 0.446418239652
# Boroldai: 1549/6619
# 0.446418239652
# Coloman of Galicia: 1550/6619
# -0.450225760301
# Ugrin Csák (bishop): 1551/6619
# -0.450225760301
# Matthias Rátót: 1552/6619
# -0.450225760301
# Frederick II, Duke of Austria: 1553/6619
# -0.450225760301
# Bartolomeo Colleoni: 1554/6619
# -0.00576584653533
# Piero di Cosimo de' Medici: 1555/6619
# 0.00191743959202
# Federico da Montefeltro: 1556/6619
# 0.00191743959202
# Devlet I Giray: 1557/6619
# -0.538294139117
# Voivode: 1558/6619
# 0.534465880023
# Vorotynsky: 1559/6619
# 0.534465880023
# Volrad V, Count von Mansfeld zu Hinterort: 1560/6619
# -0.525743491593
# King Arthur: 1561/6619
# 0.5
# Gnaeus Julius Agricola: 1562/6619
# 0.495820815532
# Calgacus: 1563/6619
# -0.499669371398
# Giordano d'Anglano: 1564/6619
# 0.5
# Odo de St Amand: 1565/6619
# 0.5
# Peter of Castile: 1566/6619
# -0.5
# Henry II of Castile: 1567/6619
# 0.5
# Henry of Nassau-Dillenburg: 1568/6619
# -0.530119271556
# Bernardino de Mendoza: 1569/6619
# 0.526282880879
# Hans von Hallwyl (1433–1504): 1570/6619
# 0.475326183356
# Hans Waldmann (mayor): 1571/6619
# 0.475326183356
# Adrian von Bubenberg: 1572/6619
# 0.475326183356
# René II, Duke of Lorraine: 1573/6619
# 0.896274633313
# Jacques of Savoy, Count of Romont: 1574/6619
# -0.479166847305
# Leopold I, Duke of Austria: 1575/6619
# -0.56089366591
# Werner Stauffacher: 1576/6619
# 0.55709861392
# Owen Tudor: 1577/6619
# -0.5
# James Butler, 5th Earl of Ormond: 1578/6619
# -0.5
# Marcus Valerius Corvus: 1579/6619
# 1.0
# Gnaeus Manlius Vulso: 1580/6619
# -0.5
# Attalus II Philadelphus: 1581/6619
# -0.5
# Jeroboam: 1582/6619
# -0.536435606761
# Abijah of Judah: 1583/6619
# 0.532605317977
# Nandana Udawatta: 1584/6619
# 0.934872603649
# Jayantha Gunarathne: 1585/6619
# 0.5
# Chaminda Lamahewa: 1586/6619
# 0.5
# Mayadunne of Sitawaka: 1587/6619
# 0.0
# Kingdom of Sitawaka: 1588/6619
# 0.0
# Rajasinha I of Sitawaka: 1589/6619
# 0.0
# Jorge de Meneses Baroche: 1590/6619
# -0.5
# Titus Labienus: 1591/6619
# -0.584206976737
# Publius Attius Varus: 1592/6619
# -0.569567557022
# Gnaeus Pompeius (son of Pompey the Great): 1593/6619
# -0.540479281948
# Critias: 1594/6619
# -0.5
# Raymond VI, Count of Toulouse: 1595/6619
# -0.576088105388
# Raymond-Roger, Count of Foix: 1596/6619
# -0.576088105388
# Simon de Montfort, 5th Earl of Leicester: 1597/6619
# 0.572324243356
# Bouchard de Marly: 1598/6619
# 0.572324243356
# Guillaume des Barres: 1599/6619
# 0.572324243356
# Guillaume de Contres: 1600/6619
# 0.572324243356
# Jean de Clamorgan: 1601/6619
# -0.533286327306
# Álvaro de Bazán the Elder: 1602/6619
# 0.529452842393
# Constantius II: 1603/6619
# 0.470812069976
# Magnentius: 1604/6619
# -0.474649256315
# Andrew Mackay (British Army officer): 1605/6619
# 0.5
# Mahayadin Ghori: 1606/6619
# 0.5
# Shurahbil ibn Amr: 1607/6619
# 0.442477972209
# Zayd ibn Harithah: 1608/6619
# -0.446278978746
# Ja'far ibn Abi Talib: 1609/6619
# -0.446278978746
# 'Abd Allah ibn Rawahah: 1610/6619
# -0.446278978746
# King Zhou of Shang: 1611/6619
# -0.513446410269
# King Wu of Zhou: 1612/6619
# 0.509599820277
# Artayntes: 1613/6619
# -0.558179180339
# Mardontes: 1614/6619
# -0.558179180339
# Tigranes (general): 1615/6619
# -0.558179180339
# Leotychidas: 1616/6619
# 0.554379306845
# Perilaus (general): 1617/6619
# 0.554379306845
# Kurushima Michifusa: 1618/6619
# -0.616805565486
# Mōri Takamasa: 1619/6619
# -0.616805565486
# Kan Michinaga: 1620/6619
# -0.616805565486
# Kim Eok-chu: 1621/6619
# 0.0871912396332
# Kim Ung-ham: 1622/6619
# 0.613160466814
# Ahn Wi: 1623/6619
# 0.613160466814
# Song Yeo-jong: 1624/6619
# 0.613160466814
# Gaius Duilius: 1625/6619
# 0.514653410114
# Lucius Aemilius Regillus: 1626/6619
# 0.503865605927
# Polyxenidas: 1627/6619
# -0.507713724034
# Andronikos Kontostephanos: 1628/6619
# -0.00192431707133
# Baldwin of Antioch: 1629/6619
# -0.5
# John Kantakouzenos (sebastos): 1630/6619
# -0.5
# Andronikos Lapardas: 1631/6619
# -0.5
# Theodore Mavrozomes: 1632/6619
# -0.5
# Constantine Makrodoukas: 1633/6619
# -0.5
# Ampud: 1634/6619
# -0.5
# Leustach Rátót: 1635/6619
# -0.5
# Kilij Arslan II: 1636/6619
# 0.5
# Nasser Badawi: 1637/6619
# -0.5
# Nasser Awais: 1638/6619
# -0.5
# Ahmed Tabouk: 1639/6619
# -0.5
# Husam Badran: 1640/6619
# -0.5
# Yitzhak Gershon: 1641/6619
# 0.5
# Aviv Kochavi: 1642/6619
# 0.5
# Shaul Mofaz: 1643/6619
# 0.5
# Moshe Tamir: 1644/6619
# 0.5
# Saitō Yoshitatsu: 1645/6619
# 0.422701779597
# Saitō Dōsan: 1646/6619
# -0.426462851009
# Okudaira Nobumasa: 1647/6619
# 0.453199063829
# Anayama Nobutada: 1648/6619
# -0.457016672853
# Takeda Nobukado: 1649/6619
# -0.457016672853
# Takeda Nobutoyo: 1650/6619
# -0.457016672853
# Michel Suleiman: 1651/6619
# 0.418141730008
# François al-Hajj: 1652/6619
# 0.418141730008
# Chamel Roukoz: 1653/6619
# 0.418141730008
# Antoine Pano: 1654/6619
# 0.418141730008
# Saleh Kais: 1655/6619
# 0.418141730008
# Georges Nader: 1656/6619
# 0.418141730008
# Georges Chreim: 1657/6619
# 0.418141730008
# Hanna Makdessi: 1658/6619
# 0.418141730008
# Shaker al-Absi: 1659/6619
# -0.421891879083
# Abu Youssef Sharqieh: 1660/6619
# -0.421891879083
# Claudius Gothicus: 1661/6619
# 0.5
# Dia Abdul Zahra Kadim: 1662/6619
# -0.589316527166
# Michael X. Garrett: 1663/6619
# 0.585585627372
# Barry F. Huggins: 1664/6619
# 0.585585627372
# Othman al-Ghanemi: 1665/6619
# 0.585585627372
# Litorius: 1666/6619
# 0.5
# Theodoric I: 1667/6619
# -0.5
# Sextus Pompey: 1668/6619
# -0.501924317071
# Phormio: 1669/6619
# 1.0432201079
# Cnemus: 1670/6619
# -0.547037389007
# Idriss Déby: 1671/6619
# 0.486553589731
# Daoud Soumain: 1672/6619
# 0.486553589731
# Mahamat Nouri: 1673/6619
# -0.490400179723
# Abdelwahid Aboud Mackaye: 1674/6619
# -0.490400179723
# Timane Erdimi: 1675/6619
# -0.490400179723
# Ardaric: 1676/6619
# 0.5
# Ellac: 1677/6619
# -0.5
# Piruz Khosrow: 1678/6619
# -0.565127396351
# Mardanshah: 1679/6619
# -0.565127396351
# Sa`d ibn Abi Waqqas: 1680/6619
# 0.561340318479
# Al-Nu'man ibn Muqrin: 1681/6619
# 0.561340318479
# Tulayha: 1682/6619
# 0.561340318479
# Amru bin Ma'adi Yakrib: 1683/6619
# 1.05941600141
# Alexios Kaballarios: 1684/6619
# -0.601493120526
# John I Doukas of Thessaly: 1685/6619
# 1.09779734356
# John I de la Roche: 1686/6619
# 0.597797343563
# Robert de Lawedre of Edrington: 1687/6619
# -0.536435606761
# David II of Scotland: 1688/6619
# -0.532715554953
# Ralph Neville, 2nd Baron Neville de Raby: 1689/6619
# 0.528881523514
# Henry de Percy, 2nd Baron Percy: 1690/6619
# 0.528881523514
# William Zouche: 1691/6619
# 0.528881523514
# Çandarlı Ali Pasha: 1692/6619
# 0.479781773276
# Stibor of Stiboricz: 1693/6619
# -0.483625253846
# Nicholas II Garai: 1694/6619
# -0.483625253846
# Philip of Artois, Count of Eu: 1695/6619
# -0.483625253846
# John the Fearless: 1696/6619
# -0.483625253846
# Enguerrand VII, Lord of Coucy: 1697/6619
# -0.483625253846
# Jean de Vienne: 1698/6619
# -0.410254968701
# Jean de Carrouges: 1699/6619
# -0.483625253846
# Mircea I of Wallachia: 1700/6619
# -0.483625253846
# Stephen II Lackfi: 1701/6619
# -0.483625253846
# Gnaeus Domitius Calvinus: 1702/6619
# -0.5
# Pharnaces II of Pontus: 1703/6619
# -0.0321673228467
# Maurice, Prince of Orange: 1704/6619
# 0.0283143932652
# Francis Vere: 1705/6619
# 1.32355088184
# Albert VII, Archduke of Austria: 1706/6619
# -0.486543352096
# Rhahzadh: 1707/6619
# -0.448670191466
# Vahram-Arshusha V: 1708/6619
# -0.448670191466
# Artabanus IV of Parthia: 1709/6619
# 0
# Macrinus: 1710/6619
# 0
# Roger II of Sicily: 1711/6619
# -0.5
# Ranulf II of Alife: 1712/6619
# 0.5
# Robert II of Capua: 1713/6619
# 0.5
# Rokkaku Yoshikata: 1714/6619
# -0.542162605653
# Azai Hisamasa: 1715/6619
# 0.53833891293
# Gnaeus Papirius Carbo (consul 113 BC): 1716/6619
# -0.417808569372
# Henry le Despenser: 1717/6619
# 0.5
# Felmingham: 1718/6619
# -0.5
# William Neville, 1st Earl of Kent: 1719/6619
# 1.00671926392
# John Talbot, 2nd Earl of Shrewsbury: 1720/6619
# -0.5
# Edmund Grey, 1st Earl of Kent: 1721/6619
# -0.5
# Chen Lin (Ming dynasty): 1722/6619
# 0.524639242397
# Deng Zilong: 1723/6619
# 0.524639242397
# Antiochus (admiral): 1724/6619
# -0.495822780219
# Jan Tarnowski: 1725/6619
# -0.48749608118
# Petru Rareș: 1726/6619
# -0.516349348885
# Myronides: 1727/6619
# -0.0120913746161
# Imagawa Yoshimoto: 1728/6619
# -0.585931280613
# Asahina Yasutomo: 1729/6619
# -0.585931280613
# Okabe Motonobu: 1730/6619
# -0.585931280613
# Ii Naomori: 1731/6619
# -0.585931280613
# Honda Tadakatsu: 1732/6619
# -0.0921057712565
# Matsui Munenobu: 1733/6619
# -0.585931280613
# Shibata Katsuie: 1734/6619

# %%
df_totalwar = pd.DataFrame(war_list).sort_values('WAR', ascending = False).reset_index(drop = True)

# %%
df_totalwar[df_totalwar.General == 'Pyrrhus of Epirus']

# %%
df_run = df_run.dropna(subset = ['belligerent'])

# %%
df_totalwar = df_totalwar[df_totalwar.General != 'Capital punishment']
df_totalwar = df_totalwar[df_totalwar.General != 'Lieutenant general']

# %%
import seaborn as sns

# %%
sns.distplot(df_totalwar['WAR'], kde = False, bins = 30)
plt.title("Distribution of Generals' War")
plt.ylabel('Number of Generals')
plt.annotate('Napoleon', xy = (16.713, 1), xytext = (17.713, 400), arrowprops = dict(facecolor = 'black'))
plt.annotate('Julius Caesar', xy = (7.364545, 1), xytext = (8.364545, 400), arrowprops = dict(facecolor = 'black'))
plt.tight_layout()
plt.savefig('/home/ethanarsht/Downloads/distplot.png')

# %%
def index():
    output_file('docs/index.html')
    source = ColumnDataSource(data = dict(battles = df_totalwar.Battles,
                                          war = df_totalwar.WAR,
                                          general = df_totalwar.General))

    hover = HoverTool(tooltips = [('General', '@general'),
                                  ('Battles', '@battles'),
                                  ('WAR', '@war'),
                                   'WAR per B'   ])
    p = figure(title = "Click a circle for a profile of that general's career WAR",
               plot_height = 600, 
               plot_width = 800,

               tools = [hover, "tap", 'box_zoom', ResetTool()])
    p.circle(x = 'war', y = 'battles', size = 10, source = source)
    p.xaxis.axis_label = 'WAR'
    p.yaxis.axis_label = 'Battles'

    link = "{}.html".format('@general')

    if link == 'https://ethanarsht.github.io/military_rankings/Thomas de Courtenay, 5th/13th Earl of Devon':
            link = 'https://ethanarsht.github.io/military_rankings/Thomas de Courtenay'
    url = link
    taptool = p.select(type=TapTool)
    taptool.callback = OpenURL(url=url)
    save(p)

# %%
index()

# %%
def bokeh(commander):
    global df_battles
    
    df_battles = pd.DataFrame()
    commander_war(commander)
    
#     df_battles = df_battles[df_battles.General == commander]
    df_battles.Year = df_battles.Year.fillna(-5000)
    df_battles.Year = df_battles.Year.astype(float, errors = 'ignore')
    df_battles = df_battles.sort_values('Year')
    wl = pd.DataFrame(df_battles.Outcome.value_counts())
    
    if 'V' in wl.index:
        wins = wl.loc['V', 'Outcome']
    else:
        wins = 0
    if 'D' in wl.index:
        losses = wl.loc['D', 'Outcome']
    else:
        losses = 0
    if 'I' in wl.index:
        draws = wl.loc['I', 'Outcome']
    else:
        draws = 0
    df_battles = df_battles.reset_index(drop = True)
    for i, row in df_battles.iterrows():
        df_battles.ix[i, 'cumulative'] = sum(df_battles.Value[0:i+1])
    
    
    source = ColumnDataSource(data = dict(battle = df_battles.Battle,
                              general = df_battles.General,
                              outcome = df_battles.Outcome,
                              value = df_battles.Value,
                              year = df_battles.Year,
                              cumulative = df_battles.cumulative))
    if all(x != -5000 for x in df_battles.Year):
        hover = HoverTool(tooltips = [('Battle', '@battle'),
                                  ('Outcome', '@outcome'),
                                  ('WAR', '@value'),
                                  ('Cumulative WAR', '@cumulative'),
                                  ('Year', '@year')])
    else:
        hover = HoverTool(tooltips = [('Battle', '@battle'),
                                  ('Outcome', '@outcome'),
                                  ('WAR', '@value'),
                                  ('Cumulative WAR', '@cumulative')
                                  ])
    
    x = list(df_battles.Battle)
    y = list(df_battles.Value)
    y_cum = list(df_battles.cumulative)
    
    if commander == 'Thomas de Courtenay, 5th/13th Earl of Devon':
        commander = 'Thomas de Courtenay'
    
    output_file('docs/{}.html'.format(commander))
    
    p = figure(title = commander + ' ({} - {} - {})'.format(wins, draws, losses), 
               plot_width=800, 
               plot_height=600, 
               x_range = x, 
               tools = [hover, 'tap'])
    p.title.text_font_size = '16pt'
    p.xaxis.axis_label = "Click on a bar for more info on the battle it represents"
    p.yaxis.axis_label = "Cumulative WAR"
    p.xaxis.axis_label_text_font_style = 'bold'
    
    url = 'https://en.wikipedia.org/wiki/{}'.format('@battle')
    taptool = p.select(type=TapTool)
    taptool.callback = OpenURL(url=url)

    p.line(x = 'battle', y = 'cumulative', source = source, line_width = 5)
#     g1_r = p.add_glyph(source_or_glyph = source, glyph = g_2)
#     g1_tap = TapTool(renderers = [g1_r],
#                     callback = OpenURL(url=url))
#     p.add_tools(g1_tap)
    
    color_mapper = CategoricalColorMapper(factors=['V', 'D', 'I'], palette=['Blue', 'Red', 'Yellow'])
    p.vbar(x = 'battle', 
           top = 'value', 
           width = 0.9, 
           color={'field': 'outcome', 'transform': color_mapper},
           alpha = 0.5,
           source = source)
    
#     url_2 = 'en.wikipedia.org/wiki/@battle'
#     g2_r = p.add_glyph(source_or_glyph = source, glyph = g_2)
#     g2_tap = TapTool(renderers = [g2_r],
#                      callback = OpenURL(url=url_2))
#     p.add_tools(g2_tap)
    
    
    p.xaxis.major_label_orientation = math.pi/2
    

#     show(p)
    save(p)

# %%
count = 0
for general in df_run.belligerent.unique()[1:]:
    battle_list = []
    count += 1
    print(str(count) + '/' + str(len(df_run.belligerent.unique())))
    print(general)
    bokeh(general)
# Out:
# 1/6619
# Yisrael Galili
# 0.463642446212
# 2/6619
# Yaakov Dori
# 0.463642446212
# /home/ethanarsht/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:27: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# 3/6619
# Yigael Yadin
# 0.463642446212
# 4/6619
# Mickey Marcus
# 0.463642446212
# 5/6619
# Yigal Allon
# 0.463642446212
# 6/6619
# Yitzhak Rabin
# 1.02629791865
# 7/6619
# David Shaltiel
# 0.463642446212
# 8/6619
# Moshe Dayan
# 2.08579443952
# 9/6619
# Shimon Avidan
# 0.463642446212
# 10/6619
# Moshe Carmel
# 0.463642446212
# 11/6619
# Yitzhak Sadeh
# 0.463642446212
# 12/6619
# Abdul Rahman Hassan Azzam
# -0.467372779277
# 13/6619
# Farouk of Egypt
# -0.467372779277
# 14/6619
# Abdullah I of Jordan
# -0.467372779277
# 15/6619
# Muzahim al-Pachachi
# -0.467372779277
# 16/6619
# Husni al-Za'im
# -0.467372779277
# 17/6619
# Amin al-Husseini
# -0.467372779277
# 18/6619
# Ahmed Ali al-Mwawi
# -0.467372779277
# 19/6619
# Mohammed Naguib
# -0.467372779277
# 20/6619
# John Bagot Glubb
# -0.467372779277
# 21/6619
# Habis al-Majali
# -0.467372779277
# 22/6619
# Hasan Salama
# -0.467372779277
# 23/6619
# Arab Liberation Army
# -0.467372779277
# 24/6619
# Fawzi al-Qawuqji
# -0.467372779277
# 25/6619
# Menachem Begin
# -0.0700961437222
# 26/6619
# Ariel Sharon
# 2.14125927485
# 27/6619
# Rafael Eitan
# -0.0700961437222
# 28/6619
# David Ivry
# -0.0700961437222
# 29/6619
# Ze'ev Almog
# -0.0700961437222
# 30/6619
# Bachir Gemayel
# -0.0700961437222
# 31/6619
# Fadi Frem
# -0.0700961437222
# 32/6619
# Elie Hobeika
# -0.0700961437222
# 33/6619
# Fawzi Mahfuz
# -0.0700961437222
# 34/6619
# Saad Haddad
# -0.0700961437222
# 35/6619
# Yasser Arafat
# 0.06641782535
# 36/6619
# Hafez al-Assad
# -0.490041131055
# 37/6619
# Mustafa Tlass
# -0.490041131055
# 38/6619
# George Hawi
# 0.06641782535
# 39/6619
# Elias Atallah
# 0.06641782535
# 40/6619
# Abbas al-Musawi
# 0.06641782535
# 41/6619
# Ibrahim Kulaylat
# 0.06641782535
# 42/6619
# Nabih Berri
# 0.06641782535
# 43/6619
# Monte Melkonian
# 0.56641782535
# 44/6619
# Mahsum Korkmaz
# 0.06641782535
# 45/6619
# Muhsin Ibrahim
# 0.06641782535
# 46/6619
# Ragheb Harb
# 0.06641782535
# 47/6619
# Murat Karayılan
# 0.06641782535
# 48/6619
# Inaam Raad
# 0.06641782535
# 49/6619
# Said Shaaban
# 0.06641782535
# 50/6619
# Chandrika Kumaratunga
# -0.5
# 51/6619
# Velupillai Prabhakaran
# -1.93859028426
# 52/6619
# Murtala Mohammed
# -0.0831734769488
# 53/6619
# Jonathan Uchendu
# 0.579524524296
# 54/6619
# Lieutenant colonel (United Kingdom)
# 0.0735058572246
# 55/6619
# Philip Robert Anstruther
# -0.50547946719
# 56/6619
# Commandant-general
# 0.501731491611
# 57/6619
# Francois Gerhardus Joubert
# 0.501731491611
# 58/6619
# George Kenney
# 0.50181131508
# 59/6619
# William Halsey Jr.
# 1.8572549959
# 60/6619
# Frederick C. Sherman
# 0.50181131508
# 61/6619
# Mineichi Koga
# -0.140642062328
# 62/6619
# Jinichi Kusaka
# -0.948603359222
# 63/6619
# Gerard Muirhead-Gould
# -0.0600236299892
# 64/6619
# Hankyu Sasaki
# 0.0563262002576
# 65/6619
# Humayun
# 0.986600121961
# 66/6619
# Bairam Khan
# 0.986600121961
# 67/6619
# Autaritus
# -0.57057370122
# 68/6619
# Hamilcar Barca
# 1.06689636471
# 69/6619
# Lieutenant general
# 0.271051993854
# 70/6619
# Sarath Fonseka
# 2.93490210099
# 71/6619
# Brigadier
# 0.0537882375326
# 72/6619
# Shavendra Silva
# 1.43490210099
# 73/6619
# Major general
# 1.96888594777
# 74/6619
# Kamal Gunaratne
# 1.0
# 75/6619
# Colonel
# 0.975614614312
# 76/6619
# G.V. Ravipriya
# 1.0
# 77/6619
# Pottu Amman (Tamil militant)
# -1.0
# 78/6619
# Theepan
# -1.0
# 79/6619
# Sivanadan Somasekaran
# -1.0
# 80/6619
# Decius
# -0.5
# 81/6619
# Herennius Etruscus
# -0.5
# 82/6619
# Cniva
# 1.0
# 83/6619
# Thrasybulus
# 2.50184241537
# 84/6619
# Thrasyllus
# 1.0089007853
# 85/6619
# Mindarus
# -1.51308513269
# 86/6619
# Leo Phokas the Elder
# -0.503575032126
# 87/6619
# Simeon I of Bulgaria
# 0.999826905026
# 88/6619
# Mark Antony
# -0.371076938459
# 89/6619
# Gaius Sosius
# -0.520081077087
# 90/6619
# Cleopatra
# 0.538135467948
# 91/6619
# Marcus Vipsanius Agrippa
# 2.00496871225
# 92/6619
# Augustus
# 3.37424733849
# 93/6619
# Lucius Arruntius the Elder
# 0.516337878027
# 94/6619
# Marcus Lurius
# 0.516337878027
# 95/6619
# Belisarius
# 1.61956137981
# 96/6619
# John the Armenian
# 1.01184067006
# 97/6619
# Gelimer
# -1.01931828145
# 98/6619
# Ammatas
# -0.48591460011
# 99/6619
# Trajan
# 1.44645158463
# 100/6619
# Tsar
# 0.49812591476
# 101/6619
# Kaloyan of Bulgaria
# 0.49812591476
# 102/6619
# Baldwin I, Latin Emperor
# -0.50187408524
# 103/6619
# Licinius
# -0.474633408471
# 104/6619
# Constantine the Great
# 2.00724753023
# 105/6619
# Fritigern
# 0.457354248289
# 106/6619
# Alatheus
# 0.457354248289
# 107/6619
# Saphrax
# 0.457354248289
# 108/6619
# Valens
# -0.461077480407
# 109/6619
# Marcus Atilius Regulus
# 0.435396554417
# 110/6619
# Bostar
# -0.450159689496
# 111/6619
# Hamilcar (Drepanum)
# -0.956252440959
# 112/6619
# Hasdrubal
# -0.902222505121
# 113/6619
# Lysander
# 0.994247306774
# 114/6619
# Aracus (admiral)
# 0.502224308662
# 115/6619
# Conon
# -0.0119444546465
# 116/6619
# Adeimantus (son of Leucolophides)
# -0.505972227323
# 117/6619
# Gerald FitzGerald, 15th Earl of Desmond
# -0.5
# 118/6619
# Thomas Butler, 10th Earl of Ormond
# 0.5
# 119/6619
# Quintus Fabius Maximus Verrucosus
# -0.499839968449
# 120/6619
# Hannibal
# 5.47679606235
# 121/6619
# Ilghazi
# -0.0557771241271
# 122/6619
# Roger of Salerno
# 0.0
# 123/6619
# Charles I of Albret
# -0.555989266542
# 124/6619
# Jean Le Maingre
# -1.03955852447
# 125/6619
# Charles, Duke of Orléans
# -0.555989266542
# 126/6619
# Henry V of England
# 1.05228503769
# 127/6619
# Edward of Norwich, 2nd Duke of York
# 0.552285037693
# 128/6619
# Humphrey, Duke of Gloucester
# 0.552285037693
# 129/6619
# Louis XII of France
# 0.43836879267
# 130/6619
# Gian Giacomo Trivulzio
# 0.890617443483
# 131/6619
# Louis II de la Trémoille
# 0.360779859688
# 132/6619
# Charles II d'Amboise
# 0.43836879267
# 133/6619
# Bartolomeo d'Alviano
# -0.0102178285139
# 134/6619
# Hanno, son of Hannibal
# -1.0312047302
# 135/6619
# Hannibal Gisco
# -0.545389330708
# 136/6619
# Lucius Postumius Megellus (consul 262 BC)
# 0.509653699618
# 137/6619
# Quintus Mamilius Vitulus
# 0.509653699618
# 138/6619
# Qutuz
# 0.468045373795
# 139/6619
# Baibars
# 0.468045373795
# 140/6619
# Kitbuqa
# -0.0211664586916
# 141/6619
# Theodore (brother of Heraclius)
# -0.0593640795939
# 142/6619
# Khalid ibn al-Walid
# 5.62566081532
# 143/6619
# Abu Ubaidah ibn al-Jarrah
# 1.51413409402
# 144/6619
# 'Amr ibn al-'As
# 0.90817422078
# 145/6619
# Shurahbil ibn Hasana
# 1.49625182952
# 146/6619
# Yazid ibn Abi Sufyan
# 0.996251829521
# 147/6619
# Dhiraar bin Al-Azwar
# 0.996251829521
# 148/6619
# Musaylimah
# -0.554515860645
# 149/6619
# Abu Dujana
# 0.550809270635
# 150/6619
# Abdallah al-Battal
# -0.5
# 151/6619
# Al-Malik ibn Shu'aib
# -0.5
# 152/6619
# Leo III the Isaurian
# 0.5
# 153/6619
# Constantine V
# 1.42207334738
# 154/6619
# Tang Jiahui
# 0.5
# 155/6619
# Ashina Xin
# 0.5
# 156/6619
# Wikipedia:Accuracy dispute
# -0.0190222295392
# 157/6619
# Talk:Battle of Aksu (717)
# 0.5
# 158/6619
# Ashina Xian
# 0.5
# 159/6619
# Alfonso VIII of Castile
# 0.0326662899546
# 160/6619
# Diego López II de Haro
# 0.0326662899546
# 161/6619
# Abu Yusuf Yaqub al-Mansur
# 0.5
# 162/6619
# Pedro Fernández de Castro (died 1214)
# 0.5
# 163/6619
# Nicolas Le Nen
# 0.5
# 164/6619
# Col. Hussein
# 0.5
# 165/6619
# Lt Colonel Sean D Wester (USMC)
# 0.5
# 166/6619
# Shirkuh
# 0
# 167/6619
# Saladin
# -0.57209548533
# 168/6619
# Amalric of Jerusalem
# 0
# 169/6619
# Abu Marwan Abd al-Malik I Saadi
# 0.446210820606
# 170/6619
# Ahmad al-Mansur
# 0.446210820606
# 171/6619
# Sebastian of Portugal
# -0.44991855111
# 172/6619
# Abu Abdallah Mohammed II Saadi
# -0.44991855111
# 173/6619
# Thomas Stukley
# -0.44991855111
# 174/6619
# Vercingetorix
# -1.03909065369
# 175/6619
# Commius
# -0.527785673842
# 176/6619
# Julius Caesar
# 7.35155883126
# 177/6619
# Afonso V of Portugal
# 0.419730914041
# 178/6619
# Afonso I, Duke of Braganza
# 0.424590641309
# 179/6619
# Peter, Duke of Coimbra
# -0.428257649192
# 180/6619
# Guy of Lusignan
# 0.514487502897
# 181/6619
# John I of Castile
# -0.584529319246
# 182/6619
# Pedro Álvares Pereira
# -1.1524558891
# 183/6619
# John I of Portugal
# 1.08088370562
# 184/6619
# Nuno Álvares Pereira
# 1.14512758279
# 185/6619
# Murray of Aberscross
# 0.5
# 186/6619
# Donald Mackay, 11th of Strathnaver
# -0.5
# 187/6619
# Ranulf de Glanvill
# 0.422073347381
# 188/6619
# William the Lion
# -0.425734700081
# 189/6619
# Baldwin I of Jerusalem
# 0.52852704598
# 190/6619
# Mawdud
# 0.5
# 191/6619
# Toghtekin
# -1.52423489952
# 192/6619
# Dawit II
# -1.0
# 193/6619
# Ahmad ibn Ibrahim al-Ghazi
# 0.445612190904
# 194/6619
# Brasidas
# -0.56049676185
# 195/6619
# Cleon
# 0.00965369961825
# 196/6619
# Nicias
# -0.490346300382
# 197/6619
# Thucydides
# -0.490346300382
# 198/6619
# Tervel of Bulgaria
# 0.5
# 199/6619
# Justinian II
# -0.5
# 200/6619
# Telets of Bulgaria
# -0.5
# 201/6619
# William Eure, 1st Baron Eure
# -0.538183313227
# 202/6619
# Brian Layton
# -0.538183313227
# 203/6619
# James Hamilton, Duke of Châtellerault
# 0.0049756772454
# 204/6619
# Archibald Douglas, 6th Earl of Angus
# 0.0049756772454
# 205/6619
# Sophron of Ephesus
# -0.5
# 206/6619
# Ptolemy Andromachou
# -0.5
# 207/6619
# Antigonus II Gonatas
# 0.5
# 208/6619
# Oda Nobunaga
# 4.22158644068
# 209/6619
# Tokugawa Ieyasu
# 1.32244793637
# 210/6619
# Inaba Yoshimichi
# 0.47558860364
# 211/6619
# Azai Nagamasa
# -0.860588851156
# 212/6619
# Asakura Yoshikage
# -1.37791631427
# 213/6619
# Timur
# 0.472789032219
# 214/6619
# Shahrukh Mirza
# 0.472789032219
# 215/6619
# Khalil Sultan
# 0.472789032219
# 216/6619
# Miran Shah
# 0.472789032219
# 217/6619
# Abu Bakr (Timurid)
# 0.472789032219
# 218/6619
# Sultan Huseyn
# 0.472789032219
# 219/6619
# Pir Muhammad ibn Jahangir
# 0.472789032219
# 220/6619
# Taj al-Din Shah-i Shahan Abu'l Fath
# 0.472789032219
# 221/6619
# Bayezid I
# -0.0223514031692
# 222/6619
# Süleyman Çelebi
# -0.476527574239
# 223/6619
# Mehmed I
# -0.476527574239
# 224/6619
# Stefan Lazarević
# 0.00329853545281
# 225/6619
# Gannys
# 0.5
# 226/6619
# Heraclius
# -0.687764985118
# 227/6619
# Shahrbaraz
# 0.422073347381
# 228/6619
# Shahin Vahmanzadegan
# 0.5
# 229/6619
# Eslamu
# -0.584834102515
# 230/6619
# Fatagar
# -0.584834102515
# 231/6619
# Theophilos (emperor)
# -0.515403254264
# 232/6619
# Theophobos
# -0.515403254264
# 233/6619
# Manuel the Armenian
# -0.515403254264
# 234/6619
# Khaydhar ibn Kawus al-Afshin
# 0.511657828617
# 235/6619
# Umar al-Aqta
# 0.511657828617
# 236/6619
# Jaysh ibn Samsama
# 0.5
# 237/6619
# Damian Dalassenos
# -0.5
# 238/6619
# Teutobod
# 0.314332033388
# 239/6619
# Gaius Marius
# 1.08136763657
# 240/6619
# Germanic kingship
# 0.453789183559
# 241/6619
# Boiorix
# 0.302529459808
# 242/6619
# Quintus Servilius Caepio
# -0.45750786222
# 243/6619
# Gnaeus Mallius Maximus
# -0.45750786222
# 244/6619
# Francesco Bussone da Carmagnola
# 0.0
# 245/6619
# Bardas Skleros
# 0.5
# 246/6619
# Peter (stratopedarches)
# 0.5
# 247/6619
# Thomas le Botiller
# -0.5
# 248/6619
# William MacGeoghegan
# 0.5
# 249/6619
# Rhydderch Hael
# 0.5
# 250/6619
# Peredur
# 0.5
# 251/6619
# Gwenddoleu ap Ceidio
# -0.5
# 252/6619
# Priarius
# -0.5
# 253/6619
# Mallobaudes
# 0.5
# 254/6619
# Nannienus
# 0.5
# 255/6619
# Callicratidas
# 0.5
# 256/6619
# John Kingston (sailor)
# -0.387455171829
# 257/6619
# Nicolas Béhuchet
# -0.138338073452
# 258/6619
# Hugues Quiéret
# -0.138338073452
# 259/6619
# Lucius Caecilius Metellus Denter
# -0.5
# 260/6619
# Britomaris
# 0.5
# 261/6619
# Richard I of England
# 1.48660012196
# 262/6619
# Hugh III, Duke of Burgundy
# 0.5
# 263/6619
# Garnier de Nablus
# 0.0278873809358
# 264/6619
# Robert IV of Sablé
# 0.986600121961
# 265/6619
# James of Avesnes
# 0.5
# 266/6619
# Al-Adil I
# -0.57209548533
# 267/6619
# Al-Afdal ibn Salah ad-Din
# -0.0316222774604
# 268/6619
# Al-Muzaffar Umar
# -0.0817491849482
# 269/6619
# Tancred, Prince of Galilee
# 2.02610657631
# 270/6619
# Fakhr al-Mulk Radwan
# -1.02423489952
# 271/6619
# Eurybiades
# 0.599204961216
# 272/6619
# Themistocles
# 1.141697099
# 273/6619
# Adeimantus of Corinth
# 0.0880404924097
# 274/6619
# Achaemenes (satrap)
# -0.606577704999
# 275/6619
# Ariabignes
# -0.606577704999
# 276/6619
# Artemisia I of Caria
# -0.606577704999
# 277/6619
# Damasithymus
# -0.606577704999
# 278/6619
# Al-Afdal Shahanshah
# -0.564727218051
# 279/6619
# Godfrey of Bouillon
# 2.46011959306
# 280/6619
# Raymond IV, Count of Toulouse
# 2.02610657631
# 281/6619
# Robert Curthose
# 2.02610657631
# 282/6619
# Robert II, Count of Flanders
# 2.02610657631
# 283/6619
# Eustace III, Count of Boulogne
# 0.559160763584
# 284/6619
# Gaston IV, Viscount of Béarn
# 1.07965499168
# 285/6619
# Publius Decius Mus (consul 279 BC)
# 0.49812591476
# 286/6619
# Pyrrhus of Epirus
# -0.536378976776
# 287/6619
# Pompeius Strabo
# 0.486600121961
# 288/6619
# Judacilius
# -0.490346300382
# 289/6619
# Fernando Sánchez de Tovar
# -0.567926569855
# 290/6619
# Pero Gonzalez de Sevilla
# -0.567926569855
# 291/6619
# Martim Anes de Barundo
# -0.567926569855
# 292/6619
# Henry of Grosmont, 1st Duke of Lancaster
# 0.5
# 293/6619
# Charles, Duke of Brittany
# -1.14972395776
# 294/6619
# John IV, Duke of Brittany
# 0.505043131031
# 295/6619
# John Chandos
# 1.03365566679
# 296/6619
# Mushkin Niusalavurd
# 0.4312303083
# 297/6619
# Mihr Narseh
# 0.4312303083
# 298/6619
# Izad Gushnasp
# 0.4312303083
# 299/6619
# Ashtat
# 0.4312303083
# 300/6619
# Vardan Mamikonian
# -0.434911317893
# 301/6619
# Jakob Henriksson Hästesko
# -0.52635125037
# 302/6619
# Daniel Rantzau
# -0.0143988131084
# 303/6619
# Hengist and Horsa
# 0
# 304/6619
# Vortigern
# 0
# 305/6619
# Vortimer
# 0
# 306/6619
# Catigern
# 0
# 307/6619
# Husayn ibn Numayr al-Sakuni
# 0.5
# 308/6619
# Udi Adam
# -0.5
# 309/6619
# Gal Hirsch
# -0.5
# 310/6619
# Romanos III Argyros
# -0.59147158456
# 311/6619
# Shibl al-Dawla Nasr
# 0.5878439346
# 312/6619
# Baldwin II of Jerusalem
# 1.0
# 313/6619
# Leo I, Prince of Armenia
# 0.5
# 314/6619
# Joscelin I, Count of Edessa
# 0.0
# 315/6619
# Pons, Count of Tripoli
# 0.5
# 316/6619
# Alfonso VI of León and Castile
# -0.5
# 317/6619
# Álvar Fáñez
# -0.5
# 318/6619
# Sancho Ramírez
# -0.5
# 319/6619
# Yusuf ibn Tashfin
# 0.5
# 320/6619
# Al-Mu'tamid ibn Abbad
# 0.5
# 321/6619
# Abdallah ibn Buluggin
# 0.5
# 322/6619
# Amr ibn Hishām
# -0.568184086556
# 323/6619
# Utbah ibn Rabi'ah
# -0.568184086556
# 324/6619
# Umayyah ibn Khalaf
# -0.568184086556
# 325/6619
# Hind bint Utbah
# -0.568184086556
# 326/6619
# Muhammad
# 1.20273113855
# 327/6619
# Hamza ibn Abdul-Muttalib
# 0.648942901013
# 328/6619
# Ali
# 1.72160026744
# 329/6619
# Abu Bakr
# 1.11829014321
# 330/6619
# Umar
# 1.11829014321
# 331/6619
# Scipio Africanus
# 2.4935309566
# 332/6619
# Hasdrubal Barca
# -0.957380781281
# 333/6619
# Abe no Hirafu
# -0.64542699677
# 334/6619
# Buyeo Pung
# -0.64542699677
# 335/6619
# Liu Rengui
# 0.641988457813
# 336/6619
# Munmu of Silla
# 0.641988457813
# 337/6619
# Buyeo Yung
# 0.641988457813
# 338/6619
# Wenceslaus I, Duke of Luxembourg
# -0.524630932688
# 339/6619
# William I, Marquis of Namur
# -0.524630932688
# 340/6619
# William II, Duke of Jülich
# 0.52089052929
# 341/6619
# Edward, Duke of Guelders
# 0.52089052929
# 342/6619
# Hasdrubal Gisco
# -0.509293890699
# 343/6619
# Syphax
# -0.5
# 344/6619
# Masinissa
# 1.00412667539
# 345/6619
# Gaius Laelius
# 0.5
# 346/6619
# Hulagu Khan
# 0.450613513309
# 347/6619
# Arghun Aqa
# 0.450613513309
# 348/6619
# Baiju
# 0.450613513309
# 349/6619
# Buqa-Temür
# 0.450613513309
# 350/6619
# Sunitai
# 0.450613513309
# 351/6619
# Guo Kan
# 0.861318401134
# 352/6619
# Koke Ilge
# 0.450613513309
# 353/6619
# Al-Musta'sim
# -0.454327814281
# 354/6619
# Capital punishment
# -4.82582277718
# 355/6619
# Mujaheduddin
# -0.454327814281
# 356/6619
# Sulaiman Shah
# -0.454327814281
# 357/6619
# Qarasunqur
# -0.454327814281
# 358/6619
# Al-Ashraf Musa, Sultan of Egypt
# -0.454327814281
# 359/6619
# Nang Wa
# -0.582635586399
# 360/6619
# Shen Yin Shu
# -0.582635586399
# 361/6619
# Helü
# 0.578985324415
# 362/6619
# Fugai
# 0.578985324415
# 363/6619
# Wu Zixu
# 0.578985324415
# 364/6619
# Sun Tzu
# 0.578985324415
# 365/6619
# Matthias Corvinus
# -0.521206624398
# 366/6619
# Stephen III of Moldavia
# 2.06540124347
# 367/6619
# Modu Chanyu
# 0.486600121961
# 368/6619
# Emperor Gaozu of Han
# -0.0676859414155
# 369/6619
# List of Khazar rulers
# 0.5
# 370/6619
# Abd ar-Rahman ibn Rabiah
# -0.5
# 371/6619
# Al-Jarrah ibn Abdallah
# 0.5
# 372/6619
# Charles the Bald
# -0.0554225006145
# 373/6619
# Nominoe
# 0.549840310504
# 374/6619
# Mohamud Muse Hersi
# 0.5
# 375/6619
# Abdulrahman Said Dhegaweyne
# 0.5
# 376/6619
# Abdi Hasan Awale Qeybdiid
# 0.5
# 377/6619
# Mohamed Mohamud Agaweine
# -0.5
# 378/6619
# Daou al-Salhine al-Jadak
# 0.453789183559
# 379/6619
# Musa Yunis
# 0.453789183559
# 380/6619
# Saif al-Islam Gaddafi
# -0.970907740258
# 381/6619
# Tarik Sulayman
# -0.542125472475
# 382/6619
# Rajah Sulayman
# -0.542125472475
# 383/6619
# Miguel López de Legazpi
# 0.538401607761
# 384/6619
# Edward II of England
# -0.047524134375
# 385/6619
# Humphrey de Bohun, 4th Earl of Hereford
# -0.9874335041
# 386/6619
# Aymer de Valence, 2nd Earl of Pembroke
# -0.599228706704
# 387/6619
# Gilbert de Clare, 8th Earl of Gloucester
# -0.547524134375
# 388/6619
# Robert de Clifford, 1st Baron de Clifford
# -0.547524134375
# 389/6619
# Robert the Bruce
# 0.588092743882
# 390/6619
# Edward Bruce
# 0.126073804414
# 391/6619
# Robert II Keith, Marischal of Scotland
# -0.0296367688994
# 392/6619
# James Douglas, Lord of Douglas
# 0.543807229388
# 393/6619
# Thomas Randolph, 1st Earl of Moray
# 0.543807229388
# 394/6619
# Yan Emperor
# 0.0272815486222
# 395/6619
# Yellow Emperor
# 1.02728154862
# 396/6619
# Osman I
# 0.5
# 397/6619
# Shapur I
# 1.5
# 398/6619
# Richard Neville, 16th Earl of Warwick
# -0.0525240768518
# 399/6619
# John Neville, 1st Marquess of Montagu
# 0.989406683904
# 400/6619
# Henry Holland, 3rd Duke of Exeter
# -1.04247391288
# 401/6619
# John de Vere, 13th Earl of Oxford
# 0.464303652466
# 402/6619
# Edward IV of England
# 3.04518198558
# 403/6619
# Richard III of England
# 0.515798898453
# 404/6619
# William Hastings, 1st Baron Hastings
# 1.03840974867
# 405/6619
# Suleiman II (Rûm)
# -0.534585389064
# 406/6619
# David Soslan
# 0.530853269292
# 407/6619
# Zakarids-Mkhargrzeli
# 0.530853269292
# 408/6619
# Shalva of Akhaltsikhe
# 0.530853269292
# 409/6619
# Nouri al-Maliki
# -0.0334036813346
# 410/6619
# Ali Ghaidan Majid
# -0.0334036813346
# 411/6619
# Mohan al-Furayji
# -0.0334036813346
# 412/6619
# Fadhil Jalil al-Barwari
# -0.0334036813346
# 413/6619
# Muqtada al-Sadr
# 0.52967042257
# 414/6619
# Shiek Ali al-Sauidi
# 0.0296704225702
# 415/6619
# Akram al-Kabi
# 0.0296704225702
# 416/6619
# Yusuf al-Mosawi
# 0.0296704225702
# 417/6619
# John Stewart, Earl of Buchan
# -0.621672250805
# 418/6619
# Gilbert Motier de La Fayette
# 0.442510005646
# 419/6619
# List of Marshals of France
# 0.442510005646
# 420/6619
# Thomas of Lancaster, 1st Duke of Clarence
# -0.446211762467
# 421/6619
# Thomas Beaufort, Duke of Exeter
# -0.446211762467
# 422/6619
# John Beaufort, 1st Duke of Somerset
# -0.446211762467
# 423/6619
# Zhang Fei
# 1.0498403105
# 424/6619
# Zhang He
# -0.0288384395588
# 425/6619
# Baldwin IV of Jerusalem
# 0.0464136707557
# 426/6619
# Baldwin of Ibelin
# 0
# 427/6619
# Balian of Ibelin
# -0.972112619064
# 428/6619
# Hugh II of Saint Omer
# 0
# 429/6619
# Gökböri
# 0.88311532427
# 430/6619
# Charles I of Naples
# 0.5
# 431/6619
# Manfred, King of Sicily
# -0.5
# 432/6619
# Quintus Fulvius Flaccus (consul 237 BC)
# -0.0524410033728
# 433/6619
# Hanno the Elder
# -0.985703937402
# 434/6619
# Tiberius Sempronius Gracchus (consul 215 BC)
# 0.498699173787
# 435/6619
# Manius Curius Dentatus
# 0.5
# 436/6619
# John II Komnenos
# 0.5
# 437/6619
# Telerig of Bulgaria
# -0.425734700081
# 438/6619
# Seron (Syrian governor)
# -0.563781287087
# 439/6619
# Judas Maccabeus
# 2.30497920067
# 440/6619
# Cestius Gallus
# -0.5
# 441/6619
# Simon bar Giora
# 0.0471354452477
# 442/6619
# Lysias (Syrian chancellor)
# -1.08260739905
# 443/6619
# Eleazar Avaran
# 0.54249213778
# 444/6619
# Mirza Aziz Koka
# 0.5
# 445/6619
# Sunshu Ao
# 0.5
# 446/6619
# Zi Zhong
# 0.5
# 447/6619
# Zi Fan
# 0.5
# 448/6619
# Xun Linfu
# -0.5
# 449/6619
# Shi Hui (Spring and Autumn period)
# -0.5
# 450/6619
# Zhao Shuo
# -0.5
# 451/6619
# Divico
# -0.531478389222
# 452/6619
# Odet of Foix, Viscount of Lautrec
# -0.518756604222
# 453/6619
# Anne de Montmorency
# -0.501139739676
# 454/6619
# Georg von Frundsberg
# 1.5386661767
# 455/6619
# Fernando d'Avalos
# 1.5386661767
# 456/6619
# Prospero Colonna
# 1.03435111901
# 457/6619
# Abdul Fatah Younis
# -1.50374817048
# 458/6619
# Shoshenq I
# 0.5
# 459/6619
# Edward III of England
# 2.35444910712
# 460/6619
# Godemar du Foy
# -0.483569257931
# 461/6619
# John Babonić
# 0.5
# 462/6619
# Ban of Slavonia
# 0.5
# 463/6619
# Paul II Šubić of Bribir
# 0.5
# 464/6619
# Mladen II Šubić of Bribir
# -0.5
# 465/6619
# Ban of Croatia
# -0.5
# 466/6619
# George II Šubić of Bribir
# -0.5
# 467/6619
# John of Islay, Earl of Ross
# -0.5
# 468/6619
# Aonghas Óg
# 0.5
# 469/6619
# James Tuchet, 5th Baron Audley
# -0.536396582609
# 470/6619
# John Sutton, 1st Baron Dudley
# -0.536396582609
# 471/6619
# Richard Neville, 5th Earl of Salisbury
# 0.519121763468
# 472/6619
# Thomas Neville
# 0.532666289955
# 473/6619
# Algirdas
# 0.47738914978
# 474/6619
# Fyodor Koriatovych
# 0.47738914978
# 475/6619
# Demetrius, Prince of the Tatars
# -0.481130871109
# 476/6619
# Tonyukuk
# 0.5
# 477/6619
# Robert Fyssher
# 0.445201062438
# 478/6619
# Le Seigneur de Tais
# -0.448907203876
# 479/6619
# Jakob Bagge
# 0.45374127955
# 480/6619
# Jacob Brockenhuus
# -0.457459894425
# 481/6619
# Andrew Harclay, 1st Earl of Carlisle
# 0.436218712913
# 482/6619
# John Peche
# 0.436218712913
# 483/6619
# Thomas, 2nd Earl of Lancaster
# -0.939909369725
# 484/6619
# Roger de Clifford, 2nd Baron de Clifford
# -0.439909369725
# 485/6619
# John Howard, 1st Duke of Norfolk
# -0.52261085022
# 486/6619
# Henry Percy, 4th Earl of Northumberland
# -0.52261085022
# 487/6619
# John de la Pole, 1st Earl of Lincoln
# -1.00374172133
# 488/6619
# Thomas Howard, 2nd Duke of Norfolk
# -0.00917918525903
# 489/6619
# Francis Lovell, 1st Viscount Lovell
# -0.52261085022
# 490/6619
# Henry VII of England
# 0.996258278671
# 491/6619
# Jasper Tudor, Duke of Bedford
# 0.496258278671
# 492/6619
# Gilbert Talbot (soldier)
# 0.518869128891
# 493/6619
# Philibert de Chandée, 1st Earl of Bath
# 0.518869128891
# 494/6619
# Rhys ap Thomas
# 0.518869128891
# 495/6619
# Otto IV, Holy Roman Emperor
# -0.516566086291
# 496/6619
# William Longespée, 3rd Earl of Salisbury
# 0.0592139678076
# 497/6619
# Renaud I, Count of Dammartin
# -0.516566086291
# 498/6619
# Ferdinand, Count of Flanders
# -0.516566086291
# 499/6619
# Theobald I, Duke of Lorraine
# -0.516566086291
# 500/6619
# Henry I, Duke of Brabant
# -0.516566086291
# 501/6619
# Philip II of France
# 0.41998335468
# 502/6619
# Robert II, Count of Dreux
# 0.512821152815
# 503/6619
# Philip of Dreux
# 0.512821152815
# 504/6619
# Odo III, Duke of Burgundy
# 0.512821152815
# 505/6619
# William IV, Count of Ponthieu
# 0.512821152815
# 506/6619
# Thomas de Rokeby
# 0.5
# 507/6619
# Henry Percy, 1st Earl of Northumberland
# -0.0301359610755
# 508/6619
# Pál Kinizsi
# 0.496168227394
# 509/6619
# Bartholomew Drágfi
# 0.496168227394
# 510/6619
# Stephen V Báthory
# 0.496168227394
# 511/6619
# Vuk Grgurević
# 0.496168227394
# 512/6619
# Demetrius Jaksics
# 0.496168227394
# 513/6619
# Basarab Laiotă cel Bătrân
# -0.0554799554176
# 514/6619
# Basarab Țepeluș cel Tânăr
# -0.499916340411
# 515/6619
# Suleiman Mahmoud
# -0.00187408523964
# 516/6619
# Mutassim Gaddafi
# -0.448464780196
# 517/6619
# William de Bohun, 1st Earl of Northampton
# 0.372235000982
# 518/6619
# Carlo Grimaldi
# -0.375745106932
# 519/6619
# Seguin de Badefol
# 0.486600121961
# 520/6619
# Petit Meschin
# 0.486600121961
# 521/6619
# James I, Count of La Marche
# -0.490346300382
# 522/6619
# Charles de Mornay
# 0.533281228429
# 523/6619
# Julian (emperor)
# 1.52736444213
# 524/6619
# Æthelstan
# 0.5
# 525/6619
# Edmund I
# 0.5
# 526/6619
# Olaf Guthfrithson
# -0.5
# 527/6619
# Constantine II of Scotland
# -0.5
# 528/6619
# Owain ap Dyfnwal (fl. 934)
# -0.5
# 529/6619
# Sten Sture the Elder
# 0.479079994208
# 530/6619
# Christian I of Denmark
# -0.482822724505
# 531/6619
# Charles the Bold
# -0.941997315209
# 532/6619
# Raes van Heers
# -0.465472586818
# 533/6619
# Edmund Mortimer (1376-1409)
# -0.516690881671
# 534/6619
# Owain Glyndŵr
# 1.01294600342
# 535/6619
# Shōni Sukeyoshi
# 0.5
# 536/6619
# 少弐資能
# 0.5
# 537/6619
# Ōtomo Yoriyasu
# 0.5
# 538/6619
# 大友頼泰
# 0.5
# 539/6619
# Kikuchi Takefusa
# 0.5
# 540/6619
# Takezaki Suenaga
# 0.5
# 541/6619
# Hindun
# -0.5
# 542/6619
# 忻都 - 维基百科，自由的百科全书
# -0.5
# 543/6619
# Liu Fuheng
# -0.5
# 544/6619
# Kim Bang-gyeong
# -0.5
# 545/6619
# 김방경 - 위키백과, 우리 모두의 백과사전
# -0.5
# 546/6619
# Yi Sun-sin
# 2.70170300971
# 547/6619
# Won Gyun
# 1.15141695226
# 548/6619
# Yi Eokgi
# 0.671211271498
# 549/6619
# Jeong Un
# 0.566297930399
# 550/6619
# 정운 - 위키백과, 우리 모두의 백과사전
# 0.566297930399
# 551/6619
# Wakisaka Yasuharu
# -1.29928792509
# 552/6619
# Kuki Yoshitaka
# -0.723245347456
# 553/6619
# Tōdō Takatora
# -1.26247126504
# 554/6619
# Katō Yoshiaki
# -0.278522229834
# 555/6619
# Æthelred, Lord of the Mercians
# 0.0
# 556/6619
# Hastein
# -0.5
# 557/6619
# Lan Yu (general)
# 0.5
# 558/6619
# Uskhal Khan Tögüs Temür
# -0.5
# 559/6619
# Maximilian III, Archduke of Austria
# -0.968610798048
# 560/6619
# Jan Zamoyski
# 0.502276327902
# 561/6619
# Tachibana Muneshige
# 0.409153949171
# 562/6619
# Ukita Hideie
# 0.73889048471
# 563/6619
# Kobayakawa Takakage
# 1.38448494495
# 564/6619
# Li Rusong
# -0.467333710045
# 565/6619
# Rhys Gryg
# 0.5
# 566/6619
# Stephen Bauzan
# -0.5
# 567/6619
# Walter Manny, 1st Baron Manny
# 0.5
# 568/6619
# Guy, Bastard of Flanders
# -0.5
# 569/6619
# Raoul II of Brienne, Count of Eu
# -0.42181783315
# 570/6619
# Publius Ostorius Scapula
# 0.5
# 571/6619
# Caratacus
# -1.05748999435
# 572/6619
# Atahualpa
# -0.0909157424939
# 573/6619
# Francisco Pizarro
# 1.48773117378
# 574/6619
# Hernando Pizarro
# 1.06166966237
# 575/6619
# Gonzalo Pizarro
# 1.56354374761
# 576/6619
# Juan Pizarro (conquistador)
# 1.48773117378
# 577/6619
# Hernando de Soto
# 1.08728660082
# 578/6619
# Fínghin Mac Carthaigh
# 0.5
# 579/6619
# John FitzGerald, 1st Baron Desmond
# -0.5
# 580/6619
# Hermogenes (magister officiorum)
# 0.045718161638
# 581/6619
# Sunicas
# 0.045718161638
# 582/6619
# Al-Harith ibn Jabalah
# -0.486948128317
# 583/6619
# Azarethes
# 0.483203297269
# 584/6619
# Al-Mundhir III ibn al-Nu'man
# 0.483203297269
# 585/6619
# Aimery IV of Narbonne
# 0.489833456592
# 586/6619
# Guillaume da Durfort
# 0.489833456592
# 587/6619
# Guglielmino Ubertini
# -0.493580595959
# 588/6619
# Pandolfo II Malatesta
# 0.428956859014
# 589/6619
# Konrad von Landau
# -0.432633223658
# 590/6619
# Boudica
# -0.159571154408
# 591/6619
# Quintus Petillius Cerialis
# -0.439909369725
# 592/6619
# Murong Bao
# -0.563117286848
# 593/6619
# Murong Nong
# -0.563117286848
# 594/6619
# Murong Lin
# -0.563117286848
# 595/6619
# Murong De
# -0.563117286848
# 596/6619
# Emperor Daowu of Northern Wei
# 0.559425402339
# 597/6619
# Gaius Terentius Varro
# -0.530959612644
# 598/6619
# Lucius Aemilius Paullus (consul 219 BC)
# -0.530959612644
# 599/6619
# Maharbal
# 0.527224131204
# 600/6619
# Mago Barca
# 0.0254883835546
# 601/6619
# Gisgo
# 0.527224131204
# 602/6619
# Hanno, son of Bomilcar
# 0.527224131204
# 603/6619
# Hasdrubal (quartermaster)
# 0.527224131204
# 604/6619
# Marcus Claudius Marcellus
# 0.486600121961
# 605/6619
# Lucius Manlius Vulso Longus
# 0.502344847831
# 606/6619
# Hanno the Great
# -1.00609275146
# 607/6619
# Appius Claudius Pulcher (consul 212 BC)
# -0.531954626205
# 608/6619
# Francesco I Sforza
# 1.4357179249
# 609/6619
# Micheletto Attendolo
# 0.0302865519644
# 610/6619
# William Kirkcaldy of Grange
# 1.01699504365
# 611/6619
# James Hepburn, 4th Earl of Bothwell
# -0.50187408524
# 612/6619
# Necho II
# -0.541138484509
# 613/6619
# Nebuchadnezzar II
# 2.03741344208
# 614/6619
# Marcus Licinius Crassus
# -0.491211476798
# 615/6619
# Publius Licinius Crassus (son of triumvir)
# -0.491211476798
# 616/6619
# Gaius Cassius Longinus
# -1.47327349498
# 617/6619
# Surena
# 0.487465010606
# 618/6619
# Hasan ibn al-Nu'man
# 0.5
# 619/6619
# Tiberios III
# -0.5
# 620/6619
# Hasdrubal the Boetharch
# -0.5
# 621/6619
# Scipio Aemilianus
# 1.0
# 622/6619
# Manius Manilius
# 0.5
# 623/6619
# Alberico da Barbiano
# 0.5
# 624/6619
# Muzio Sforza
# -0.0283906257621
# 625/6619
# Galeotto I Malatesta
# 0.459305765876
# 626/6619
# John Hawkwood
# 0.0586629801086
# 627/6619
# Hanneken von Baumgarten
# -0.463031328849
# 628/6619
# Azzo VII d'Este
# 0.5
# 629/6619
# Ezzelino III da Romano
# -0.5
# 630/6619
# Nicolaas Zannekin
# -0.50187408524
# 631/6619
# Philip VI of France
# 0.49812591476
# 632/6619
# Giovanni Ordelaffi
# -0.525434154288
# 633/6619
# Da Polenta family
# -0.525434154288
# 634/6619
# Giovanni dell'Ischia
# -0.525434154288
# 635/6619
# Francesco Novello da Carrara
# 0.521694308957
# 636/6619
# Jean Bureau
# 0.494981803544
# 637/6619
# John Talbot, 1st Earl of Shrewsbury
# -1.55621982016
# 638/6619
# Leptines of Syracuse
# 0.538648421107
# 639/6619
# Mieszko I of Poland
# 0.483309118329
# 640/6619
# Czcibor
# 0.483309118329
# 641/6619
# Odo I, Margrave of the Saxon Ostmark
# -0.487053996575
# 642/6619
# Nasar
# 0.925034583997
# 643/6619
# Ibn al-Hawas
# -0.624643345303
# 644/6619
# Roger I of Sicily
# 0.621121568782
# 645/6619
# Serlo II of Hauteville
# 0.621121568782
# 646/6619
# Alfonso d'Avalos
# -0.510533100367
# 647/6619
# Francis, Count of Enghien
# 1.00678605418
# 648/6619
# Louis d'Armagnac, Duke of Nemours
# -0.523079837196
# 649/6619
# Yves d'Alègre
# -0.523079837196
# 650/6619
# Pierre Terrail, seigneur de Bayard
# -0.523079837196
# 651/6619
# Gonzalo Fernández de Córdoba
# 1.44598831633
# 652/6619
# Pedro Navarro, Count of Oliveto
# 0.0360818128608
# 653/6619
# Fabrizio Colonna
# 0.0360818128608
# 654/6619
# Prince Henry the Navigator
# 0.5
# 655/6619
# Chares of Athens
# -1.00985442863
# 656/6619
# Lysicles (4th century BC)
# -0.509854428625
# 657/6619
# Athens
# -0.509854428625
# 658/6619
# Theagenes (general)
# -0.509854428625
# 659/6619
# Philip II of Macedon
# 0.506107213096
# 660/6619
# Alexander the Great
# 4.37012536068
# 661/6619
# Archelaus (general)
# -1.63435498831
# 662/6619
# Sulla
# 1.62698699499
# 663/6619
# Constantine I of Georgia
# -0.5
# 664/6619
# Ibrahim I of Shirvan
# -0.5
# 665/6619
# Syed Ahmed Orlat
# -0.5
# 666/6619
# Qara Yusuf
# 0.5
# 667/6619
# Yar Ahmed Qaramanli
# 0.5
# 668/6619
# Jagath Jayasuriya
# 0.934902100991
# 669/6619
# Prasanna Silva
# 0.5
# 670/6619
# Vinayagam
# -0.5
# 671/6619
# Selim I
# 1.49029390237
# 672/6619
# Hasan Pasha (Ottoman commander)
# 0.483309118329
# 673/6619
# Ismail I
# -0.487053996575
# 674/6619
# Abd al-Baqi Yazdi
# -0.487053996575
# 675/6619
# Hossein Beg Laleh Shamlu
# -0.487053996575
# 676/6619
# Saru Pira Ustajlu
# -0.487053996575
# 677/6619
# Durmish Khan Shamlu
# -0.487053996575
# 678/6619
# Nur-Ali Khalifa
# -0.487053996575
# 679/6619
# Mohammad Khan Ustajlu
# -0.487053996575
# 680/6619
# Sayyed Sharif al-Din Ali Shirazi
# -0.487053996575
# 681/6619
# John of Montfort
# -0.5
# 682/6619
# Bai Qi
# 1.02041855237
# 683/6619
# Lian Po
# -0.491498819221
# 684/6619
# Zhao Kuo
# -0.491498819221
# 685/6619
# Cheng Dechen
# -0.5
# 686/6619
# Zishang
# -0.5
# 687/6619
# Zixi (Zhou dynasty)
# -0.5
# 688/6619
# Hu Mao
# 0.5
# 689/6619
# Hu Yan
# 0.5
# 690/6619
# Xian Zhen
# 0.5
# 691/6619
# Xi Zhen
# 0.5
# 692/6619
# Xu Chen (Zhou dynasty)
# 0.5
# 693/6619
# Luan Zhi
# 0.5
# 694/6619
# Konishi Yukinaga
# 1.69330254749
# 695/6619
# Shimazu Yoshihiro
# 0.954984758354
# 696/6619
# Choe Ho
# -0.412109536057
# 697/6619
# Bae Seol
# -0.412109536057
# 698/6619
# Chalcuchimac
# 1.0061072131
# 699/6619
# Quizquiz
# 0.506107213096
# 700/6619
# Rumiñawi (Inca warrior)
# 0.5
# 701/6619
# Inca Empire
# -0.5
# 702/6619
# Atoc
# -0.5
# 703/6619
# Hango (general)
# -0.5
# 704/6619
# Ullco Colla
# -0.5
# 705/6619
# Albert of Schwarzburg
# 0.490833139672
# 706/6619
# Mehmed Beg
# -0.494580512674
# 707/6619
# Philip V of Macedon
# -1.03603231607
# 708/6619
# Attalus I
# 0.545811929459
# 709/6619
# Theophiliscus
# 0.545811929459
# 710/6619
# Bertrand du Guesclin
# 1.50237469564
# 711/6619
# John Devereux, 1st Baron Devereux
# -0.464204186946
# 712/6619
# Bernhard von Zinnenberg
# 0.470539922527
# 713/6619
# Casimir IV Jagiellon
# -0.474276678889
# 714/6619
# Jan Taszka Koniecpolski
# -0.474276678889
# 715/6619
# Piotr of Szczekociny
# -0.474276678889
# 716/6619
# Mullah Mutalib
# -0.5
# 717/6619
# Mullah Ismael
# -0.5
# 718/6619
# Shin Rip
# -0.556088457012
# 719/6619
# Byeon Gi
# -0.556088457012
# 720/6619
# Kim Yeo-mul
# -0.556088457012
# 721/6619
# Yi Il
# -1.4916655813
# 722/6619
# Yi Jong-jang
# -0.556088457012
# 723/6619
# Sō Yoshitoshi
# 0.903717290362
# 724/6619
# Matsura Shigenobu
# 0.552384389462
# 725/6619
# Arima Harunobu
# 0.552384389462
# 726/6619
# Ōmura Yoshiaki
# 0.552384389462
# 727/6619
# Gnaeus Cornelius Scipio Calvus
# 0.986321455837
# 728/6619
# Walter Sans Avoir
# -0.563781287087
# 729/6619
# Kilij Arslan I
# -0.327768559417
# 730/6619
# Rudolf of Benevento
# -0.529146523296
# 731/6619
# Gerard, Duke of Lorraine
# -0.529146523296
# 732/6619
# Humphrey of Hauteville
# 0.52540950888
# 733/6619
# Robert Guiscard
# 1.52963889876
# 734/6619
# Richard I of Capua
# 0.52540950888
# 735/6619
# Brian Boru
# 0.995074272957
# 736/6619
# Murchad mac Briain
# 0.495074272957
# 737/6619
# Sigtrygg Silkbeard
# -0.998822303808
# 738/6619
# Máel Mórda mac Murchada
# -0.998822303808
# 739/6619
# Sigurd the Stout
# -0.498822303808
# 740/6619
# Brodir and Ospak of Man
# -0.498822303808
# 741/6619
# Pharnabazus II
# -0.00266162487831
# 742/6619
# Peisander (general)
# -0.497775691338
# 743/6619
# Jean III de Grailly, captal de Buch
# -0.0188759192918
# 744/6619
# John I Albert
# -0.5
# 745/6619
# Stanisław Chodecki
# -0.5
# 746/6619
# Provenzano Salvani
# -0.603406791056
# 747/6619
# Giambertoldo
# 0.599813416303
# 748/6619
# Conrad III of Germany
# -1.5
# 749/6619
# Manuel I Komnenos
# 0.0
# 750/6619
# Lucius Mummius Achaicus
# 0.45540641651
# 751/6619
# Diaeus
# -0.459127208091
# 752/6619
# Titus Manlius Torquatus (dictator)
# 0.486071136189
# 753/6619
# Hasdrubal the Bald
# -0.489817127542
# 754/6619
# Hampsicora
# -0.489817127542
# 755/6619
# Agesilaus II
# 0.5
# 756/6619
# Tolmides
# -0.5
# 757/6619
# Sparton
# 0.5
# 758/6619
# James Stewart, 1st Earl of Moray
# 0.436218712913
# 759/6619
# John Stewart, 4th Earl of Atholl
# 0.436218712913
# 760/6619
# James Douglas, 4th Earl of Morton
# 0.436218712913
# 761/6619
# George Gordon, 4th Earl of Huntly
# 0.0789597591662
# 762/6619
# Pietro Tiepolo
# -0.591666971548
# 763/6619
# Roman Catholic Archdiocese of Milan
# -0.591666971548
# 764/6619
# Frederick II, Holy Roman Emperor
# 0.0880398481599
# 765/6619
# Henry IV of France
# 1.00395650157
# 766/6619
# Anne de Joyeuse
# -0.50187408524
# 767/6619
# Munuza
# -0.604059078385
# 768/6619
# Al Qama
# -0.604059078385
# 769/6619
# Pelagius of Asturias
# 0.600467700498
# 770/6619
# Alexander, 2nd Lord Forbes of Pitsligo
# -0.507977001888
# 771/6619
# Adam Gordon of Auchindoun
# 0.504229389879
# 772/6619
# Antipater
# 0.929923408419
# 773/6619
# Craterus
# 2.41891635042
# 774/6619
# Antiphilus (general)
# -0.470052987209
# 775/6619
# Menon IV of Pharsalus
# -0.470052987209
# 776/6619
# Louis, Count of Vendôme
# -0.536396582609
# 777/6619
# Thomas Montagu, 4th Earl of Salisbury
# 1.05671386361
# 778/6619
# Gerard de Ridefort
# -0.403893884068
# 779/6619
# Roger de Moulins
# -0.418381386965
# 780/6619
# Otto II, Holy Roman Emperor
# -0.5
# 781/6619
# Landulf IV of Benevento
# -0.5
# 782/6619
# Abu al-Qasim (Kalbid)
# 0.5
# 783/6619
# Abu al-Qasim (Kalbite) — Wikipédia
# 0.5
# 784/6619
# Emirate of Sicily
# 0.5
# 785/6619
# Owain Gwynedd
# 0.5
# 786/6619
# Cadwaladr ap Gruffydd
# 0.5
# 787/6619
# Gruffydd ap Rhys
# 0.5
# 788/6619
# Robert fitz Martin
# -0.5
# 789/6619
# Maurice FitzGerald, Lord of Lanstephan
# -0.5
# 790/6619
# Avidius Cassius
# 0.5
# 791/6619
# Vologases IV
# -0.5
# 792/6619
# Merena
# 0
# 793/6619
# Artaxerxes II of Persia
# -0.0545158606446
# 794/6619
# Gobrias
# -0.0545158606446
# 795/6619
# Tissaphernes
# -0.0545158606446
# 796/6619
# Cyrus the Younger
# 0.0508092706347
# 797/6619
# Clearchus of Sparta
# -0.44588012692
# 798/6619
# Ariaeus
# 0.0508092706347
# 799/6619
# Lamba Doria
# 0.519849499845
# 800/6619
# Andrea Dandolo (admiral)
# -0.52359059727
# 801/6619
# Titus Quinctius Flamininus
# 0.982761654518
# 802/6619
# Ubba
# -0.5
# 803/6619
# Odda, Ealdorman of Devon
# 0.5
# 804/6619
# Alcibiades
# 0.492941630068
# 805/6619
# Theramenes
# 0.492941630068
# 806/6619
# Hermocrates
# 0.00331060244495
# 807/6619
# Gar Trinring Tsendro
# 0.418165636976
# 808/6619
# Xue Rengui
# -0.42181783315
# 809/6619
# Ashina Daozi
# -0.42181783315
# 810/6619
# Guo Daifeng
# -0.42181783315
# 811/6619
# Abdul Qayyum Zakir
# -0.5
# 812/6619
# Sancho d'Avila
# 1.02643830842
# 813/6619
# Mas'ud I of Ghazni
# -0.555101990602
# 814/6619
# Ali Daya
# -0.555101990602
# 815/6619
# Ahmad Shirazi
# -0.555101990602
# 816/6619
# Abu Sahl Zawzani
# -0.555101990602
# 817/6619
# Abd al-Razzaq Maymandi
# -0.555101990602
# 818/6619
# Begtoghdi
# -0.555101990602
# 819/6619
# Subashi (general)
# -0.555101990602
# 820/6619
# Chaghri Beg
# 0.551396332061
# 821/6619
# Tughril
# 0.551396332061
# 822/6619
# Faramurz
# 0.551396332061
# 823/6619
# Minamoto no Yoshitsune
# 1.55083672291
# 824/6619
# Taira no Munemori
# -1.03052500714
# 825/6619
# Taira no Tomomori
# -0.0305250071446
# 826/6619
# Perozes
# -0.536396582609
# 827/6619
# Pityaxes
# -0.536396582609
# 828/6619
# Baresmanas
# -0.536396582609
# 829/6619
# Pharas the Herulian
# 0.532666289955
# 830/6619
# Taddeo d'Este
# -0.5
# 831/6619
# Niccolò Piccinino
# 1.0
# 832/6619
# William the Silent
# -1.06477398197
# 833/6619
# Thomas Morgan (died 1595)
# 0.986865652326
# 834/6619
# Francisco de Valdez
# -0.998960623624
# 835/6619
# Julian Romero
# 0.0122120770477
# 836/6619
# Pagondas
# 0.490145571375
# 837/6619
# Hippocrates of Athens
# -0.493892786904
# 838/6619
# Alexios Doukas Philanthropenos
# 0.473596907315
# 839/6619
# John Palaiologos (brother of Michael VIII)
# -0.627878858758
# 840/6619
# Fillippo Sanudo
# -0.477336053669
# 841/6619
# Guglielmo II da Verona
# -0.477336053669
# 842/6619
# Publius Cornelius Scipio
# -0.507623648247
# 843/6619
# Chen Tai
# 0.442510005646
# 844/6619
# Deng Ai
# 0.442510005646
# 845/6619
# Hu Fen
# 0.442510005646
# 846/6619
# Jiang Wei
# -0.413545472513
# 847/6619
# Xiahou Ba
# -0.446211762467
# 848/6619
# Zhang Yi (Bogong)
# -0.446211762467
# 849/6619
# Mazyadid dynasty
# -0.555777124127
# 850/6619
# David IV of Georgia
# 0.552072551295
# 851/6619
# Demetrius I of Georgia
# 0.552072551295
# 852/6619
# Francisco de Almeida
# 0.469474992855
# 853/6619
# Amir Husain Al-Kurdi
# -0.47321085075
# 854/6619
# Malik Ayyaz
# -0.47321085075
# 855/6619
# Kunhali Marakkar
# -0.47321085075
# 856/6619
# Giovanni Andrea Doria
# -0.0274970893362
# 857/6619
# Juan de la Cerda, 4th Duke of Medinaceli
# -0.542872568702
# 858/6619
# Álvaro de Sande
# -0.542872568702
# 859/6619
# Piali Pasha
# -0.0289371428198
# 860/6619
# Dragut
# 0.408049329441
# 861/6619
# Major general (United States)
# 0.5
# 862/6619
# Major (United States)
# 0.5
# 863/6619
# Sviatoslav I of Kiev
# -1.05557134768
# 864/6619
# John I Tzimiskes
# 1.04809514732
# 865/6619
# Bohemond I of Antioch
# 1.40518821935
# 866/6619
# Adhemar of Le Puy
# 1.40095882947
# 867/6619
# Danishmend Gazi
# -0.437699500196
# 868/6619
# Mesud I
# 0.5
# 869/6619
# Adherbal (admiral)
# 0.49812591476
# 870/6619
# Hamilcar
# 0.49812591476
# 871/6619
# Publius Claudius Pulcher (consul 249 BC)
# -0.50187408524
# 872/6619
# Francis, Duke of Guise
# 0.884911100432
# 873/6619
# Louis, Prince of Condé (1530–1569)
# -1.49840938475
# 874/6619
# Gaspard II de Coligny
# -0.994819382239
# 875/6619
# Hector Roy Mackenzie
# -0.0277856738421
# 876/6619
# John Balliol
# -0.50187408524
# 877/6619
# John de Warenne, 6th Earl of Surrey
# -0.0318305592121
# 878/6619
# Domhnall II, Earl of Mar
# -0.573443998287
# 879/6619
# Edward Balliol
# 0.569772707684
# 880/6619
# Henry de Beaumont
# 0.569772707684
# 881/6619
# Burchard von Hornhausen
# -0.536396582609
# 882/6619
# Treniota
# 0.532666289955
# 883/6619
# Alexios I Komnenos
# 0.514079413101
# 884/6619
# George Palaiologos
# -0.00797700188799
# 885/6619
# Sikelgaita
# 0.504229389879
# 886/6619
# Pompey
# 0.911983324414
# 887/6619
# Richard de Clare, Steward of Forest of Essex
# -0.5
# 888/6619
# Valerian (emperor)
# -0.5
# 889/6619
# Successianus
# -0.5
# 890/6619
# Robin of Redesdale
# 0.5
# 891/6619
# William Herbert, 1st Earl of Pembroke (died 1469)
# -0.5
# 892/6619
# Humphrey Stafford, 1st Earl of Devon
# -0.5
# 893/6619
# Alfred the Great
# 0.5
# 894/6619
# Guthrum
# -0.5
# 895/6619
# Bacchides (general)
# 0.404489138237
# 896/6619
# Iphicrates
# 0.0
# 897/6619
# Timotheus (general)
# -0.5
# 898/6619
# Aurelian
# 0.953789183559
# 899/6619
# Zenobia
# -0.95750786222
# 900/6619
# Zabdas
# -0.95750786222
# 901/6619
# Gorgias (general)
# -0.527785673842
# 902/6619
# Nicanor (Seleucid general)
# -0.527785673842
# 903/6619
# Hegesandridas
# 0.5
# 904/6619
# Edward I of England
# 0.870445975578
# 905/6619
# Gilbert de Clare, 7th Earl of Gloucester
# 0.996269707346
# 906/6619
# Simon de Montfort, 6th Earl of Leicester
# 0.0653325799092
# 907/6619
# Peter de Montfort
# -0.467333710045
# 908/6619
# Lucius Aemilius Papus
# -0.00486543592723
# 909/6619
# Stilicho
# 0.995161458712
# 910/6619
# Sarus the Goth
# 0.5
# 911/6619
# Uldin
# 0.5
# 912/6619
# Radagaisus
# -0.5
# 913/6619
# Theodore Trithyrius
# -1.00187408524
# 914/6619
# Hasan ibn Ali
# 0.0188691288909
# 915/6619
# William Wallace
# 0.0792780250589
# 916/6619
# Cao Ren
# 0.0181394522136
# 917/6619
# Yu Jin
# 0.479826109692
# 918/6619
# Pang De
# 0.479826109692
# 919/6619
# Xu Huang
# 0.450325267977
# 920/6619
# Guan Yu
# 0.066271052573
# 921/6619
# Louis IX of France
# 0.0942114205766
# 922/6619
# Guillaume de Sonnac
# -0.5
# 923/6619
# Al-Muazzam Turanshah
# 0.5
# 924/6619
# Shane O'Neill (son of Conn)
# -0.00187408523964
# 925/6619
# Sir Hugh O'Donnell
# 0.49812591476
# 926/6619
# John de Bermingham, 1st Earl of Louth
# 0.414091265204
# 927/6619
# Edmund Butler, Earl of Carrick
# 0.414091265204
# 928/6619
# Earl of Carrick (Ireland)
# 0.414091265204
# 929/6619
# Earl of Carrick
# -0.417733424974
# 930/6619
# Fu Jian (337–385)
# -0.587257148493
# 931/6619
# Fu Rong
# -0.587257148493
# 932/6619
# Xie An
# 0.583618420313
# 933/6619
# Xie Xuan
# 0.583618420313
# 934/6619
# Huan Chong
# 0.583618420313
# 935/6619
# John Clifford, 9th Baron Clifford
# 0.463603417391
# 936/6619
# John Neville, Baron Neville
# 0
# 937/6619
# James IV of Scotland
# 0.00687124973799
# 938/6619
# Alexander Home, 3rd Lord Home
# -0.517176323921
# 939/6619
# William Graham, 1st Earl of Montrose
# -0.517176323921
# 940/6619
# Adam Hepburn, 2nd Earl of Bothwell
# -0.517176323921
# 941/6619
# Matthew Stewart, 2nd Earl of Lennox
# -0.517176323921
# 942/6619
# Archibald Campbell, 2nd Earl of Argyll
# -0.517176323921
# 943/6619
# Catherine of Aragon
# 0.513431664961
# 944/6619
# Thomas Howard, 3rd Duke of Norfolk
# 0.513431664961
# 945/6619
# Lord Edmund Howard
# 0.513431664961
# 946/6619
# Thomas Dacre, 2nd Baron Dacre
# 0.513431664961
# 947/6619
# Edward Stanley, 1st Baron Monteagle
# 0.513431664961
# 948/6619
# Marmaduke Constable
# 0.513431664961
# 949/6619
# Charles I, Duke of Bourbon
# 0.49698571238
# 950/6619
# Arthur III, Duke of Brittany
# 0.49698571238
# 951/6619
# Sir Thomas Kyriell
# -0.500733863367
# 952/6619
# Francesco II Gonzaga, Marquess of Mantua
# -0.534139872004
# 953/6619
# Charles VIII of France
# 0.530407317895
# 954/6619
# Gaius Vibius Pansa Caetronianus
# 0.894533548533
# 955/6619
# Aulus Hirtius
# 0.894533548533
# 956/6619
# Enzo of Sardinia
# 0.471127899515
# 957/6619
# Ottaviano degli Ubaldini
# -0.474865137357
# 958/6619
# Thomas Müntzer
# 0.483309118329
# 959/6619
# Philip I, Landgrave of Hesse
# 0.512946003425
# 960/6619
# George, Duke of Saxony
# 0.512946003425
# 961/6619
# Minamoto no Yoritomo
# 1.08039248979
# 962/6619
# Taira no Koremori
# -1.08370844826
# 963/6619
# Harald Hardrada
# -0.475748906885
# 964/6619
# Tostig Godwinson
# -0.0123490089494
# 965/6619
# Morcar
# -0.467333710045
# 966/6619
# Edwin, Earl of Mercia
# -0.467333710045
# 967/6619
# Antigonus I Monophthalmus
# 0.494392057239
# 968/6619
# Eumenes
# -0.480852353855
# 969/6619
# Han Xin
# 0.982750989241
# 970/6619
# Xiang Yu
# 0.130556888051
# 971/6619
# Pietro Loredan
# 0.5
# 972/6619
# Alberic I of Spoleto
# 0.5
# 973/6619
# Nicholas Picingli
# 0.5
# 974/6619
# Pope John X
# 0.5
# 975/6619
# Ludovico II, Marquess of Saluzzo
# -0.512448313198
# 976/6619
# Willekin von Endorp
# -0.5
# 977/6619
# Darius III
# -1.08122500459
# 978/6619
# Bessus
# -0.526313722044
# 979/6619
# Mazaeus
# -0.526313722044
# 980/6619
# Orontes II
# -0.526313722044
# 981/6619
# Atropates
# -0.526313722044
# 982/6619
# Hephaestion
# 2.46023147153
# 983/6619
# Parmenion
# 1.53875003341
# 984/6619
# Ptolemy I Soter
# 2.02214326693
# 985/6619
# Perdiccas
# 0.997604363538
# 986/6619
# Cleitus the Black
# 0.987544713612
# 987/6619
# Nearchus
# 0.52257451004
# 988/6619
# Seleucus I Nicator
# 1.99554952922
# 989/6619
# Ariston of Paionia
# 0.52257451004
# 990/6619
# Simmias of Macedon
# 0.52257451004
# 991/6619
# Coenus (general)
# 0.997604363538
# 992/6619
# Ariston of Macedon
# 0.52257451004
# 993/6619
# Glaucias of Macedon
# 0.52257451004
# 994/6619
# Sopolis of Macedon
# 0.52257451004
# 995/6619
# Francesco Ferruccio
# -0.532675306313
# 996/6619
# Philibert of Chalon
# 0.52894136639
# 997/6619
# Fabrizio Maramaldo
# 0.52894136639
# 998/6619
# Demetrius I of Macedon
# -0.127573834133
# 999/6619
# Dionysius I of Syracuse
# 1.01934316768
# 1000/6619
# Himilco (general)
# -0.0479066397481
# 1001/6619
# Antoine de Goignies
# -0.517371607688
# 1002/6619
# Maximilien de Hénin-Liétard
# -0.0203477882811
# 1003/6619
# William II de La Marck
# -0.517371607688
# 1004/6619
# Maarten Schenck van Nydeggen
# -0.517371607688
# 1005/6619
# Emanuel Philibert de Lalaing
# -0.517371607688
# 1006/6619
# Philip, Count of Egmont
# -1.02694947507
# 1007/6619
# Charles Philippe de Croÿ, Marquis d’Havré
# -0.517371607688
# 1008/6619
# Henry Balfour (soldier)
# -0.517371607688
# 1009/6619
# John of Austria
# 0.537216351041
# 1010/6619
# Alexander Farnese, Duke of Parma
# 0.0100785538293
# 1011/6619
# Cristóbal de Mondragón
# 0.513627038937
# 1012/6619
# Ottavio Gonzaga
# 0.513627038937
# 1013/6619
# Peter Ernst I von Mansfeld-Vorderort
# 0.513627038937
# 1014/6619
# Francisco Verdugo
# 0.513627038937
# 1015/6619
# John FitzAlan, 14th Earl of Arundel
# -0.57057370122
# 1016/6619
# La Hire
# 1.12068460225
# 1017/6619
# Jean Poton de Xaintrailles
# 1.12068460225
# 1018/6619
# Marcus Minucius Rufus
# -0.467333710045
# 1019/6619
# Magister equitum
# -0.467333710045
# 1020/6619
# Archibald Campbell, 7th Earl of Argyll
# -0.57057370122
# 1021/6619
# George Gordon, 1st Marquess of Huntly
# 0.566896364714
# 1022/6619
# Francis Hay, 9th Earl of Erroll
# 0.566896364714
# 1023/6619
# Máel Sechnaill mac Domnaill
# 0.5
# 1024/6619
# Sorley Boy MacDonnell
# -0.5
# 1025/6619
# Joseph Kabila
# 0.442510005646
# 1026/6619
# Babacar Gaye
# 0.442510005646
# 1027/6619
# Ignace Murwanashyaka
# 0.442510005646
# 1028/6619
# José Eduardo dos Santos
# 0.442510005646
# 1029/6619
# Robert Mugabe
# 0.442510005646
# 1030/6619
# Laurent Nkunda
# -0.446211762467
# 1031/6619
# Lamoral, Count of Egmont
# 0.932358099612
# 1032/6619
# Paul de Thermes
# -0.485372964828
# 1033/6619
# Gaius Claudius Nero
# 0.96393294043
# 1034/6619
# Ulrich von Jungingen
# -0.527361717394
# 1035/6619
# Władysław II Jagiełło
# 1.0424924192
# 1036/6619
# Vytautas
# 0.063815174161
# 1037/6619
# Roderic
# -0.51601783027
# 1038/6619
# Tariq ibn Ziyad
# 0.512272659688
# 1039/6619
# Chunyu Qiong
# -0.550126907488
# 1040/6619
# Guo Tu
# -0.550126907488
# 1041/6619
# Cao Hong
# -0.509008829859
# 1042/6619
# Tian Ji
# 0.961729332152
# 1043/6619
# Sun Bin
# 0.961729332152
# 1044/6619
# Pang Juan
# -0.969207795285
# 1045/6619
# Maximilian I, Holy Roman Emperor
# 0.339227663091
# 1046/6619
# Philippe de Crèvecœur d'Esquerdes
# -0.457815260813
# 1047/6619
# Henry VIII of England
# 1.43401301675
# 1048/6619
# Henry Bourchier, 2nd Earl of Essex
# 0.434013016753
# 1049/6619
# Jacques de La Palice
# -0.379785636274
# 1050/6619
# Charles IV, Duke of Alençon
# -0.437699500196
# 1051/6619
# Louis I d'Orléans, duc de Longueville
# -0.437699500196
# 1052/6619
# Petar Svačić
# -0.5
# 1053/6619
# Coloman, King of Hungary
# 0.5
# 1054/6619
# Eumenes II
# 0.99812591476
# 1055/6619
# Dexagoridas
# -0.5
# 1056/6619
# Gorgopas (2nd century BC)
# -0.5
# 1057/6619
# Marinus Brandt
# -0.530525007145
# 1058/6619
# Robert Bowes (lawyer)
# -0.52261085022
# 1059/6619
# Katō Kiyomasa
# 0.886862185929
# 1060/6619
# Kuroda Nagamasa
# 1.33953602575
# 1061/6619
# Ishida Mitsunari
# -0.624677938507
# 1062/6619
# Kikkawa Hiroie
# -0.577926652619
# 1063/6619
# Kobayakawa Hideaki
# -0.577926652619
# 1064/6619
# Kwon Yul
# 0.0469035825258
# 1065/6619
# Jo Gyeong
# 0.574265299919
# 1066/6619
# Seon Geoi
# 0.574265299919
# 1067/6619
# Kim Cheon Il
# 0.574265299919
# 1068/6619
# Heo Uk
# 0.574265299919
# 1069/6619
# Cheo Yung
# 0.574265299919
# 1070/6619
# Archibald Douglas (died 1333)
# -0.520727833321
# 1071/6619
# Thomas of Brotherton, 1st Earl of Norfolk
# 0.516984993779
# 1072/6619
# Walter V, Count of Brienne
# -0.5
# 1073/6619
# Al-Husayn ibn Zikrawayh
# -0.5
# 1074/6619
# Muhammad ibn Sulayman al-Katib
# 0.5
# 1075/6619
# Husayn ibn Hamdan
# 0.5
# 1076/6619
# Cao Xiu
# -1.11103840973
# 1077/6619
# Zhao Yun
# 0.538535330657
# 1078/6619
# Huang Zhong
# 0.549840310504
# 1079/6619
# Liu Bei
# 1.10933432063
# 1080/6619
# Raymond III, Count of Tripoli
# -1.02960261342
# 1081/6619
# Bohemond III of Antioch
# -0.557489994354
# 1082/6619
# Constantine Kalamanos
# -0.557489994354
# 1083/6619
# Thoros II, Prince of Armenia
# -0.557489994354
# 1084/6619
# Hugh VIII of Lusignan
# -0.557489994354
# 1085/6619
# Joscelin III, Count of Edessa
# -1.02960261342
# 1086/6619
# Nur ad-Din (died 1174)
# 1.48780125429
# 1087/6619
# Qutb ad-Din Mawdud
# 0.553788237533
# 1088/6619
# Alexander Stewart, Earl of Mar
# -0.5
# 1089/6619
# Donald of Islay, Lord of the Isles
# 0
# 1090/6619
# Mosul
# 1.0
# 1091/6619
# Sökmen (Artuqid)
# -0.024234899525
# 1092/6619
# William the Conqueror
# 0.495321692754
# 1093/6619
# Alan Rufus
# 0.495321692754
# 1094/6619
# William FitzOsbern, 1st Earl of Hereford
# 0.495321692754
# 1095/6619
# Eustace II, Count of Boulogne
# 0.495321692754
# 1096/6619
# Harold Godwinson
# -0.0268554191715
# 1097/6619
# Gyrth Godwinson
# -0.499069745329
# 1098/6619
# Leofwine Godwinson
# -0.499069745329
# 1099/6619
# Raynald of Châtillon
# 0.0743010516915
# 1100/6619
# Humphrey IV of Toron
# -0.472112619064
# 1101/6619
# Aimery of Cyprus
# -0.472112619064
# 1102/6619
# Reginald of Sidon
# -0.472112619064
# 1103/6619
# Þórður kakali Sighvatsson
# 0.5
# 1104/6619
# Henry Beaufort, 3rd Duke of Somerset
# -1.03935772623
# 1105/6619
# Thomas de Ros, 9th Baron de Ros
# -0.99244185695
# 1106/6619
# Robert Hungerford, 3rd Baron Hungerford
# -0.99244185695
# 1107/6619
# Ralph Percy
# -0.49244185695
# 1108/6619
# Louis of Nassau
# -1.63530672613
# 1109/6619
# Adolf of Nassau (1540–1568)
# 0.467583852601
# 1110/6619
# Jean de Ligne, Duke of Arenberg
# -0.47131803104
# 1111/6619
# John, King of Denmark
# -0.5
# 1112/6619
# Frederick I of Denmark
# -0.5
# 1113/6619
# Publius Valerius Laevinus
# -0.469227307154
# 1114/6619
# Ismail Khan
# 0.5
# 1115/6619
# Tommy Franks
# -0.00187408523964
# 1116/6619
# Yahya Rahim Safavi
# 0.5
# 1117/6619
# Flaccus
# -0.484987291909
# 1118/6619
# Hannibal Mago
# 1.5
# 1119/6619
# Hamilcar I of Carthage
# -0.575409358691
# 1120/6619
# Gelo
# 0.571742350808
# 1121/6619
# Theron of Acragas
# 0.571742350808
# 1122/6619
# Henry Percy (Hotspur)
# -0.537112599373
# 1123/6619
# George I, Earl of March
# 1.00253032888
# 1124/6619
# Archibald Douglas, 4th Earl of Douglas
# -1.00138590284
# 1125/6619
# Jan Žižka
# 2.18547469421
# 1126/6619
# Diviš Bořek of Miletínek
# 1.48826591417
# 1127/6619
# Čeněk of Wartenberg
# -0.522217088688
# 1128/6619
# Artabanus V of Parthia
# -0.5
# 1129/6619
# Ardashir I
# 0.5
# 1130/6619
# Dou Jiande
# -0.540694234124
# 1131/6619
# Wang Shichong
# -0.00802794416948
# 1132/6619
# Duan Da
# -0.540694234124
# 1133/6619
# Shan Xiongxin
# -0.540694234124
# 1134/6619
# Emperor Taizong of Tang
# 0.536968671151
# 1135/6619
# Li Yuanji
# 0.536968671151
# 1136/6619
# Liu Dewei
# 0.536968671151
# 1137/6619
# Huang Junhan
# 0.536968671151
# 1138/6619
# Yuwen Shiji
# 0.536968671151
# 1139/6619
# Shi Wanbao
# 0.536968671151
# 1140/6619
# Li Shiji
# 0.536968671151
# 1141/6619
# Emperor Gaozu of Tang
# 0.5
# 1142/6619
# Li Jiancheng
# 0.5
# 1143/6619
# Kim Yu-sin
# 0.414091265204
# 1144/6619
# Kim Heum-sun
# 0.414091265204
# 1145/6619
# Kim Pumil
# 0.414091265204
# 1146/6619
# Gyebaek
# -0.417733424974
# 1147/6619
# Cyrus the Great
# 1.59710486643
# 1148/6619
# Harpagus
# -0.0301699782883
# 1149/6619
# Taira no Tadanori
# -0.527785673842
# 1150/6619
# Taira no Shigehira
# -0.0277856738421
# 1151/6619
# Taira no Noritsune
# -1.02778567384
# 1152/6619
# Minamoto no Noriyori
# 0.524047573659
# 1153/6619
# Frederick I, Holy Roman Emperor
# 0.00610721309575
# 1154/6619
# Frederick VI, Duke of Swabia
# 0.986600121961
# 1155/6619
# Géza, son of Géza II of Hungary
# 0.5
# 1156/6619
# Děpolt II
# 0.986600121961
# 1157/6619
# Demosthenes (general)
# 1.5
# 1158/6619
# Northern Chanyu (1st century)
# -0.50187408524
# 1159/6619
# Dou Xian
# 0.49812591476
# 1160/6619
# Lucius Afranius (consul)
# -0.517371607688
# 1161/6619
# Marcus Petreius
# -0.572642752546
# 1162/6619
# Marcus Terentius Varro
# -0.517371607688
# 1163/6619
# Mu'in ad-Din Unur
# 0.934013016753
# 1164/6619
# ...
# 0.559829240433
# 6245/6619
# Jeong Gi-ryong
# 0.0324675230393
# 6246/6619
# Im Gye-yeong
# 0.559829240433
# 6247/6619
# Choi Gyeong-hoe
# 0.559829240433
# 6248/6619
# Yu Sung-in
# 0.559829240433
# 6249/6619
# Hwang Jin
# -0.477725340493
# 6250/6619
# Kim Cheon-il
# -0.477725340493
# 6251/6619
# Ivan the Terrible
# 0.5
# 6252/6619
# Alexander Gorbatyi-Shuisky
# 0.5
# 6253/6619
# Andrey Kurbsky
# 0.5
# 6254/6619
# Shahghali
# 0.5
# 6255/6619
# Yadegar Mokhammad of Kazan
# -0.5
# 6256/6619
# Yapancha beg
# -0.5
# 6257/6619
# Zaynash morza
# -0.5
# 6258/6619
# Qolsharif
# -0.5
# 6259/6619
# Afonso Pereira de Lacerda
# 0.5
# 6260/6619
# Diogo de Melo Coutinho
# 0.5
# 6261/6619
# Gabriel, comte de Montgomery
# 0
# 6262/6619
# Pieter Adriaanszoon van der Werff
# 0.51408539989
# 6263/6619
# Afonso I of Portugal
# 0.5
# 6264/6619
# Hervey de Glanvill
# 0.5
# 6265/6619
# Arnout IV, Count of Aarschot
# 0.5
# 6266/6619
# Christian of Ghistelles
# 0.5
# 6267/6619
# Simon of Dover
# 0.5
# 6268/6619
# Saher of Archelle
# 0.5
# 6269/6619
# Louis XIV of France
# 1.22487087035
# 6270/6619
# Jacques de Fariaux, baron de Maulde
# -0.826732017665
# 6271/6619
# Alaal-Din
# -0.5
# 6272/6619
# Leonis Pereira
# 0.5
# 6273/6619
# Jean Parisot de Valette
# 0.564404383178
# 6274/6619
# Jean de la Cassière
# 0.564404383178
# 6275/6619
# Mathurin Romegas
# 0.564404383178
# 6276/6619
# Goncales de Medran
# 0.564404383178
# 6277/6619
# Melchior de Robles
# 0.564404383178
# 6278/6619
# García de Toledo Osorio, 4th Marquis of Villafranca
# 0.564404383178
# 6279/6619
# Decimus Junius Brutus Albinus
# 0.466596318665
# 6280/6619
# Trebonius
# 0.466596318665
# 6281/6619
# Lucius Domitius Ahenobarbus (consul 54 BC)
# -0.47032957743
# 6282/6619
# Kamiizumi Nobutsuna
# -0.475952426341
# 6283/6619
# Nagano Narimori
# -0.475952426341
# 6284/6619
# Niho Takayasu
# 0.5
# 6285/6619
# Ōtomo Sōrin
# -0.5
# 6286/6619
# Tachibana Dōsetsu
# -0.5
# 6287/6619
# Tawara Chikakata
# -0.5
# 6288/6619
# Usuki Akihaya
# -0.5
# 6289/6619
# Oi Sadataka
# -0.45750786222
# 6290/6619
# Yi Bok-nam
# -0.429649141208
# 6291/6619
# Yi Chun-won
# -0.429649141208
# 6292/6619
# Kim Gyeong-ro
# -0.429649141208
# 6293/6619
# Ma Eung-bang
# -0.429649141208
# 6294/6619
# Oh Eung-jeong
# -0.429649141208
# 6295/6619
# Im Hyeon
# -0.429649141208
# 6296/6619
# Yi Deok-hoe
# -0.429649141208
# 6297/6619
# Jeong Gi-won
# -0.429649141208
# 6298/6619
# Hwang Dae-jung
# -0.429649141208
# 6299/6619
# Shin Ho
# -0.429649141208
# 6300/6619
# Jo Gyeong-nam
# -0.429649141208
# 6301/6619
# Yang Hao (Ming dynasty)
# -0.957010858602
# 6302/6619
# Jiang Biao
# -0.429649141208
# 6303/6619
# Mao Cheng Xian
# -0.429649141208
# 6304/6619
# Aristagoras
# -0.5
# 6305/6619
# Megabates
# -0.5
# 6306/6619
# Manuel Boutoumites
# 0.446451584625
# 6307/6619
# Charles V, Holy Roman Emperor
# -0.5
# 6308/6619
# Charles III, Duke of Savoy
# -0.5
# 6309/6619
# Suganuma Sadamichi
# -0.399831747074
# 6310/6619
# Satake Yoshiaki
# -0.57826666603
# 6311/6619
# Ōta Sukemasa
# -0.57826666603
# 6312/6619
# Nagano Narimasa
# -0.57826666603
# 6313/6619
# Oda Ujiharu
# -0.57826666603
# 6314/6619
# Utsunomiya Hirotsuna
# -0.57826666603
# 6315/6619
# Satomi Yoshihiro
# -0.57826666603
# 6316/6619
# Nasu Suketane
# -0.57826666603
# 6317/6619
# Yura Narishige
# -0.57826666603
# 6318/6619
# Mita Tsunahide
# -0.57826666603
# 6319/6619
# Oda Nobukatsu
# 0.450870995805
# 6320/6619
# Gamō Ujisato
# 0.450870995805
# 6321/6619
# Sanada Masayuki
# 0.450870995805
# 6322/6619
# Chōsokabe Motochika
# 0.950870995805
# 6323/6619
# Shimazu Hisayasu
# 0.450870995805
# 6324/6619
# Hōjō Ujimasa
# -0.454585663008
# 6325/6619
# Hōjō Ujinao
# -0.454585663008
# 6326/6619
# Narita Ujinaga
# -0.454585663008
# 6327/6619
# Kaihime
# -0.454585663008
# 6328/6619
# Niccolò di Pitigliano
# 0.545166511364
# 6329/6619
# Andrea Gritti
# 0.545166511364
# 6330/6619
# Henry II of France
# -0.5
# 6331/6619
# Yun Doo-su
# -0.525926766578
# 6332/6619
# Ryu Seong-ryong
# -0.525926766578
# 6333/6619
# Kim Myeong-won
# -0.525926766578
# 6334/6619
# Yi Won-ik
# -0.525926766578
# 6335/6619
# Hwang Won
# -0.525926766578
# 6336/6619
# Kim Ung-seo
# -0.525926766578
# 6337/6619
# Go Eop-baek
# -0.525926766578
# 6338/6619
# Zu Chengxun
# -0.525926766578
# 6339/6619
# Tian Cong
# -0.525926766578
# 6340/6619
# Abu'l-Hasan Asaf Khan
# 0.5
# 6341/6619
# Munim Khan
# 0.5
# 6342/6619
# Mesih Pasha
# -0.594599394098
# 6343/6619
# Pierre d'Aubusson
# 0.590980311713
# 6344/6619
# Suleiman the Magnificent
# -0.174042038622
# 6345/6619
# Çoban Mustafa Pasha
# 0.403106724651
# 6346/6619
# Kurtoğlu Muslihiddin Reis
# 0.403106724651
# 6347/6619
# Philippe Villiers de L'Isle-Adam
# -0.406719336485
# 6348/6619
# Ares (General)
# -0.454651827848
# 6349/6619
# Vitiges
# -0.565689602762
# 6350/6619
# Claude de La Chatre
# 0.447543019959
# 6351/6619
# Mayor Johnanneau
# -0.451252800071
# 6352/6619
# Captain Lafleur
# -0.451252800071
# 6353/6619
# Ankokuji Ekei
# 0.5
# 6354/6619
# Antonio Loredan
# 0.600400119736
# 6355/6619
# Pietro Mocenigo
# 0.600400119736
# 6356/6619
# Triadan Gritti
# 0.600400119736
# 6357/6619
# Ivan Crnojević
# 0.600400119736
# 6358/6619
# Mago II of Carthage
# -0.580390106309
# 6359/6619
# Spitamenes
# -0.5
# 6360/6619
# Mahmud Pasha Angelović
# 0.5
# 6361/6619
# David of Trebizond
# -0.5
# 6362/6619
# Sinan Pasha (Ottoman admiral)
# 0.407733244926
# 6363/6619
# Gaspard de Vallier
# -0.411358744708
# 6364/6619
# Kim Gwi-hoe
# -0.527361717394
# 6365/6619
# Jang Un-ik
# -0.527361717394
# 6366/6619
# Ma Gui (general)
# -0.527361717394
# 6367/6619
# Qian Wanli
# -0.527361717394
# 6368/6619
# Asano Yoshinaga
# 0.523623290311
# 6369/6619
# Mōri Hidemoto
# 0.523623290311
# 6370/6619
# Nabeshima Naoshige
# 0.523623290311
# 6371/6619
# Hachisuka Iemasa
# 0.523623290311
# 6372/6619
# Pargalı Ibrahim Pasha
# -0.577148763273
# 6373/6619
# Nicholas, Count of Salm
# 0.573485642664
# 6374/6619
# Philip, Duke of Palatinate-Neuburg
# 0.573485642664
# 6375/6619
# Wilhelm von Roggendorf
# 0.573485642664
# 6376/6619
# Josephus
# -0.50187408524
# 6377/6619
# Jazzar Pasha
# -0.583138457529
# 6378/6619
# Sidney Smith (Royal Navy officer)
# -1.0658045118
# 6379/6619
# David Hendrik Chassé
# -0.5
# 6380/6619
# Étienne Maurice Gérard
# 0.5
# 6381/6619
# François-Nicolas-Benoît Haxo
# 0.5
# 6382/6619
# Victor Deguise
# -0.542125472475
# 6383/6619
# Archibald Paris (Royal Marines officer)
# -0.542125472475
# 6384/6619
# Armand Philippon
# -0.429586363617
# 6385/6619
# Ulrich Frédéric Woldemar, Comte de Lowendal
# 0.446451584625
# 6386/6619
# Domingo Ugartechea
# -0.536396582609
# 6387/6619
# Stephen F. Austin
# 0.532666289955
# 6388/6619
# Edward Burleson
# 0.532666289955
# 6389/6619
# Benjamin Milam
# 0.532666289955
# 6390/6619
# Justinus van Nassau
# -0.0100540719619
# 6391/6619
# Ambrogio Spinola, 1st Marquis of the Balbases
# 0.91851978719
# 6392/6619
# Carlos Coloma
# 0.506107213096
# 6393/6619
# Jean-Louis Dubreton
# 0.589688497143
# 6394/6619
# Nana Sahib
# 0.442510005646
# 6395/6619
# Tatya Tope
# 0.442510005646
# 6396/6619
# Hugh Wheeler (East India Company officer)
# -0.446211762467
# 6397/6619
# Captain (British Army and Royal Marines)
# -0.446211762467
# 6398/6619
# John Moore (British Major)
# -0.446211762467
# 6399/6619
# Mariot Arbuthnot
# 0.428411787244
# 6400/6619
# William Moultrie
# -0.432087015132
# 6401/6619
# James Hogun
# -0.432087015132
# 6402/6619
# Abraham Whipple
# -0.432087015132
# 6403/6619
# Louis Lebègue Duportail
# -0.432087015132
# 6404/6619
# Jean Léonard Barrié
# -0.431232354876
# 6405/6619
# William Hull
# -0.527019819413
# 6406/6619
# Charles Pearson (British Army officer)
# 0.527719619427
# 6407/6619
# Edmund P. Gaines
# 0.50755814305
# 6408/6619
# Siege of Fort Harrison
# -0.588722618091
# 6409/6619
# Stone Eater
# -0.588722618091
# 6410/6619
# Green Clay
# 0.484505694454
# 6411/6619
# William Dudley (colonel)
# 0.484505694454
# 6412/6619
# David Wooster
# 0.453388221066
# 6413/6619
# Charles Preston
# -0.457106363711
# 6414/6619
# William Phillips (British Army officer)
# 0.452156755637
# 6415/6619
# Arthur St. Clair
# -0.952806357112
# 6416/6619
# James Rhea
# 0.431849248719
# 6417/6619
# Winamac
# -0.435531495965
# 6418/6619
# Five Medals
# -0.435531495965
# 6419/6619
# George Monro (British Army officer)
# -0.447714962307
# 6420/6619
# Koxinga
# 0.5
# 6421/6619
# Frederick Coyett
# -0.5
# 6422/6619
# Barthold Nicolai Landsberg
# 0.553788237533
# 6423/6619
# Matthijs Dulken
# -0.508631292141
# 6424/6619
# Hendrik van den Bergh (count)
# -0.508631292141
# 6425/6619
# Christoph Bernhard von Galen
# -0.102906251718
# 6426/6619
# Gustaff Tungel
# -0.400688646659
# 6427/6619
# Carl von Rabenhaupt
# 0.5
# 6428/6619
# Nikolay Muravyov-Karsky
# 0.491619285278
# 6429/6619
# Fenwick Williams
# -0.495366820953
# 6430/6619
# Mehmet Vasıf Pasha Gürcü
# -0.495366820953
# 6431/6619
# George White (British Army officer)
# 0.524433831314
# 6432/6619
# Ivan Fedyuninsky
# 0.485277599251
# 6433/6619
# Mikhail Khozin
# 0.485277599251
# 6434/6619
# Archibald H. Gillespie
# -0.448603667939
# 6435/6619
# Begum Hazrat Mahal
# 0.43836879267
# 6436/6619
# Birjis Qadr
# 0.43836879267
# 6437/6619
# John Eardley Inglis
# -0.442063376815
# 6438/6619
# Henry Havelock
# -0.442063376815
# 6439/6619
# Colin Campbell, 1st Baron Clyde
# -0.442063376815
# 6440/6619
# James George Smith Neill
# -0.442063376815
# 6441/6619
# Robert Baden-Powell, 1st Baron Baden-Powell
# -0.431316731677
# 6442/6619
# Bryan Mahon
# -0.431316731677
# 6443/6619
# Joseph Anthelme Fournier
# -0.5
# 6444/6619
# Hans von Zwehl
# 0.5
# 6445/6619
# Diwan Mulraj Chopra
# 0.5
# 6446/6619
# Ferdinand II, Holy Roman Emperor
# -0.562853132812
# 6447/6619
# Tiryaki Hasan Pasha
# 0.559160763584
# 6448/6619
# Octavius Ignatius, Prince of Arenberg and Barbançon
# -0.409019688287
# 6449/6619
# Menno van Coehoorn
# 0.0428940269677
# 6450/6619
# Alexander II of Russia
# 0.465000804405
# 6451/6619
# Carol I of Romania
# 0.465000804405
# 6452/6619
# Grand Duke Nicholas Nikolaevich of Russia (1831–1891)
# 0.465000804405
# 6453/6619
# Eduard Totleben
# -0.0010085485352
# 6454/6619
# Nogi Maresuke
# 0.457354248289
# 6455/6619
# Franklin Gardner
# -0.435102821826
# 6456/6619
# Joaquín Rea
# -0.508790584206
# 6457/6619
# Thomas Childs
# 0.505043131031
# 6458/6619
# Calixto García
# 0.483309118329
# 6459/6619
# José Toral y Velázquez
# -0.487053996575
# 6460/6619
# Alija Izetbegović
# -0.0726145323017
# 6461/6619
# Sefer Halilović
# -0.0726145323017
# 6462/6619
# Rasim Delić
# -0.0726145323017
# 6463/6619
# Jovan Divjak
# -0.0726145323017
# 6464/6619
# Enver Hadžihasanović
# -0.0726145323017
# 6465/6619
# Mustafa Hajrulahović Talijan
# -0.0726145323017
# 6466/6619
# Mušan Topalović
# -0.0726145323017
# 6467/6619
# Leighton W. Smith Jr.
# -0.0726145323017
# 6468/6619
# Milutin Kukanjac
# 0.0689414690771
# 6469/6619
# Radovan Karadžić
# 0.0689414690771
# 6470/6619
# Stanislav Galić
# 0.0689414690771
# 6471/6619
# Dragomir Milošević
# 0.0689414690771
# 6472/6619
# Curt von Stedingk
# -0.620279829897
# 6473/6619
# Maurice, Count de Benyovszky
# -0.620279829897
# 6474/6619
# Augustine Prévost
# 0.616742232396
# 6475/6619
# John Maitland (British Army officer)
# 0.616742232396
# 6476/6619
# Aimable Pélissier
# 0.462280457139
# 6477/6619
# Edmund Lyons, 1st Baron Lyons
# 0.462280457139
# 6478/6619
# James Simpson (British Army officer)
# 0.462280457139
# 6479/6619
# William John Codrington
# 0.462280457139
# 6480/6619
# Vladimir Kornilov
# -0.46600935294
# 6481/6619
# Pavel Nakhimov
# -0.46600935294
# 6482/6619
# Anthonie II Schetz
# -0.4451940227
# 6483/6619
# Sigismund III Vasa
# 0.433196750293
# 6484/6619
# Mikhail Shein
# -0.436881652199
# 6485/6619
# Jean-Jacques Uhrich — Wikipédia
# -0.473898857967
# 6486/6619
# Jean François Leval
# -0.559018782617
# 6487/6619
# Francisco Copons
# 0.555319613658
# 6488/6619
# John Byrne Skerrett
# 0.555319613658
# 6489/6619
# Gastone Gambara
# -0.515257863809
# 6490/6619
# Leslie Morshead
# 0.511512379479
# 6491/6619
# Ronald Scobie
# 0.511512379479
# 6492/6619
# Jean François Carteaux
# 0.478923413806
# 6493/6619
# Jean François Cornu de La Poype
# 0.478923413806
# 6494/6619
# Marquess of Normanby
# -0.482666054273
# 6495/6619
# Jan Piotr Sapieha
# -0.576408071656
# 6496/6619
# Aleksander Józef Lisowski
# -0.576408071656
# 6497/6619
# Grigory Dolgorukov
# 0.572743284599
# 6498/6619
# Aleksey Golokhvastov
# 0.572743284599
# 6499/6619
# Tang Ching-sung
# -0.594146665032
# 6500/6619
# Marc-Edmond Dominé
# 0.590526324317
# 6501/6619
# William Oliphant (died after 1313)
# -0.5
# 6502/6619
# Sanada Yukitaka
# 0.409839949166
# 6503/6619
# Yokota Takatoshi
# 0.409839949166
# 6504/6619
# John Ancrum Winslow
# 0.49812591476
# 6505/6619
# Raphael Semmes
# -0.50187408524
# 6506/6619
# Tom Phillips (Royal Navy officer)
# -0.50187408524
# 6507/6619
# William Tennant (Royal Navy officer)
# -0.50187408524
# 6508/6619
# Niichi Nakanishi
# 0.49812591476
# 6509/6619
# Shichizo Miyauchi
# 0.49812591476
# 6510/6619
# Hachiro Shoji
# 0.49812591476
# 6511/6619
# Luo Ruiqing
# 0.420139711612
# 6512/6619
# Zhou Enlai
# 0.420139711612
# 6513/6619
# Brij Mohan Kaul
# -0.423796590858
# 6514/6619
# Jawaharlal Nehru
# -0.423796590858
# 6515/6619
# V. K. Krishna Menon
# -0.423796590858
# 6516/6619
# Pran Nath Thapar
# -0.423796590858
# 6517/6619
# Gamal Abdel Nasser
# -1.07682935666
# 6518/6619
# Abdel Hakim Amer
# -1.07682935666
# 6519/6619
# Abdul Munim Riad
# -0.566341271895
# 6520/6619
# Asad Ghanma
# -0.566341271895
# 6521/6619
# Salah Jadid
# -0.566341271895
# 6522/6619
# Nureddin al-Atassi
# -0.566341271895
# 6523/6619
# Abdul Rahman Arif
# -0.566341271895
# 6524/6619
# Mubarak Abdullah Al-Jaber Al-Sabah
# -0.566341271895
# 6525/6619
# Saleh Mohammed Al-Sabah
# -0.566341271895
# 6526/6619
# Fahad Al-Ahmed Al-Jaber Al-Sabah
# -0.566341271895
# 6527/6619
# Levi Eshkol
# 0.562655472434
# 6528/6619
# Israel Tal
# 1.62215199331
# 6529/6619
# Mordechai Hod
# 0.562655472434
# 6530/6619
# Yeshayahu Gavish
# 0.562655472434
# 6531/6619
# Ezer Weizman
# 0.562655472434
# 6532/6619
# Shlomo Erell
# 0.562655472434
# 6533/6619
# Otozō Yamada
# -0.454077960831
# 6534/6619
# Zhang Jinghui
# -0.454077960831
# 6535/6619
# Francis Drake
# 0.499800356663
# 6536/6619
# John Hawkins (naval commander)
# 0.499800356663
# 6537/6619
# Juan Martínez de Recalde
# -0.503548485107
# 6538/6619
# Richard Butler (general)
# -0.496933135282
# 6539/6619
# William Darke
# -0.496933135282
# 6540/6619
# Asaf Simhoni
# 0.506741026917
# 6541/6619
# Haim Bar-Lev
# 1.05949652088
# 6542/6619
# Avraham Yoffe
# 0.506741026917
# 6543/6619
# Anthony Eden
# 0.506741026917
# 6544/6619
# Gerald Templer
# 0.506741026917
# 6545/6619
# Charles Keightley
# 0.506741026917
# 6546/6619
# Hugh Stockwell
# 0.506741026917
# 6547/6619
# Manley Laurence Power
# 0.506741026917
# 6548/6619
# René Coty
# 0.506741026917
# 6549/6619
# Guy Mollet
# 0.506741026917
# 6550/6619
# Pierre Barjot
# 0.506741026917
# 6551/6619
# André Beaufre
# 0.506741026917
# 6552/6619
# Jacques Massu
# 0.506741026917
# 6553/6619
# Martti Miettinen
# 0.5
# 6554/6619
# Leopold I of Belgium
# 0.46647156492
# 6555/6619
# Amédée de Failly
# 0.46647156492
# 6556/6619
# Charles Niellon
# 0.46647156492
# 6557/6619
# Tito Speri
# -0.5
# 6558/6619
# Julius Jacob von Haynau
# 0.5
# 6559/6619
# Khalifa Haftar
# -0.5
# 6560/6619
# Filipp Golikov
# -0.570247729144
# 6561/6619
# Paul Hausser
# 0.566569721691
# 6562/6619
# Eberhard von Mackensen
# 0.566569721691
# 6563/6619
# Theodor Eicke
# 0.566569721691
# 6564/6619
# Haim Nadel
# 0.453789183559
# 6565/6619
# Timur Shah Durrani
# 0.464563704679
# 6566/6619
# Najib ad-Dawlah
# 0.464563704679
# 6567/6619
# Sadashivrao Bhau
# -0.468294978333
# 6568/6619
# Vishwasrao
# -0.468294978333
# 6569/6619
# Malhar Rao Holkar
# -0.468294978333
# 6570/6619
# Mahadaji Shinde
# -0.468294978333
# 6571/6619
# Ibrahim Khan Gardi
# -0.468294978333
# 6572/6619
# Jankoji Rao Scindia
# -0.468294978333
# 6573/6619
# Bhoite
# -0.468294978333
# 6574/6619
# Fahri Korutürk
# 0.479826109692
# 6575/6619
# Bülent Ecevit
# 0.479826109692
# 6576/6619
# Necmettin Erbakan
# 0.479826109692
# 6577/6619
# Rauf Denktaş
# 0.479826109692
# 6578/6619
# Nikos Sampson
# -0.483569257931
# 6579/6619
# Glafcos Clerides
# -0.483569257931
# 6580/6619
# Dimitrios Ioannidis
# -0.483569257931
# 6581/6619
# Stephen Decatur
# 0.49812591476
# 6582/6619
# John Surman Carden
# -0.50187408524
# 6583/6619
# Ludwig von Falkenhausen
# -0.435970599508
# 6584/6619
# Karl von Fasbender
# -0.435970599508
# 6585/6619
# Georg Karl Wichura
# -0.435970599508
# 6586/6619
# Ferdinand von Sammern-Frankenegg
# 0.461599916337
# 6587/6619
# Jürgen Stroop
# 0.461599916337
# 6588/6619
# Arpad Wigand
# 0.461599916337
# 6589/6619
# Ludwig Hahn
# 0.461599916337
# 6590/6619
# Mordechai Anielewicz
# -0.46532807311
# 6591/6619
# Paweł Frenkiel
# -0.46532807311
# 6592/6619
# Tadeusz Bór-Komorowski
# -0.531892318115
# 6593/6619
# Tadeusz Pełczyński
# -0.531892318115
# 6594/6619
# Antoni Chruściel
# -0.531892318115
# 6595/6619
# Karol Ziemski
# -0.531892318115
# 6596/6619
# Edward Pfeiffer
# -0.531892318115
# 6597/6619
# Leopold Okulicki
# -0.531892318115
# 6598/6619
# Jan Mazurkiewicz
# -0.531892318115
# 6599/6619
# Zygmunt Berling
# -0.531892318115
# 6600/6619
# Nikolaus von Vormann
# 0.528157663729
# 6601/6619
# Reiner Stahel
# 0.528157663729
# 6602/6619
# Erich von dem Bach-Zelewski
# 0.528157663729
# 6603/6619
# Heinz Reinefarth
# 0.528157663729
# 6604/6619
# Bronislav Kaminski
# 0.528157663729
# 6605/6619
# Oskar Dirlewanger
# 0.528157663729
# 6606/6619
# Petro Dyachenko
# 0.528157663729
# 6607/6619
# Iosif Igelström
# -0.51862540605
# 6608/6619
# Stanisław Mokronowski
# 0.514881443734
# 6609/6619
# Jan Kiliński
# 0.514881443734
# 6610/6619
# James W. Forsyth
# 0.439294275316
# 6611/6619
# Spotted Elk
# -0.442990507155
# 6612/6619
# Anwar Sadat
# -0.556458956405
# 6613/6619
# Yusuf Shakkour
# -0.556458956405
# 6614/6619
# Mohamed Abdel Ghani el-Gamasy
# -0.556458956405
# 6615/6619
# Ali Aslan
# -0.556458956405
# 6616/6619
# Golda Meir
# 0.552755493959
# 6617/6619
# Yitzhak Hofi
# 0.552755493959
# 6618/6619
# Harold Franklyn
# -0.429705079575

# %%
mka = df_run.loc[8965, 'belligerent']

# %%
mka

# %%
df_battles

# %%
battle_list = []
bokeh(u'Ariel Sharon')

# %%
df_warchart = pd.DataFrame({'Labels': ['Win = 1', 'Replacement-Level Performance = .51', 'WAR From Battle = .49'],
              'Values': [1, .51, .49]})

# %%
df_warchart = df_warchart.sort_values('Values', ascending = True)

# %%
df_warchart

# %%
df_warchart = df_warchart.iloc[::-1]

# %%
fig = plt.figure(figsize = (12,9))
plt.style.use('fivethirtyeight')
plt.bar(df_warchart.index, df_warchart.Values, width = 1, color = ['red', 'blue', 'yellow'])
plt.xticks(df_warchart.index + .5, df_warchart.Labels, rotation = 45)
plt.xticks()
plt.title("Bonaparte's WAR in Battle of Borodino")
plt.tight_layout()
plt.savefig('napoleon_war_sample')

# ax.set_axis_bgcolor('gray')

# %%
df_warchart_two = pd.DataFrame({'Labels': ['Win = -1', 'Replacement-Level Performance = .49', 'WAR From Battle = -.51'],
              'Values': [-1, -.49, -.51]})

# %%
fig = plt.figure(figsize = (12,9))
plt.style.use('fivethirtyeight')
plt.bar(df_warchart_two.index, df_warchart_two.Values, width = 1, color = ['red', 'blue', 'white'])
plt.xticks(df_warchart_two.index, df_warchart_two.Labels, rotation = 45)
plt.title("Kutuzov's WAR in Battle of Borodino")
plt.tight_layout()
plt.savefig('/home/ethanarsht/Downloads/kutuzov_war_sample')

# ax.set_axis_bgcolor('gray')
